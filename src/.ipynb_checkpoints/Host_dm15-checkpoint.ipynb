# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db
import composite
import matplotlib.gridspec as gridspec

# %%
def make_colorbar(composites):
    params = []
    # for comp in composites:
    # 	params.append(np.average(comp.dm15_array[comp.x1:comp.x2]))
    # norm = matplotlib.colors.Normalize(vmin=np.min(params),vmax=np.max(params))
    norm = matplotlib.colors.Normalize(vmin=1.,vmax=len(composites) + 1.)
    c_m = matplotlib.cm.plasma
    # c_m = matplotlib.cm.winter_r
    s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
    s_m.set_array([])

    return s_m

# %%
def comparison_plot(composites):

#     plt.style.use('ggplot')
    colors = [color['color'] for color in list(plt.rcParams['axes.prop_cycle'])]
    h = [3,1,1,1,1,1,1]
    font = {'family' : 'serif',
        'color'  : 'black',
        'size'   : 25,
        }

#     gs = gridspec.GridSpec(7, 1, height_ratios=h, hspace = .001)
#     fig = plt.figure(num = 1, dpi = 100, figsize = [10,10])
    fig = plt.figure(num = 1, dpi = 100, figsize = [10,8])
    s_m = make_colorbar(composites)
    lw = 3

    composites, scales = composite.optimize_scales(composites, composites[0], True)
    
    plt.rc('font', family='serif')
    plt.gca().set_yticklabels([])
    plt.minorticks_on()
    plt.xticks(fontsize = 20)
    plt.yticks(fontsize = 20)
    plt.tick_params(
        which='major', 
        bottom='on', 
        top='on',
        left='on',
        right='on',
        length=10)
    plt.tick_params(
        which='minor', 
        bottom='on', 
        top='on',
        left='on',
        right='on',
        length=5)
    
    i = 0
    k = 1
    for comp in composites:
        # param = np.average(comp.dm15_array[comp.x1:comp.x2])
        param = k

#         rel_flux = plt.subplot(gs[0])
        rel_flux = plt.subplot(111)
#         plt.setp(rel_flux.get_xticklabels(), visible=False)
        plt.ylabel('Relative Flux', fontdict = font)
#         rel_flux.axes.get_yaxis().set_ticks([])
        # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], color = s_m.to_rgba(param))
        plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))
        if len(comp.low_conf) > 0 and len(comp.up_conf) > 0:
            plt.fill_between(comp.wavelength[comp.x1:comp.x2], comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], color = s_m.to_rgba(param), alpha = 0.5)
            # plt.fill_between(comp.wavelength[comp.x1:comp.x2], comp.low_conf[comp.x1:comp.x2], 
            # 	             comp.up_conf[comp.x1:comp.x2], color = colors[i%len(colors)], alpha = 0.5)

#         var = plt.subplot(gs[1], sharex = rel_flux)
#         plt.setp(var.get_xticklabels(), visible=False)
#         plt.ylabel('Variance', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.ivar[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.ivar[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         res = plt.subplot(gs[2], sharex = rel_flux)
#         plt.setp(res.get_xticklabels(), visible=False)
#         plt.ylabel('Residuals', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))
#         if len(comp.low_conf) > 0 and len(comp.up_conf) > 0:
#             low_resid = comp.low_conf[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2]
#             up_resid = comp.up_conf[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2]
#             plt.fill_between(comp.wavelength[comp.x1:comp.x2], low_resid, up_resid, color = s_m.to_rgba(param), alpha = 0.5)
#             # plt.fill_between(comp.wavelength[comp.x1:comp.x2], low_resid, up_resid, color = colors[i%len(colors)], alpha = 0.5)

#         spec = plt.subplot(gs[3], sharex = rel_flux)
#         plt.setp(spec.get_xticklabels(), visible=False)
#         plt.ylabel('Spectra/Bin', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.spec_bin[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.spec_bin[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         phase = plt.subplot(gs[4], sharex = rel_flux)
#         plt.setp(phase.get_xticklabels(), visible=False)
#         plt.ylabel('Phase [d]', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.phase_array[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.phase_array[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         delt = plt.subplot(gs[5], sharex = rel_flux)
#         plt.setp(delt.get_xticklabels(), visible=False)
#         plt.ylabel('$\Delta$m$_{15}$', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.dm15[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.dm15[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         plt.subplot(gs[6], sharex = rel_flux)
#         plt.ylabel('Redshift', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.red_array[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.red_array[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

        i+=1
        k+=1

    plt.xlabel('Wavelength ' + "($\mathrm{\AA}$)", fontdict = font)
    # cb = plt.colorbar(s_m, ax = fig.axes)
    # cb.set_label('Phase', fontdict = font)
    # for ax in fig.axes:
    # 	ax.set_axis_bgcolor('white')

    plt.show()

# %%
def stacked_plot_max(composites,buff,label_buff):
    font1 = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 20,
        }
    
    font2 = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 10,
        }
    
    fig, ax = plt.subplots(1,1)
    fig.set_size_inches(15, 30, forward = True)
#     ax.get_yaxis().set_ticks([])
    ax.xaxis.set_tick_params(length=10, width = 2)
    plt.ylabel('Relative Flux + const.', fontdict = font1, fontsize = 40)
    plt.xlabel( 'Wavelength ' + "($\mathrm{\AA}$)", fontdict = font1, fontsize = 40)
    
    plt.rc('font', family='serif')
    plt.gca().set_yticklabels([])
    plt.minorticks_on()
    plt.xticks(fontsize = 20)
    plt.yticks(fontsize = 20)
    plt.tick_params(
        which='major', 
        bottom='on', 
        top='on',
        left='on',
        right='on',
        length=10)
    plt.tick_params(
        which='minor', 
        bottom='on', 
        top='on',
        left='on',
        right='on',
        length=5)
    
    composites, scales = composite.optimize_scales(composites, composites[0], True)

    i = 0
    for comp in composites:
        dm15 = np.average(comp.dm15_array[comp.x1:comp.x2])
#         ax.plot(comp.wavelength[comp.x1:comp.x2], 2.e15*comp.flux[comp.x1:comp.x2] - 1200*dm15, color = '#3F5D7D', linewidth = 4)
        ax.plot(comp.wavelength[comp.x1:comp.x2], 2.e15*comp.flux[comp.x1:comp.x2] - buff*i, color = '#3F5D7D', linewidth = 4)
        plt.fill_between(comp.wavelength[comp.x1:comp.x2], 2.e15*comp.low_conf[comp.x1:comp.x2]- buff*i, 2.e15*comp.up_conf[comp.x1:comp.x2] - buff*i, alpha = 0.5)
#         plt.text(9700, comp.flux[comp.x2] - 1200*dm15 + 30, '$\mathbf{\Delta m_{15}}$ = ' + str(round(dm15, 2)), fontdict = font1)
        plt.text(8000, comp.flux[comp.x2] - buff*i +label_buff, '$\mathbf{\Delta m_{15}}$ = ' + str(round(dm15, 2)), fontdict = font2, fontsize = 30)
        i += 1
#     plt.title('Maximum Light Composite Spectra \n for Different Light Curve Shapes', fontdict = font1, fontsize = 40)
    plt.xlim([3000,10500])
#     plt.savefig('../../FOE_figures/dm15_split_max.png', dpi = 300, bbox_inches = 'tight')
#     plt.savefig('host_lowdm15_p1week.pdf', dpi = 300, bbox_inches = 'tight')
    plt.show()

# %% [markdown]
# # Max-No dm15 Match

# %%
query_host_max = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 14 and 19",
                  "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 10 and 13",
                  "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 1 and 9"]

# %%
comps_host_max, sn_arrays_host_max, boot_sn_arrays_host_max = query_db.main(len(query_host_max), query_host_max, boot='b', medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 14 and 19
# Collecting data...
# 47 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 46 spectra left
# 2 Peculiar Ias removed 44 spectra left
# 33 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed
# Host correction...
# 2006cf sn2006cf-20060519.25-fast.flm 25.8546360074 None 1.04621465431 1.85 cfa 3396.0 7062.0 10 15.0
# Host correction...
# 2007ae sn2007ae-20070225.54-fast.flm 9.77849625348 0.98 None 2.54 cfa 3314.0 6914.0 None 19.0
# Host correction...
# 2004ey SN04ey_041025_b01_CLA_LD.dat 23.7352288876 None 0.969286867038 -0.350000000093 csp 3596.0 8812.0 None 14.0
# Host correction...
# 2006os SN06os_061122_b01_DUP_WF.dat 13.9284910072 None 1.06693926911 -1.06999999983 csp 3730.0 8892.0 7 19.0
# Host correction...
# 2007ai SN07ai_070314_b01_DUP_BC.dat 19.4959683076 None 0.909922433992 2.04000000004 csp 3376.0 9300.0 9 14.0
# Host correction...
# 2007ca SN07ca_070508_b01_BAA_IM.dat 31.5813058497 0.89 None 1.41999999993 csp 3506.0 9446.0 9 14.0
# Host correction...
# 2007le SN07le_071028_g01_CLA_LD.dat 78.7656416336 1.01 None 2.84999999963 csp 4100.0 9192.0 8 14.0
# Host correction...
# 32 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 10 and 13
# Collecting data...
# 71 spectra found
# 152 questionable files currently ignored
# 8 questionable spectra removed 63 spectra left
# 2 Peculiar Ias removed 61 spectra left
# 42 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 42 spectra left
# 1994s sn1994s-19940616-uoi.flm 34.8971198257 0.94 None 1.11 bsnip 3124.0 11082.0 6 11.0
# Host correction...
# 1995e sn1995e-19950224-uoi2.flm 44.325356664 1.16 None -2.46 bsnip 3136.0 11162.0 7 12.0
# Host correction...
# 1996ai sn1996ai-19960622-uoi.flm 46.9712987061 0.88 None 1.231 bsnip 3202.0 10368.0 8 13.0
# Host correction...
# 1997y sn1997y-19970209-uohp.flm 44.230493937 1.15 None 1.27 bsnip 3202.0 9716.0 7 12.0
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 24.0178237234 0.88 None 1.39 bsnip 3278.0 10124.0 8 13.0
# Host correction...
# 2001da sn2001da-20010716-ui-corrected.flm 30.0099081637 1.12 None -1.12 bsnip 3296.0 10176.0 6 11.0
# Host correction...
# 2001ep sn2001ep-20011020-ui-corrected.flm 50.8449098727 1.3 None 2.83 bsnip 3308.0 10218.0 7 12.0
# Host correction...
# 2001fe sn2001fe-20011115-ui.flm 63.0968901259 1.0 None -0.99 bsnip 3288.0 10212.0 5 10.0
# Host correction...
# 2002bf sn2002bf-20020307-os.flm 143.279946281 1.12 None 2.97 bsnip 3858.0 8544.0 7 12.0
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 23.7964870723 0.84 None 1.1 bsnip 3318.0 10244.0 8 13.0
# Host correction...
# 2003cq sn2003cq-20030408-ui.flm 15.7476139398 1.2 None -0.15 bsnip 3084.0 10016.0 8 13.0
# Host correction...
# 2004dt sn2004dt-20040824-vis2-corrected.flm 63.786388267 1.14 None 1.38 bsnip 4464.0 9562.0 7 10.0
# Host correction...
# 2005na sn2005na-20060105.335-ui.flm 23.8296042949 1.09 None 0.03 bsnip 3276.0 10182.0 7 10.0
# Host correction...
# 2006or sn2006or-20061123.654-br.flm 44.3136157707 None 1.0351558298 -2.79 bsnip 3036.0 9014.0 8 13.0
# Host correction...
# 2006ot sn2006ot-20061123.362-br.flm 35.3768439715 0.84 None -1.338 bsnip 3008.0 8736.0 5 10.0
SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 32 spectra left
# 1991bg sn1991bg-19911214-noz.flm 55.4333249814 None 1.88326464208 1.14 bsnip 3942.0 9816.0 1 3.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0 3 8.0
# Host correction...
# 1999da sn1999da-19990709-ui.flm 35.441805608 1.9 None -2.12 bsnip 3300.0 10368.0 1 1.0
# Host correction...
# 2000dk sn2000dk-20000926-ui-corrected.flm 46.5582359543 1.62 None 1.0 bsnip 3294.0 10172.0 1 1.0
# Host correction...
# 2002fb sn2002fb-20020913-ui-corrected.flm 27.2042647112 1.77 None 0.98 bsnip 3198.0 10192.0 1 1.0
# Host correction...
# 2002he sn2002he-20021108-br.flm 70.9263350618 1.44 None 0.29 bsnip 3048.0 9150.0 1 1.0
# Host correction...
# 2004gs sn2004gs-20041217.447-ui-corrected.flm 28.3734591732 1.41 None 0.44 bsnip 3318.0 10008.0 1 8.0
# Host correction...
# 2005cf sn2005cf-20050610.7-uvot.flm 25.8392814942 1.1 None -2.7 uv 2038.0 9886.0 3 8.0
# Host correction...
# 2005dv sn2005dv-20050911.170-ui.flm 13.1133435614 None 0.78046044795 -0.57 bsnip 3366.0 10244.0 3 8.0
# Host correction...
# 2005el sn2005el-20051004.534-ui-corrected.flm 40.230445764 1.27 None 1.22 bsnip 3320.0 10296.0 3 8.0
# Host correction...
# 2005ki sn2005ki-20051202.649-deimos.flm 69.6995974072 1.41 None 1.62 bsnip 3826.0 8844.0 3 8.0
# Host correction...
# 2006bt sn2006bt-20060505.444-ui.flm 31.8522994411 1.0 None 2.27 bsnip 3296.0 10028.0 4 9.0
# Host correction...
# 2006cs sn2006cs-20060605.335-ui.flm 11.9352989284 None 2.00347119949 2.28 bsnip 3284.0 10306.0 3 8.0
# Host correction...
# 2007ba sn2007ba-20070410.475-ui.flm 11.9667177729 1.89 None 2.14 bsnip 3242.0 10158.0 4 9.0
# Host correction...
# 2007ci sn2007ci-20070524.264-ui-corrected.flm 36.9959617847 1.6 None -1.71 bsnip 3312.0 10264.0 1 1.0
# Host correction...
# 1994t sn1994T-19940612.19-fast.flm 3.62813221224 1.51 None 0.790000000001 cfa 3726.0 7420.0 5 9.0
# Host correction...
# 1996x 1996X_19960419_3077_10669_00.dat 72.6747082167 1.26 None 0.900000000001 other 3108.0 10548.0 1 2.0
# Host correction...
# 1998bp sn1998bp-19980430.47-fast.flm 28.7557905032 1.79 None -2.93 cfa 3732.0 7394.0 1 1.0
# Host correction...
# 1998co sn1998co-19980623.45-fast.flm 41.8372717871 None 0.959027462694 -0.0500000000029 cfa 3704.0 7356.0 3 8.0
# Host correction...
# 1998de sn1998de-19980730.46-fast.flm 13.7634061513 1.88 None -2.24 cfa 3710.0 7368.0 3 8.0
# Host correction...
# 1999ej sn1999ej-19991030.28-fast.flm 41.0343492423 1.48 None -1.82 cfa 3720.0 7390.0 4 9.0
# Host correction...
# 2002do sn2002do-20020619.43-fast.flm 30.1719891566 1.56 None 2.03 cfa 3712.0 7374.0 1 3.0
# Host correction...
# 2002es sn2002es-20020903.45-fast.flm 18.2117848296 None 1.44350951456 2.14999999999 cfa 3706.0 7358.0 3 8.0
# Host correction...
# 2002hd sn2002hd-20021029.52-fast.flm 14.2622103278 1.16 None 1.42 cfa 3646.0 7236.0 1 8.0
# Host correction...
# 2003ch sn2003ch-20030329.11-mmt.flm 28.8381350326 1.22 None 1.81 cfa 3172.0 9024.0 3 8.0
# Host correction...
# 2003ic sn2003ic-20030921.36-fast.flm 11.8373131267 None 1.20279024729 -2.44 cfa 3576.0 7096.0 3 8.0
# Host correction...
# 2007au sn2007au-20070326.15-fast.flm 14.5404931844 1.69 None 1.15 cfa 3456.0 7222.0 3 8.0
# Host correction...
# 2007ax SN07ax_070326_b01_DUP_BC.dat 19.8323399731 1.87 None -2.04000000004 csp 3428.0 9494.0 2 8.0
# Host correction...
# 2006kf SN06kf_061103_g01_NTT_EM.dat 19.4132855756 1.55 None 1.45000000019 csp 3978.0 9938.0 3 8.0
# Host correction...
# 2008fp SN08fp_080917_b01_CLA_LD.dat 56.6444579431 None 0.933670014532 -2.85000000009 csp 3676.0 9358.0 None 8.0
# Host correction...
# 2008hv SN08hv_081218_b02_CLA_LD.dat 54.0657963049 None 1.11901047681 2.00999999978 csp 3636.0 9276.0 None 8.0
# Host correction...
# 2008ia SN08ia_081215_b01_CLA_LD.dat 42.770341803 None 1.21109716364 2.97999999998 csp 3670.0 9380.0 None 8.0
# Host correction...
# 32 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(comps_host_max, 1)
# comparison_plot(comps_host_max)
query_db.comparison_plot(comps_host_max)
# stacked_plot_max(comps_host_max,5,1)

# %% [markdown]
# # Max-Low dm15 Matched

# %%
query_host_low_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 12 and 18 and ((dm15_source < 1.1 or dm15_from_fits < 1.1))",
                       "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 1 and 12 and ((dm15_source < 1.15 or dm15_from_fits < 1.15)) and filename != 'sn2002bf-20020307-os.flm'"]
# query_host_low_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and morphology >= 7 and ((dm15_cfa < 1.1 or dm15_from_fits < 1.1))",
#                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and morphology between 1 and 7 and ((dm15_cfa < 1.15 or dm15_from_fits < 1.15))"]

# %%
comps_host_low_dm15, sn_arrays_low_dm15, boot_sn_arrays_low_dm15 = query_db.main(len(query_host_low_dm15), query_host_low_dm15, boot='b', medmean=1, selection='max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 12 and 18 and ((dm15_source < 1.1 or dm15_from_fits < 1.1))
# Collecting data...
# 40 spectra found
# 152 questionable files currently ignored
# 3 questionable spectra removed 37 spectra left
# 0 Peculiar Ias removed 37 spectra left
# 31 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 30 spectra left
# 1996ai sn1996ai-19960622-uoi.flm 46.9712987061 0.88 None 1.231 bsnip 3202.0 10368.0 8 13.0
# Host correction...
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0 6 14.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 44.0459361476 0.78 None 0.24 bsnip 3344.0 10350.0 9 14.0
# Host correction...
# 1999dq sn1999dq-near-19990917-clear-ui-corrected.flm 49.3372100352 0.86 None 2.97 bsnip 3304.0 10352.0 9 14.0
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 24.0178237234 0.88 None 1.39 bsnip 3278.0 10124.0 8 13.0
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 23.7964870723 0.84 None 1.1 bsnip 3318.0 10244.0 8 13.0
# Host correction...
# 2005eq sn2005eq-20051011.376-ui-corrected.flm 37.8569772533 0.88 None 0.66 bsnip 3278.0 10156.0 10 15.0
# Host correction...
# 2006cz sn2006cz-20060620.266-ui.flm 19.4230633279 None 1.00098460136 1.12 bsnip 3264.0 10126.0 9 15.0
# Host correction...
# 2006or sn2006or-20061123.654-br.flm 44.3136157707 None 1.0351558298 -2.79 bsnip 3036.0 9014.0 8 13.0
# Host correction...
# 2007af sn2007af-20070313.545-ui-corrected.flm 62.682927791 1.04 None -1.25 bsnip 3382.0 10394.0 10 15.0
# Host correction...
# 2007o sn2007o-20070122.663-deimos.flm 42.7383273579 None 1.08812276376 -0.33 bsnip 4328.0 9186.0 None 14.0
# Host correction...
# 1994ae sn1994ae-19941201.50-fast.flm 150.102991241 0.96 None 2.0 cfa 3486.0 6936.0 9 14.0
# Host correction...
# 1997dt sn1997dt-19971204.11-fast.flm 56.9668367955 1.04 None 0.209999999999 cfa 3744.0 7436.0 8 13.0
# Host correction...
# 1998ec sn1998ec-19980930.50-fast.flm 25.4049698217 1.08 None -3.0 cfa 3698.0 7326.0 7 12.0
# Host correction...
# 1998v sn1998V-19980319.51-fast.flm 30.4713646656 0.99 None 0.310000000005 cfa 3708.0 7362.0 7 12.0
# Host correction...
# 1999gp sn1999gp-20000105.10-fast.flm 33.6958139173 0.87 None -2.0 cfa 3674.0 7296.0 7 12.0
# Host correction...
# 2001eh sn2001eh-20010915.42-fast.flm 15.1100402768 0.92 None -2.08 cfa 3638.0 7222.0 7 12.0
# Host correction...
# 2001n sn2001N-20010122.46-fast.flm 20.2770059103 None 1.05844576181 0.659999999996 cfa 3694.0 7336.0 7 12.0
# Host correction...
# 2002ck sn2002ck-20020502.46-fast.flm 14.1023856776 1.08 None -0.540000000001 cfa 3664.0 7274.0 6 12.0
# Host correction...
# 2002jy sn2002jy-20021226.12-fast.flm 31.1301164169 0.88 None 0.120000000003 cfa 3700.0 7346.0 9 14.0
# Host correction...
# 2004bg sn2004bg-20040417.19-fast.flm 57.2971141657 1.05 None 2.69 cfa 3696.0 7338.0 7 15.0
# Host correction...
# 2006ax SN06ax_060330_b01_DUP_WF.dat 58.502090858 1.06 None -2.36000000034 csp 3788.0 9034.0 8 13.0
# Host correction...
# 2006cf sn2006cf-20060519.25-fast.flm 25.8546360074 None 1.04621465431 1.85 cfa 3396.0 7062.0 10 15.0
# Host correction...
# 2006gr sn2006gr-20061002.26-fast.flm 13.8261860644 0.81 None -2.14 cfa 3414.0 7120.0 7 12.0
# Host correction...
# 2004ey SN04ey_041025_b01_CLA_LD.dat 23.7352288876 None 0.969286867038 -0.350000000093 csp 3596.0 8812.0 None 14.0
# Host correction...
# 2007ai SN07ai_070314_b01_DUP_BC.dat 19.4959683076 None 0.909922433992 2.04000000004 csp 3376.0 9300.0 9 14.0
# Host correction...
# 2007as SN07as_070319_b01_DUP_BC.dat 39.7347234703 None 1.09592874297 -2.70999999996 csp 3410.0 9410.0 None 12.0
# Host correction...
# 2007ca SN07ca_070508_b01_BAA_IM.dat 31.5813058497 0.89 None 1.41999999993 csp 3506.0 9446.0 9 14.0
# Host correction...
# 2007le SN07le_071028_g01_CLA_LD.dat 78.7656416336 1.01 None 2.84999999963 csp 4100.0 9192.0 8 14.0
# Host correction...
# 2012fr sn2012fr-20121111.62-fixedbg-swift.flm 6.46181942199 0.85 None -0.9 swift_uv 1942.0 6710.0 None 12.0
# Host correction...
# 30 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 1 and 12 and ((dm15_source < 1.15 or dm15_from_fits < 1.15)) and filename != 'sn2002bf-20020307-os.flm'
# Collecting data...
# 35 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 33 spectra left
# 0 Peculiar Ias removed 33 spectra left
# 29 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed
SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
# composite.optimize_scales(comps_host_low_dm15, comps_host_low_dm15[0], True)
query_db.set_min_num_spec(comps_host_low_dm15, 1)
query_db.comparison_plot(comps_host_low_dm15)

# %% [markdown]
# # Max-High dm15 Matched

# %%
query_host_high_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 12 and 18 and ((dm15_source > 1.2 and dm15_source < 1.9) or (dm15_from_fits > 1.2 and dm15_from_fits < 1.9))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 1 and 12 and ((dm15_source > 1.2 and dm15_source < 1.5) or (dm15_from_fits > 1.2 and dm15_from_fits < 1.5))"]
# query_host_high_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and morphology >= 7 and ((dm15_cfa > 1.2 or dm15_from_fits > 1.2)) and ((dm15_cfa < 1.9 or dm15_from_fits < 1.9))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and morphology between 0 and 5 and ((dm15_cfa > 1.2 or dm15_from_fits > 1.2)) and ((dm15_cfa < 1.5 or dm15_from_fits < 1.5))"]

# %%
comps_host_high_dm15, sn_arrays_high_dm15, boot_sn_arrays_high_dm15 = query_db.main(len(query_host_high_dm15), query_host_high_dm15, boot='nb', medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 12 and 18 and ((dm15_source > 1.2 and dm15_source < 1.9) or (dm15_from_fits > 1.2 and dm15_from_fits < 1.9))
# Collecting data...
# 9 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 9 spectra left
# 2 Peculiar Ias removed 7 spectra left
# 5 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 5 spectra left
# 1999ac sn1999ac-19990312-ui-corrected.flm 66.9161014359 1.23 None -0.89 bsnip 3296.0 10352.0 10 15.0
# Host correction...
# 2001ep sn2001ep-20011020-ui-corrected.flm 50.8449098727 1.3 None 2.83 bsnip 3308.0 10218.0 7 12.0
# Host correction...
# 2003u sn2003U-20030204-ui.flm 29.2694201484 1.46 None -2.55 bsnip 3074.0 10084.0 9 15.0
# Host correction...
# 1999cc sn1999cc-19990516.34-fast.flm 23.2075050712 1.35 None -1.26 cfa 3658.0 7262.0 9 14.0
# Host correction...
# 2004ef SN04ef_040914_b01_DUP_WF.dat 16.9958777651 1.39 None -1.35000000009 csp 3736.0 8908.0 7 12.0
# Host correction...
# 5 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and NED_host between 1 and 12 and ((dm15_source > 1.2 and dm15_source < 1.5) or (dm15_from_fits > 1.2 and dm15_from_fits < 1.5))
# Collecting data...
# 26 spectra found
# 152 questionable files currently ignored
# 3 questionable spectra removed 23 spectra left
# 0 Peculiar Ias removed 23 spectra left
# 18 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 18 spectra left
# 2001ep sn2001ep-20011020-ui-corrected.flm 50.8449098727 1.3 None 2.83 bsnip 3308.0 10218.0 7 12.0
# Host correction...
# 2002he sn2002he-20021108-br.flm 70.9263350618 1.44 None 0.29 bsnip 3048.0 9150.0 1 1.0
# Host correction...
# 2004gs sn2004gs-20041217.447-ui-corrected.flm 28.3734591732 1.41 None 0.44 bsnip 3318.0 10008.0 1 8.0
# Host correction...
# 2005el sn2005el-20051004.534-ui-corrected.flm 40.230445764 1.27 None 1.22 bsnip 3320.0 10296.0 3 8.0
# Host correction...
# 2005ki sn2005ki-20051202.649-deimos.flm 69.6995974072 1.41 None 1.62 bsnip 3826.0 8844.0 3 8.0
# Host correction...
# 1996x 1996X_19960419_3077_10669_00.dat 72.6747082167 1.26 None 0.900000000001 other 3108.0 10548.0 1 2.0
# Host correction...
# 1999ej sn1999ej-19991030.28-fast.flm 41.0343492423 1.48 None -1.82 cfa 3720.0 7390.0 4 9.0
# Host correction...
# 2002es sn2002es-20020903.45-fast.flm 18.2117848296 None 1.44350951456 2.14999999999 cfa 3706.0 7358.0 3 8.0
# Host correction...
# 2003ch sn2003ch-20030329.11-mmt.flm 28.8381350326 1.22 None 1.81 cfa 3172.0 9024.0 3 8.0
# Host correction...
# 2003ic sn2003ic-20030921.36-fast.flm 11.8373131267 None 1.20279024729 -2.44 cfa 3576.0 7096.0 3 8.0
# Host correction...
# 2004ef SN04ef_040914_b01_DUP_WF.dat 16.9958777651 1.39 None -1.35000000009 csp 3736.0 8908.0 7 12.0
# Host correction...
# 2005am sn2005am-20050303.30-fast.flm 28.1181574341 1.3 None -3.0 cfa 3506.0 7300.0 5 10.0
# Host correction...
# 2005bo SN05bo_050418_b01_DUP_WF.dat 28.2383319009 1.28 None -1.0299999998 csp 3798.0 9060.0 6 11.0
# Host correction...
# 2006gj sn2006gj-20060920.43-fast.flm 19.217234825 1.48 None -0.669999999998 cfa 3440.0 7168.0 6 11.0
# Host correction...
# 2007bd SN07bd_070417_b01_DUP_WF.dat 28.1437031822 1.3 None 0.540000000037 csp 3736.0 8908.0 5 10.0
# Host correction...
# 2005kc SN05kc_051125_b01_DUP_MS.dat 44.736357905 1.24 None 1.91999999993 csp 3774.0 7132.0 6 11.0
# Host correction...
# 2008ia SN08ia_081215_b01_CLA_LD.dat 42.770341803 None 1.21109716364 2.97999999998 csp 3670.0 9380.0 None 8.0
# Host correction...
# 2002er 2002er_20020910_3209_9997_00.dat 68.2099143412 1.23 None 2.1 other 3232.0 9858.0 5 10.0
# Host correction...
# 18 SNs with host corrections
# Creating composite...
# Done.

# %%
composite.optimize_scales(comps_host_high_dm15, comps_host_high_dm15[0], True)
query_db.set_min_num_spec(comps_host_high_dm15, 1)
query_db.comparison_plot(comps_host_high_dm15)

# %% [markdown]
# # +1 Week-Low dm15 Matched

# %%
query_host_low_dm15_p1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology >= 6 and ((dm15_cfa < 1.1 or dm15_from_fits < 1.1))",
                              "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology <= 5 and ((dm15_cfa < 1.15 or dm15_from_fits < 1.15))"]

# %%
comps_host_low_dm15_p1week, sn_arrays = query_db.main(len(query_host_low_dm15_p1week), query_host_low_dm15_p1week, boot='b')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology >= 6 and ((dm15_cfa < 1.1 or dm15_from_fits < 1.1))
# Collecting data...
# ERROR:  sn2001eh-20010925.757-hst.flm None
# 42 spectra found
# 151 questionable files currently ignored
# 0 questionable spectra removed 42 spectra left
# 0 Peculiar Ias removed 42 spectra left
# 37 SNs with host corrections
# Arrays cleaned
# 151 questionable files currently ignored
# 0 spectra with nan ivars removed 37 spectra left
# 1997bp sn1997bp-19970416-uoi.flm
# Host correction...
# 1998v sn1998v-19980326-br.flm
# Host correction...
# 2000fa sn2000fa-20001221-ui-corrected.flm
# Host correction...
# 2001ay sn2001ay-20010430-ui.flm
# Host correction...
# 2002de sn2002de-20020617-ui-corrected.flm
# Host correction...
# 2005m sn2005m-20050211.413-br.flm
# Host correction...
# 2006cf sn2006cf-20060523.291-ui.flm
# Host correction...
# 2006cm sn2006cm-20060605.470-ui.flm
# Host correction...
# 2006os sn2006os-20061201.142-ui.flm
# Host correction...
# 2007le sn2007le-20071102.182-ui-corrected.flm
# Host correction...
# 2007s sn2007s-20070218.375-ui.flm
# Host correction...
# 1994ae sn1994ae-19941207.55-mmt.flm
# Host correction...
# 1995al sn1995al-19951114.52-fast.flm
# Host correction...
# 1995d sn1995D-19950228.26-fast.flm
# Host correction...
# 1997br sn1997br-19970429.28-fast.flm
# Host correction...
# 1997do sn1997do-19971122.45-fast.flm
# Host correction...
# 1998ab sn1998ab-19980419.29-fast.flm
# Host correction...
# 1998bu sn1998bu-19980528.19-fast.flm
# Host correction...
# 1998dm sn1998dm-19980910.42-fast.flm
# Host correction...
# 1999dq sn1999dq-19990920.46-fast.flm
# Host correction...
# 1999ef sn1999ef-19991013.29-fast.flm
# Host correction...
# 1999gp sn1999gp-20000114.16-fast.flm
# Host correction...
# 2000ce sn2000ce-20000510.15-fast.flm
# Host correction...
# 2001eh sn2001eh-20010926.37-fast.flm
# Host correction...
# 2002jy sn2002jy-20030101.10-fast.flm
# Host correction...
# 2003fa sn2003fa-20030623.33-fast.flm
# Host correction...
# 2004as sn2004as-20040327.35-fast.flm
# Host correction...
# 2004bg sn2004bg-20040420.33-fast.flm
# Host correction...
# 2006cp sn2006cp-20060617.21-fast.flm
# Host correction...
# 2006le sn2006le-20061114.38-fast.flm
# Host correction...
# 2007af sn2007af-20070320.48-fast.flm
# Host correction...
# 2007bm SN07bm_070511_b01_DUP_BC.dat
# Host correction...
# 2007ca sn2007ca-20070512.27-fast.flm
# Host correction...
# 2007cg sn2007cg-20070515.22-fast.flm
# Host correction...
# 2005eq SN05eq_051018_g01_NTT_EM.dat
# Host correction...
# 2000e 2000E_20000210_3217_7484_00.dat
# Host correction...
# 2003du 2003du_20030516_3258_9799_00.dat
# Host correction...
# 37 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology <= 5 and ((dm15_cfa < 1.15 or dm15_from_fits < 1.15))
# Collecting data...
# 19 spectra found
# 151 questionable files currently ignored
# 1 questionable spectra removed 18 spectra left
# 1 Peculiar Ias removed 17 spectra left
# 16 SNs with host corrections
# Arrays cleaned
# 151 questionable files currently ignored
# 0 spectra with nan ivars removed 16 spectra left
# 2005hj sn2005hj-20051108.457-deimos.flm
# Host correction...
# 2006mp sn2006mp-20061120.101-ui.flm
# Host correction...
# 2006ot sn2006ot-20061201.241-ui.flm
# Host correction...
# 2007qe sn2007qe-20071201.176-ui.flm
# Host correction...
# 1996c sn1996C-19960223.44-mmt.flm
# Host correction...
# 2001bf sn2001bf-20010525.47-mmt.flm
# Host correction...
# 2001fe sn2001fe-20011122.48-fast.flm
# Host correction...
# 2003hu sn2003hu-20030927.14-fast.flm
# Host correction...
# 2005eu sn2005eu-20051025.29-fast.flm
# Host correction...
# 2005hc sn2005hc-20051031.29-fast.flm
# Host correction...
# 2006bt sn2006bt-20060508.31-fast.flm
# Host correction...
# 2006et sn2006et-20060922.37-fast.flm
# Host correction...
# 2007if sn2007if-20070911.29-mmt.flm
# Host correction...
# 2008bf sn2008bf-20080406.29-fast.flm
# Host correction...
# 2008c sn2008C-20080109.29-fast.flm
# Host correction...
# 2005cf 2005cf_20050618_3258_9998_00.dat
# Host correction...
# 16 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_host_low_dm15_p1week, comps_host_low_dm15_p1week[0], True)
query_db.set_min_num_spec(comps_host_low_dm15_p1week, 5)
plt.plot(comps_host_low_dm15_p1week[1].wavelength, comps_host_low_dm15_p1week[1].flux)
plt.show()
# comparison_plot(comps_host_low_dm15_p1week)
# plt.savefig('../../Paper_Drafts/hostlowdm15_p1week.pdf', dpi = 300, bbox_inches = 'tight')
# stacked_plot_max(comps_host_low_dm15_p1week,5,1)

# %% [markdown]
# # +1 Week-High dm15 Matched

# %%
query_host_high_dm15_p1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology >= 6 and ((dm15_cfa > 1.3 or dm15_from_fits > 1.2)) and ((dm15_cfa < 1.7 or dm15_from_fits > 1.7))",
                              "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology <= 5 and ((dm15_cfa > 1.3 or dm15_from_fits > 1.3)) and ((dm15_cfa < 1.6 or dm15_from_fits > 1.6))"]

# %%
comps_host_high_dm15_p1week = query_db.main(len(query_host_high_dm15_p1week), query_host_high_dm15_p1week)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology >= 6 and ((dm15_cfa > 1.3 or dm15_from_fits > 1.2)) and ((dm15_cfa < 1.7 or dm15_from_fits > 1.7))
# Collecting data...
# 14 spectra found
# 151 questionable files currently ignored
# 1 questionable spectra removed 13 spectra left
# 0 Peculiar Ias removed 13 spectra left
# 8 SNs with host corrections
# Arrays cleaned
# 151 questionable files currently ignored
# 0 spectra with nan ivars removed 8 spectra left
# 1998dx sn1998dx-19980921-ui.flm
# Host correction...
# 2001fh sn2001fh-20011116-ui-corrected.flm
# Host correction...
# 2003iv sn2003iv-20031028-ui.flm
# Host correction...
# 2004ef sn2004ef-20040924.302-ui-corrected.flm
# Host correction...
# 2000cn sn2000cn-20000621.37-fast.flm
# Host correction...
# 2006ev sn2006ev-20060916.23-fast.flm
# Host correction...
# 2006gj SN06gj_060927_b01_DUP_WF.dat
# Host correction...
# 1994d 1994D_19940328_4403_7013_00.dat
# Host correction...
# 8 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and morphology <= 5 and ((dm15_cfa > 1.3 or dm15_from_fits > 1.3)) and ((dm15_cfa < 1.6 or dm15_from_fits > 1.6))
# Collecting data...
# 17 spectra found
# 151 questionable files currently ignored
# 2 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 15 SNs with host corrections
# Arrays cleaned
# 151 questionable files currently ignored
# 0 spectra with nan ivars removed 15 spectra left
# 2005ki sn2005ki-20051209.514-ui.flm
# Host correction...
# 1999ej sn1999ej-19991109.26-fast.flm
# Host correction...
# 2000b sn2000B-20000128.13-fast.flm
# Host correction...
# 2002eu sn2002eu-20020907.49-fast.flm
# Host correction...
# 2002he sn2002he-20021113.53-fast.flm
# Host correction...
# 2005be SN05be_050407_b01_DUP_WF.dat
# Host correction...
# 2006al sn2006al-20060227.42-fast.flm
# Host correction...
# 2006hb SN06hb_060928_b01_DUP_WF.dat
# Host correction...
# 2006n sn2006N-20060131.22-fast.flm
# Host correction...
# 2007ap sn2007ap-20070315.45-fast.flm
# Host correction...
# 2007bc SN07bc_070417_b01_DUP_WF.dat
# Host correction...
# 2007nq SN07nq_071030_g01_NTT_EM.dat
# Host correction...
# 2008af sn2008af-20080211.48-fast.flm
# Host correction...
# 2008l sn2008L-20080202.15-fast.flm
# Host correction...
# 2008r sn2008R-20080202.13-fast.flm
# Host correction...
# 15 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_host_high_dm15_p1week, comps_host_high_dm15_p1week[0], True)
query_db.set_min_num_spec(comps_host_high_dm15_p1week, 5)
comparison_plot(comps_host_high_dm15_p1week)
# plt.savefig('../../Paper_Drafts/hosthighdm15_p1week.png', dpi = 300, bbox_inches = 'tight')
# stacked_plot_max(comps_host_high_dm15_p1week,5,1)
