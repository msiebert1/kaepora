# %%
import find_event_data as fed
import matplotlib.pyplot as plt
import numpy as np

# %%
def specific_query(test_query):
    # event = "'" + event + "'"
    query = "SELECT * FROM Supernovae " + test_query
    print query
    SN_Array = fed.grab_event_data(query)
    return SN_Array

# %%
questionable_files = []
f = open('data_notes_csp_other.txt', 'r')
questionable_files = []
for line in f.readlines():
    comment = line.split()[2]
    if 't' in comment.split(','):
        questionable_files.append("'" + line.split()[1] + "'")

# %%
f_string = "("
for f in questionable_files:
    f_string = f_string + f + ','
f_string = f_string[0:-1] + ")"

# SN_Array = specific_query("where phase between 4.5 and 5")
SN_Array = specific_query("where filename in "+ f_string)
# Out:
# SELECT * FROM Supernovae where filename in ('SN04ef_040914_b01_DUP_WF.dat','SN04ef_040920_b01_DUP_WF.dat','SN04ey_041126_b01_CLA_LD.dat','SN04ey_041209_b01_DUP_WF.dat','SN04gu_041219_b01_CLA_LD.dat','SN06dd_060621_b01_BAA_IM.dat','SN06dd_060927_b01_DUP_WF.dat','SN06hb_060928_b01_DUP_WF.dat','SN06is_061001_b01_BAA_IM.dat','SN06X_060213_r01_NTT_EM.dat','SN07al_070313_g01_BAA_IM.dat','SN07as_070418_b01_DUP_WF.dat','SN07bc_070417_b01_DUP_WF.dat','SN07on_071125_b01_CLA_MA.dat','SN07ux_080103_r01_3P6_EF.dat','SN08ar_080319_b01_CLA_MA.dat','SN08bc_080319_b01_CLA_MA.dat','SN08bf_080324_b01_CLA_LD.dat','SN08bf_080325_b01_CLA_LD.dat','SN08fp_080917_b01_CLA_LD.dat','SN08ia_081210_r01_NTT_EF.dat','SN08ia_081223_b01_DUP_WF.dat','SN08R_080131jan08_b01_CLA_MA.dat','SN09ab_090226_b01_DUP_WF.dat','SN09ad_090226_b01_DUP_WF.dat','SN09ag_090226_b01_DUP_WF.dat','SN09D_090110_r01_GEM_GM.dat','SN09F_090110_r01_GEM_GM.dat','SN09F_090112_r01_GEM_GM.dat','SN09Y_090225_b01_DUP_WF.dat','1994D_19940310_2988_7148
# ...

# %%
for SN in SN_Array:
    plt.plot(SN.wavelength[SN.x1:SN.x2], SN.flux[SN.x1:SN.x2])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d3a11009580c> in <module>()
#       1 for SN in SN_Array:
#       2     plt.plot(SN.wavelength[SN.x1:SN.x2], SN.flux[SN.x1:SN.x2])
# ----> 3     plt.show()
#
# C:\Program Files\Anaconda2\lib\site-packages\matplotlib\pyplot.pyc in show(*args, **kw)
#     250     """
#     251     global _show
# --> 252     return _show(*args, **kw)
#     253
#     254
#
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\pylab\backend_inline.pyc in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# C:\Program Files\Anaconda2\lib\site-packages\IPython\core\display.pyc in display(*objs, **kwargs)
# ...
