# %%
import matplotlib
matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db
import matplotlib.gridspec as gridspec
import spectral_analysis as sa
from scipy.special import erf
import datafidelity as df

# %%
# %load_ext autoreload
# %autoreload 2

# %%
query_dm15_max_fewer_bins = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa < .95 or dm15_from_fits < .95)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.42) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.42)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.42 and dm15_cfa < 1.7) or (dm15_from_fits >= 1.42 and dm15_from_fits < 1.7)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.7 or dm15_from_fits >= 1.7)) and Supernovae.SN !='2002bf'"]
# query_dm15_max_fewer_bins = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa < .9 or dm15_from_fits < .9)",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .9 and dm15_cfa < 1.) or (dm15_from_fits >= .9 and dm15_from_fits < 1))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1 and dm15_cfa < 1.05) or (dm15_from_fits >= 1 and dm15_from_fits < 1.05))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.05 and dm15_cfa < 1.1) or (dm15_from_fits >= 1.05 and dm15_from_fits < 1.1))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.2) or (dm15_from_fits >= 1.1 and dm15_from_fits < 1.2))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.3) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.3))", 
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.4) or (dm15_from_fits >= 1.3 and dm15_from_fits < 1.4))", 
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.4 and dm15_cfa < 1.6) or (dm15_from_fits >= 1.4 and dm15_from_fits < 1.6))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa >= 1.6 or dm15_from_fits >= 1.6)"]

# %%
comps_dm15_max_fewer_bins_med, sn_arrays_med, boot_sn_arrays_med = query_db.main(len(query_dm15_max_fewer_bins), query_dm15_max_fewer_bins, boot='b', medmean=2)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa < .95 or dm15_from_fits < .95)) and Supernovae.SN !='2002bf'
# Collecting data...
# 27 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 25 spectra left
# 0 Peculiar Ias removed 25 spectra left
# 23 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 23 spectra left
# 1994s sn1994s-19940616-uoi.flm 34.8971198257 0.94 None 1.11 bsnip 3124.0 11082.0
# Host correction...
# 1996ai sn1996ai-19960622-uoi.flm 46.9712987061 0.88 None 1.231 bsnip 3202.0 10368.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 44.0459361476 0.78 None 0.24 bsnip 3344.0 10350.0
# Host correction...
# 1999dq sn1999dq-near-19990917-clear-ui-corrected.flm 49.3372100352 0.86 None 2.97 bsnip 3304.0 10352.0
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 24.0178237234 0.88 None 1.39 bsnip 3278.0 10124.0
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 23.7964870723 0.84 None 1.1 bsnip 3318.0 10244.0
# Host correction...
# 2005eq sn2005eq-20051011.376-ui-corrected.flm 37.8569772533 0.88 None 0.66 bsnip 3278.0 10156.0
# Host correction...
# 2006cq sn2006cq-20060605.307-ui.flm 11.4517795753 None 0.905291256764 2.0 bsnip 3208.0 10062.0
# Host correction...
# 2006ot sn2006ot-20061123.362-br.flm 35.3768439715 0.84 None -1.338 bsnip 3008.0 8736.0
# Host correction...
# 2006s sn2006s-20060206.517-ui.flm 14.4997537352 0.93 None 2.99 bsnip 3254.0 10124.0
# Host correction...
# 1996c sn1996C-19960217.48-fast.flm 27.3132541144 0.93 None 1.98 cfa 3654.0 7314.0
# Host correction...
# 1999gp sn1999gp-20000105.10-fast.flm 33.6958139173 0.87 None -2.0 cfa 3674.0 7296.0
# Host correction...
# 2001ay sn2001ay-20010421.48-fast.flm 18.6087981469 0.68 None -1.52 cfa 3662.0 7270.0
# Host correction...
# 2001eh sn2001eh-20010915.42-fast.flm 15.1100402768 0.92 None -2.08 cfa 3638.0 7222.0
# Host correction...
# 2002jy sn2002jy-20021226.12-fast.flm 31.1301164169 0.88 None 0.120000000003 cfa 3700.0 7346.0
# Host correction...
# 2003hu sn2003hu-20030919.19-fast.flm 11.1326469482 None 0.880569111523 0.0900000000038 cfa 3512.0 6966.0
# Host correction...
# 2004as sn2004as-20040319.28-fast.flm 25.3622106076 0.92 None -2.12 cfa 3660.0 7264.0
# Host correction...
# 2006cj sn2006cj-20060522.29-fast.flm 11.127962287 0.81 None -1.21 cfa 3312.0 6886.0
# Host correction...
# 2006gr sn2006gr-20061002.26-fast.flm 13.8261860644 0.81 None -2.14 cfa 3414.0 7120.0
# Host correction...
# 2006oa sn2006oa-20061125.08-fast.flm 12.6130547741 0.89 None -2.12 cfa 3330.0 6944.0
# Host correction...
# 2007s sn2007S-20070210.32-fast.flm 56.6730771507 0.94 None -2.78 cfa 3480.0 7264.0
# Host correction...
# 2007ca SN07ca_070508_b01_BAA_IM.dat 31.5813058497 0.89 None 1.41999999993 csp 3506.0 9446.0
# Host correction...
# 23 SNs with host corrections
# Creating composite...
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\nanfunctions.py:769: RuntimeWarning: All-NaN slice encountered
#   warnings.warn("All-NaN slice encountered", RuntimeWarning)
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15)) and Supernovae.SN !='2002bf'
# Collecting data...
# 56 spectra found
# 152 questionable files currently ignored
# 3 questionable spectra removed 53 spectra left
# 1 Peculiar Ias removed 52 spectra left
# 45 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 44 spectra left
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0
# Host correction...
# 2001bf sn2001bf-20010516-ui-corrected.flm 46.0714551832 0.99 None 1.22 bsnip 3300.0 10242.0
# Host correction...
# 2001da sn2001da-20010716-ui-corrected.flm 30.0099081637 1.12 None -1.12 bsnip 3296.0 10176.0
# Host correction...
# 2001fe sn2001fe-20011115-ui.flm 63.0968901259 1.0 None -0.99 bsnip 3288.0 10212.0
# Host correction...
# 2002bo sn2002bo-20020322-ui-corrected.flm 27.2745675657 1.08 None -1.08 bsnip 3338.0 10308.0
# Host correction...
# 2002de sn2002de-20020608.374-ui-corrected.flm 7.9496540894 0.96 None -0.32 bsnip 3140.0 10066.0
# Host correction...
# 2004dt sn2004dt-20040824-vis2-corrected.flm 63.786388267 1.14 None 1.38 bsnip 4464.0 9562.0
# Host correction...
# 2004fu sn2004fu-20041119-ui.flm 45.3537215501 1.08 None 2.43 bsnip 3340.0 10356.0
# Host correction...
# 2005cf sn2005cf-20050610.7-uvot.flm 25.8392814942 1.1 None -2.7 uv 2038.0 9886.0
# Host correction...
# 2005ms sn2005ms-20060106.400-ui.flm 16.6601127349 None 1.0139405966 -1.88 bsnip 3280.0 10192.0
# Host correction...
# 2005na sn2005na-20060105.335-ui.flm 23.8296042949 1.09 None 0.03 bsnip 3276.0 10182.0
# Host correction...
# 2006bt sn2006bt-20060505.444-ui.flm 31.8522994411 1.0 None 2.27 bsnip 3296.0 10028.0
# Host correction...
# 2007a sn2007a-20070113.208-br.flm 66.6691522711 0.95 None 2.37 bsnip 3278.0 9044.0
# Host correction...
# 2007af sn2007af-20070313.545-ui-corrected.flm 62.682927791 1.04 None -1.25 bsnip 3382.0 10394.0
# Host correction...
# 2007bz sn2007bz-20070426.419-ui.flm 23.2078944384 1.05 None 1.65 bsnip 3320.0 10228.0
# Host correction...
# 2007o sn2007o-20070122.663-deimos.flm 42.7383273579 None 1.14429493781 -0.33 bsnip 4328.0 9186.0
# Host correction...
# 1994ae sn1994ae-19941201.50-fast.flm 150.102991241 0.96 None 2.0 cfa 3486.0 6936.0
# Host correction...
# 1996ab sn1996ab-19960522.37-fast.flm 5.13550481345 1.01 None 1.47 cfa 3346.0 6640.0
# Host correction...
# 1996bl sn1996bl-19961018.18-fast.flm 20.0727335243 1.07 None -2.32 cfa 3622.0 7244.0
# Host correction...
# 1997dt sn1997dt-19971204.11-fast.flm 56.9668367955 1.04 None 0.209999999999 cfa 3744.0 7436.0
# Host correction...
# 1998aq sn1998aq-19980429.26-fast.flm 161.199075666 1.11 None 1.06 cfa 3756.0 7442.0
# Host correction...
# 1998bu sn1998bu-19980517.15-fast.flm 137.136179272 1.03 None -2.55 cfa 3760.0 7470.0
# Host correction...
# 1998ec sn1998ec-19980930.50-fast.flm 25.4049698217 1.08 None -3.0 cfa 3698.0 7326.0
# Host correction...
# 1998eg sn1998eg-19981024.15-fast.flm 32.3460405034 1.14 None -0.75 cfa 3680.0 7230.0
# Host correction...
# 1998v sn1998V-19980319.51-fast.flm 30.4713646656 0.99 None 0.310000000005 cfa 3708.0 7362.0
# Host correction...
# 2000fa sn2000fa-20001215.36-fast.flm 17.7816354784 1.0 None 1.26 cfa 3654.0 7334.0
# Host correction...
# 2001en sn2001en-20011011.39-fast.flm 48.5003119433 1.12 None 1.49 cfa 3710.0 7370.0
# Host correction...
# 2001n sn2001N-20010122.46-fast.flm 20.2770059103 None 1.11269436615 0.659999999996 cfa 3694.0 7336.0
# Host correction...
# 2002ck sn2002ck-20020502.46-fast.flm 14.1023856776 1.08 None -0.540000000001 cfa 3664.0 7274.0
# Host correction...
# 2002fk sn2002fk-20020929.44-fast.flm 178.698803338 1.13 None -1.46 cfa 3744.0 7436.0
# Host correction...
# 2002hu sn2002hu-20021113.25-fast.flm 12.5387071627 1.05 None -0.75 cfa 3636.0 7220.0
# Host correction...
# 2003w sn2003W-20030207.40-fast.flm 28.9656419776 1.14 None -2.3 cfa 3698.0 7342.0
# Host correction...
# 2004bg sn2004bg-20040417.19-fast.flm 57.2971141657 1.05 None 2.69 cfa 3696.0 7338.0
# Host correction...
# 2004l sn2004L-20040127.40-fast.flm 27.3156204976 1.12 None 2.5 cfa 3654.0 7256.0
# Host correction...
# 2005a sn2005A-20050110.11-ldss2.flm 9.38778641688 1.11 None 0.610000000001 cfa 3698.0 9324.0
# Host correction...
# 2006ax SN06ax_060330_b01_DUP_WF.dat 58.502090858 1.06 None -2.36000000034 csp 3788.0 9034.0
# Host correction...
# 2006br SN06br_060426_b01_DUP_WF.dat 23.0514109304 1.12 None 0.560000000056 csp 3760.0 8964.0
# Host correction...
# 2006cf sn2006cf-20060519.25-fast.flm 25.8546360074 None 1.08670703312 1.85 cfa 3396.0 7062.0
# Host correction...
# 2006et sn2006et-20060918.36-fast.flm 31.9424489049 1.02 None 2.46 cfa 3450.0 7202.0
# Host correction...
# 2007ae sn2007ae-20070225.54-fast.flm 9.77849625348 0.98 None 2.54 cfa 3314.0 6914.0
# Host correction...
# 2008bf SN08bf_080326_b01_CLA_LD.dat 50.7093698903 1.05 None -2.77000000002 csp 3766.0 9926.0
# Host correction...
# 2005hc SN05hc_051024_b01_MGH_BC.dat 26.8404829147 1.03 None 0.699999999721 csp 3764.0 6970.0
# Host correction...
# 2006os SN06os_061122_b01_DUP_WF.dat 13.9284910072 None 1.07243123623 -1.06999999983 csp 3730.0 8892.0
# Host correction...
# 2007le SN07le_071028_g01_CLA_LD.dat 78.7656416336 1.01 None 2.84999999963 csp 4100.0 9192.0
# Host correction...
# 44 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25)) and Supernovae.SN !='2002bf'
# Collecting data...
# 19 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 17 spectra left
# 0 Peculiar Ias removed 17 spectra left
# 16 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 16 spectra left
# 1995e sn1995e-19950224-uoi2.flm 44.325356664 1.16 None -2.46 bsnip 3136.0 11162.0
# Host correction...
# 1997y sn1997y-19970209-uohp.flm 44.230493937 1.15 None 1.27 bsnip 3202.0 9716.0
# Host correction...
# 1999ac sn1999ac-19990312-ui-corrected.flm 66.9161014359 1.23 None -0.89 bsnip 3296.0 10352.0
# Host correction...
# 1999gd sn1999gd-19991205-uvoir.flm 65.3296710526 1.18 None -1.12 bsnip 3978.0 9770.0
# Host correction...
# 2002ha sn2002ha-20021102-ui-corrected.flm 48.9404969523 1.22 None -0.85 bsnip 3108.0 10206.0
# Host correction...
# 2003cq sn2003cq-20030408-ui.flm 15.7476139398 1.2 None -0.15 bsnip 3084.0 10016.0
# Host correction...
# 2006sr sn2006sr-20061220.097-ui.flm 38.6421198907 1.24 None -2.34 bsnip 3282.0 10204.0
# Host correction...
# 2007co sn2007co-20070614.468-ui-corrected.flm 40.524617158 1.16 None 0.85 bsnip 3288.0 10176.0
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0
# Host correction...
# 2002cr sn2002cr-20020515.28-fast.flm 77.3222473254 1.19 None 0.68 cfa 3736.0 7422.0
# Host correction...
# 2002hd sn2002hd-20021029.52-fast.flm 14.2622103278 1.16 None 1.42 cfa 3646.0 7236.0
# Host correction...
# 2002kf sn2002kf-20021231.34-fast.flm 31.8967736134 1.2 None 1.14 cfa 3700.0 7348.0
# Host correction...
# 2003ch sn2003ch-20030329.11-mmt.flm 28.8381350326 1.22 None 1.81 cfa 3172.0 9024.0
# Host correction...
# 2007jg SN07jg_070922_b01_CLA_LD.dat 17.4357299818 1.17 None -1.27000000002 csp 3636.0 9556.0
# Host correction...
# 2005kc SN05kc_051125_b01_DUP_MS.dat 44.736357905 1.24 None 1.91999999993 csp 3774.0 7132.0
# Host correction...
# 2002er 2002er_20020910_3209_9997_00.dat 68.2099143412 1.23 None 2.1 other 3232.0 9858.0
# Host correction...
# 16 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.42) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.42)) and Supernovae.SN !='2002bf'
# Collecting data...
# 28 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 26 spectra left
# 0 Peculiar Ias removed 26 spectra left
# 22 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 22 spectra left
# 2001ep sn2001ep-20011020-ui-corrected.flm 50.8449098727 1.3 None 2.83 bsnip 3308.0 10218.0
# Host correction...
# 2004gs sn2004gs-20041217.447-ui-corrected.flm 28.3734591732 1.41 None 0.44 bsnip 3318.0 10008.0
# Host correction...
# 2005el sn2005el-20051004.534-ui-corrected.flm 40.230445764 1.27 None 1.22 bsnip 3320.0 10296.0
# Host correction...
# 2005ki sn2005ki-20051202.649-deimos.flm 69.6995974072 1.41 None 1.62 bsnip 3826.0 8844.0
# Host correction...
# 2005lz sn2005lz-20060101.381-deimos.flm 22.438944213 1.34 None 0.58 bsnip 4792.0 9626.0
# Host correction...
# 2007bc sn2007bc-20070410.323-ui-corrected.flm 40.8042361928 1.37 None 0.61 bsnip 3298.0 10336.0
# Host correction...
# 1994m sn1994M-19940504.15-fast.flm 13.8602235972 1.26 None 1.65 cfa 3672.0 7408.0
# Host correction...
# 1996x 1996X_19960419_3077_10669_00.dat 72.6747082167 1.26 None 0.900000000001 other 3108.0 10548.0
# Host correction...
# 1998dx sn1998dx-19980914.18-fast.flm 10.9653036298 1.32 None -1.72 cfa 3580.0 7104.0
# Host correction...
# 1998ef sn1998ef-19981029.31-fast.flm 34.6262112005 1.27 None 1.41 cfa 3706.0 7244.0
# Host correction...
# 1999cc sn1999cc-19990516.34-fast.flm 23.2075050712 1.35 None -1.26 cfa 3658.0 7262.0
# Host correction...
# 2002es sn2002es-20020903.45-fast.flm 18.2117848296 None 1.36630609234 2.14999999999 cfa 3706.0 7358.0
# Host correction...
# 2002g sn2002G-20020122.52-fast.flm 12.2192785184 1.25 None -2.58 cfa 3650.0 7244.0
# Host correction...
# 2003ic sn2003ic-20030921.36-fast.flm 11.8373131267 None 1.31624075043 -2.44 cfa 3576.0 7096.0
# Host correction...
# 2003it sn2003it-20031020.23-fast.flm 50.6117952173 1.36 None -2.27 cfa 3680.0 7306.0
# Host correction...
# 2004ef SN04ef_040914_b01_DUP_WF.dat 16.9958777651 1.39 None -1.35000000009 csp 3736.0 8908.0
# Host correction...
# 2005am sn2005am-20050303.30-fast.flm 28.1181574341 1.3 None -3.0 cfa 3506.0 7300.0
# Host correction...
# 2005bo SN05bo_050418_b01_DUP_WF.dat 28.2383319009 1.28 None -1.0299999998 csp 3798.0 9060.0
# Host correction...
# 2006al sn2006al-20060224.34-fast.flm 9.36935831043 1.35 None 2.64 cfa 3460.0 6900.0
# Host correction...
# 2006az sn2006az-20060331.37-fast.flm 24.2208984929 1.29 None -1.03 cfa 3438.0 7142.0
# Host correction...
# 2007bd SN07bd_070417_b01_DUP_WF.dat 28.1437031822 1.3 None 0.540000000037 csp 3736.0 8908.0
# Host correction...
# 2006d sn2006d-20060120-snifs-r.dat 96.6707202467 1.35 None -2.0 other 5010.0 9860.0
# Host correction...
# 22 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.42 and dm15_cfa < 1.7) or (dm15_from_fits >= 1.42 and dm15_from_fits < 1.7)) and Supernovae.SN !='2002bf'
# Collecting data...
# 22 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 20 spectra left
# 3 Peculiar Ias removed 17 spectra left
# 14 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 14 spectra left
# 2000dk sn2000dk-20000926-ui-corrected.flm 46.5582359543 1.62 None 1.0 bsnip 3294.0 10172.0
# Host correction...
# 2002eu sn2002eu-20020903-ui.flm 21.8482743207 1.52 None -0.06 bsnip 3086.0 9974.0
# Host correction...
# 2002he sn2002he-20021108-br.flm 70.9263350618 1.44 None 0.29 bsnip 3048.0 9150.0
# Host correction...
# 2003u sn2003U-20030204-ui.flm 29.2694201484 1.46 None -2.55 bsnip 3074.0 10084.0
# Host correction...
# 2006n sn2006n-20060123.286-ui.flm 36.4972497748 1.5 None -1.89 bsnip 3320.0 10402.0
# Host correction...
# 2007ci sn2007ci-20070524.264-ui-corrected.flm 36.9959617847 1.6 None -1.71 bsnip 3312.0 10264.0
# Host correction...
# 1994t sn1994T-19940612.19-fast.flm 3.62813221224 1.51 None 0.790000000001 cfa 3726.0 7420.0
# Host correction...
# 1998co sn1998co-19980623.45-fast.flm 41.8372717871 None 1.43684328517 -0.0500000000029 cfa 3704.0 7356.0
# Host correction...
# 1999ej sn1999ej-19991030.28-fast.flm 41.0343492423 1.48 None -1.82 cfa 3720.0 7390.0
# Host correction...
# 2002do sn2002do-20020619.43-fast.flm 30.1719891566 1.56 None 2.03 cfa 3712.0 7374.0
# Host correction...
# 2006gj sn2006gj-20060920.43-fast.flm 19.217234825 1.48 None -0.669999999998 cfa 3440.0 7168.0
# Host correction...
# 2006gt SN06gt_060925_b01_DUP_WF.dat 21.7787084927 1.66 None 0.279999999795 csp 3688.0 8790.0
# Host correction...
# 2007au sn2007au-20070326.15-fast.flm 14.5404931844 1.69 None 1.15 cfa 3456.0 7222.0
# Host correction...
# 2006kf SN06kf_061103_g01_NTT_EM.dat 19.4132855756 1.55 None 1.45000000019 csp 3978.0 9938.0
# Host correction...
# 14 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.7 or dm15_from_fits >= 1.7)) and Supernovae.SN !='2002bf'
# Collecting data...
# 19 spectra found
# 152 questionable files currently ignored
# 4 questionable spectra removed 15 spectra left
# 1 Peculiar Ias removed 14 spectra left
# 11 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 11 spectra left
# 1999da sn1999da-19990709-ui.flm 35.441805608 1.9 None -2.12 bsnip 3300.0 10368.0
# Host correction...
# 2002fb sn2002fb-20020913-ui-corrected.flm 27.2042647112 1.77 None 0.98 bsnip 3198.0 10192.0
# Host correction...
# 2005dv sn2005dv-20050911.170-ui.flm 13.1133435614 None 1.82222873525 -0.57 bsnip 3366.0 10244.0
# Host correction...
# 2006bz sn2006bz-20060505.218-ui.flm 12.9015209065 2.09 None -2.44 bsnip 3310.0 10068.0
# Host correction...
# 2006cs sn2006cs-20060605.335-ui.flm 11.9352989284 None 1.94090186807 2.28 bsnip 3284.0 10306.0
# Host correction...
# 2007ba sn2007ba-20070410.475-ui.flm 11.9667177729 1.89 None 2.14 bsnip 3242.0 10158.0
# Host correction...
# 2007n sn2007n-20070122.583-deimos.flm 46.123607582 None 1.88681529203 0.44 bsnip 4442.0 9398.0
# Host correction...
# 1998bp sn1998bp-19980430.47-fast.flm 28.7557905032 1.79 None -2.93 cfa 3732.0 7394.0
# Host correction...
# 1998de sn1998de-19980730.46-fast.flm 13.7634061513 1.88 None -2.24 cfa 3710.0 7368.0
# Host correction...
# 1999by sn1999by-19990514.15-fast.flm 96.4401838766 1.97 None 2.95 cfa 3444.0 9210.0
# Host correction...
# 2007ax SN07ax_070326_b01_DUP_BC.dat 19.8323399731 1.87 None -2.04000000004 csp 3428.0 9494.0
# Host correction...
# 11 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
# comps_dm15_max_fewer_bins_mean, sn_arrays_mean, boot_sn_arrays_mean = query_db.main(len(query_dm15_max_fewer_bins), query_dm15_max_fewer_bins, boot='b', medmean=1)
comps_dm15_max_fewer_bins_mean, sn_arrays_mean, boot_sn_arrays_mean = query_db.main(len(query_dm15_max_fewer_bins), query_dm15_max_fewer_bins, boot='b', medmean=1, selection='max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa < .95 or dm15_from_fits < .95)) and Supernovae.SN !='2002bf'
# Collecting data...
# 27 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 25 spectra left
# 0 Peculiar Ias removed 25 spectra left
# 23 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 23 spectra left
# 1994s sn1994s-19940616-uoi.flm 34.8971198257 0.94 None 1.11 bsnip 3124.0 11082.0 6 11.0
# Host correction...
# 1996ai sn1996ai-19960622-uoi.flm 46.9712987061 0.88 None 1.231 bsnip 3202.0 10368.0 8 13.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0 3 8.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 44.0459361476 0.78 None 0.24 bsnip 3344.0 10350.0 9 14.0
# Host correction...
# 1999dq sn1999dq-near-19990917-clear-ui-corrected.flm 49.3372100352 0.86 None 2.97 bsnip 3304.0 10352.0 9 14.0
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 24.0178237234 0.88 None 1.39 bsnip 3278.0 10124.0 8 13.0
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 23.7964870723 0.84 None 1.1 bsnip 3318.0 10244.0 8 13.0
# Host correction...
# 2005eq sn2005eq-20051011.376-ui-corrected.flm 37.8569772533 0.88 None 0.66 bsnip 3278.0 10156.0 10 15.0
# Host correction...
# 2006cq sn2006cq-20060605.307-ui.flm 11.4517795753 None 0.905291256764 2.0 bsnip 3208.0 10062.0 7 19.0
# Host correction...
# 2006ot sn2006ot-20061123.362-br.flm 35.3768439715 0.84 None -1.338 bsnip 3008.0 8736.0 5 10.0
# Host correction...
# 2006s sn2006s-20060206.517-ui.flm 14.4997537352 0.93 None 2.99 bsnip 3254.0 10124.0 7 19.0
# Host correction...
# 1996c sn1996C-19960217.48-fast.flm 27.3132541144 0.93 None 1.98 cfa 3654.0 7314.0 5 None
# Host correction...
# 1999gp sn1999gp-20000105.10-fast.flm 33.6958139173 0.87 None -2.0 cfa 3674.0 7296.0 7 12.0
# Host correction...
# 2001ay sn2001ay-20010421.48-fast.flm 18.6087981469 0.68 None -1.52 cfa 3662.0 7270.0 7 19.0
# Host correction...
# 2001eh sn2001eh-20010915.42-fast.flm 15.1100402768 0.92 None -2.08 cfa 3638.0 7222.0 7 12.0
# Host correction...
# 2002jy sn2002jy-20021226.12-fast.flm 31.1301164169 0.88 None 0.120000000003 cfa 3700.0 7346.0 9 14.0
# Host correction...
# 2003hu sn2003hu-20030919.19-fast.flm 11.1326469482 None 0.880569111523 0.0900000000038 cfa 3512.0 6966.0 0 None
# Host correction...
# 2004as sn2004as-20040319.28-fast.flm 25.3622106076 0.92 None -2.12 cfa 3660.0 7264.0 11 None
# Host correction...
# 2006cj sn2006cj-20060522.29-fast.flm 11.127962287 0.81 None -1.21 cfa 3312.0 6886.0 0 None
# Host correction...
# 2006gr sn2006gr-20061002.26-fast.flm 13.8261860644 0.81 None -2.14 cfa 3414.0 7120.0 7 12.0
# Host correction...
# 2006oa sn2006oa-20061125.08-fast.flm 12.6130547741 0.89 None -2.12 cfa 3330.0 6944.0 0 None
# Host correction...
# 2007s sn2007S-20070210.32-fast.flm 56.6730771507 0.94 None -2.78 cfa 3480.0 7264.0 7 None
# Host correction...
# 2007ca SN07ca_070508_b01_BAA_IM.dat 31.5813058497 0.89 None 1.41999999993 csp 3506.0 9446.0 9 14.0
# Host correction...
# 23 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15)) and Supernovae.SN !='2002bf'
# Collecting data...
# 56 spectra found
# 152 questionable files currently ignored
# 3 questionable spectra removed 53 spectra left
# 1 Peculiar Ias removed 52 spectra left
# 45 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 44 spectra left
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0 6 14.0
# Host correction...
# 2001bf sn2001bf-20010516-ui-corrected.flm 46.0714551832 0.99 None 1.22 bsnip 3300.0 10242.0 0 None
# Host correction...
# 2001da sn2001da-20010716-ui-corrected.flm 30.0099081637 1.12 None -1.12 bsnip 3296.0 10176.0 6 11.0
# Host correction...
# 2001fe sn2001fe-20011115-ui.flm 63.0968901259 1.0 None -0.99 bsnip 3288.0 10212.0 5 10.0
# Host correction...
# 2002bo sn2002bo-20020322-ui-corrected.flm 27.2745675657 1.08 None -1.08 bsnip 3338.0 10308.0 5 None
# Host correction...
# 2002de sn2002de-20020608.374-ui-corrected.flm 7.9496540894 0.96 None -0.32 bsnip 3140.0 10066.0 11 19.0
# Host correction...
# 2004dt sn2004dt-20040824-vis2-corrected.flm 63.786388267 1.14 None 1.38 bsnip 4464.0 9562.0 7 10.0
# Host correction...
# 2004fu sn2004fu-20041119-ui.flm 45.3537215501 1.08 None 2.43 bsnip 3340.0 10356.0 9 19.0
# Host correction...
# 2005cf sn2005cf-20050610.7-uvot.flm 25.8392814942 1.1 None -2.7 uv 2038.0 9886.0 3 8.0
# Host correction...
# 2005ms sn2005ms-20060106.400-ui.flm 16.6601127349 None 1.0139405966 -1.88 bsnip 3280.0 10192.0 7 19.0
# Host correction...
# 2005na sn2005na-20060105.335-ui.flm 23.8296042949 1.09 None 0.03 bsnip 3276.0 10182.0 7 10.0
# Host correction...
# 2006bt sn2006bt-20060505.444-ui.flm 31.8522994411 1.0 None 2.27 bsnip 3296.0 10028.0 4 9.0
# Host correction...
# 2007a sn2007a-20070113.208-br.flm 66.6691522711 0.95 None 2.37 bsnip 3278.0 9044.0 5 None
# Host correction...
# 2007af sn2007af-20070313.545-ui-corrected.flm 62.682927791 1.04 None -1.25 bsnip 3382.0 10394.0 10 15.0
# Host correction...
# 2007bz sn2007bz-20070426.419-ui.flm 23.2078944384 1.05 None 1.65 bsnip 3320.0 10228.0 9 None
# Host correction...
# 2007o sn2007o-20070122.663-deimos.flm 42.7383273579 None 1.14429493781 -0.33 bsnip 4328.0 9186.0 None 14.0
# Host correction...
# 1994ae sn1994ae-19941201.50-fast.flm 150.102991241 0.96 None 2.0 cfa 3486.0 6936.0 9 14.0
# Host correction...
# 1996ab sn1996ab-19960522.37-fast.flm 5.13550481345 1.01 None 1.47 cfa 3346.0 6640.0 7 None
# Host correction...
# 1996bl sn1996bl-19961018.18-fast.flm 20.0727335243 1.07 None -2.32 cfa 3622.0 7244.0 9 None
# Host correction...
# 1997dt sn1997dt-19971204.11-fast.flm 56.9668367955 1.04 None 0.209999999999 cfa 3744.0 7436.0 8 13.0
# Host correction...
# 1998aq sn1998aq-19980429.26-fast.flm 161.199075666 1.11 None 1.06 cfa 3756.0 7442.0 7 12.0
# Host correction...
# 1998bu sn1998bu-19980517.15-fast.flm 137.136179272 1.03 None -2.55 cfa 3760.0 7470.0 6 11.0
# Host correction...
# 1998ec sn1998ec-19980930.50-fast.flm 25.4049698217 1.08 None -3.0 cfa 3698.0 7326.0 7 12.0
# Host correction...
# 1998eg sn1998eg-19981024.15-fast.flm 32.3460405034 1.14 None -0.75 cfa 3680.0 7230.0 9 15.0
# Host correction...
# 1998v sn1998V-19980319.51-fast.flm 30.4713646656 0.99 None 0.310000000005 cfa 3708.0 7362.0 7 12.0
# Host correction...
# 2000fa sn2000fa-20001215.36-fast.flm 17.7816354784 1.0 None 1.26 cfa 3654.0 7334.0 11 None
# Host correction...
# 2001en sn2001en-20011011.39-fast.flm 48.5003119433 1.12 None 1.49 cfa 3710.0 7370.0 8 None
# Host correction...
# 2001n sn2001N-20010122.46-fast.flm 20.2770059103 None 1.11269436615 0.659999999996 cfa 3694.0 7336.0 7 12.0
# Host correction...
# 2002ck sn2002ck-20020502.46-fast.flm 14.1023856776 1.08 None -0.540000000001 cfa 3664.0 7274.0 6 12.0
# Host correction...
# 2002fk sn2002fk-20020929.44-fast.flm 178.698803338 1.13 None -1.46 cfa 3744.0 7436.0 8 13.0
# Host correction...
# 2002hu sn2002hu-20021113.25-fast.flm 12.5387071627 1.05 None -0.75 cfa 3636.0 7220.0 7 None
# Host correction...
# 2003w sn2003W-20030207.40-fast.flm 28.9656419776 1.14 None -2.3 cfa 3698.0 7342.0 9 14.0
# Host correction...
# 2004bg sn2004bg-20040417.19-fast.flm 57.2971141657 1.05 None 2.69 cfa 3696.0 7338.0 7 15.0
# Host correction...
# 2004l sn2004L-20040127.40-fast.flm 27.3156204976 1.12 None 2.5 cfa 3654.0 7256.0 9 None
# Host correction...
# 2005a sn2005A-20050110.11-ldss2.flm 9.38778641688 1.11 None 0.610000000001 cfa 3698.0 9324.0 8 None
# Host correction...
# 2006ax SN06ax_060330_b01_DUP_WF.dat 58.502090858 1.06 None -2.36000000034 csp 3788.0 9034.0 8 13.0
# Host correction...
# 2006br SN06br_060426_b01_DUP_WF.dat 23.0514109304 1.12 None 0.560000000056 csp 3760.0 8964.0 7 12.0
# Host correction...
# 2006cf sn2006cf-20060519.25-fast.flm 25.8546360074 None 1.08670703312 1.85 cfa 3396.0 7062.0 10 15.0
# Host correction...
# 2006et sn2006et-20060918.36-fast.flm 31.9424489049 1.02 None 2.46 cfa 3450.0 7202.0 5 10.0
# Host correction...
# 2007ae sn2007ae-20070225.54-fast.flm 9.77849625348 0.98 None 2.54 cfa 3314.0 6914.0 None 19.0
# Host correction...
# 2008bf SN08bf_080326_b01_CLA_LD.dat 50.7093698903 1.05 None -2.77000000002 csp 3766.0 9926.0 1 None
# Host correction...
# 2005hc SN05hc_051024_b01_MGH_BC.dat 26.8404829147 1.03 None 0.699999999721 csp 3764.0 6970.0 0 None
# Host correction...
# 2006os SN06os_061122_b01_DUP_WF.dat 13.9284910072 None 1.07243123623 -1.06999999983 csp 3730.0 8892.0 7 19.0
# Host correction...
# 2007le SN07le_071028_g01_CLA_LD.dat 78.7656416336 1.01 None 2.84999999963 csp 4100.0 9192.0 8 14.0
# Host correction...
# 44 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25)) and Supernovae.SN !='2002bf'
# Collecting data...
# 19 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 17 spectra left
# 0 Peculiar Ias removed 17 spectra left
# 16 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 16 spectra left
# 1995e sn1995e-19950224-uoi2.flm 44.325356664 1.16 None -2.46 bsnip 3136.0 11162.0 7 12.0
# Host correction...
# 1997y sn1997y-19970209-uohp.flm 44.230493937 1.15 None 1.27 bsnip 3202.0 9716.0 7 12.0
# Host correction...
# 1999ac sn1999ac-19990312-ui-corrected.flm 66.9161014359 1.23 None -0.89 bsnip 3296.0 10352.0 10 15.0
# Host correction...
# 1999gd sn1999gd-19991205-uvoir.flm 65.3296710526 1.18 None -1.12 bsnip 3978.0 9770.0 7 None
# Host correction...
# 2002ha sn2002ha-20021102-ui-corrected.flm 48.9404969523 1.22 None -0.85 bsnip 3108.0 10206.0 6 None
# Host correction...
# 2003cq sn2003cq-20030408-ui.flm 15.7476139398 1.2 None -0.15 bsnip 3084.0 10016.0 8 13.0
# Host correction...
# 2006sr sn2006sr-20061220.097-ui.flm 38.6421198907 1.24 None -2.34 bsnip 3282.0 10204.0 9 19.0
# Host correction...
# 2007co sn2007co-20070614.468-ui-corrected.flm 40.524617158 1.16 None 0.85 bsnip 3288.0 10176.0 0 None
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0 8 13.0
# Host correction...
# 2002cr sn2002cr-20020515.28-fast.flm 77.3222473254 1.19 None 0.68 cfa 3736.0 7422.0 10 None
# Host correction...
# 2002hd sn2002hd-20021029.52-fast.flm 14.2622103278 1.16 None 1.42 cfa 3646.0 7236.0 1 8.0
# Host correction...
# 2002kf sn2002kf-20021231.34-fast.flm 31.8967736134 1.2 None 1.14 cfa 3700.0 7348.0 0 None
# Host correction...
# 2003ch sn2003ch-20030329.11-mmt.flm 28.8381350326 1.22 None 1.81 cfa 3172.0 9024.0 3 8.0
# Host correction...
# 2007jg SN07jg_070922_b01_CLA_LD.dat 17.4357299818 1.17 None -1.27000000002 csp 3636.0 9556.0 0 None
# Host correction...
# 2005kc SN05kc_051125_b01_DUP_MS.dat 44.736357905 1.24 None 1.91999999993 csp 3774.0 7132.0 6 11.0
# Host correction...
# 2002er 2002er_20020910_3209_9997_00.dat 68.2099143412 1.23 None 2.1 other 3232.0 9858.0 5 10.0
# Host correction...
# 16 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.42) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.42)) and Supernovae.SN !='2002bf'
# Collecting data...
# 28 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 26 spectra left
# 0 Peculiar Ias removed 26 spectra left
# 22 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 22 spectra left
# 2001ep sn2001ep-20011020-ui-corrected.flm 50.8449098727 1.3 None 2.83 bsnip 3308.0 10218.0 7 12.0
# Host correction...
# 2004gs sn2004gs-20041217.447-ui-corrected.flm 28.3734591732 1.41 None 0.44 bsnip 3318.0 10008.0 1 8.0
# Host correction...
# 2005el sn2005el-20051004.534-ui-corrected.flm 40.230445764 1.27 None 1.22 bsnip 3320.0 10296.0 3 8.0
# Host correction...
# 2005ki sn2005ki-20051202.649-deimos.flm 69.6995974072 1.41 None 1.62 bsnip 3826.0 8844.0 3 8.0
# Host correction...
# 2005lz sn2005lz-20060101.381-deimos.flm 22.438944213 1.34 None 0.58 bsnip 4792.0 9626.0 11 None
# Host correction...
# 2007bc sn2007bc-20070410.323-ui-corrected.flm 40.8042361928 1.37 None 0.61 bsnip 3298.0 10336.0 5 None
# Host correction...
# 1994m sn1994M-19940504.15-fast.flm 13.8602235972 1.26 None 1.65 cfa 3672.0 7408.0 1 None
# Host correction...
# 1996x 1996X_19960419_3077_10669_00.dat 72.6747082167 1.26 None 0.900000000001 other 3108.0 10548.0 1 2.0
# Host correction...
# 1998dx sn1998dx-19980914.18-fast.flm 10.9653036298 1.32 None -1.72 cfa 3580.0 7104.0 7 None
# Host correction...
# 1998ef sn1998ef-19981029.31-fast.flm 34.6262112005 1.27 None 1.41 cfa 3706.0 7244.0 7 19.0
# Host correction...
# 1999cc sn1999cc-19990516.34-fast.flm 23.2075050712 1.35 None -1.26 cfa 3658.0 7262.0 9 14.0
# Host correction...
# 2002es sn2002es-20020903.45-fast.flm 18.2117848296 None 1.36630609234 2.14999999999 cfa 3706.0 7358.0 3 8.0
# Host correction...
# 2002g sn2002G-20020122.52-fast.flm 12.2192785184 1.25 None -2.58 cfa 3650.0 7244.0 1 None
# Host correction...
# 2003ic sn2003ic-20030921.36-fast.flm 11.8373131267 None 1.31624075043 -2.44 cfa 3576.0 7096.0 3 8.0
# Host correction...
# 2003it sn2003it-20031020.23-fast.flm 50.6117952173 1.36 None -2.27 cfa 3680.0 7306.0 7 19.0
# Host correction...
# 2004ef SN04ef_040914_b01_DUP_WF.dat 16.9958777651 1.39 None -1.35000000009 csp 3736.0 8908.0 7 12.0
# Host correction...
# 2005am sn2005am-20050303.30-fast.flm 28.1181574341 1.3 None -3.0 cfa 3506.0 7300.0 5 10.0
# Host correction...
# 2005bo SN05bo_050418_b01_DUP_WF.dat 28.2383319009 1.28 None -1.0299999998 csp 3798.0 9060.0 6 11.0
# Host correction...
# 2006al sn2006al-20060224.34-fast.flm 9.36935831043 1.35 None 2.64 cfa 3460.0 6900.0 0 None
# Host correction...
# 2006az sn2006az-20060331.37-fast.flm 24.2208984929 1.29 None -1.03 cfa 3438.0 7142.0 7 19.0
# Host correction...
# 2007bd SN07bd_070417_b01_DUP_WF.dat 28.1437031822 1.3 None 0.540000000037 csp 3736.0 8908.0 5 10.0
# Host correction...
# 2006d sn2006d-20060120-snifs-r.dat 96.6707202467 1.35 None -2.0 other 5010.0 9860.0 6 None
# Host correction...
# 22 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.42 and dm15_cfa < 1.7) or (dm15_from_fits >= 1.42 and dm15_from_fits < 1.7)) and Supernovae.SN !='2002bf'
# Collecting data...
# 22 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 20 spectra left
# 3 Peculiar Ias removed 17 spectra left
# 14 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 14 spectra left
# 2000dk sn2000dk-20000926-ui-corrected.flm 46.5582359543 1.62 None 1.0 bsnip 3294.0 10172.0 1 1.0
# Host correction...
# 2002eu sn2002eu-20020903-ui.flm 21.8482743207 1.52 None -0.06 bsnip 3086.0 9974.0 0 None
# Host correction...
# 2002he sn2002he-20021108-br.flm 70.9263350618 1.44 None 0.29 bsnip 3048.0 9150.0 1 1.0
# Host correction...
# 2003u sn2003U-20030204-ui.flm 29.2694201484 1.46 None -2.55 bsnip 3074.0 10084.0 9 15.0
# Host correction...
# 2006n sn2006n-20060123.286-ui.flm 36.4972497748 1.5 None -1.89 bsnip 3320.0 10402.0 0 None
# Host correction...
# 2007ci sn2007ci-20070524.264-ui-corrected.flm 36.9959617847 1.6 None -1.71 bsnip 3312.0 10264.0 1 1.0
# Host correction...
# 1994t sn1994T-19940612.19-fast.flm 3.62813221224 1.51 None 0.790000000001 cfa 3726.0 7420.0 5 9.0
# Host correction...
# 1998co sn1998co-19980623.45-fast.flm 41.8372717871 None 1.43684328517 -0.0500000000029 cfa 3704.0 7356.0 3 8.0
# Host correction...
# 1999ej sn1999ej-19991030.28-fast.flm 41.0343492423 1.48 None -1.82 cfa 3720.0 7390.0 4 9.0
# Host correction...
# 2002do sn2002do-20020619.43-fast.flm 30.1719891566 1.56 None 2.03 cfa 3712.0 7374.0 1 3.0
# Host correction...
# 2006gj sn2006gj-20060920.43-fast.flm 19.217234825 1.48 None -0.669999999998 cfa 3440.0 7168.0 6 11.0
# Host correction...
# 2006gt SN06gt_060925_b01_DUP_WF.dat 21.7787084927 1.66 None 0.279999999795 csp 3688.0 8790.0 0 None
# Host correction...
# 2007au sn2007au-20070326.15-fast.flm 14.5404931844 1.69 None 1.15 cfa 3456.0 7222.0 3 8.0
# Host correction...
# 2006kf SN06kf_061103_g01_NTT_EM.dat 19.4132855756 1.55 None 1.45000000019 csp 3978.0 9938.0 3 8.0
# Host correction...
# 14 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.7 or dm15_from_fits >= 1.7)) and Supernovae.SN !='2002bf'
# Collecting data...
# 19 spectra found
# 152 questionable files currently ignored
# 4 questionable spectra removed 15 spectra left
# 1 Peculiar Ias removed 14 spectra left
# 11 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 11 spectra left
# 1999da sn1999da-19990709-ui.flm 35.441805608 1.9 None -2.12 bsnip 3300.0 10368.0 1 1.0
# Host correction...
# 2002fb sn2002fb-20020913-ui-corrected.flm 27.2042647112 1.77 None 0.98 bsnip 3198.0 10192.0 1 1.0
# Host correction...
# 2005dv sn2005dv-20050911.170-ui.flm 13.1133435614 None 1.82222873525 -0.57 bsnip 3366.0 10244.0 3 8.0
# Host correction...
# 2006bz sn2006bz-20060505.218-ui.flm 12.9015209065 2.09 None -2.44 bsnip 3310.0 10068.0 3 None
# Host correction...
# 2006cs sn2006cs-20060605.335-ui.flm 11.9352989284 None 1.94090186807 2.28 bsnip 3284.0 10306.0 3 8.0
# Host correction...
# 2007ba sn2007ba-20070410.475-ui.flm 11.9667177729 1.89 None 2.14 bsnip 3242.0 10158.0 4 9.0
# Host correction...
# 2007n sn2007n-20070122.583-deimos.flm 46.123607582 None 1.88681529203 0.44 bsnip 4442.0 9398.0 None None
# Host correction...
# 1998bp sn1998bp-19980430.47-fast.flm 28.7557905032 1.79 None -2.93 cfa 3732.0 7394.0 1 1.0
# Host correction...
# 1998de sn1998de-19980730.46-fast.flm 13.7634061513 1.88 None -2.24 cfa 3710.0 7368.0 3 8.0
# Host correction...
# 1999by sn1999by-19990514.15-fast.flm 96.4401838766 1.97 None 2.95 cfa 3444.0 9210.0 7 12.0
# Host correction...
# 2007ax SN07ax_070326_b01_DUP_BC.dat 19.8323399731 1.87 None -2.04000000004 csp 3428.0 9494.0 2 8.0
# Host correction...
# 11 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(comps_dm15_max_fewer_bins_mean, 5)
query_db.stacked_plot(comps_dm15_max_fewer_bins_mean)

# %%
si_ratios_med = []
phases_med = []
dm15s_med = []
for comp in comps_dm15_max_fewer_bins_med:
    p = np.average(comp.phase_array[comp.x1:comp.x2])
    dm15 = np.round(np.nanmean(comp.dm15_array[comp.x1:comp.x2]),2)
    r = sa.measure_si_ratio(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], vexp=.002)
    phases_med.append(p)
    dm15s_med.append(dm15)
    si_ratios_med.append(r)

# %%
si_ratios_mean = []
phases_mean = []
dm15s_mean = []
for comp in comps_dm15_max_fewer_bins_mean:
    p = np.average(comp.phase_array[comp.x1:comp.x2])
    dm15 = np.round(np.nanmean(comp.dm15_array[comp.x1:comp.x2]),2)
    r = sa.measure_si_ratio(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], vexp=.001)
    phases_mean.append(p)
    dm15s_mean.append(dm15)
    si_ratios_mean.append(r)

# %%
boot_ratios_med = []
errors_med  = []
percentile = erf(1/np.sqrt(2.))
low_pc = 0.5 - percentile*0.5
up_pc = 0.5 + percentile*0.5
# for k in range(len(boot_sn_arrays[0:27])):
for k in range(len(boot_sn_arrays_med)):
    rs = []
    print k
    for comp in boot_sn_arrays_med[k]:
        r = sa.measure_si_ratio(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], vexp=.002)
        rs.append(r)
    boot_ratios_med.append(rs)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
boot_ratios_mean = []
errors_mean  = []
percentile = erf(1/np.sqrt(2.))
low_pc = 0.5 - percentile*0.5
up_pc = 0.5 + percentile*0.5
# for k in range(len(boot_sn_arrays[0:27])):
for k in range(len(boot_sn_arrays_mean)):
    rs = []
    print k
    for comp in boot_sn_arrays_mean[k]:
        r = sa.measure_si_ratio(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], vexp=.001)
        rs.append(r)
    boot_ratios_mean.append(rs)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
low_errors = []
up_errors = []
boot_resids = []
boot_ratios_med = np.asarray(boot_ratios_med)
for j in range(len(boot_ratios_med)):
    r_resids = []
    r_resids.append(boot_ratios_med[j] - si_ratios_med[j])
    resid_sort = np.sort(r_resids)[0]
    boot_resids.append(resid_sort)
    low_ind = np.round((len(resid_sort)-1) * low_pc).astype(int)
    up_ind = np.round((len(resid_sort)-1) * up_pc).astype(int)
    low_errors.append(np.absolute(resid_sort[low_ind]))
    up_errors.append(resid_sort[up_ind])
#     errors.append(np.nanstd(rs))
errors_med = [low_errors, up_errors]

# %%
low_errors = []
up_errors = []
boot_resids = []
boot_ratios_mean = np.asarray(boot_ratios_mean)
for j in range(len(boot_ratios_mean)):
    r_resids = []
    r_resids.append(boot_ratios_mean[j] - si_ratios_mean[j])
    resid_sort = np.sort(r_resids)[0]
    boot_resids.append(resid_sort)
    low_ind = np.round((len(resid_sort)-1) * low_pc).astype(int)
    up_ind = np.round((len(resid_sort)-1) * up_pc).astype(int)
    low_errors.append(np.absolute(resid_sort[low_ind]))
    up_errors.append(resid_sort[up_ind])
#     errors.append(np.nanstd(rs))
errors_mean = [low_errors, up_errors]

# %%
all_dm15s_med = []
all_ratios_med = []
i=0
for sn_arr in sn_arrays_med:
    print i
    dm15_bin = []
    ratio_bin = []
    for SN in sn_arr:
        if SN.dm15_cfa != None:
            dm15 = SN.dm15_cfa
        else:
            dm15 = SN.dm15_from_fits
        var = 1./SN.ivar
        r = sa.measure_si_ratio(SN.wavelength[SN.x1:SN.x2], SN.flux[SN.x1:SN.x2], varflux = var[SN.x1:SN.x2], vexp=.002)
        dm15_bin.append(dm15)
        ratio_bin.append(r)
    all_dm15s_med.append(dm15_bin)
    all_ratios_med.append(ratio_bin)
    i+=1
# Out:
# 0
# spectral_analysis.py:22: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if varflux == None:
# 1
# 2
# 3
# 4
# 5

# %%
plt.rc('font', family='serif')
fig, ax = plt.subplots(1,1)
fig.set_size_inches(16, 12, forward = True)
plt.minorticks_on()
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('R(Si)', fontsize = 35)
plt.ylabel('$\Delta m_{15}$ (B)', fontsize = 35)
plt.tick_params(
    which='major', 
    bottom='on', 
    top='on',
    left='on',
    right='on',
    length=10)
plt.tick_params(
    which='minor', 
    bottom='on', 
    top='on',
    left='on',
    right='on',
    length=5)
dm15_bin_medians = []
ratio_bin_medians = []
for i in range(len(all_dm15s_med)):
    dm15_bin_medians.append(np.nanmedian(all_dm15s_med[i]))
    ratio_bin_medians.append(np.nanmedian(all_ratios_med[i]))
    plt.plot(np.asarray(all_ratios_med[i]), all_dm15s_med[i], 'o', alpha=.3)
plt.plot(ratio_bin_medians, dm15_bin_medians, 'd', markersize=20, alpha=.6, color = 'maroon')
plt.errorbar(si_ratios_med, dm15s_med, xerr=errors_med, fmt='o', markersize=10)
plt.errorbar(si_ratios_mean, dm15s_mean, xerr=errors_mean, fmt='k*', markersize=20)
plt.gca().invert_yaxis()
plt.savefig('../../Paper_Drafts/si_ratio_median.pdf', dpi = 300, bbox_inches = 'tight')
plt.show()
