# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db
import composite
import matplotlib.gridspec as gridspec

# %%
query_max = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1"]

# %%
comps_max, sn_arrays, boot_sn_arrays = query_db.main(len(query_max), query_max, boot='b', medmean=1, selection = 'max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1
# ...
# 146 spectra found
# 152 questionable files currently ignored
# 6 questionable spectra removed 140 spectra left
# 3 Peculiar Ias removed 137 spectra left
# 98 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 2 spectra with nan ivars removed 96 spectra left
# 1991bg sn1991bg-19911213-noz.flm 64.7109206589 None 1.88326464208 0.14 bsnip 3340.0 8600.0 1 3.0
# Host correction...
# 1996ai sn1996ai-19960620.15-mmt.flm 28.307554791 0.88 None -0.949999999997 cfa 3176.0 8806.0 8 13.0
# Host correction...
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0 6 14.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0 3 8.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 44.0459361476 0.78 None 0.24 bsnip 3344.0 10350.0 9 14.0
# ...

# %%
comps_max_spliced, sn_arrays_spliced, boot_sn_arrays_spliced = query_db.main(len(query_max), query_max, boot='nb', medmean=1, selection = 'max_coverage_splice')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1
# ...
# 149 spectra found
# 152 questionable files currently ignored
# 6 questionable spectra removed 143 spectra left
# 3 Peculiar Ias removed 140 spectra left
# 99 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 2 spectra with nan ivars removed 97 spectra left
# 1991bg sn1991bg-19911213-noz.flm 64.7109206589 None 1.88326464208 0.14 bsnip 3340.0 8600.0 1 3.0
# Host correction...
# 1996ai sn1996ai-19960620.15-mmt.flm 28.307554791 0.88 None -0.949999999997 cfa 3176.0 8806.0 8 13.0
# Host correction...
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0 6 14.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0 3 8.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 44.0459361476 0.78 None 0.24 bsnip 3344.0 10350.0 9 14.0
# ...

# %%
query_db.set_min_num_spec([comps_max[0], comps_max_spliced[0]], 1)
# comparison_plot(comps_host_max)
query_db.comparison_plot([comps_max[0], comps_max_spliced[0]])

# %%
comps_max_phase, sn_arrays_phase, boot_sn_arrays_phase = query_db.main(len(query_max), query_max, boot='nb', medmean=1, selection = 'accurate_phase')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1
# ...
# 146 spectra found
# 152 questionable files currently ignored
# 4 questionable spectra removed 142 spectra left
# 3 Peculiar Ias removed 139 spectra left
# 100 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 3 spectra with nan ivars removed 97 spectra left
# 1991bg sn1991bg-19911213-noz.flm 64.7109206589 None 1.88326464208 0.14 bsnip 3340.0 8600.0 1 3.0
# Host correction...
# 1996ai sn1996ai-19960621-uo.flm 4.13114666667 0.88 None -0.0999999999985 bsnip 3640.0 7528.0 8 13.0
# Host correction...
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0 6 14.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0 3 8.0
# Host correction...
# ...

# %%
query_db.set_min_num_spec([comps_max[0], comps_max_phase[0]], 1)
# comparison_plot(comps_host_max)
query_db.comparison_plot([comps_max[0], comps_max_phase[0]])

# %%
comps_max_snr, sn_arrays_snr, boot_sn_arrays_snr = query_db.main(len(query_max), query_max, boot='nb', medmean=1, selection = 'max_snr')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1
# ...
# 146 spectra found
# 152 questionable files currently ignored
# 4 questionable spectra removed 142 spectra left
# 3 Peculiar Ias removed 139 spectra left
# 100 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 3 spectra with nan ivars removed 97 spectra left
# 1991bg sn1991bg-19911213-noz.flm 64.7109206589 None 1.88326464208 0.14 bsnip 3340.0 8600.0 1 3.0
# Host correction...
# 1996ai sn1996ai-19960621.23-fast.flm 35.1654257593 0.88 None 0.130000000005 cfa 3740.0 7484.0 8 13.0
# Host correction...
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0 6 14.0
# Host correction...
# 1998es sn1998es-19981126.22-fast.flm 77.9532922082 0.85 None 0.520000000004 cfa 3484.0 7194.0 3 8.0
# Host correction...
# ...

# %%
query_db.set_min_num_spec([comps_max[0], comps_max_snr[0]], 1)
query_db.comparison_plot([comps_max[0], comps_max_snr[0]])

# %%
comps_max_med, sn_arrays_med, boot_sn_arrays_med = query_db.main(len(query_max), query_max, boot='b', medmean=2, selection = 'max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1
# ...
# 146 spectra found
# 152 questionable files currently ignored
# 6 questionable spectra removed 140 spectra left
# 3 Peculiar Ias removed 137 spectra left
# 98 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 2 spectra with nan ivars removed 96 spectra left
# 1991bg sn1991bg-19911213-noz.flm 64.7109206589 None 1.88326464208 0.14 bsnip 3340.0 8600.0 1 3.0
# Host correction...
# 1996ai sn1996ai-19960620.15-mmt.flm 28.307554791 0.88 None -0.949999999997 cfa 3176.0 8806.0 8 13.0
# Host correction...
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0 6 14.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0 3 8.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 44.0459361476 0.78 None 0.24 bsnip 3344.0 10350.0 9 14.0
# ...

# %%
query_db.set_min_num_spec([comps_max[0], comps_max_med[0]], 1)
query_db.comparison_plot([comps_max[0], comps_max_med[0]])

# %%
query_max_lim = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1 and ((dm15_source > 1.1 and dm15_source < 1.2) or (dm15_from_fits > 1.1 and dm15_from_fits < 1.2))"]

# %%
comps_max_lim, sn_arrays_lim, boot_sn_arrays_lim = query_db.main(len(query_max_lim), query_max_lim, boot='b', medmean=1, selection = 'max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1 and ((dm15_source > 1.1 and dm15_source < 1.2) or (dm15_from_fits > 1.1 and dm15_from_fits < 1.2))
# ...
# 17 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 12 spectra left
# 2007co sn2007co-20070614.468-ui-corrected.flm 40.524617158 1.16 None 0.85 bsnip 3288.0 10176.0 0 None
# Host correction...
# 1995e sn1995E-19950226.27-fast.flm 23.3670233998 1.16 None -0.93 cfa 3538.0 6926.0 7 12.0
# Host correction...
# 1998aq sn1998aq-19980428.26-fast.flm 141.039854289 1.11 None 0.0600000000049 cfa 3756.0 7432.0 7 12.0
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0 8 13.0
# ...

# %%
comps_max_lim_spliced, sn_arrays_lim_spliced, boot_sn_arrays_lim_spliced = query_db.main(len(query_max_lim), query_max_lim, boot='nb', medmean=1, selection = 'max_coverage_splice')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1 and ((dm15_source > 1.1 and dm15_source < 1.2) or (dm15_from_fits > 1.1 and dm15_from_fits < 1.2))
# ...
# 17 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 12 spectra left
# 2007co sn2007co-20070614.468-ui-corrected.flm 40.524617158 1.16 None 0.85 bsnip 3288.0 10176.0 0 None
# Host correction...
# 1995e sn1995E-19950226.27-fast.flm 23.3670233998 1.16 None -0.93 cfa 3538.0 6926.0 7 12.0
# Host correction...
# 1998aq sn1998aq-19980428.26-fast.flm 141.039854289 1.11 None 0.0600000000049 cfa 3756.0 7432.0 7 12.0
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0 8 13.0
# ...

# %%
query_db.set_min_num_spec([comps_max_lim[0], comps_max_lim_spliced[0]], 1)
query_db.comparison_plot([comps_max_lim[0], comps_max_lim_spliced[0]])

# %%
comps_max_lim_phase, sn_arrays_lim_phase, boot_sn_arrays_lim_phase = query_db.main(len(query_max_lim), query_max_lim, boot='nb', medmean=1, selection = 'accurate_phase')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1 and ((dm15_source > 1.1 and dm15_source < 1.2) or (dm15_from_fits > 1.1 and dm15_from_fits < 1.2))
# ...
# 17 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 12 spectra left
# 2007co sn2007co-20070613.39-fast.flm 22.8191364539 1.16 None -0.209999999999 cfa 3434.0 7172.0 0 None
# Host correction...
# 1995e sn1995E-19950226.27-fast.flm 23.3670233998 1.16 None -0.93 cfa 3538.0 6926.0 7 12.0
# Host correction...
# 1998aq sn1998aq-19980428.26-fast.flm 141.039854289 1.11 None 0.0600000000049 cfa 3756.0 7432.0 7 12.0
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0 8 13.0
# ...

# %%
query_db.set_min_num_spec([comps_max_lim[0], comps_max_lim_phase[0]], 1)
query_db.comparison_plot([comps_max_lim[0], comps_max_lim_phase[0]])

# %%
comps_max_lim_snr, sn_arrays_lim_snr, boot_sn_arrays_lim_snr = query_db.main(len(query_max_lim), query_max_lim, boot='nb', medmean=1, selection = 'max_snr')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1 and ((dm15_source > 1.1 and dm15_source < 1.2) or (dm15_from_fits > 1.1 and dm15_from_fits < 1.2))
# ...
# 17 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 12 spectra left
# 2007co sn2007co-20070614.468-ui-corrected.flm 40.524617158 1.16 None 0.85 bsnip 3288.0 10176.0 0 None
# Host correction...
# 1995e sn1995E-19950226.27-fast.flm 23.3670233998 1.16 None -0.93 cfa 3538.0 6926.0 7 12.0
# Host correction...
# 1998aq sn1998aq-19980427.29-fast.flm 142.041477411 1.11 None -0.909999999996 cfa 3756.0 7422.0 7 12.0
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0 8 13.0
# ...

# %%
query_db.set_min_num_spec([comps_max_lim[0], comps_max_lim_snr[0]], 1)
query_db.comparison_plot([comps_max_lim[0], comps_max_lim_snr[0]])

# %%
comps_max_lim_med, sn_arrays_lim_med, boot_sn_arrays_lim_med = query_db.main(len(query_max_lim), query_max_lim, boot='b', medmean=2, selection = 'max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1 and ((dm15_source > 1.1 and dm15_source < 1.2) or (dm15_from_fits > 1.1 and dm15_from_fits < 1.2))
# ...
# 17 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 12 spectra left
# 2007co sn2007co-20070614.468-ui-corrected.flm 40.524617158 1.16 None 0.85 bsnip 3288.0 10176.0 0 None
# Host correction...
# 1995e sn1995E-19950226.27-fast.flm 23.3670233998 1.16 None -0.93 cfa 3538.0 6926.0 7 12.0
# Host correction...
# 1998aq sn1998aq-19980428.26-fast.flm 141.039854289 1.11 None 0.0600000000049 cfa 3756.0 7432.0 7 12.0
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0 8 13.0
# ...

# %%
query_db.set_min_num_spec([comps_max_lim[0], comps_max_lim_med[0]], 1)
query_db.comparison_plot([comps_max_lim[0], comps_max_lim_med[0]])
