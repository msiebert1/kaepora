# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db
import composite
import spectral_analysis as sa
import scipy.interpolate as inter
from scipy.special import erf

# %% [markdown]
# ## Load comparison templates

# %%
phase_h, wavelength_hsiao, flux_hsiao = np.loadtxt('../data/info_files/hsiao_template.dat', unpack = True)

# %%
epoch_n, wavelength_nugent, flux_nugent = np.loadtxt('../data/info_files/nugent_templates.dat', unpack = True)
epoch_n_91t, wavelength_nugent_91t, flux_nugent_91t = np.loadtxt('../data/info_files/nugent_91t_templates.dat', unpack = True)
epoch_n_91bg, wavelength_nugent_91bg, flux_nugent_91bg = np.loadtxt('../data/info_files/nugent_91bg_templates.dat', unpack = True)

# %%
phase_s, wavelength_salt, flux_salt = np.loadtxt('../data/info_files/SALT/salt2-4/salt2_template_0.dat', unpack = True)

# %%
t_h, U_h, B_h, V_h, R_h, I_h, Y_h, J_h, H_h, K_h = np.loadtxt('../data/info_files/hsiao_lc_template.dat', unpack = True)

# %%
t_n, U_n, B_n, V_n, R_n, I_n, J_n, H_n, K_n = np.loadtxt('../data/info_files/nugent_light_curves.dat', unpack = True)

# %%
hsiao_temps = {}
phase_list = []
first = True
for i, phase in enumerate(phase_h):
    if phase not in phase_list:
        phase_list.append(phase)
        if not first:
            hsiao_temps[float(phase_h[i-1])] = [temp_wave, temp_flux]
        temp_wave = [wavelength_hsiao[i]]
        temp_flux = [flux_hsiao[i]]
    else:
        temp_wave.append(wavelength_hsiao[i])
        temp_flux.append(flux_hsiao[i])
    first = False

# %%
nug_temps = {}
phase_list = []
first = True
for i, phase in enumerate(epoch_n):
    if phase not in phase_list:
        phase_list.append(phase)
        if not first:
            nug_temps[float(epoch_n[i-1]) - 20.] = [temp_wave, temp_flux]
        temp_wave = [wavelength_nugent[i]]
        temp_flux = [flux_nugent[i]]
    else:
        temp_wave.append(wavelength_nugent[i])
        temp_flux.append(flux_nugent[i])
    first = False

nug_temps_91t = {}
phase_list = []
first = True
for i, phase in enumerate(epoch_n_91t):
    if phase not in phase_list:
        phase_list.append(phase)
        if not first:
            nug_temps_91t[float(epoch_n_91t[i-1]) - 20.] = [temp_wave, temp_flux]
        temp_wave = [wavelength_nugent_91t[i]]
        temp_flux = [flux_nugent_91t[i]]
    else:
        temp_wave.append(wavelength_nugent_91t[i])
        temp_flux.append(flux_nugent_91t[i])
    first = False
    
nug_temps_91bg = {}
phase_list = []
first = True
for i, phase in enumerate(epoch_n_91bg):
    if phase not in phase_list:
        phase_list.append(phase)
        if not first:
            nug_temps_91bg[float(epoch_n_91bg[i-1]) - 20.] = [temp_wave, temp_flux]
        temp_wave = [wavelength_nugent_91bg[i]]
        temp_flux = [flux_nugent_91bg[i]]
    else:
        temp_wave.append(wavelength_nugent_91bg[i])
        temp_flux.append(flux_nugent_91bg[i])
    first = False

# %%
salt_temps = {}
phase_list = []
first = True
for i, phase in enumerate(phase_s):
    if phase not in phase_list:
        phase_list.append(phase)
        if not first:
            salt_temps[float(phase_s[i-1])] = [temp_wave, temp_flux]
        temp_wave = [wavelength_salt[i]]
        temp_flux = [flux_salt[i]]
    else:
        temp_wave.append(wavelength_salt[i])
        temp_flux.append(flux_salt[i])
    first = False

# %% [markdown]
# ## Interpolate templates

# %%
wave_h = hsiao_temps[0.][0]
flux_h = hsiao_temps[0.][1]

# %%
wave_interp_h = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_h = inter.splrep(wave_h, flux_h)
flux_interp_h = inter.splev(wave_interp_h, flux_spl_h, ext = 3)
h_template = composite.supernova(wave_interp_h, flux_interp_h)
h_template.phase_array = np.zeros(len(flux_interp_h))

# %%
wave_n = nug_temps[0.][0]
flux_n = nug_temps[0.][1]

wave_n_91t = nug_temps_91t[0.][0]
flux_n_91t = nug_temps_91t[0.][1]

wave_n_91bg = nug_temps_91bg[0.][0]
flux_n_91bg = nug_temps_91bg[0.][1]

# %%
wave_interp_n = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_n = inter.splrep(wave_n, flux_n)
flux_interp_n = inter.splev(wave_interp_n, flux_spl_n, ext = 3)
n_template = composite.supernova(wave_interp_n,flux_interp_n)
n_template.phase_array = np.zeros(len(flux_interp_n))

wave_interp_n_91t = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_n_91t = inter.splrep(wave_n_91t, flux_n_91t)
flux_interp_n_91t = inter.splev(wave_interp_n_91t, flux_spl_n_91t, ext = 3)
n_template_91t = composite.supernova(wave_interp_n_91t,flux_interp_n_91t)
n_template_91t.phase_array = np.zeros(len(flux_interp_n_91t))

wave_interp_n_91bg = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_n_91bg = inter.splrep(wave_n_91bg, flux_n_91bg)
flux_interp_n_91bg = inter.splev(wave_interp_n_91bg, flux_spl_n_91bg, ext = 3)
n_template_91bg = composite.supernova(wave_interp_n_91bg,flux_interp_n_91bg)
n_template_91bg.phase_array = np.zeros(len(flux_interp_n_91bg))

# %%
wave_s = salt_temps[0.][0]
flux_s = salt_temps[0.][1]

# %%
wave_interp_s = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_s = inter.splrep(wave_s, flux_s)
flux_interp_s = inter.splev(wave_interp_s, flux_spl_s, ext = 3)
s_template = composite.supernova(wave_interp_s, flux_interp_s)
s_template.phase_array = np.zeros(len(flux_interp_s))

# %% [markdown]
# ## Maximum light - normal Ia composite spectrum

# %%
query = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1",
         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1 and phase <= 1 and ((dm15_source >= 1.02 and dm15_source < 1.24) or (dm15_from_fits >= 1.02 and dm15_from_fits < 1.24)) and Supernovae.SN !='2002bf'"]

# %%
composites, sn_arrays, boot_sn_arrays = query_db.main(len(query), query, boot='b', medmean=1, gini_balance = True, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 1
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2004dt-20040820-hst.flm']
# (13, 'questionable spectra removed', 197, 'spectra left')
# (5, 'Peculiar Ias removed', 192, 'spectra left')
# 147 spectra with host corrections
# 172 questionable files currently ignored
# 99 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 99 SNs with host corrections
# Creating composite...
# gini.py:43: RuntimeWarning: invalid value encountered in absolute
#   g_diff = np.absolute(g_wi - g_wj)
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# composite.py:979: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if template.RMSE != None:
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1 and phase <= 1 and ((dm15_source >= 1.02 and dm15_source < 1.24) or (dm15_from_fits >= 1.02 and dm15_from_fits < 1.24)) and Supernovae.SN !='2002bf'
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2004dt-20040820-hst.flm']
# (8, 'questionable spectra removed', 62, 'spectra left')
# (0, 'Peculiar Ias removed', 62, 'spectra left')
# 53 spectra with host corrections
# 172 questionable files currently ignored
# 35 valid SNe found
# Arrays cleaned
# 2 spectra may have telluric contamination
# 35 SNs with host corrections
# Creating composite...
# gini.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   gini_coeffs.append(gini_num/gini_denom)
# C:\Program Files\Anaconda2\lib\site-packages\numpy\lib\nanfunctions.py:703: RuntimeWarning: Mean of empty slice
#   warnings.warn("Mean of empty slice", RuntimeWarning)
# Gini balancing...
# Balanced after 7 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(composites, 5)

# %%
comps_and_temps = []
for comp in composites:
    comps_and_temps.append(comp)
comps_and_temps.append(h_template)
comps_and_temps.append(n_template)
comps_and_temps.append(s_template)
comps_and_temps, scales = composite.optimize_scales(comps_and_temps, comps_and_temps[2], True)

# %% [markdown]
# ## Generate photometry from template spectra and compare to template light curves

# %%
import pyphot

# %%
from pyphot.vega import Vega
vega = Vega()
lib = pyphot.get_library()
f = lib['GROUND_JOHNSON_B']
# compute the integrated flux through the filter f
# note that it work on many spectra at once
fluxes = f.get_flux(vega.wavelength, vega.flux, axis=-1)
# convert to vega magnitudes
mags = -2.5 * np.log10(fluxes) - f.Vega_zero_mag
print("Vega magnitude of Vega in {0:s} is : {1:f} mag".format(f.name, mags))
mags = -2.5 * np.log10(fluxes) - f.AB_zero_mag
print("AB magnitude of Vega in {0:s} is : {1:f} mag".format(f.name, mags))
mags = -2.5 * np.log10(fluxes) - f.ST_zero_mag
print("ST magnitude of Vega in {0:s} is : {1:f} mag".format(f.name, mags))
# Out:
# Vega magnitude of Vega in GROUND_JOHNSON_B is : 0.000000 mag
# AB magnitude of Vega in GROUND_JOHNSON_B is : -0.074212 mag
# ST magnitude of Vega in GROUND_JOHNSON_B is : -0.587021 mag

# %%
lib = pyphot.get_library()
B = lib['GROUND_JOHNSON_B']
V = lib['GROUND_JOHNSON_V']
hsiao_fluxB = B.get_flux(comps_and_temps[2].wavelength, comps_and_temps[2].flux, axis = -1)
hsiao_fluxV = V.get_flux(comps_and_temps[2].wavelength, comps_and_temps[2].flux, axis = -1)
hsiao_magB = -2.5 * np.log10(hsiao_fluxB) - B.Vega_zero_mag
hsiao_magV = -2.5 * np.log10(hsiao_fluxV) - V.Vega_zero_mag
print hsiao_magB, hsiao_magV
hsiao_magB = -2.5 * np.log10(hsiao_fluxB) - B.AB_zero_mag
hsiao_magV = -2.5 * np.log10(hsiao_fluxV) - V.AB_zero_mag
print hsiao_magB, hsiao_magV
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# -0.0387656219521 0.0423946332271
# -0.112977534603 0.0345530104216

# %%
hsiao_B = []
hsiao_V = []
i=-20.
phases_h = []
while i <= np.amax(hsiao_temps.keys()):
    Bflux = B.get_flux(np.asarray(hsiao_temps[i][0]), np.asarray(hsiao_temps[i][1]), axis = -1)
    Vflux = V.get_flux(np.asarray(hsiao_temps[i][0]), np.asarray(hsiao_temps[i][1]), axis = -1)
    Bmag = -2.5 * np.log10(Bflux) - B.Vega_zero_mag
    Vmag = -2.5 * np.log10(Vflux) - V.Vega_zero_mag
#     Bmag = -2.5 * np.log10(Bflux) - B.AB_zero_mag
#     Vmag = -2.5 * np.log10(Vflux) - V.AB_zero_mag
    hsiao_B.append(Bmag)
    hsiao_V.append(Vmag)
    phases_h.append(i)
    i+=1
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent

# %%
nug_B = []
nug_V = []
i=-20.
phases_n = []
while i <= np.amax(nug_temps.keys()):
    Bflux = B.get_flux(np.asarray(nug_temps[i][0]), np.asarray(nug_temps[i][1]), axis = -1)
    Vflux = V.get_flux(np.asarray(nug_temps[i][0]), np.asarray(nug_temps[i][1]), axis = -1)
    Bmag = -2.5 * np.log10(Bflux) - B.Vega_zero_mag
    Vmag = -2.5 * np.log10(Vflux) - V.Vega_zero_mag
#     Bmag = -2.5 * np.log10(Bflux) - B.AB_zero_mag
#     Vmag = -2.5 * np.log10(Vflux) - V.AB_zero_mag
    nug_B.append(Bmag)
    nug_V.append(Vmag)
    phases_n.append(i)
    i+=1
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent

# %%
salt_B = []
salt_V = []
i=-20.
phases_s = []
while i <= np.amax(salt_temps.keys()):
    Bflux = B.get_flux(np.asarray(salt_temps[i][0]), np.asarray(salt_temps[i][1]), axis = -1)
    Vflux = V.get_flux(np.asarray(salt_temps[i][0]), np.asarray(salt_temps[i][1]), axis = -1)
#     Bmag = -2.5 * np.log10(Bflux) - B.Vega_zero_mag
#     Vmag = -2.5 * np.log10(Vflux) - V.Vega_zero_mag
    Bmag = -2.5 * np.log10(Bflux) - B.AB_zero_mag
    Vmag = -2.5 * np.log10(Vflux) - V.AB_zero_mag
    salt_B.append(Bmag)
    salt_V.append(Vmag)
    phases_s.append(i)
    i+=1
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent

# %%
plt.plot(phases_h, hsiao_B)
plt.plot(phases_h, hsiao_V)
plt.plot(t_h, B_h, 'o', markersize=2)
plt.plot(t_h, V_h, 'o', markersize=2)
plt.gca().invert_yaxis()
plt.xlim([-19,30])
plt.ylim([10,-1])
plt.show()

# %%
plt.plot(phases_n, nug_B)
plt.plot(phases_n, nug_V)
plt.plot(t_n, B_n, 'o', markersize=2)
plt.plot(t_n, V_n, 'o', markersize=2)
plt.gca().invert_yaxis()
plt.xlim([-19,30])
plt.ylim([10,-1])
plt.show()

# %%
salt_B[0] = np.nan
salt_V[0] = np.nan
plt.plot(phases_s, salt_B)
plt.plot(phases_s, salt_V)
plt.gca().invert_yaxis()
plt.xlim([-19,30])
plt.show()

# %%
plt.plot(phases_h, np.asarray(hsiao_B)-np.asarray(hsiao_V))
plt.plot(t_h, np.asarray(B_h) - np.asarray(V_h), 'o', markersize=2)
plt.plot(phases_n, np.asarray(nug_B)-np.asarray(nug_V))
plt.plot(t_n, np.asarray(B_n) - np.asarray(V_n), 'o', markersize=2)
plt.plot(phases_s, np.asarray(salt_B)-np.asarray(salt_V))
plt.xlim([-19,85])
plt.show()

# %% [markdown]
# ## Composite spectral time series for normal - Ias and non dm15 controlled

# %%
#changeable phase bin size
query_strings_all = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -10."]
max_phase = 60.
p1 = -10.
k = 2.
p2 = p1+k
while p1 < max_phase:
    if p1 > 30.:
        k=7
        p2=p1+4
    query_strings_all.append("SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= %f and phase < %f"% (p1,p2))
    p1 += k
    p2 += k
print query_strings_all
# Out:
# ['SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -10.', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -10.000000 and phase < -8.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -8.000000 and phase < -6.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -6.000000 and phase < -4.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4.000000 and phase < -2.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2.000000 and phase < 0.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0.000000 and phase < 2.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2.000000 and phase < 4.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4.000000 and phase < 6.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6.000000 and phase < 8.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8.000000 and phase < 10.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10.000000 and phase < 12.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12.000000 and phase < 14.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14.000000 and phase < 16.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16.000000 and phase < 18.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18.000000 and phase < 20.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20.000000 and phase < 22.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22.000000 and phase < 24.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 24.000000 and phase < 26.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 26.000000 and phase < 28.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28.000000 and phase < 30.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 30.000000 and phase < 32.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 32.000000 and phase < 36.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39.000000 and phase < 43.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 46.000000 and phase < 50.000000', 'SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 53.000000 and phase < 57.000000']

# %%
query_strings_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -10. and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))"]
max_phase = 60.
p1 = -10.
k = 2.
p2 = p1+k
while p1 < max_phase:
    if p1 > 30.:
        k=7
        p2=p1+4
    query_strings_dm15.append("SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= %f and phase < %f and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))"% (p1,p2))
    p1 += k
    p2 += k
for q in query_strings_dm15:
    print q
# Out:
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -10. and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -10.000000 and phase < -8.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -8.000000 and phase < -6.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -6.000000 and phase < -4.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4.000000 and phase < -2.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2.000000 and phase < 0.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0.000000 and phase < 2.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2.000000 and phase < 4.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4.000000 and phase < 6.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6.000000 and phase < 8.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8.000000 and phase < 10.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10.000000 and phase < 12.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12.000000 and phase < 14.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14.000000 and phase < 16.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16.000000 and phase < 18.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18.000000 and phase < 20.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20.000000 and phase < 22.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22.000000 and phase < 24.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 24.000000 and phase < 26.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 26.000000 and phase < 28.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28.000000 and phase < 30.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 30.000000 and phase < 32.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 32.000000 and phase < 36.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39.000000 and phase < 43.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 46.000000 and phase < 50.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 53.000000 and phase < 57.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))

# %%
composites_all, sn_arrays_all, boot_sn_arrays_all = query_db.main(len(query_strings_all), query_strings_all, boot='b', medmean=1, gini_balance = True, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -10.
# Collecting data...
# ERROR:  2002bo_20020313_3360_7726_00.dat None
# ERROR:  sn2006oa-20061116-not.dat None
# 172 questionable files currently ignored
# Generate variance failed for:  [u'2005cf_20050601_3243_9720_00.dat']
# (4, 'questionable spectra removed', 87, 'spectra left')
# (0, 'Peculiar Ias removed', 87, 'spectra left')
# 74 spectra with host corrections
# 172 questionable files currently ignored
# 32 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 32 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 7 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -10.000000 and phase < -8.000000
# Collecting data...
# ERROR:  2002bo_20020314_0_2_00.dat None
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050603-hst.flm']
# (6, 'questionable spectra removed', 116, 'spectra left')
# (3, 'Peculiar Ias removed', 113, 'spectra left')
# 96 spectra with host corrections
# 172 questionable files currently ignored
# 53 valid SNe found
# Arrays cleaned
# 2 spectra may have telluric contamination
# 53 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 4 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -8.000000 and phase < -6.000000
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050605-hst.flm', u'sn2005m-20050128-hst.flm']
# (10, 'questionable spectra removed', 148, 'spectra left')
# (2, 'Peculiar Ias removed', 146, 'spectra left')
# 106 spectra with host corrections
# 172 questionable files currently ignored
# 67 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 67 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -6.000000 and phase < -4.000000
# Collecting data...
# ERROR:  sn2006oa-20061122-not.dat None
# ERROR:  sn2007jg-20070918-not.dat None
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050607-hst.flm']
# (7, 'questionable spectra removed', 177, 'spectra left')
# (5, 'Peculiar Ias removed', 172, 'spectra left')
# 136 spectra with host corrections
# 172 questionable files currently ignored
# 79 valid SNe found
# Arrays cleaned
# 6 spectra may have telluric contamination
# 79 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 12 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4.000000 and phase < -2.000000
# Collecting data...
# ERROR:  sn1992a-19920116.220-iue.flm None
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005m-20050131-hst.flm']
# (12, 'questionable spectra removed', 182, 'spectra left')
# (4, 'Peculiar Ias removed', 178, 'spectra left')
# 147 spectra with host corrections
# 172 questionable files currently ignored
# 93 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 93 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 14 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2.000000 and phase < 0.000000
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2004ef-20040914-hst.flm', u'sn2005cf-20050611-hst.flm']
# (12, 'questionable spectra removed', 199, 'spectra left')
# (6, 'Peculiar Ias removed', 193, 'spectra left')
# 141 spectra with host corrections
# 172 questionable files currently ignored
# 95 valid SNe found
# Arrays cleaned
# 5 spectra may have telluric contamination
# 95 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0.000000 and phase < 2.000000
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2004dt-20040820-hst.flm', u'sn2004ef-20040918-hst.flm', u'sn2005cf-20050614-hst.flm']
# (21, 'questionable spectra removed', 193, 'spectra left')
# (4, 'Peculiar Ias removed', 189, 'spectra left')
# 153 spectra with host corrections
# 172 questionable files currently ignored
# 100 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 100 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 15 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2.000000 and phase < 4.000000
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2004dt-20040823-hst.flm']
# (8, 'questionable spectra removed', 210, 'spectra left')
# (3, 'Peculiar Ias removed', 207, 'spectra left')
# 163 spectra with host corrections
# 172 questionable files currently ignored
# 94 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 94 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4.000000 and phase < 6.000000
# Collecting data...
# 172 questionable files currently ignored
# (16, 'questionable spectra removed', 205, 'spectra left')
# (4, 'Peculiar Ias removed', 201, 'spectra left')
# 145 spectra with host corrections
# 172 questionable files currently ignored
# 97 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 97 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 12 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6.000000 and phase < 8.000000
# Collecting data...
# 172 questionable files currently ignored
# (20, 'questionable spectra removed', 177, 'spectra left')
# (3, 'Peculiar Ias removed', 174, 'spectra left')
# 140 spectra with host corrections
# 172 questionable files currently ignored
# 99 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 99 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8.000000 and phase < 10.000000
# Collecting data...
# 172 questionable files currently ignored
# (12, 'questionable spectra removed', 151, 'spectra left')
# (2, 'Peculiar Ias removed', 149, 'spectra left')
# 122 spectra with host corrections
# 172 questionable files currently ignored
# 92 valid SNe found
# Arrays cleaned
# 6 spectra may have telluric contamination
# 92 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10.000000 and phase < 12.000000
# Collecting data...
# ERROR:  2002bo_20020403_0_2_00.dat None
# 172 questionable files currently ignored
# (17, 'questionable spectra removed', 160, 'spectra left')
# (2, 'Peculiar Ias removed', 158, 'spectra left')
# 133 spectra with host corrections
# 172 questionable files currently ignored
# 86 valid SNe found
# Arrays cleaned
# 8 spectra may have telluric contamination
# 86 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 12 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12.000000 and phase < 14.000000
# Collecting data...
# 172 questionable files currently ignored
# (13, 'questionable spectra removed', 131, 'spectra left')
# (2, 'Peculiar Ias removed', 129, 'spectra left')
# 110 spectra with host corrections
# 172 questionable files currently ignored
# 85 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 85 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14.000000 and phase < 16.000000
# Collecting data...
# 172 questionable files currently ignored
# (9, 'questionable spectra removed', 131, 'spectra left')
# (4, 'Peculiar Ias removed', 127, 'spectra left')
# 105 spectra with host corrections
# 172 questionable files currently ignored
# 76 valid SNe found
# Arrays cleaned
# 4 spectra may have telluric contamination
# 76 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 8 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16.000000 and phase < 18.000000
# Collecting data...
# 172 questionable files currently ignored
# (12, 'questionable spectra removed', 118, 'spectra left')
# (2, 'Peculiar Ias removed', 116, 'spectra left')
# 99 spectra with host corrections
# 172 questionable files currently ignored
# 75 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 75 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18.000000 and phase < 20.000000
# Collecting data...
# 172 questionable files currently ignored
# (4, 'questionable spectra removed', 101, 'spectra left')
# (1, 'Peculiar Ias removed', 100, 'spectra left')
# 87 spectra with host corrections
# 172 questionable files currently ignored
# 68 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 68 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20.000000 and phase < 22.000000
# Collecting data...
# 172 questionable files currently ignored
# (4, 'questionable spectra removed', 99, 'spectra left')
# (3, 'Peculiar Ias removed', 96, 'spectra left')
# 80 spectra with host corrections
# 172 questionable files currently ignored
# 61 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 61 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 12 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22.000000 and phase < 24.000000
# Collecting data...
# 172 questionable files currently ignored
# (2, 'questionable spectra removed', 90, 'spectra left')
# (4, 'Peculiar Ias removed', 86, 'spectra left')
# 71 spectra with host corrections
# 172 questionable files currently ignored
# 56 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 56 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 9 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 24.000000 and phase < 26.000000
# Collecting data...
# 172 questionable files currently ignored
# (3, 'questionable spectra removed', 96, 'spectra left')
# (1, 'Peculiar Ias removed', 95, 'spectra left')
# 83 spectra with host corrections
# 172 questionable files currently ignored
# 66 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 66 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 26.000000 and phase < 28.000000
# Collecting data...
# 172 questionable files currently ignored
# (4, 'questionable spectra removed', 87, 'spectra left')
# (2, 'Peculiar Ias removed', 85, 'spectra left')
# 69 spectra with host corrections
# 172 questionable files currently ignored
# 57 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 57 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28.000000 and phase < 30.000000
# Collecting data...
# ERROR:  2002bo_20020421_0_2_00.dat None
# 172 questionable files currently ignored
# (5, 'questionable spectra removed', 85, 'spectra left')
# (2, 'Peculiar Ias removed', 83, 'spectra left')
# 66 spectra with host corrections
# 172 questionable files currently ignored
# 52 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 52 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 9 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 30.000000 and phase < 32.000000
# Collecting data...
# 172 questionable files currently ignored
# (3, 'questionable spectra removed', 65, 'spectra left')
# (2, 'Peculiar Ias removed', 63, 'spectra left')
# 59 spectra with host corrections
# 172 questionable files currently ignored
# 51 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 51 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 9 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 32.000000 and phase < 36.000000
# Collecting data...
# 172 questionable files currently ignored
# (7, 'questionable spectra removed', 118, 'spectra left')
# (3, 'Peculiar Ias removed', 115, 'spectra left')
# 93 spectra with host corrections
# 172 questionable files currently ignored
# 67 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 67 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39.000000 and phase < 43.000000
# Collecting data...
# 172 questionable files currently ignored
# (7, 'questionable spectra removed', 103, 'spectra left')
# (6, 'Peculiar Ias removed', 97, 'spectra left')
# 83 spectra with host corrections
# 172 questionable files currently ignored
# 51 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 51 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 46.000000 and phase < 50.000000
# Collecting data...
# 172 questionable files currently ignored
# (4, 'questionable spectra removed', 63, 'spectra left')
# (0, 'Peculiar Ias removed', 63, 'spectra left')
# 53 spectra with host corrections
# 172 questionable files currently ignored
# 38 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 38 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 7 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 53.000000 and phase < 57.000000
# Collecting data...
# ERROR:  2002bo_20020518_0_2_00.dat None
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 63, 'spectra left')
# (2, 'Peculiar Ias removed', 61, 'spectra left')
# 49 spectra with host corrections
# 172 questionable files currently ignored
# 33 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 33 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
composites_dm15, sn_arrays_dm15, boot_sn_arrays_dm15 = query_db.main(len(query_strings_dm15), query_strings_dm15, boot='b', medmean=1, gini_balance = True, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -10. and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# ERROR:  2002bo_20020313_3360_7726_00.dat None
# 172 questionable files currently ignored
# Generate variance failed for:  [u'2005cf_20050601_3243_9720_00.dat']
# (1, 'questionable spectra removed', 43, 'spectra left')
# (0, 'Peculiar Ias removed', 43, 'spectra left')
# 41 spectra with host corrections
# 172 questionable files currently ignored
# 15 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 15 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -10.000000 and phase < -8.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# ERROR:  2002bo_20020314_0_2_00.dat None
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050603-hst.flm']
# (2, 'questionable spectra removed', 49, 'spectra left')
# (0, 'Peculiar Ias removed', 49, 'spectra left')
# 39 spectra with host corrections
# 172 questionable files currently ignored
# 18 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 18 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 3 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -8.000000 and phase < -6.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050605-hst.flm']
# (3, 'questionable spectra removed', 48, 'spectra left')
# (0, 'Peculiar Ias removed', 48, 'spectra left')
# 39 spectra with host corrections
# 172 questionable files currently ignored
# 26 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 26 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -6.000000 and phase < -4.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050607-hst.flm']
# (4, 'questionable spectra removed', 46, 'spectra left')
# (1, 'Peculiar Ias removed', 45, 'spectra left')
# 39 spectra with host corrections
# 172 questionable files currently ignored
# 26 valid SNe found
# Arrays cleaned
# 2 spectra may have telluric contamination
# 26 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 8 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4.000000 and phase < -2.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (4, 'questionable spectra removed', 59, 'spectra left')
# (0, 'Peculiar Ias removed', 59, 'spectra left')
# 51 spectra with host corrections
# 172 questionable files currently ignored
# 29 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 29 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 7 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2.000000 and phase < 0.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050611-hst.flm']
# (4, 'questionable spectra removed', 59, 'spectra left')
# (2, 'Peculiar Ias removed', 57, 'spectra left')
# 47 spectra with host corrections
# 172 questionable files currently ignored
# 30 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 30 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0.000000 and phase < 2.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2004dt-20040820-hst.flm', u'sn2005cf-20050614-hst.flm']
# (8, 'questionable spectra removed', 55, 'spectra left')
# (1, 'Peculiar Ias removed', 54, 'spectra left')
# 48 spectra with host corrections
# 172 questionable files currently ignored
# 31 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 31 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 7 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2.000000 and phase < 4.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2004dt-20040823-hst.flm']
# (3, 'questionable spectra removed', 69, 'spectra left')
# (0, 'Peculiar Ias removed', 69, 'spectra left')
# 63 spectra with host corrections
# 172 questionable files currently ignored
# 41 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 41 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4.000000 and phase < 6.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (6, 'questionable spectra removed', 69, 'spectra left')
# (2, 'Peculiar Ias removed', 67, 'spectra left')
# 57 spectra with host corrections
# 172 questionable files currently ignored
# 37 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 37 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6.000000 and phase < 8.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (6, 'questionable spectra removed', 44, 'spectra left')
# (2, 'Peculiar Ias removed', 42, 'spectra left')
# 38 spectra with host corrections
# 172 questionable files currently ignored
# 32 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 32 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 5 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8.000000 and phase < 10.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (2, 'questionable spectra removed', 40, 'spectra left')
# (1, 'Peculiar Ias removed', 39, 'spectra left')
# 38 spectra with host corrections
# 172 questionable files currently ignored
# 29 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 29 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10.000000 and phase < 12.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# ERROR:  2002bo_20020403_0_2_00.dat None
# 172 questionable files currently ignored
# (3, 'questionable spectra removed', 63, 'spectra left')
# (1, 'Peculiar Ias removed', 62, 'spectra left')
# 57 spectra with host corrections
# 172 questionable files currently ignored
# 37 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 37 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 7 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12.000000 and phase < 14.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (2, 'questionable spectra removed', 49, 'spectra left')
# (1, 'Peculiar Ias removed', 48, 'spectra left')
# 45 spectra with host corrections
# 172 questionable files currently ignored
# 35 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 35 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14.000000 and phase < 16.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (4, 'questionable spectra removed', 35, 'spectra left')
# (0, 'Peculiar Ias removed', 35, 'spectra left')
# 32 spectra with host corrections
# 172 questionable files currently ignored
# 25 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 25 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 4 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16.000000 and phase < 18.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (2, 'questionable spectra removed', 45, 'spectra left')
# (1, 'Peculiar Ias removed', 44, 'spectra left')
# 39 spectra with host corrections
# 172 questionable files currently ignored
# 28 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 28 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18.000000 and phase < 20.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 42, 'spectra left')
# (0, 'Peculiar Ias removed', 42, 'spectra left')
# 39 spectra with host corrections
# 172 questionable files currently ignored
# 29 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 29 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 9 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20.000000 and phase < 22.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 39, 'spectra left')
# (1, 'Peculiar Ias removed', 38, 'spectra left')
# 36 spectra with host corrections
# 172 questionable files currently ignored
# 27 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 27 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22.000000 and phase < 24.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (1, 'questionable spectra removed', 31, 'spectra left')
# (1, 'Peculiar Ias removed', 30, 'spectra left')
# 26 spectra with host corrections
# 172 questionable files currently ignored
# 19 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 19 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 24.000000 and phase < 26.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (3, 'questionable spectra removed', 37, 'spectra left')
# (1, 'Peculiar Ias removed', 36, 'spectra left')
# 35 spectra with host corrections
# 172 questionable files currently ignored
# 26 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 26 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 7 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 26.000000 and phase < 28.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 31, 'spectra left')
# (1, 'Peculiar Ias removed', 30, 'spectra left')
# 30 spectra with host corrections
# 172 questionable files currently ignored
# 23 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 23 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 4 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28.000000 and phase < 30.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# ERROR:  2002bo_20020421_0_2_00.dat None
# 172 questionable files currently ignored
# (2, 'questionable spectra removed', 29, 'spectra left')
# (1, 'Peculiar Ias removed', 28, 'spectra left')
# 25 spectra with host corrections
# 172 questionable files currently ignored
# 18 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 18 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 5 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 30.000000 and phase < 32.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 28, 'spectra left')
# (1, 'Peculiar Ias removed', 27, 'spectra left')
# 27 spectra with host corrections
# 172 questionable files currently ignored
# 23 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 23 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 32.000000 and phase < 36.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 46, 'spectra left')
# (0, 'Peculiar Ias removed', 46, 'spectra left')
# 42 spectra with host corrections
# 172 questionable files currently ignored
# 27 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 27 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 4 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39.000000 and phase < 43.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 45, 'spectra left')
# (2, 'Peculiar Ias removed', 43, 'spectra left')
# 42 spectra with host corrections
# 172 questionable files currently ignored
# 23 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 23 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 13 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 46.000000 and phase < 50.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 172 questionable files currently ignored
# (1, 'questionable spectra removed', 27, 'spectra left')
# (0, 'Peculiar Ias removed', 27, 'spectra left')
# 23 spectra with host corrections
# 172 questionable files currently ignored
# 18 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 18 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 53.000000 and phase < 57.000000 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# ERROR:  2002bo_20020518_0_2_00.dat None
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 27, 'spectra left')
# (2, 'Peculiar Ias removed', 25, 'spectra left')
# 22 spectra with host corrections
# 172 questionable files currently ignored
# 17 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 17 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %% [markdown]
# ## Average phases of each composite in time series

# %%
comp_phases = []
comp_B = []
comp_V = []
query_db.set_min_num_spec(composites_all, 5)
for comp in composites_all:
    Bflux = B.get_flux(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], axis = -1)
    Vflux = V.get_flux(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], axis = -1)
    Bmag = -2.5 * np.log10(Bflux) - B.Vega_zero_mag
    Vmag = -2.5 * np.log10(Vflux) - V.Vega_zero_mag
#     Bmag = -2.5 * np.log10(Bflux) - B.AB_zero_mag
#     Vmag = -2.5 * np.log10(Vflux) - V.AB_zero_mag
    comp_B.append(Bmag)
    comp_V.append(Vmag)
    comp_phases.append(np.average(comp.phase_array[comp.x1:comp.x2]))
print comp_phases
print comp_B
print comp_V
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# [-11.22377500921125, -8.7697109296383662, -6.9400443108160026, -5.1039701804487212, -3.0172823370587447, -1.0420596916907221, 0.96227315594232743, 2.8536002687834103, 4.8202310043936736, 6.8485118175327289, 9.03299755267469, 10.941621565671472, 12.855447108356806, 14.858276463621985, 17.069888215534803, 18.904620469885796, 20.901793163393595, 23.115828211741679, 25.120784798929673, 27.084083565483319, 28.780005075260718, 31.078183561273271, 33.915831009473287, 41.09072218373209, 48.097773716787579, 54.97738417791853]
# [-20.045270725529832, -20.03761143627634, -20.032685855942042, -20.050095708281066, -20.06078696540931, -20.06552760612804, -20.07571939807497, -20.104302027030375, -20.066926642910698, -20.214783836059226, -20.086924032048639, -20.061613302473233, -19.964623190930237, -19.916500430357761, -19.865847714176731, -19.785522147165068, -19.815321269155266, -19.785279170679143, -19.653650089974825, -19.605099171210234, -19.59561248418045, -19.580225338354815, -19.619515602279332, -19.61991219849256, -19.811827339323671, -19.814219851996114]
# [-19.91963526523503, -19.881998199836314, -19.885948475334779, -19.923272406243363, -19.953787497817604, -19.981858982323534, -20.043848704027955, -20.13578286843854, -20.134738826945441, -20.352035278631735, -20.322000239823474, -20.385132059049781, -20.327189070319665, -20.327967090080708, -20.437451114641508, -20.461410725570463, -20.588731547032481, -20.637237182228645, -20.609989548725284, -20.587723677279055, -20.577531913436204, -20.542644905928821, -20.563918347572649, -20.560435801725212, -20.627515156350359, -20.572770994377262]

# %%
comp_phases_dm15 = []
comp_B_dm15 = []
comp_V_dm15 = []
query_db.set_min_num_spec(composites_dm15, 5)
for comp in composites_dm15:
    Bflux = B.get_flux(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], axis = -1)
    Vflux = V.get_flux(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], axis = -1)
    Bmag = -2.5 * np.log10(Bflux) - B.Vega_zero_mag
    Vmag = -2.5 * np.log10(Vflux) - V.Vega_zero_mag
#     Bmag = -2.5 * np.log10(Bflux) - B.AB_zero_mag
#     Vmag = -2.5 * np.log10(Vflux) - V.AB_zero_mag
    comp_B_dm15.append(Bmag)
    comp_V_dm15.append(Vmag)
    comp_phases_dm15.append(np.average(comp.phase_array[comp.x1:comp.x2]))
print comp_phases_dm15
print comp_B_dm15
print comp_V_dm15
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# [-11.187821873145293, -8.9059774024367577, -6.9649255017715745, -4.9909335126304892, -2.965240673542509, -1.0493884128633284, 0.85115509125830446, 2.8046430414742671, 4.9792692685674904, 7.0751579012139318, 8.9051933100741412, 11.002911257203268, 12.905880136070687, 15.024224599839876, 17.25598803027189, 19.140360265464249, 20.966523275140723, 22.927947553483449, 25.148048952193378, 27.27170966213373, 28.703675548846114, 30.861928050770921, 33.795647983337261, 41.122457729770133, 48.412072731608944, 55.034894559270619]
# [-19.942734240741718, -19.991901995532, -20.017872716098481, -20.018509296631457, -20.02086627871488, -20.016151760813699, -20.030902677328893, -20.088499225027267, -20.077667176269326, -20.046754410237771, -20.031505486524619, -20.006730403415585, -19.971938461353474, -19.90640883613225, -19.836539854655761, -19.745312576029441, -19.759036982943222, -19.76275376846402, -19.308809757830613, -19.552594862402195, -19.540468746512531, -19.604761061941801, -19.490022141227119, -19.669611032285992, -19.79623410596836, -19.756673587068594]
# [-19.725986902394308, -19.805551636606218, -19.81095750421801, -19.812532345407128, -19.842156137528097, -19.889342571639812, -19.897994505023778, -20.036486348899818, -20.080931174407084, -20.077291858300192, -20.150376834304236, -20.176713905450761, -20.266857433846489, -20.268121761684874, -20.376047576699225, -20.386628226209659, -20.514370268078657, -20.622159553662968, -20.158983816461848, -20.574079435944551, -20.542820824446697, -20.574267957674948, -20.473979388021256, -20.554267857741888, -20.585711733432213, -20.564191804571962]

# %% [markdown]
# ## Measure error on composite colors from bootstrapped templates

# %%
#bootstrap colors
boot_BmVs = []
for boots in boot_sn_arrays_all:
    boot_B = []
    boot_V = []
    for b in boots:
        Bflux = B.get_flux(b.wavelength[b.x1:b.x2], b.flux[b.x1:b.x2], axis = -1)
        Vflux = V.get_flux(b.wavelength[b.x1:b.x2], b.flux[b.x1:b.x2], axis = -1)
        Bmag = -2.5 * np.log10(Bflux) - B.Vega_zero_mag
        Vmag = -2.5 * np.log10(Vflux) - V.Vega_zero_mag
    #     Bmag = -2.5 * np.log10(Bflux) - B.AB_zero_mag
    #     Vmag = -2.5 * np.log10(Vflux) - V.AB_zero_mag
        boot_B.append(Bmag)
        boot_V.append(Vmag)
    BmV = np.asarray(boot_B) - np.asarray(boot_V)
    boot_BmVs.append(BmV)
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# ...
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent

# %%
low_errors = []
up_errors = []
boot_resids = []
percentile = erf(1/np.sqrt(2.))
low_pc = 0.5 - percentile*0.5
up_pc = 0.5 + percentile*0.5
for k in range(len(boot_sn_arrays_all)):
    resids = []
    comp_BmVs = np.asarray(comp_B[k]) - np.asarray(comp_V[k])
    resids.append(boot_BmVs[k] - comp_BmVs)
    resid_sort = np.sort(resids)[0]
    boot_resids.append(resid_sort)
    low_ind = np.round((len(resid_sort)-1) * low_pc).astype(int)
    up_ind = np.round((len(resid_sort)-1) * up_pc).astype(int)
    low_errors.append(np.absolute(resid_sort[low_ind]))
    up_errors.append(resid_sort[up_ind])
errors = [low_errors, up_errors]

# %%
#bootstrap colors dm15
boot_BmVs_dm15 = []
for boots in boot_sn_arrays_dm15:
    boot_B = []
    boot_V = []
    for b in boots:
        Bflux = B.get_flux(b.wavelength[b.x1:b.x2], b.flux[b.x1:b.x2], axis = -1)
        Vflux = V.get_flux(b.wavelength[b.x1:b.x2], b.flux[b.x1:b.x2], axis = -1)
        Bmag = -2.5 * np.log10(Bflux) - B.Vega_zero_mag
        Vmag = -2.5 * np.log10(Vflux) - V.Vega_zero_mag
    #     Bmag = -2.5 * np.log10(Bflux) - B.AB_zero_mag
    #     Vmag = -2.5 * np.log10(Vflux) - V.AB_zero_mag
        boot_B.append(Bmag)
        boot_V.append(Vmag)
    BmV = np.asarray(boot_B) - np.asarray(boot_V)
    boot_BmVs_dm15.append(BmV)
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# ...
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent

# %%
low_errors_dm15 = []
up_errors_dm15 = []
boot_resids_dm15 = []
for k in range(len(boot_sn_arrays_dm15)):
    resids = []
    comp_BmVs_dm15 = np.asarray(comp_B_dm15[k]) - np.asarray(comp_V_dm15[k])
    resids.append(boot_BmVs_dm15[k] - comp_BmVs_dm15)
    resid_sort = np.sort(resids)[0]
    boot_resids_dm15.append(resid_sort)
    low_ind = np.round((len(resid_sort)-1) * low_pc).astype(int)
    up_ind = np.round((len(resid_sort)-1) * up_pc).astype(int)
    low_errors_dm15.append(np.absolute(resid_sort[low_ind]))
    up_errors_dm15.append(resid_sort[up_ind])
errors_dm15 = [low_errors_dm15, up_errors_dm15]

# %%
dm15s = []
for comp in composites_all:
    dm15s.append(np.average(comp.dm15_array[comp.x1:comp.x2]))
print np.average(dm15s)
dm15s = []
for comp in composites_dm15:
    dm15s.append(np.average(comp.dm15_array[comp.x1:comp.x2]))
print np.average(dm15s)
# Out:
# 1.14309991448
# 1.06400126081

# %%
# Comp_BV = [-0.12563546 -0.15561324 -0.14673738 -0.1268233  -0.10699947 -0.08366862
#  -0.03187069  0.03148084  0.06781218  0.13725144  0.23507621  0.32351876
#   0.36256588  0.41146666  0.5716034   0.67588858  0.77341028  0.85195801
#   0.95633946  0.98262451  0.98191943  0.96241957  0.94440275  0.9405236
#   0.81568782  0.75855114]
# Comp_err = [[0.026675651247156651, 0.031365897412193533, 0.028532962885481794, 0.031216962099435364, 0.018832239420536467, 0.027376933492110567, 0.046882649876842208, 0.023850727456736109, 0.028121755574929352, 0.050264648829823955, 0.046598657865732918, 0.019496048389047616, 0.028795135717313514, 0.039144667725928173, 0.061833863773202324, 0.029287013081791713, 0.052773316287471062, 0.04483940826726851, 0.026825973913815915, 0.042554113217917688, 0.044222091113120143, 0.033390780683031807, 0.045908265173554952, 0.032778608909232787, 0.057374400282501625, 0.063763394898415982], [0.023993201641609119, 0.031151963546598438, 0.027424028058224081, 0.01588879775144747, 0.023646720748555339, 0.043553118763693277, 0.047040296527850245, 0.039142212551443123, 0.023187585313511505, 0.018728045093133971, 0.02546172402733049, 0.065120782115215547, 0.030989785857119756, 0.025262758319609446, 0.061657806729261466, 0.032755532155626099, 0.011914686921592477, 0.035514381076218626, 0.037363686244905381, 0.024868090208865823, 0.025245788450568796, 0.038197685748254884, 0.035281283747600867, 0.012449073144740197, 0.032349344777504285, 0.0026469786813585472]]
# Comp_BV_dm15 = [-0.21674734 -0.18635036 -0.20691521 -0.20597695 -0.17871014 -0.12680919
#  -0.13290817 -0.05201288  0.003264    0.03053745  0.11887135  0.1699835
#   0.29491897  0.36171293  0.53950772  0.64131565  0.75533329  0.85940579
#   0.85017406  1.02148457  1.00235208  0.9695069   0.98395725  0.88465683
#   0.78947763  0.80751822]
# Comp_err:  [[0.042882793006732811, 0.029695277373416928, 0.033285065845095829, 0.01164947168584618, 0.035603550303441978, 0.029482093853967939, 0.010961900063943375, 0.024714052500446115, 0.01488842682293523, 0.035070511139405625, 0.034477839619540873, 0.034372273556286359, 0.035791968562033816, 0.047301089321830858, 0.10920281880335025, 0.049030228137748821, 0.080119080965555867, 0.073723758036805975, 0.038858693997784854, 0.070953693727997091, 0.069249248905808969, 0.061597925017249366, 0.04985542720709546, 0.022601192012899674, 0.026596631558792438, 0.041564340123684929], [0.07621037746082493, 0.017441385430643663, 0.019167419942043296, 0.030138444638090789, 0.027284247914046489, 0.020776211082594642, 0.067987464014741761, 0.030321516429907547, 0.014274583606880498, 0.028603988933884494, 0.030763222323773931, 0.043767400690928326, 0.02944511814683537, 0.038164193429540916, 0.076627382214311979, 0.026598763427148953, 0.037009950869091313, 0.060110958702701112, 0.053159894470834246, 0.049607796688562189, 0.044260656141812404, 0.056618424975763304, 0.040641748987059856, 0.058705554766913082, 0.033998520825115008, 0.020257811282576199]]

# %%
color_dict = {"Comp": "#000080", "Hsiao": "orange", "Nugent": "turquoise", "SALT-II": "black"}
plt.rc('font', family='serif')
plt.figure(num = 1, dpi = 100, figsize = [10,7])
plt.minorticks_on()
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
plt.tick_params(
    which='major', 
    bottom='on', 
    top='on',
    left='on',
    right='on',
    length=10)
plt.tick_params(
    which='minor', 
    bottom='on', 
    top='on',
    left='on',
    right='on',
    length=5)
plt.xlabel('Rest-Frame Days Since B-Band Maximum', fontsize = 20)
plt.ylabel('B - V (mag)', fontsize = 20)
plt.plot(phases_h, np.asarray(hsiao_B)-np.asarray(hsiao_V), color = color_dict['Hsiao'], label = 'Hsiao', linewidth=3)
plt.plot(phases_n, np.asarray(nug_B)-np.asarray(nug_V), color = color_dict['Nugent'], label = 'Nugent', linewidth=3)
plt.plot(phases_s, np.asarray(salt_B)-np.asarray(salt_V), color = color_dict['SALT-II'],label='SALT2', linewidth=3)
plt.errorbar(comp_phases, np.asarray(comp_B) - np.asarray(comp_V), yerr=errors, fmt='s', markersize=8, color = "crimson", label = 'Composite Spectra')
plt.errorbar(comp_phases_dm15, np.asarray(comp_B_dm15) - np.asarray(comp_V_dm15), yerr=errors_dm15, fmt='*', markersize=13, color = color_dict['Comp'], label = 'Composite Spectra \n($0.95 \leq \Delta m_{15}$ (B) $\leq 1.15$)')
plt.xlim([-19,60])
plt.ylim([-.5,1.3])
plt.legend(loc='best', bbox_to_anchor=(0.5, -0.05, 0.48, 0.5),numpoints=1, fontsize=17)
plt.savefig('../../../Paper_Drafts/template_comparisons_updated/color_curve.pdf', dpi = 300, bbox_inches = 'tight')
# plt.savefig('../../../FLASH/color_curve.png', dpi = 300, bbox_inches = 'tight')
print 'Last Run: '
print 'Comp B-V:', np.asarray(comp_B) - np.asarray(comp_V)
print 'Comp err: ', errors
print 'Comp B-V dm15: ', np.asarray(comp_B_dm15) - np.asarray(comp_V_dm15)
print 'Comp err: ', errors_dm15
plt.show()
# Out:
# Last Run:
# Comp B-V: [-0.12563546 -0.15561324 -0.14673738 -0.1268233  -0.10699947 -0.08366862
#  -0.03187069  0.03148084  0.06781218  0.13725144  0.23507621  0.32351876
#   0.36256588  0.41146666  0.5716034   0.67588858  0.77341028  0.85195801
#   0.95633946  0.98262451  0.98191943  0.96241957  0.94440275  0.9405236
#   0.81568782  0.75855114]
# Comp err:  [[0.026675651247156651, 0.031365897412193533, 0.028532962885481794, 0.031216962099435364, 0.018832239420536467, 0.027376933492110567, 0.046882649876842208, 0.023850727456736109, 0.028121755574929352, 0.050264648829823955, 0.046598657865732918, 0.019496048389047616, 0.028795135717313514, 0.039144667725928173, 0.061833863773202324, 0.029287013081791713, 0.052773316287471062, 0.04483940826726851, 0.026825973913815915, 0.042554113217917688, 0.044222091113120143, 0.033390780683031807, 0.045908265173554952, 0.032778608909232787, 0.057374400282501625, 0.063763394898415982], [0.023993201641609119, 0.031151963546598438, 0.027424028058224081, 0.01588879775144747, 0.023646720748555339, 0.043553118763693277, 0.047040296527850245, 0.039142212551443123, 0.023187585313511505, 0.018728045093133971, 0.02546172402733049, 0.065120782115215547, 0.030989785857119756, 0.025262758319609446, 0.061657806729261466, 0.032755532155626099, 0.011914686921592477, 0.035514381076218626, 0.037363686244905381, 0.024868090208865823, 0.025245788450568796, 0.038197685748254884, 0.035281283747600867, 0.012449073144740197, 0.032349344777504285, 0.0026469786813585472]]
# Comp B-V dm15:  [-0.21674734 -0.18635036 -0.20691521 -0.20597695 -0.17871014 -0.12680919
#  -0.13290817 -0.05201288  0.003264    0.03053745  0.11887135  0.1699835
#   0.29491897  0.36171293  0.53950772  0.64131565  0.75533329  0.85940579
#   0.85017406  1.02148457  1.00235208  0.9695069   0.98395725  0.88465683
#   0.78947763  0.80751822]
# Comp err:  [[0.042882793006732811, 0.029695277373416928, 0.033285065845095829, 0.01164947168584618, 0.035603550303441978, 0.029482093853967939, 0.010961900063943375, 0.024714052500446115, 0.01488842682293523, 0.035070511139405625, 0.034477839619540873, 0.034372273556286359, 0.035791968562033816, 0.047301089321830858, 0.10920281880335025, 0.049030228137748821, 0.080119080965555867, 0.073723758036805975, 0.038858693997784854, 0.070953693727997091, 0.069249248905808969, 0.061597925017249366, 0.04985542720709546, 0.022601192012899674, 0.026596631558792438, 0.041564340123684929], [0.07621037746082493, 0.017441385430643663, 0.019167419942043296, 0.030138444638090789, 0.027284247914046489, 0.020776211082594642, 0.067987464014741761, 0.030321516429907547, 0.014274583606880498, 0.028603988933884494, 0.030763222323773931, 0.043767400690928326, 0.02944511814683537, 0.038164193429540916, 0.076627382214311979, 0.026598763427148953, 0.037009950869091313, 0.060110958702701112, 0.053159894470834246, 0.049607796688562189, 0.044260656141812404, 0.056618424975763304, 0.040641748987059856, 0.058705554766913082, 0.033998520825115008, 0.020257811282576199]]

# %% [markdown]
# ## Foley08 Templates

# %%
wavelength_f08_m7, flux_f08_m7, low_f08_m7, up_f08_m7 = np.loadtxt('../data/foley/foley=0.01=-6.6=-0.08=0.37=47.flm', unpack = True)
wavelength_f08_0, flux_f08_0, low_f08_0, up_f08_0 = np.loadtxt('../data/foley/foley=0.01=-0.3=0.43=0.04=12.flm', unpack = True)
wavelength_f08_p6, flux_f08_p6, low_f08_p6, up_f08_p6 = np.loadtxt('../data/foley/foley=0.01=6.2=0.08=0.28=45.flm', unpack = True)
wavelength_f08_p14, flux_f08_p14, low_f08_p14, up_f08_p14 = np.loadtxt('../data/foley/foley=0.01=13.8=0.06=0.42=43.flm', unpack = True)
wavelength_f08_p19, flux_f08_p19, low_f08_p19, up_f08_p19 = np.loadtxt('../data/foley/foley=0.01=19.4=-0.02=0.59=26.flm', unpack = True)

# %%
#-1week
wave_interp_f08_m7 = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_f08_m7 = inter.splrep(wavelength_f08_m7, flux_f08_m7)
low_spl_f08_m7 = inter.splrep(wavelength_f08_m7, low_f08_m7)
up_spl_f08_m7 = inter.splrep(wavelength_f08_m7, up_f08_m7)

flux_interp_f08_m7 = inter.splev(wave_interp_f08_m7, flux_spl_f08_m7, ext = 3)
low_interp_f08_m7 = inter.splev(wave_interp_f08_m7, low_spl_f08_m7, ext = 3)
up_interp_f08_m7 = inter.splev(wave_interp_f08_m7, up_spl_f08_m7, ext = 3)

f08_template_m7 = composite.supernova(wave_interp_f08_m7, flux_interp_f08_m7, low_conf=low_interp_f08_m7, up_conf=up_interp_f08_m7)
f08_template_m7.phase_array = np.zeros(len(flux_interp_f08_m7))

#max
wave_interp_f08_0 = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_f08_0 = inter.splrep(wavelength_f08_0, flux_f08_0)
low_spl_f08_0 = inter.splrep(wavelength_f08_0, low_f08_0)
up_spl_f08_0 = inter.splrep(wavelength_f08_0, up_f08_0)

flux_interp_f08_0 = inter.splev(wave_interp_f08_0, flux_spl_f08_0, ext = 3)
low_interp_f08_0 = inter.splev(wave_interp_f08_0, low_spl_f08_0, ext = 3)
up_interp_f08_0 = inter.splev(wave_interp_f08_0, up_spl_f08_0, ext = 3)

f08_template_0 = composite.supernova(wave_interp_f08_0, flux_interp_f08_0, low_conf=low_interp_f08_0, up_conf=up_interp_f08_0)
f08_template_0.phase_array = np.zeros(len(flux_interp_f08_0))

#+1week
wave_interp_f08_p6 = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_f08_p6 = inter.splrep(wavelength_f08_p6, flux_f08_p6)
low_spl_f08_p6 = inter.splrep(wavelength_f08_p6, low_f08_p6)
up_spl_f08_p6 = inter.splrep(wavelength_f08_p6, up_f08_p6)

flux_interp_f08_p6 = inter.splev(wave_interp_f08_p6, flux_spl_f08_p6, ext = 3)
low_interp_f08_p6 = inter.splev(wave_interp_f08_p6, low_spl_f08_p6, ext = 3)
up_interp_f08_p6 = inter.splev(wave_interp_f08_p6, up_spl_f08_p6, ext = 3)

f08_template_p6 = composite.supernova(wave_interp_f08_p6, flux_interp_f08_p6, low_conf=low_interp_f08_p6, up_conf=up_interp_f08_p6)
f08_template_p6.phase_array = np.zeros(len(flux_interp_f08_m7))

#+2week
wave_interp_f08_p14 = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_f08_p14 = inter.splrep(wavelength_f08_p14, flux_f08_p14)
low_spl_f08_p14 = inter.splrep(wavelength_f08_p14, low_f08_p14)
up_spl_f08_p14 = inter.splrep(wavelength_f08_p14, up_f08_p14)

flux_interp_f08_p14 = inter.splev(wave_interp_f08_p14, flux_spl_f08_p14, ext = 3)
low_interp_f08_p14 = inter.splev(wave_interp_f08_p14, low_spl_f08_p14, ext = 3)
up_interp_f08_p14 = inter.splev(wave_interp_f08_p14, up_spl_f08_p14, ext = 3)

f08_template_p14 = composite.supernova(wave_interp_f08_p14, flux_interp_f08_p14, low_conf=low_interp_f08_p14, up_conf=up_interp_f08_p14)
f08_template_p14.phase_array = np.zeros(len(flux_interp_f08_p14))

#+19days
wave_interp_f08_p19 = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_f08_p19 = inter.splrep(wavelength_f08_p19, flux_f08_p19)
low_spl_f08_p19 = inter.splrep(wavelength_f08_p19, low_f08_p19)
up_spl_f08_p19 = inter.splrep(wavelength_f08_p19, up_f08_p19)

flux_interp_f08_p19 = inter.splev(wave_interp_f08_p19, flux_spl_f08_p19, ext = 3)
low_interp_f08_p19 = inter.splev(wave_interp_f08_p19, low_spl_f08_p19, ext = 3)
up_interp_f08_p19 = inter.splev(wave_interp_f08_p19, up_spl_f08_p19, ext = 3)

f08_template_p19 = composite.supernova(wave_interp_f08_p19, flux_interp_f08_p19, low_conf=low_interp_f08_p19, up_conf=up_interp_f08_p19)
f08_template_p19.phase_array = np.zeros(len(flux_interp_f08_p19))

# %%
test_template = f08_template_p6
plt.plot(test_template.wavelength[test_template.x1:test_template.x2],test_template.flux[test_template.x1:test_template.x2])
plt.fill_between(test_template.wavelength[test_template.x1:test_template.x2],test_template.low_conf[test_template.x1:test_template.x2], test_template.up_conf[test_template.x1:test_template.x2], color='b',alpha=.5)
# plt.ylim([-1,12])
plt.show()

# %% [markdown]
# ## Spectral feature comparison at various epochs

# %%
query_db.set_min_num_spec(composites, 5)
comps_and_temps = []
for comp in composites:
    comps_and_temps.append(comp)
srange = np.where((s_template.wavelength > 2000.) & (s_template.wavelength < 9200))[0]
s_template.x1 = srange[0]
s_template.x2 = srange[-1]
comps_and_temps.append(h_template)
comps_and_temps.append(f08_template_0)
comps_and_temps.append(n_template)
comps_and_temps.append(s_template)
comps_and_temps, scales = composite.optimize_scales(comps_and_temps, comps_and_temps[2], True)

print np.average(comps_and_temps[0].dm15_array[comps_and_temps[0].x1:comps_and_temps[0].x2])
print np.average(comps_and_temps[1].dm15_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
comps_and_temps[0].name = "Comp"
comps_and_temps[1].name = "Comp"
comps_and_temps[2].name = "Hsiao"
comps_and_temps[3].name = "Foley08"
comps_and_temps[4].name = "Nugent"
comps_and_temps[5].name = "SALT2"
# for comp in comps_and_temps:
#     v_strong, si_min_wave = sa.measure_velocity(comp.wavelength[comp.x1:comp.x2],comp.flux[comp.x1:comp.x2], 5900., 6300.)
#     print comp.name, 'v = ', v_strong
#     r = sa.measure_si_ratio(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], vexp = .002, plot=False)
#     print comp.name, 'r = ', r
# query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2]],include_spec_bin=True, legend_labels = ["Composite Spectrum", "Hsiao",])
# Out:
# 1.16694976714
# 1.10551170049

# %%
# query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2]], include_spec_bin=True, legend_labels = ["Composite Spectrum \n($ 1.02 < \Delta m_{15} (B) < 1.24$)", "Hsiao",])

# %%
query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4], comps_and_temps[5]], include_spec_bin=True, legend_labels = ["Composite Spectrum", "Hsiao", "Foley08","Nugent","SALT2"], rm_last_label=True, text='Maximum Light', savename = 'template_comparisons_updated/temp_max_light_all')
# query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], include_spec_bin=True, legend_labels = ["Composite Spectrum", "Hsiao", "Nugent","SALT2"])
# Out:
# Phase:  0.195240776393
# dm15:  1.16694976714
# Redshift:  0.0151395010649

# %%
# query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], include_spec_bin=True, savename = 'max_light_temp_comparison_dm15')
query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4], comps_and_temps[5]], include_spec_bin=True, rm_last_label=True, legend_labels = ["Composite Spectrum \n($ 1.02 < \Delta m_{15} (B) < 1.24$)", "Hsiao","Foley08", "Nugent","SALT2"], text='Maximum Light',savename = 'template_comparisons_updated/temp_max_light_dm15')
# query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], include_spec_bin=True, legend_labels = ["Composite Spectrum \n($ 1.02 < \Delta m_{15} (B) < 1.24$)", "Hsiao", "Nugent","SALT2"])
# Out:
# Phase:  0.0646409880413
# dm15:  1.10551170049
# Redshift:  0.0137985146173

# %%
comps_and_temps[1].name = "Comp2"
query_db.scaled_plot([comps_and_temps[0], comps_and_temps[1]], include_spec_bin=True, rm_last_label=True, legend_labels = ["Total Composite Spectrum","Composite Spectrum \n($ 1.02 < \Delta m_{15} (B) < 1.24$)"],text ='Maximum Light', savename = 'template_comparisons_updated/max_light_total_bin_comp')
# Out:
# Phase:  0.195240776393
# dm15:  1.16694976714
# Redshift:  0.0151395010649
# Phase:  0.0646409880413
# dm15:  1.10551170049
# Redshift:  0.0137985146173

# %%
wave_h_1week = []
flux_h_1week = []
for i, phase in enumerate(phase_h):
    if float(phase) == 7.0:
        wave_h_1week.append(wavelength_hsiao[i])
        flux_h_1week.append(flux_hsiao[i])

# %%
wave_interp_h_1week = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_h_1week = inter.splrep(wave_h_1week, flux_h_1week)
flux_interp_h_1week = inter.splev(wave_interp_h_1week, flux_spl_h_1week, ext = 3)
h_template_1week = composite.supernova(wave_interp_h_1week, flux_interp_h_1week)
h_template_1week.phase_array = np.zeros(len(flux_interp_h_1week))

# %%
wave_n_1week = []
flux_n_1week = []
for i, phase in enumerate(epoch_n):
    if float(phase) == 27.0:
        wave_n_1week.append(wavelength_nugent[i])
        flux_n_1week.append(flux_nugent[i])

# %%
wave_interp_n_1week = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_n_1week = inter.splrep(wave_n_1week, flux_n_1week)
flux_interp_n_1week = inter.splev(wave_interp_n_1week, flux_spl_n_1week, ext = 3)
n_template_1week = composite.supernova(wave_interp_n_1week,flux_interp_n_1week)
n_template_1week.phase_array = np.zeros(len(flux_interp_n_1week))

# %%
wave_s_1week = []
flux_s_1week = []
for i, phase in enumerate(phase_s):
    if float(phase) == 7.0:
        wave_s_1week.append(wavelength_salt[i])
        flux_s_1week.append(flux_salt[i])

# %%
wave_interp_s_1week = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_s_1week = inter.splrep(wave_s_1week, flux_s_1week)
flux_interp_s_1week = inter.splev(wave_interp_s_1week, flux_spl_s_1week, ext = 3)
s_template_1week = composite.supernova(wave_interp_s_1week,flux_interp_s_1week)
s_template_1week.phase_array = np.zeros(len(flux_interp_s_1week))

# %%
query_1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6 and phase < 8",
         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 6 and phase <= 8 and ((dm15_source >= 1. and dm15_source < 1.2) or (dm15_from_fits >= 1. and dm15_from_fits < 1.2)) and Supernovae.SN !='2002bf'"]

# %%
composites_1week, sn_arrays_1week, boot_sn_arrays_1week = query_db.main(len(query_1week), query_1week, boot='b', medmean=1, gini_balance=True, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6 and phase < 8
# Collecting data...
# 172 questionable files currently ignored
# (20, 'questionable spectra removed', 177, 'spectra left')
# (3, 'Peculiar Ias removed', 174, 'spectra left')
# 140 spectra with host corrections
# 172 questionable files currently ignored
# 99 valid SNe found
# Arrays cleaned
# 3 spectra may have telluric contamination
# 99 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 10 iterations
# Done.
# composite.py:979: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if template.RMSE != None:
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 6 and phase <= 8 and ((dm15_source >= 1. and dm15_source < 1.2) or (dm15_from_fits >= 1. and dm15_from_fits < 1.2)) and Supernovae.SN !='2002bf'
# Collecting data...
# 172 questionable files currently ignored
# (6, 'questionable spectra removed', 46, 'spectra left')
# (0, 'Peculiar Ias removed', 46, 'spectra left')
# 42 spectra with host corrections
# 172 questionable files currently ignored
# 35 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 35 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(composites_1week, 5)

comps_and_temps = []
for comp in composites_1week:
    comps_and_temps.append(comp)

srange = np.where((s_template_1week.wavelength > 2000.) & (s_template_1week.wavelength < 9200))[0]
s_template_1week.x1 = srange[0]
s_template_1week.x2 = srange[-1]

comps_and_temps.append(h_template_1week)
comps_and_temps.append(f08_template_p6)
comps_and_temps.append(n_template_1week)
comps_and_temps.append(s_template_1week)
comps_and_temps, scales = composite.optimize_scales(comps_and_temps, comps_and_temps[0], True)

print np.average(comps_and_temps[0].dm15_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
print np.average(comps_and_temps[1].dm15_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
comps_and_temps[0].name = "Comp"
comps_and_temps[1].name = "Comp"
comps_and_temps[2].name = "Hsiao"
comps_and_temps[3].name = "Foley08"
comps_and_temps[4].name = "Nugent"
comps_and_temps[5].name = "SALT2"
# for comp in comps_and_temps:
#     v_strong, si_min_wave = sa.measure_velocity(comp.wavelength[comp.x1:comp.x2],comp.flux[comp.x1:comp.x2], 5900., 6300.)
#     print comp.name, 'v = ', v_strong, si_min_wave
query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4], comps_and_temps[5]], include_spec_bin=True, 
                     legend_labels = ["Composite Spectrum", "Hsiao", "Foley08","Nugent","SALT2"], text='+1 Week', rm_last_label=True, zoom=True,
                     savename = 'template_comparisons_updated/temp_p7_all')
# query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], legend_labels = ["Composite Spectrum", "Hsiao", "Nugent","SALT2"])
# Out:
# 1.14855852773
# 1.09398934165
# Phase:  6.84851181753
# dm15:  1.14881538739
# Redshift:  0.0192747248784

# %%
query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4], comps_and_temps[5]], include_spec_bin=True, 
                     legend_labels = ["Composite Spectrum \n($ 1.0 < \Delta m_{15} (B) < 1.2$)", "Hsiao", "Foley08","Nugent","SALT2"],
                     rm_last_label=True, text='$+$1 Week',
                     savename = 'template_comparisons_updated/temp_p7_dm15')
# query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], legend_labels = ["Composite Spectrum \n($ 1.0 < \Delta m_{15} (B) < 1.2$)", "Hsiao", "Nugent","SALT2"])
# Out:
# Phase:  7.18803927269
# dm15:  1.09398934165
# Redshift:  0.0208532876193

# %%
wave_h_m1week = []
flux_h_m1week = []
for i, phase in enumerate(phase_h):
    if float(phase) == -7.0:
        wave_h_m1week.append(wavelength_hsiao[i])
        flux_h_m1week.append(flux_hsiao[i])

# %%
wave_interp_h_m1week = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_h_m1week = inter.splrep(wave_h_m1week, flux_h_m1week)
flux_interp_h_m1week = inter.splev(wave_interp_h_m1week, flux_spl_h_m1week, ext = 3)
h_template_m1week = composite.supernova(wave_interp_h_m1week, flux_interp_h_m1week)
h_template_m1week.phase_array = np.zeros(len(flux_interp_h_m1week))

# %%
wave_n_m1week = []
flux_n_m1week = []
for i, phase in enumerate(epoch_n):
    if float(phase) == 13.0:
        wave_n_m1week.append(wavelength_nugent[i])
        flux_n_m1week.append(flux_nugent[i])

# %%
wave_interp_n_m1week = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_n_m1week = inter.splrep(wave_n_m1week, flux_n_m1week)
flux_interp_n_m1week = inter.splev(wave_interp_n_m1week, flux_spl_n_m1week, ext = 3)
n_template_m1week = composite.supernova(wave_interp_n_m1week, flux_interp_n_m1week)
n_template_m1week.phase_array = np.zeros(len(flux_interp_n_m1week))

# %%
wave_s_m1week = []
flux_s_m1week = []
for i, phase in enumerate(phase_s):
    if float(phase) == -7.0:
        wave_s_m1week.append(wavelength_salt[i])
        flux_s_m1week.append(flux_salt[i])

# %%
wave_interp_s_m1week = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_s_m1week = inter.splrep(wave_s_m1week, flux_s_m1week)
flux_interp_s_m1week = inter.splev(wave_interp_s_m1week, flux_spl_s_m1week, ext = 3)
s_template_m1week = composite.supernova(wave_interp_s_m1week, flux_interp_s_m1week)
s_template_m1week.phase_array = np.zeros(len(flux_interp_s_m1week))

# %%
query_m1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -8 and phase < -6",
         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -8 and phase <= -6 and ((dm15_source >= .98 and dm15_source < 1.18) or (dm15_from_fits >= .98 and dm15_from_fits < 1.18)) and Supernovae.SN !='2002bf'"]

# %%
composites_m1week, sn_arrays_m1week, boot_sn_arrays_m1week = query_db.main(len(query_m1week), query_m1week, boot='b', medmean=1, gini_balance=True, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -8 and phase < -6
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050605-hst.flm', u'sn2005m-20050128-hst.flm']
# (10, 'questionable spectra removed', 148, 'spectra left')
# (2, 'Peculiar Ias removed', 146, 'spectra left')
# 106 spectra with host corrections
# 172 questionable files currently ignored
# 67 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 67 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 11 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -8 and phase <= -6 and ((dm15_source >= .98 and dm15_source < 1.18) or (dm15_from_fits >= .98 and dm15_from_fits < 1.18)) and Supernovae.SN !='2002bf'
# Collecting data...
# 172 questionable files currently ignored
# Generate variance failed for:  [u'sn2005cf-20050605-hst.flm']
# (3, 'questionable spectra removed', 46, 'spectra left')
# (0, 'Peculiar Ias removed', 46, 'spectra left')
# 37 spectra with host corrections
# 172 questionable files currently ignored
# 25 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 25 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 9 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(composites_m1week, 5)
comps_and_temps = []
for comp in composites_m1week:
    comps_and_temps.append(comp)
    
srange = np.where((s_template_m1week.wavelength > 2000.) & (s_template_m1week.wavelength < 9200))[0]
s_template_m1week.x1 = srange[0]
s_template_m1week.x2 = srange[-1]

comps_and_temps.append(h_template_m1week)
comps_and_temps.append(f08_template_m7)
comps_and_temps.append(n_template_m1week)
comps_and_temps.append(s_template_m1week)
comps_and_temps, scales = composite.optimize_scales(comps_and_temps, comps_and_temps[0], True)

print 'dm15:'
print np.average(comps_and_temps[0].dm15_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
print np.average(comps_and_temps[1].dm15_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
print 'phase:'
print np.average(comps_and_temps[0].phase_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
print np.average(comps_and_temps[1].phase_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
comps_and_temps[0].name = "Comp"
comps_and_temps[1].name = "Comp"
comps_and_temps[2].name = "Hsiao"
comps_and_temps[3].name = "Foley08"
comps_and_temps[4].name = "Nugent"
comps_and_temps[5].name = "SALT2"
# for comp in comps_and_temps:
#     v_strong, si_min_wave = sa.measure_velocity(comp.wavelength[comp.x1:comp.x2],comp.flux[comp.x1:comp.x2], 5900., 6300.)
#     print comp.name, 'v = ', v_strong
query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4], comps_and_temps[5]], include_spec_bin=True, 
                     legend_labels = ["Composite Spectrum", "Hsiao", "Foley08", "Nugent","SALT2"], 
                     rm_last_label=True, text='$-$1 Week',
                     savename = 'template_comparisons_updated/temp_m7_all')
# query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], legend_labels = ["Composite Spectrum", "Hsiao", "Nugent","SALT2"])
# Out:
# dm15:
# 1.10885390425
# 1.07124913215
# phase:
# -6.94672578876
# -6.92899087054
# Phase:  -6.94004431082
# dm15:  1.10724188772
# Redshift:  0.0144760464564

# %%
query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4], comps_and_temps[5]], include_spec_bin=True, 
                     legend_labels = ["Composite Spectrum \n($ 0.98 < \Delta m_{15} (B) < 1.18$)", "Hsiao", "Foley08","Nugent","SALT2"], 
                     rm_last_label=True, text='$-$1 Week',
                     savename = 'template_comparisons_updated/temp_m7_dm15')
# query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], legend_labels = ["Composite Spectrum \n($ 0.98 < \Delta m_{15} (B) < 1.18$)", "Hsiao", "Nugent","SALT2"])
# Out:
# Phase:  -6.92899087054
# dm15:  1.07124913215
# Redshift:  0.0124535934784

# %%
wave_h_1month = []
flux_h_1month = []
for i, phase in enumerate(phase_h):
    if float(phase) == 30.0:
        wave_h_1month.append(wavelength_hsiao[i])
        flux_h_1month.append(flux_hsiao[i])

# %%
wave_interp_h_1month = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_h_1month = inter.splrep(wave_h_1month, flux_h_1month)
flux_interp_h_1month = inter.splev(wave_interp_h_1month, flux_spl_h_1month, ext = 3)
h_template_1month = composite.supernova(wave_interp_h_1month, flux_interp_h_1month)
h_template_1month.phase_array = np.zeros(len(flux_interp_h_1month))

# %%
wave_n_1month = []
flux_n_1month = []
for i, phase in enumerate(epoch_n):
    if float(phase) == 50.0:
        wave_n_1month.append(wavelength_nugent[i])
        flux_n_1month.append(flux_nugent[i])

# %%
wave_interp_n_1month = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_n_1month = inter.splrep(wave_n_1month, flux_n_1month)
flux_interp_n_1month = inter.splev(wave_interp_n_1month, flux_spl_n_1month, ext = 3)
n_template_1month = composite.supernova(wave_interp_n_1month, flux_interp_n_1month)
n_template_1month.phase_array = np.zeros(len(flux_interp_n_1month))

# %%
wave_s_1month = []
flux_s_1month = []
for i, phase in enumerate(phase_s):
    if float(phase) == 30.0:
        wave_s_1month.append(wavelength_salt[i])
        flux_s_1month.append(flux_salt[i])

# %%
wave_interp_s_1month = np.arange(1000., 12000., dtype=int, step=2)
flux_spl_s_1month = inter.splrep(wave_s_1month, flux_s_1month)
flux_interp_s_1month = inter.splev(wave_interp_s_1month, flux_spl_s_1month, ext = 3)
s_template_1month = composite.supernova(wave_interp_s_1month, flux_interp_s_1month)
s_template_1month.phase_array = np.zeros(len(flux_interp_s_1month))

# %%
query_1month = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28 and phase < 32",
         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 28 and phase <= 32 and ((dm15_source >= 1.0 and dm15_source < 1.2) or (dm15_from_fits >= 1.0 and dm15_from_fits < 1.2)) and Supernovae.SN !='2002bf'"]

# %%
composites_1month, sn_arrays_1month, boot_sn_arrays_tmonth = query_db.main(len(query_1month), query_1month, boot='b', medmean=1, gini_balance=True, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28 and phase < 32
# Collecting data...
# ERROR:  2002bo_20020421_0_2_00.dat None
# 172 questionable files currently ignored
# (8, 'questionable spectra removed', 150, 'spectra left')
# (4, 'Peculiar Ias removed', 146, 'spectra left')
# 125 spectra with host corrections
# 172 questionable files currently ignored
# 89 valid SNe found
# Arrays cleaned
# 4 spectra may have telluric contamination
# 89 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 12 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 28 and phase <= 32 and ((dm15_source >= 1.0 and dm15_source < 1.2) or (dm15_from_fits >= 1.0 and dm15_from_fits < 1.2)) and Supernovae.SN !='2002bf'
# Collecting data...
# ERROR:  2002bo_20020421_0_2_00.dat None
# 172 questionable files currently ignored
# (6, 'questionable spectra removed', 56, 'spectra left')
# (0, 'Peculiar Ias removed', 56, 'spectra left')
# 53 spectra with host corrections
# 172 questionable files currently ignored
# 37 valid SNe found
# Arrays cleaned
# 4 spectra may have telluric contamination
# 37 SNs with host corrections
# Creating composite...
# Gini balancing...
# Balanced after 6 iterations
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(composites_1month, 5)
comps_and_temps = []
for comp in composites_1month:
    comps_and_temps.append(comp)

srange = np.where((s_template_1month.wavelength > 2000.) & (s_template_1month.wavelength < 9200))[0]
s_template_1month.x1 = srange[0]
s_template_1month.x2 = srange[-1]

comps_and_temps.append(h_template_1month)
comps_and_temps.append(n_template_1month)
comps_and_temps.append(s_template_1month)
comps_and_temps, scales = composite.optimize_scales(comps_and_temps, comps_and_temps[0], True)

print 'dm15:'
print np.average(comps_and_temps[0].dm15_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
print np.average(comps_and_temps[1].dm15_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
print 'phase:'
print np.average(comps_and_temps[0].phase_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
print np.average(comps_and_temps[1].phase_array[comps_and_temps[1].x1:comps_and_temps[1].x2])
comps_and_temps[0].name = "Comp"
comps_and_temps[1].name = "Comp"
comps_and_temps[2].name = "Hsiao"
comps_and_temps[3].name = "Nugent"
comps_and_temps[4].name = "SALT2"
query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], include_spec_bin=True, 
                     legend_labels = ["Composite Spectrum", "Hsiao", "Nugent","SALT2"], text='$+$1 Month',
                     rm_last_label=True,
                     savename = 'template_comparisons_updated/temp_p30_all')
# query_db.scaled_plot([comps_and_temps[0], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], legend_labels = ["Composite Spectrum", "Hsiao", "Nugent","SALT2"])
# Out:
# dm15:
# 1.18333168381
# 1.08366708237
# phase:
# 29.7997267406
# 29.809989554
# Phase:  29.7946840506
# dm15:  1.18077012478
# Redshift:  0.0154614162088

# %%
query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], include_spec_bin=True, 
                     legend_labels = ["Composite Spectrum \n($ 0.95 < \Delta m_{15} (B) < 1.15$)", "Hsiao", "Nugent","SALT2"], 
                     rm_last_label=True, text='$+$1 Month',
                     savename = 'template_comparisons_updated/temp_p30_dm15')
# query_db.scaled_plot([comps_and_temps[1], comps_and_temps[2], comps_and_temps[3], comps_and_temps[4]], legend_labels = ["Composite Spectrum \n($ 0.95 < \Delta m_{15} (B) < 1.15$)", "Hsiao", "Nugent","SALT2"])
# Out:
# Phase:  29.809989554
# dm15:  1.08366708237
# Redshift:  0.0141841989954

# %% [markdown]
# ## 91t and 91bg nugent maximum light comparisons

# %%
query_91t = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1 and phase <= 1 and ((dm15_source <= .9) or (dm15_from_fits <= .9)) and Supernovae.SN !='2002bf'"]

# %%
composites_91t, sn_arrays_91t, boot_sn_arrays_91t = query_db.main(len(query_91t), query_91t, boot='b', medmean=1, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1 and phase <= 1 and ((dm15_source <= .9) or (dm15_from_fits <= .9)) and Supernovae.SN !='2002bf'
# Collecting data...
# 172 questionable files currently ignored
# (0, 'questionable spectra removed', 23, 'spectra left')
# (0, 'Peculiar Ias removed', 23, 'spectra left')
# 23 spectra with host corrections
# 172 questionable files currently ignored
# 15 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 15 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(composites_91t, 5)

# %%
comps_and_temps = []
for comp in composites_91t:
    comps_and_temps.append(comp)
comps_and_temps.append(n_template_91t)
comps_and_temps, scales = composite.optimize_scales(comps_and_temps, comps_and_temps[1], True)

print np.average(comps_and_temps[0].dm15_array[comps_and_temps[0].x1:comps_and_temps[0].x2])
comps_and_temps[0].name = "Comp"
comps_and_temps[1].name = "Nugent"
query_db.scaled_plot([comps_and_temps[0], comps_and_temps[1]], legend_labels = ["Composite Spectrum \n($ 0.75 < \Delta m_{15} (B) < 0.90$)", "Nugent-91T"])
# Out:
# 0.843894858993

# %%
query_91bg = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_source >= 1.8) or (dm15_from_fits >= 1.8)) and Supernovae.SN !='2002bf'"]

# %%
composites_91bg, sn_arrays_91bg, boot_sn_arrays_91bg = query_db.main(len(query_91bg), query_91bg, boot='b', medmean=1, verbose=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_source >= 1.8) or (dm15_from_fits >= 1.8)) and Supernovae.SN !='2002bf'
# Collecting data...
# 172 questionable files currently ignored
# (6, 'questionable spectra removed', 29, 'spectra left')
# (1, 'Peculiar Ias removed', 28, 'spectra left')
# 23 spectra with host corrections
# 172 questionable files currently ignored
# 10 valid SNe found
# Arrays cleaned
# 0 spectra may have telluric contamination
# 10 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# computing confidence intervals...

# %%
query_db.set_min_num_spec(composites_91bg, 5)
comps_and_temps = []
for comp in composites_91bg:
    comps_and_temps.append(comp)
comps_and_temps.append(n_template_91bg)
comps_and_temps, scales = composite.optimize_scales(comps_and_temps, comps_and_temps[1], True)

print np.average(comps_and_temps[0].dm15_array[comps_and_temps[0].x1:comps_and_temps[0].x2])
comps_and_temps[0].name = "Comp"
comps_and_temps[1].name = "Nugent"
query_db.scaled_plot([comps_and_temps[0], comps_and_temps[1]], include_spec_bin=True, 
                     legend_labels = ["Composite Spectrum \n($\Delta m_{15} (B) > 1.8$)", "Nugent-91bg"], 
                     rm_last_label=True, expand_ratio=True, text='Maximum Light',
                     savename = 'template_comparisons_updated/temp_max_light_91bg')
# query_db.scaled_plot([comps_and_temps[0], comps_and_temps[1]], legend_labels = ["Composite Spectrum \n($\Delta m_{15} (B) > 1.8$)", "Nugent-91bg"])
# Out:
# 1.91399447567
# Phase:  0.657976815866
# dm15:  1.91399447567
# Redshift:  0.00824983471842
