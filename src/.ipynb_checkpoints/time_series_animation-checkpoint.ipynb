# %%
import query_db

# %%
query_strings = ["SELECT * FROM Supernovae where phase < -11",
                 "SELECT * FROM Supernovae where phase >= -11 and phase < -10",
                 "SELECT * FROM Supernovae where phase >= -10 and phase < -9",
                 "SELECT * FROM Supernovae where phase >= -9 and phase < -8.5",
                 "SELECT * FROM Supernovae where phase >= -8.5 and phase < -8",
                 "SELECT * FROM Supernovae where phase >= -8 and phase < -7.5",
                 "SELECT * FROM Supernovae where phase >= -7.5 and phase < -7",
                 "SELECT * FROM Supernovae where phase >= -7 and phase < -6.5",
                 "SELECT * FROM Supernovae where phase >= -6.5 and phase < -6",
                 "SELECT * FROM Supernovae where phase >= -6 and phase < -5.5",
                 "SELECT * FROM Supernovae where phase >= -5.5 and phase < -5",
                 "SELECT * FROM Supernovae where phase >= -5 and phase < -4.5",
                 "SELECT * FROM Supernovae where phase >= -4.5 and phase < -4",
                 "SELECT * FROM Supernovae where phase >= -4 and phase < -3.5",
                 "SELECT * FROM Supernovae where phase >= -3.5 and phase < -3",
                 "SELECT * FROM Supernovae where phase >= -3 and phase < -2.5",
                 "SELECT * FROM Supernovae where phase >= -2.5 and phase < -2",
                 "SELECT * FROM Supernovae where phase >= -2 and phase < -1.5",
                 "SELECT * FROM Supernovae where phase >= -1.5 and phase < -1",
                 "SELECT * FROM Supernovae where phase >= -1 and phase < -.5",
                 "SELECT * FROM Supernovae where phase >= -.5 and phase < 0",
                 "SELECT * FROM Supernovae where phase >= 0 and phase < .5",
                 "SELECT * FROM Supernovae where phase >= .5 and phase < 1",
                 "SELECT * FROM Supernovae where phase >= 1 and phase < 1.5",
                 "SELECT * FROM Supernovae where phase >= 1.5 and phase < 2",
                 "SELECT * FROM Supernovae where phase >= 2 and phase < 2.5",
                 "SELECT * FROM Supernovae where phase >= 2.5 and phase < 3",
                 "SELECT * FROM Supernovae where phase >= 3 and phase < 3.5",
                 "SELECT * FROM Supernovae where phase >= 3.5 and phase < 4",
                 "SELECT * FROM Supernovae where phase >= 4 and phase < 4.5",
                 "SELECT * FROM Supernovae where phase >= 4.5 and phase < 5",
                 "SELECT * FROM Supernovae where phase >= 5 and phase < 5.5",
                 "SELECT * FROM Supernovae where phase >= 5.5 and phase < 6",
                 "SELECT * FROM Supernovae where phase >= 6 and phase < 6.5",
                 "SELECT * FROM Supernovae where phase >= 6.5 and phase < 7",
                 "SELECT * FROM Supernovae where phase >= 7 and phase < 7.5",
                 "SELECT * FROM Supernovae where phase >= 7.5 and phase < 8",
                 "SELECT * FROM Supernovae where phase >= 8 and phase < 8.5",
                 "SELECT * FROM Supernovae where phase >= 8.5 and phase < 9",
                 "SELECT * FROM Supernovae where phase >= 9 and phase < 9.5",
                 "SELECT * FROM Supernovae where phase >= 9.5 and phase < 10",
                 "SELECT * FROM Supernovae where phase >= 10 and phase < 10.5",
                 "SELECT * FROM Supernovae where phase >= 10.5 and phase < 11",
                 "SELECT * FROM Supernovae where phase >= 11 and phase < 11.5",
                 "SELECT * FROM Supernovae where phase >= 11.5 and phase < 12",
                 "SELECT * FROM Supernovae where phase >= 12 and phase < 12.5",
                 "SELECT * FROM Supernovae where phase >= 12.5 and phase < 13",
                 "SELECT * FROM Supernovae where phase >= 13 and phase < 13.5",
                 "SELECT * FROM Supernovae where phase >= 13.5 and phase < 14",
                 "SELECT * FROM Supernovae where phase >= 14 and phase < 14.5",
                 "SELECT * FROM Supernovae where phase >= 14.5 and phase < 15",
                 "SELECT * FROM Supernovae where phase >= 15 and phase < 15.5",
                 "SELECT * FROM Supernovae where phase >= 15.5 and phase < 16",
                 "SELECT * FROM Supernovae where phase >= 16 and phase < 16.5",
                 "SELECT * FROM Supernovae where phase >= 16.5 and phase < 17",
                 "SELECT * FROM Supernovae where phase >= 17 and phase < 17.5",
                 "SELECT * FROM Supernovae where phase >= 17.5 and phase < 18",
                 "SELECT * FROM Supernovae where phase >= 18 and phase < 18.5",
                 "SELECT * FROM Supernovae where phase >= 18.5 and phase < 19",
                 "SELECT * FROM Supernovae where phase >= 19 and phase < 19.5",
                 "SELECT * FROM Supernovae where phase >= 19.5 and phase < 20",
                 "SELECT * FROM Supernovae where phase >= 20 and phase < 20.5",
                 "SELECT * FROM Supernovae where phase >= 20.5 and phase < 21.25",
                 "SELECT * FROM Supernovae where phase >= 21.25 and phase < 21.75",
                 "SELECT * FROM Supernovae where phase >= 21.75 and phase < 22.75",
                 "SELECT * FROM Supernovae where phase >= 22.75 and phase < 23.5",
                 "SELECT * FROM Supernovae where phase >= 23.5 and phase < 24",
                 "SELECT * FROM Supernovae where phase >= 24 and phase < 24.5",
                 "SELECT * FROM Supernovae where phase >= 24.5 and phase < 25.5",
                 "SELECT * FROM Supernovae where phase >= 25.5 and phase < 26.5",
                 "SELECT * FROM Supernovae where phase >= 26.5 and phase < 27.5",
                 "SELECT * FROM Supernovae where phase >= 27.5 and phase < 28.5",
                 "SELECT * FROM Supernovae where phase >= 28.5 and phase < 29.5",
                 "SELECT * FROM Supernovae where phase >= 29.5 and phase < 30.5",
                 "SELECT * FROM Supernovae where phase >= 30.5 and phase < 31.5",
                 "SELECT * FROM Supernovae where phase >= 31.5 and phase < 32.5",
                 "SELECT * FROM Supernovae where phase >= 32.5 and phase < 33.5",
                 "SELECT * FROM Supernovae where phase >= 33.5 and phase < 34.5",
                 "SELECT * FROM Supernovae where phase >= 34.5 and phase < 36",
                 "SELECT * FROM Supernovae where phase >= 36 and phase < 37.5",
                 "SELECT * FROM Supernovae where phase >= 37.5 and phase < 38.5",
                 "SELECT * FROM Supernovae where phase >= 38.5 and phase < 39.5",
                 "SELECT * FROM Supernovae where phase >= 39.5 and phase < 41",
                 "SELECT * FROM Supernovae where phase >= 41 and phase < 42.5",
                 "SELECT * FROM Supernovae where phase >= 42.5 and phase < 44",
                 "SELECT * FROM Supernovae where phase >= 44 and phase < 45.5",
                 "SELECT * FROM Supernovae where phase >= 45.5 and phase < 47.5",
                 "SELECT * FROM Supernovae where phase >= 47.5 and phase < 50",
                 "SELECT * FROM Supernovae where phase >= 50 and phase < 52.5",
                 "SELECT * FROM Supernovae where phase >= 52.5 and phase < 56",
                 "SELECT * FROM Supernovae where phase >= 56 and phase < 59",
                 "SELECT * FROM Supernovae where phase >= 59 and phase < 62",
                 "SELECT * FROM Supernovae where phase >= 62 and phase < 66",
                 "SELECT * FROM Supernovae where phase >= 66 and phase < 71",
                 "SELECT * FROM Supernovae where phase >= 71 and phase < 78",
                 "SELECT * FROM Supernovae where phase >= 78 and phase < 88",
                 "SELECT * FROM Supernovae where phase >= 88 and phase < 98",
                 "SELECT * FROM Supernovae where phase >= 98 and phase < 125",
                 "SELECT * FROM Supernovae where phase >= 125 and phase < 180",
                 "SELECT * FROM Supernovae where phase >= 180",
                 
                ]

# %%
composites = query_db.main(len(query_strings), query_strings)
# Out:
# SQL Query: SELECT * FROM Supernovae where phase < -11
# ...
# 24 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 20 spectra left
# 1994d sn1994D-19940310.36-mmt.flm -11.14
# Host correction...
# 2002bo sn2002bo-20020311-ui-corrected.flm -11.94
# Host correction...
# 2006qo sn2006qo-20061201.436-ui.flm -11.08
# Host correction...
# 2007ca sn2007ca-20070426.305-ui.flm -11.14
# Host correction...
# 1997do sn1997do-19971102.46-fast.flm -11.64
# Host correction...
# 1999cp sn1999cp-19990622.20-fast.flm -12.0
# Host correction...
# 2001v sn2001V-20010220.29-fast.flm -12.51
# Host correction...
# 2002cr sn2002cr-20020503.29-fast.flm -11.31
# Host correction...
# 2003du 2003du_20030425_3451_10400_00.dat -12.1
# Host correction...
# 2003w sn2003W-20030129.35-mmt.flm -11.35
# Host correction...
# 2005cf 2005cf_20050531_3321_9999_00.dat -12.7
# Host correction...
# ...

# %%
import matplotlib.pyplot as plt
import time
import numpy as np

# %%
# %matplotlib inline
temp = composites
# fig=plt.figure(figsize=(18, 16), dpi= 80, facecolor='w', edgecolor='k')
# fig, ax = plt.subplots(1,1)
# fig = plt.figure(num = 1, dpi = 100, figsize = [20,10], facecolor = 'w')
# plt.xlim([3000,10000])
# plt.ylim([0.,12.e-15])

# num_plots = 5
# num_comps = len(composites)/num_plots

phases = []
for comp in composites:
    phases.append(np.average(comp.phase_array[comp.x1:comp.x2]))

for i in range(num_plots):
    fig, ax = plt.subplots(1,1)
    fig.set_size_inches(18.5, 6.5)
    s_m = query_db.make_colorbar(composites[i*num_comps:i*num_comps + num_comps])
    cb = plt.colorbar(s_m, ax = fig.axes)
    plt.xlim([3000,10000])
    plt.ylim([0.,12.e-15])
    f = i*num_comps
    for comp in composites[i*num_comps:i*num_comps + num_comps]:
        ax.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], color = s_m.to_rgba(phases[f]))
        f = f + 1
    plt.show()
    

# s_m = query_db.make_colorbar(composites)
# cb = plt.colorbar(s_m, ax = fig.axes)

# phases = []
# for comp in composites:
#     phases.append(np.average(comp.phase_array[comp.x1:comp.x2]))
    
# for f in range(len(composites[0:30])):
#     ax.plot(composites[f].wavelength[composites[f].x1:composites[f].x2], 
#             composites[f].flux[composites[f].x1:composites[f].x2], color = s_m.to_rgba(phases[f]))
#     ax.plot(composites[f].wavelength[composites[f].x1:composites[f].x2], 
#             composites[f].low_conf[composites[f].x1:composites[f].x2], color = s_m.to_rgba(phases[f]), alpha = .5)
#     ax.plot(composites[f].wavelength[composites[f].x1:composites[f].x2], 
#             composites[f].up_conf[composites[f].x1:composites[f].x2], color = s_m.to_rgba(phases[f]), alpha = .5)
#     fig.canvas.draw()
#     time.sleep(.2)
