# %%
import matplotlib
matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.gridspec as gridspec
import spectral_analysis as sa
from scipy.special import erf
import datafidelity as df

# %%
def make_colorbar(composites):
    params = []
    # for comp in composites:
    # 	params.append(np.average(comp.dm15_array[comp.x1:comp.x2]))
    # norm = matplotlib.colors.Normalize(vmin=np.min(params),vmax=np.max(params))
    norm = matplotlib.colors.Normalize(vmin=1.,vmax=len(composites) + 1.)
    c_m = matplotlib.cm.plasma
    # c_m = matplotlib.cm.winter_r
    s_m = matplotlib.cm.ScalarMappable(cmap=c_m, norm=norm)
    s_m.set_array([])

    return s_m

# %%
def comparison_plot(composites):

#     plt.style.use('ggplot')
    colors = [color['color'] for color in list(plt.rcParams['axes.prop_cycle'])]
    h = [3,1,1,1,1,1,1]
    font = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 10,
        }

#     gs = gridspec.GridSpec(7, 1, height_ratios=h, hspace = .001)
#     fig = plt.figure(num = 1, dpi = 100, figsize = [10,10])
    fig = plt.figure(num = 1, dpi = 100, figsize = [10,8])
    s_m = make_colorbar(composites)
    lw = 3

    composites, scales = composite.optimize_scales(composites, composites[0], True)

    i = 0
    k = 1
    for comp in composites:
        # param = np.average(comp.dm15_array[comp.x1:comp.x2])
        param = k

#         rel_flux = plt.subplot(gs[0])
        rel_flux = plt.subplot(111)
#         plt.setp(rel_flux.get_xticklabels(), visible=False)
        plt.ylabel('Relative Flux', fontdict = font)
        rel_flux.axes.get_yaxis().set_ticks([])
        # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], color = s_m.to_rgba(param))
        plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))
        if len(comp.low_conf) > 0 and len(comp.up_conf) > 0:
            plt.fill_between(comp.wavelength[comp.x1:comp.x2], comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], color = s_m.to_rgba(param), alpha = 0.5)
            # plt.fill_between(comp.wavelength[comp.x1:comp.x2], comp.low_conf[comp.x1:comp.x2], 
            # 	             comp.up_conf[comp.x1:comp.x2], color = colors[i%len(colors)], alpha = 0.5)

#         var = plt.subplot(gs[1], sharex = rel_flux)
#         plt.setp(var.get_xticklabels(), visible=False)
#         plt.ylabel('Variance', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.ivar[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.ivar[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         res = plt.subplot(gs[2], sharex = rel_flux)
#         plt.setp(res.get_xticklabels(), visible=False)
#         plt.ylabel('Residuals', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))
#         if len(comp.low_conf) > 0 and len(comp.up_conf) > 0:
#             low_resid = comp.low_conf[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2]
#             up_resid = comp.up_conf[comp.x1:comp.x2] - composites[0].flux[comp.x1:comp.x2]
#             plt.fill_between(comp.wavelength[comp.x1:comp.x2], low_resid, up_resid, color = s_m.to_rgba(param), alpha = 0.5)
#             # plt.fill_between(comp.wavelength[comp.x1:comp.x2], low_resid, up_resid, color = colors[i%len(colors)], alpha = 0.5)

#         spec = plt.subplot(gs[3], sharex = rel_flux)
#         plt.setp(spec.get_xticklabels(), visible=False)
#         plt.ylabel('Spectra/Bin', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.spec_bin[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.spec_bin[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         phase = plt.subplot(gs[4], sharex = rel_flux)
#         plt.setp(phase.get_xticklabels(), visible=False)
#         plt.ylabel('Phase [d]', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.phase_array[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.phase_array[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         delt = plt.subplot(gs[5], sharex = rel_flux)
#         plt.setp(delt.get_xticklabels(), visible=False)
#         plt.ylabel('$\Delta$m$_{15}$', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.dm15[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.dm15[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

#         plt.subplot(gs[6], sharex = rel_flux)
#         plt.ylabel('Redshift', fontdict = font)
#         # plt.plot(comp.wavelength[comp.x1:comp.x2], comp.red_array[comp.x1:comp.x2], color = s_m.to_rgba(param))
#         plt.plot(comp.wavelength[comp.x1:comp.x2], comp.red_array[comp.x1:comp.x2], linewidth = lw, color = s_m.to_rgba(param))

        i+=1
        k+=1

    plt.xlabel( 'Wavelength ' + "($\mathrm{\AA}$)", fontdict = font)
    # cb = plt.colorbar(s_m, ax = fig.axes)
    # cb.set_label('Phase', fontdict = font)
    # for ax in fig.axes:
    # 	ax.set_axis_bgcolor('white')

    plt.show()

# %%
query_strings_low_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -7 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -7 and phase < -4 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4 and phase < -2 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2 and phase < -1 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 0 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0 and phase < 1 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 1 and phase < 2 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2 and phase < 3 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 3 and phase < 4 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4 and phase < 5 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 5 and phase < 6 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6 and phase < 7 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 7 and phase < 8 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8 and phase < 9 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 9 and phase < 10 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10 and phase < 11 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 11 and phase < 12 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12 and phase < 14 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14 and phase < 16 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16 and phase < 18 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18 and phase < 20 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20 and phase < 22 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22 and phase < 25 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 25 and phase < 28 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28 and phase < 31 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 31 and phase < 34 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 34 and phase < 39 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39 and phase < 49 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 49 and phase < 70 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 70 and phase < 110 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 110 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)"
                         ]

# %%
query_strings_high_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -7 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -7 and phase < -4 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4 and phase < -2 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2 and phase < -1 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 0 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0 and phase < 1 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 1 and phase < 2 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2 and phase < 3 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 3 and phase < 4 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4 and phase < 5 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 5 and phase < 6 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6 and phase < 7 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 7 and phase < 8 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8 and phase < 9 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 9 and phase < 10 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10 and phase < 11 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 11 and phase < 12 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12 and phase < 14 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14 and phase < 16 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16 and phase < 18 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18 and phase < 20 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20 and phase < 22 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22 and phase < 25 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 25 and phase < 28 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28 and phase < 31 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 31 and phase < 34 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 34 and phase < 39 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39 and phase < 49 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 49 and phase < 70 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 70 and phase < 110 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                         ]

# %%
comps_low_dm15 = query_db.main(len(query_strings_low_dm15), query_strings_low_dm15)
comps_high_dm15 = query_db.main(len(query_strings_high_dm15), query_strings_high_dm15)

# %%
def stacked_plot(comps_low, comps_high):
    fig, ax = plt.subplots(1,1)
    ax.get_yaxis().set_ticks([])
    plt.ylabel('Relative Flux + const.')
    plt.xlabel('Wavelength (A)')
    fig.set_size_inches(8.5, 11.)
#     comps_low, scales = composite.optimize_scales(comps_low, comps_low[0], True)
#     comps_high, scales = composite.optimize_scales(comps_high, comps_high[0], True)
    upper_buff = 100

    for i in range(len(comps_low)):
#         scaled_comps, scales = composite.optimize_scales([comps_low[i], comps_high[i]], comps_low[i], True)
        phase_1 = np.average(scaled_comps[0].phase_array[scaled_comps[0].x1:scaled_comps[0].x2])
        phase_2 = np.average(scaled_comps[1].phase_array[scaled_comps[1].x1:scaled_comps[1].x2])
        phase = (phase_1 + phase_2)/2.
        ax.plot(scaled_comps[0].wavelength[scaled_comps[0].x1:scaled_comps[0].x2], 2.e15*scaled_comps[0].flux[scaled_comps[0].x1:scaled_comps[0].x2] + upper_buff - 3.*phase, 'b-')
        ax.plot(scaled_comps[1].wavelength[scaled_comps[1].x1:scaled_comps[1].x2], 2.e15*scaled_comps[1].flux[scaled_comps[1].x1:scaled_comps[1].x2] + upper_buff - 3.*phase, 'r-')
#         plt.fill_between(scaled_comps[0].wavelength[scaled_comps[0].x1:scaled_comps[0].x2], 2.e15*scaled_comps[0].low_conf[scaled_comps[0].x1:scaled_comps[0].x2] + upper_buff - 3.*phase, 2.e15*scaled_comps[0].up_conf[scaled_comps[0].x1:scaled_comps[0].x2] + upper_buff - 3.*phase, alpha = 0.5)
#         plt.fill_between(scaled_comps[1].wavelength[scaled_comps[1].x1:scaled_comps[1].x2], 2.e15*scaled_comps[1].low_conf[scaled_comps[1].x1:scaled_comps[1].x2] + upper_buff - 3.*phase, 2.e15*scaled_comps[1].up_conf[scaled_comps[1].x1:scaled_comps[1].x2] + upper_buff - 3.*phase, color = 'r', alpha = 0.5)
        plt.text(scaled_comps[0].wavelength[scaled_comps[0].x2], scaled_comps[0].flux[scaled_comps[0].x2] + upper_buff - 3.*phase + 1, str(round(phase, 2)) + ' days')
    plt.show()

# %%
import composite

# %%
query_db.set_min_num_spec(comps_low_dm15, 5)
query_db.set_min_num_spec(comps_high_dm15, 5)

# %%
sub_list_1_low = comps_low_dm15[0:6]
sub_list_2_low = comps_low_dm15[6:12]
sub_list_3_low = comps_low_dm15[12:18]
sub_list_4_low = comps_low_dm15[18:24]
sub_list_5_low = comps_low_dm15[24:28]
sub_list_6_low = comps_low_dm15[28:30]
sub_list_7_low = comps_low_dm15[30:]

sub_list_1_high = comps_high_dm15[0:6]
sub_list_2_high = comps_high_dm15[6:12]
sub_list_3_high = comps_high_dm15[12:18]
sub_list_4_high = comps_high_dm15[18:24]
sub_list_5_high = comps_high_dm15[24:28]
sub_list_6_high = comps_high_dm15[28:30]
sub_list_7_high = comps_high_dm15[30:]

# %%
stacked_plot(sub_list_1_low, sub_list_1_high)

# %%
stacked_plot(sub_list_2_low, sub_list_2_high)

# %%
stacked_plot(sub_list_3_low, sub_list_3_high)

# %%
stacked_plot(sub_list_4_low, sub_list_4_high)

# %%
stacked_plot(sub_list_5_low, sub_list_5_high)

# %%
stacked_plot(sub_list_6_low, sub_list_6_high)

# %%
stacked_plot(sub_list_7_low, sub_list_7_high)

# %% [markdown]
# # Maximum Light - Max Bins

# %%
query_dm15_split_max = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa < .9 or dm15_from_fits < .9)",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .9 and dm15_cfa < 1.) or (dm15_from_fits >= .9 and dm15_from_fits < 1))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1 and dm15_cfa < 1.05) or (dm15_from_fits >= 1 and dm15_from_fits < 1.05))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.05 and dm15_cfa < 1.1) or (dm15_from_fits >= 1.05 and dm15_from_fits < 1.1))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.2) or (dm15_from_fits >= 1.1 and dm15_from_fits < 1.2))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.3) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.3))", 
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.4) or (dm15_from_fits >= 1.3 and dm15_from_fits < 1.4))", 
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.4 and dm15_cfa < 1.6) or (dm15_from_fits >= 1.4 and dm15_from_fits < 1.6))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa >= 1.6 or dm15_from_fits >= 1.6)"
                       ]

# %%
comps_dm15_split_max, sn_arrays, boot_sn_arrays = query_db.main(len(query_dm15_split_max), query_dm15_split_max)

# %%
def stacked_plot_max(composites,buff,label_buff):
    font1 = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 20,
        }
    
    font2 = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 10,
        }
    
    fig, ax = plt.subplots(1,1)
    fig.set_size_inches(15, 30, forward = True)
    ax.get_yaxis().set_ticks([])
    ax.xaxis.set_tick_params(length=10, width = 2)
    plt.ylabel('Relative Flux + const.', fontdict = font1, fontsize = 40)
    plt.xlabel( 'Wavelength ' + "($\mathrm{\AA}$)", fontdict = font1, fontsize = 40)
    plt.xticks(fontsize = 20)
#     composites, scales = composite.optimize_scales(composites, composites[0], True)

    i = 0
    for comp in composites:
        dm15 = np.nanmean(comp.dm15_array[comp.x1:comp.x2])
#         ax.plot(comp.wavelength[comp.x1:comp.x2], 2.e15*comp.flux[comp.x1:comp.x2] - 1200*dm15, color = '#3F5D7D', linewidth = 4)
        ax.plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2] - i, color = '#3F5D7D', linewidth = 4)
#         plt.fill_between(comp.wavelength[comp.x1:comp.x2], comp.low_conf[comp.x1:comp.x2]- i, comp.up_conf[comp.x1:comp.x2] - i, alpha = 0.5)
#         plt.text(9700, comp.flux[comp.x2] - 1200*dm15 + 30, '$\mathbf{\Delta m_{15}}$ = ' + str(round(dm15, 2)), fontdict = font1)
        plt.text(8000, comp.flux[comp.x2] - i + .1, '$\mathbf{\Delta m_{15}}$ = ' + str(round(dm15, 2)), fontdict = font2, fontsize = 30)
        i += 1
#     plt.title('Maximum Light Composite Spectra \n for Different Light Curve Shapes', fontdict = font1, fontsize = 40)
    plt.xlim([3000,10500])
#     plt.savefig('../../Paper_Drafts/dm15_split_max.pdf', dpi = 300, bbox_inches = 'tight')
    plt.show()

# %%
# composite.optimize_scales(comps_dm15_split_max, comps_dm15_split_max[0], True)
query_db.set_min_num_spec(comps_dm15_split_max, 5)
# comparison_plot(comps_dm15_split_max)
stacked_plot_max(comps_dm15_split_max, 110, 30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-aa44ec3af161> in <module>()
#       1 # composite.optimize_scales(comps_dm15_split_max, comps_dm15_split_max[0], True)
# ----> 2 query_db.set_min_num_spec(comps_dm15_split_max, 5)
#       3 # comparison_plot(comps_dm15_split_max)
#       4 stacked_plot_max(comps_dm15_split_max, 110, 30)
#
# NameError: name 'comps_dm15_split_max' is not defined

# %% [markdown]
# # Maximum Light - Grid Bins

# %%
query_dm15_max_fewer_bins = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa < .95 or dm15_from_fits < .95)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5)) and Supernovae.SN !='2002bf'",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5)) and Supernovae.SN !='2002bf'"]
# query_dm15_max_fewer_bins = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa < .9 or dm15_from_fits < .9)",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .9 and dm15_cfa < 1.) or (dm15_from_fits >= .9 and dm15_from_fits < 1))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1 and dm15_cfa < 1.05) or (dm15_from_fits >= 1 and dm15_from_fits < 1.05))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.05 and dm15_cfa < 1.1) or (dm15_from_fits >= 1.05 and dm15_from_fits < 1.1))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.2) or (dm15_from_fits >= 1.1 and dm15_from_fits < 1.2))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.3) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.3))", 
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.4) or (dm15_from_fits >= 1.3 and dm15_from_fits < 1.4))", 
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.4 and dm15_cfa < 1.6) or (dm15_from_fits >= 1.4 and dm15_from_fits < 1.6))",
#                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa >= 1.6 or dm15_from_fits >= 1.6)"]

# %%
comps_dm15_max_fewer_bins, sn_arrays_2, boot_sn_arrays_2 = query_db.main(len(query_dm15_max_fewer_bins), query_dm15_max_fewer_bins, boot='b', medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa < .95 or dm15_from_fits < .95)) and Supernovae.SN !='2002bf'
# Collecting data...
# 27 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 25 spectra left
# 0 Peculiar Ias removed 25 spectra left
# 23 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 23 spectra left
# 1994s sn1994s-19940616-uoi.flm 34.8971198257 0.94 None 1.11 bsnip 3124.0 11082.0
# Host correction...
# 1996ai sn1996ai-19960622-uoi.flm 46.9712987061 0.88 None 1.231 bsnip 3202.0 10368.0
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 69.1436677309 0.85 None 0.28 bsnip 3346.0 10044.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 44.0459361476 0.78 None 0.24 bsnip 3344.0 10350.0
# Host correction...
# 1999dq sn1999dq-near-19990917-clear-ui-corrected.flm 49.3372100352 0.86 None 2.97 bsnip 3304.0 10352.0
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 24.0178237234 0.88 None 1.39 bsnip 3278.0 10124.0
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 23.7964870723 0.84 None 1.1 bsnip 3318.0 10244.0
# Host correction...
# 2005eq sn2005eq-20051011.376-ui-corrected.flm 37.8569772533 0.88 None 0.66 bsnip 3278.0 10156.0
# Host correction...
# 2006cq sn2006cq-20060605.307-ui.flm 11.4517795753 None 0.905291256764 2.0 bsnip 3208.0 10062.0
# Host correction...
# 2006ot sn2006ot-20061123.362-br.flm 35.3768439715 0.84 None -1.338 bsnip 3008.0 8736.0
# Host correction...
# 2006s sn2006s-20060206.517-ui.flm 14.4997537352 0.93 None 2.99 bsnip 3254.0 10124.0
# Host correction...
# 1996c sn1996C-19960217.48-fast.flm 27.3132541144 0.93 None 1.98 cfa 3654.0 7314.0
# Host correction...
# 1999gp sn1999gp-20000105.10-fast.flm 33.6958139173 0.87 None -2.0 cfa 3674.0 7296.0
# Host correction...
# 2001ay sn2001ay-20010421.48-fast.flm 18.6087981469 0.68 None -1.52 cfa 3662.0 7270.0
# Host correction...
# 2001eh sn2001eh-20010915.42-fast.flm 15.1100402768 0.92 None -2.08 cfa 3638.0 7222.0
# Host correction...
# 2002jy sn2002jy-20021226.12-fast.flm 31.1301164169 0.88 None 0.120000000003 cfa 3700.0 7346.0
# Host correction...
# 2003hu sn2003hu-20030919.19-fast.flm 11.1326469482 None 0.880569111523 0.0900000000038 cfa 3512.0 6966.0
# Host correction...
# 2004as sn2004as-20040319.28-fast.flm 25.3622106076 0.92 None -2.12 cfa 3660.0 7264.0
# Host correction...
# 2006cj sn2006cj-20060522.29-fast.flm 11.127962287 0.81 None -1.21 cfa 3312.0 6886.0
# Host correction...
# 2006gr sn2006gr-20061002.26-fast.flm 13.8261860644 0.81 None -2.14 cfa 3414.0 7120.0
# Host correction...
# 2006oa sn2006oa-20061125.08-fast.flm 12.6130547741 0.89 None -2.12 cfa 3330.0 6944.0
# Host correction...
# 2007s sn2007S-20070210.32-fast.flm 56.6730771507 0.94 None -2.78 cfa 3480.0 7264.0
# Host correction...
# 2007ca SN07ca_070508_b01_BAA_IM.dat 31.5813058497 0.89 None 1.41999999993 csp 3506.0 9446.0
# Host correction...
# 23 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15)) and Supernovae.SN !='2002bf'
# Collecting data...
# 56 spectra found
# 152 questionable files currently ignored
# 3 questionable spectra removed 53 spectra left
# 1 Peculiar Ias removed 52 spectra left
# 45 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 44 spectra left
# 1998dk sn1998dk-19980831-ui.flm 70.6132013702 1.05 None -0.54 bsnip 3308.0 10018.0
# Host correction...
# 2001bf sn2001bf-20010516-ui-corrected.flm 46.0714551832 0.99 None 1.22 bsnip 3300.0 10242.0
# Host correction...
# 2001da sn2001da-20010716-ui-corrected.flm 30.0099081637 1.12 None -1.12 bsnip 3296.0 10176.0
# Host correction...
# 2001fe sn2001fe-20011115-ui.flm 63.0968901259 1.0 None -0.99 bsnip 3288.0 10212.0
# Host correction...
# 2002bo sn2002bo-20020322-ui-corrected.flm 27.2745675657 1.08 None -1.08 bsnip 3338.0 10308.0
# Host correction...
# 2002de sn2002de-20020608.374-ui-corrected.flm 7.9496540894 0.96 None -0.32 bsnip 3140.0 10066.0
# Host correction...
# 2004dt sn2004dt-20040824-vis2-corrected.flm 63.786388267 1.14 None 1.38 bsnip 4464.0 9562.0
# Host correction...
# 2004fu sn2004fu-20041119-ui.flm 45.3537215501 1.08 None 2.43 bsnip 3340.0 10356.0
# Host correction...
# 2005cf sn2005cf-20050610.7-uvot.flm 25.8392814942 1.1 None -2.7 uv 2038.0 9886.0
# Host correction...
# 2005ms sn2005ms-20060106.400-ui.flm 16.6601127349 None 1.0139405966 -1.88 bsnip 3280.0 10192.0
# Host correction...
# 2005na sn2005na-20060105.335-ui.flm 23.8296042949 1.09 None 0.03 bsnip 3276.0 10182.0
# Host correction...
# 2006bt sn2006bt-20060505.444-ui.flm 31.8522994411 1.0 None 2.27 bsnip 3296.0 10028.0
# Host correction...
# 2007a sn2007a-20070113.208-br.flm 66.6691522711 0.95 None 2.37 bsnip 3278.0 9044.0
# Host correction...
# 2007af sn2007af-20070313.545-ui-corrected.flm 62.682927791 1.04 None -1.25 bsnip 3382.0 10394.0
# Host correction...
# 2007bz sn2007bz-20070426.419-ui.flm 23.2078944384 1.05 None 1.65 bsnip 3320.0 10228.0
# Host correction...
# 2007o sn2007o-20070122.663-deimos.flm 42.7383273579 None 1.14429493781 -0.33 bsnip 4328.0 9186.0
# Host correction...
# 1994ae sn1994ae-19941201.50-fast.flm 150.102991241 0.96 None 2.0 cfa 3486.0 6936.0
# Host correction...
# 1996ab sn1996ab-19960522.37-fast.flm 5.13550481345 1.01 None 1.47 cfa 3346.0 6640.0
# Host correction...
# 1996bl sn1996bl-19961018.18-fast.flm 20.0727335243 1.07 None -2.32 cfa 3622.0 7244.0
# Host correction...
# 1997dt sn1997dt-19971204.11-fast.flm 56.9668367955 1.04 None 0.209999999999 cfa 3744.0 7436.0
# Host correction...
# 1998aq sn1998aq-19980429.26-fast.flm 161.199075666 1.11 None 1.06 cfa 3756.0 7442.0
# Host correction...
# 1998bu sn1998bu-19980517.15-fast.flm 137.136179272 1.03 None -2.55 cfa 3760.0 7470.0
# Host correction...
# 1998ec sn1998ec-19980930.50-fast.flm 25.4049698217 1.08 None -3.0 cfa 3698.0 7326.0
# Host correction...
# 1998eg sn1998eg-19981024.15-fast.flm 32.3460405034 1.14 None -0.75 cfa 3680.0 7230.0
# Host correction...
# 1998v sn1998V-19980319.51-fast.flm 30.4713646656 0.99 None 0.310000000005 cfa 3708.0 7362.0
# Host correction...
# 2000fa sn2000fa-20001215.36-fast.flm 17.7816354784 1.0 None 1.26 cfa 3654.0 7334.0
# Host correction...
# 2001en sn2001en-20011011.39-fast.flm 48.5003119433 1.12 None 1.49 cfa 3710.0 7370.0
# Host correction...
# 2001n sn2001N-20010122.46-fast.flm 20.2770059103 None 1.11269436615 0.659999999996 cfa 3694.0 7336.0
# Host correction...
# 2002ck sn2002ck-20020502.46-fast.flm 14.1023856776 1.08 None -0.540000000001 cfa 3664.0 7274.0
# Host correction...
# 2002fk sn2002fk-20020929.44-fast.flm 178.698803338 1.13 None -1.46 cfa 3744.0 7436.0
# Host correction...
# 2002hu sn2002hu-20021113.25-fast.flm 12.5387071627 1.05 None -0.75 cfa 3636.0 7220.0
# Host correction...
# 2003w sn2003W-20030207.40-fast.flm 28.9656419776 1.14 None -2.3 cfa 3698.0 7342.0
# Host correction...
# 2004bg sn2004bg-20040417.19-fast.flm 57.2971141657 1.05 None 2.69 cfa 3696.0 7338.0
# Host correction...
# 2004l sn2004L-20040127.40-fast.flm 27.3156204976 1.12 None 2.5 cfa 3654.0 7256.0
# Host correction...
# 2005a sn2005A-20050110.11-ldss2.flm 9.38778641688 1.11 None 0.610000000001 cfa 3698.0 9324.0
# Host correction...
# 2006ax SN06ax_060330_b01_DUP_WF.dat 58.502090858 1.06 None -2.36000000034 csp 3788.0 9034.0
# Host correction...
# 2006br SN06br_060426_b01_DUP_WF.dat 23.0514109304 1.12 None 0.560000000056 csp 3760.0 8964.0
# Host correction...
# 2006cf sn2006cf-20060519.25-fast.flm 25.8546360074 None 1.08670703312 1.85 cfa 3396.0 7062.0
# Host correction...
# 2006et sn2006et-20060918.36-fast.flm 31.9424489049 1.02 None 2.46 cfa 3450.0 7202.0
# Host correction...
# 2007ae sn2007ae-20070225.54-fast.flm 9.77849625348 0.98 None 2.54 cfa 3314.0 6914.0
# Host correction...
# 2008bf SN08bf_080326_b01_CLA_LD.dat 50.7093698903 1.05 None -2.77000000002 csp 3766.0 9926.0
# Host correction...
# 2005hc SN05hc_051024_b01_MGH_BC.dat 26.8404829147 1.03 None 0.699999999721 csp 3764.0 6970.0
# Host correction...
# 2006os SN06os_061122_b01_DUP_WF.dat 13.9284910072 None 1.07243123623 -1.06999999983 csp 3730.0 8892.0
# Host correction...
# 2007le SN07le_071028_g01_CLA_LD.dat 78.7656416336 1.01 None 2.84999999963 csp 4100.0 9192.0
# Host correction...
# 44 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25)) and Supernovae.SN !='2002bf'
# Collecting data...
# 19 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 17 spectra left
# 0 Peculiar Ias removed 17 spectra left
# 16 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 16 spectra left
# 1995e sn1995e-19950224-uoi2.flm 44.325356664 1.16 None -2.46 bsnip 3136.0 11162.0
# Host correction...
# 1997y sn1997y-19970209-uohp.flm 44.230493937 1.15 None 1.27 bsnip 3202.0 9716.0
# Host correction...
# 1999ac sn1999ac-19990312-ui-corrected.flm 66.9161014359 1.23 None -0.89 bsnip 3296.0 10352.0
# Host correction...
# 1999gd sn1999gd-19991205-uvoir.flm 65.3296710526 1.18 None -1.12 bsnip 3978.0 9770.0
# Host correction...
# 2002ha sn2002ha-20021102-ui-corrected.flm 48.9404969523 1.22 None -0.85 bsnip 3108.0 10206.0
# Host correction...
# 2003cq sn2003cq-20030408-ui.flm 15.7476139398 1.2 None -0.15 bsnip 3084.0 10016.0
# Host correction...
# 2006sr sn2006sr-20061220.097-ui.flm 38.6421198907 1.24 None -2.34 bsnip 3282.0 10204.0
# Host correction...
# 2007co sn2007co-20070614.468-ui-corrected.flm 40.524617158 1.16 None 0.85 bsnip 3288.0 10176.0
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm 58.8004615819 1.17 None -0.540000000001 cfa 3738.0 7426.0
# Host correction...
# 2002cr sn2002cr-20020515.28-fast.flm 77.3222473254 1.19 None 0.68 cfa 3736.0 7422.0
# Host correction...
# 2002hd sn2002hd-20021029.52-fast.flm 14.2622103278 1.16 None 1.42 cfa 3646.0 7236.0
# Host correction...
# 2002kf sn2002kf-20021231.34-fast.flm 31.8967736134 1.2 None 1.14 cfa 3700.0 7348.0
# Host correction...
# 2003ch sn2003ch-20030329.11-mmt.flm 28.8381350326 1.22 None 1.81 cfa 3172.0 9024.0
# Host correction...
# 2007jg SN07jg_070922_b01_CLA_LD.dat 17.4357299818 1.17 None -1.27000000002 csp 3636.0 9556.0
# Host correction...
# 2005kc SN05kc_051125_b01_DUP_MS.dat 44.736357905 1.24 None 1.91999999993 csp 3774.0 7132.0
# Host correction...
# 2002er 2002er_20020910_3209_9997_00.dat 68.2099143412 1.23 None 2.1 other 3232.0 9858.0
# Host correction...
# 16 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5)) and Supernovae.SN !='2002bf'
# Collecting data...
# 34 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 32 spectra left
# 0 Peculiar Ias removed 32 spectra left
# 27 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 27 spectra left
# 2001ep sn2001ep-20011020-ui-corrected.flm 50.8449098727 1.3 None 2.83 bsnip 3308.0 10218.0
# Host correction...
# 2002he sn2002he-20021108-br.flm 70.9263350618 1.44 None 0.29 bsnip 3048.0 9150.0
# Host correction...
# 2003u sn2003U-20030204-ui.flm 29.2694201484 1.46 None -2.55 bsnip 3074.0 10084.0
# Host correction...
# 2004gs sn2004gs-20041217.447-ui-corrected.flm 28.3734591732 1.41 None 0.44 bsnip 3318.0 10008.0
# Host correction...
# 2005el sn2005el-20051004.534-ui-corrected.flm 40.230445764 1.27 None 1.22 bsnip 3320.0 10296.0
# Host correction...
# 2005ki sn2005ki-20051202.649-deimos.flm 69.6995974072 1.41 None 1.62 bsnip 3826.0 8844.0
# Host correction...
# 2005lz sn2005lz-20060101.381-deimos.flm 22.438944213 1.34 None 0.58 bsnip 4792.0 9626.0
# Host correction...
# 2007bc sn2007bc-20070410.323-ui-corrected.flm 40.8042361928 1.37 None 0.61 bsnip 3298.0 10336.0
# Host correction...
# 1994m sn1994M-19940504.15-fast.flm 13.8602235972 1.26 None 1.65 cfa 3672.0 7408.0
# Host correction...
# 1996x 1996X_19960419_3077_10669_00.dat 72.6747082167 1.26 None 0.900000000001 other 3108.0 10548.0
# Host correction...
# 1998co sn1998co-19980623.45-fast.flm 41.8372717871 None 1.43684328517 -0.0500000000029 cfa 3704.0 7356.0
# Host correction...
# 1998dx sn1998dx-19980914.18-fast.flm 10.9653036298 1.32 None -1.72 cfa 3580.0 7104.0
# Host correction...
# 1998ef sn1998ef-19981029.31-fast.flm 34.6262112005 1.27 None 1.41 cfa 3706.0 7244.0
# Host correction...
# 1999cc sn1999cc-19990516.34-fast.flm 23.2075050712 1.35 None -1.26 cfa 3658.0 7262.0
# Host correction...
# 1999ej sn1999ej-19991030.28-fast.flm 41.0343492423 1.48 None -1.82 cfa 3720.0 7390.0
# Host correction...
# 2002es sn2002es-20020903.45-fast.flm 18.2117848296 None 1.36630609234 2.14999999999 cfa 3706.0 7358.0
# Host correction...
# 2002g sn2002G-20020122.52-fast.flm 12.2192785184 1.25 None -2.58 cfa 3650.0 7244.0
# Host correction...
# 2003ic sn2003ic-20030921.36-fast.flm 11.8373131267 None 1.31624075043 -2.44 cfa 3576.0 7096.0
# Host correction...
# 2003it sn2003it-20031020.23-fast.flm 50.6117952173 1.36 None -2.27 cfa 3680.0 7306.0
# Host correction...
# 2004ef SN04ef_040914_b01_DUP_WF.dat 16.9958777651 1.39 None -1.35000000009 csp 3736.0 8908.0
# Host correction...
# 2005am sn2005am-20050303.30-fast.flm 28.1181574341 1.3 None -3.0 cfa 3506.0 7300.0
# Host correction...
# 2005bo SN05bo_050418_b01_DUP_WF.dat 28.2383319009 1.28 None -1.0299999998 csp 3798.0 9060.0
# Host correction...
# 2006al sn2006al-20060224.34-fast.flm 9.36935831043 1.35 None 2.64 cfa 3460.0 6900.0
# Host correction...
# 2006az sn2006az-20060331.37-fast.flm 24.2208984929 1.29 None -1.03 cfa 3438.0 7142.0
# Host correction...
# 2006gj sn2006gj-20060920.43-fast.flm 19.217234825 1.48 None -0.669999999998 cfa 3440.0 7168.0
# Host correction...
# 2007bd SN07bd_070417_b01_DUP_WF.dat 28.1437031822 1.3 None 0.540000000037 csp 3736.0 8908.0
# Host correction...
# 2006d sn2006d-20060120-snifs-r.dat 96.6707202467 1.35 None -2.0 other 5010.0 9860.0
# Host correction...
# 27 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5)) and Supernovae.SN !='2002bf'
# Collecting data...
# 35 spectra found
# 152 questionable files currently ignored
# 6 questionable spectra removed 29 spectra left
# 4 Peculiar Ias removed 25 spectra left
# 20 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 20 spectra left
# 1999da sn1999da-19990709-ui.flm 35.441805608 1.9 None -2.12 bsnip 3300.0 10368.0
# Host correction...
# 2000dk sn2000dk-20000926-ui-corrected.flm 46.5582359543 1.62 None 1.0 bsnip 3294.0 10172.0
# Host correction...
# 2002eu sn2002eu-20020903-ui.flm 21.8482743207 1.52 None -0.06 bsnip 3086.0 9974.0
# Host correction...
# 2002fb sn2002fb-20020913-ui-corrected.flm 27.2042647112 1.77 None 0.98 bsnip 3198.0 10192.0
# Host correction...
# 2005dv sn2005dv-20050911.170-ui.flm 13.1133435614 None 1.82222873525 -0.57 bsnip 3366.0 10244.0
# Host correction...
# 2006bz sn2006bz-20060505.218-ui.flm 12.9015209065 2.09 None -2.44 bsnip 3310.0 10068.0
# Host correction...
# 2006cs sn2006cs-20060605.335-ui.flm 11.9352989284 None 1.94090186807 2.28 bsnip 3284.0 10306.0
# Host correction...
# 2006n sn2006n-20060123.286-ui.flm 36.4972497748 1.5 None -1.89 bsnip 3320.0 10402.0
# Host correction...
# 2007ba sn2007ba-20070410.475-ui.flm 11.9667177729 1.89 None 2.14 bsnip 3242.0 10158.0
# Host correction...
# 2007ci sn2007ci-20070524.264-ui-corrected.flm 36.9959617847 1.6 None -1.71 bsnip 3312.0 10264.0
# Host correction...
# 2007n sn2007n-20070122.583-deimos.flm 46.123607582 None 1.88681529203 0.44 bsnip 4442.0 9398.0
# Host correction...
# 1994t sn1994T-19940612.19-fast.flm 3.62813221224 1.51 None 0.790000000001 cfa 3726.0 7420.0
# Host correction...
# 1998bp sn1998bp-19980430.47-fast.flm 28.7557905032 1.79 None -2.93 cfa 3732.0 7394.0
# Host correction...
# 1998de sn1998de-19980730.46-fast.flm 13.7634061513 1.88 None -2.24 cfa 3710.0 7368.0
# Host correction...
# 1999by sn1999by-19990514.15-fast.flm 96.4401838766 1.97 None 2.95 cfa 3444.0 9210.0
# Host correction...
# 2002do sn2002do-20020619.43-fast.flm 30.1719891566 1.56 None 2.03 cfa 3712.0 7374.0
# Host correction...
# 2006gt SN06gt_060925_b01_DUP_WF.dat 21.7787084927 1.66 None 0.279999999795 csp 3688.0 8790.0
# Host correction...
# 2007au sn2007au-20070326.15-fast.flm 14.5404931844 1.69 None 1.15 cfa 3456.0 7222.0
# Host correction...
# 2007ax SN07ax_070326_b01_DUP_BC.dat 19.8323399731 1.87 None -2.04000000004 csp 3428.0 9494.0
# Host correction...
# 2006kf SN06kf_061103_g01_NTT_EM.dat 19.4132855756 1.55 None 1.45000000019 csp 3978.0 9938.0
# Host correction...
# 20 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
# composite.optimize_scales(comps_dm15_max_fewer_bins, comps_dm15_max_fewer_bins[0], True)
query_db.set_min_num_spec(comps_dm15_max_fewer_bins, 5)
# comparison_plot(comps_dm15_max_fewer_bins)
temp = [comps_dm15_max_fewer_bins[0], comps_dm15_max_fewer_bins[3]]
# comparison_plot(temp)
# plt.savefig('../../Paper_Drafts/dm15_max.png', dpi = 300, bbox_inches = 'tight')
query_db.stacked_plot(comps_dm15_max_fewer_bins)

# %% [markdown]
# # Very Early

# %%
query_dm15_very_early = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= 1.1 or dm15_from_fits >= 1.1))"]

# %%
comps_dm15_very_early, sn_arrays, boot_arrays = query_db.main(len(query_dm15_very_early), query_dm15_very_early, boot='b',medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# ERROR:  sn2006oa-20061116-not.dat None
# 12 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 10 spectra left
# 0 Peculiar Ias removed 10 spectra left
# 9 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 9 spectra left
# 1999aa sn1999aa-19990212-uoi.flm 32.5387670237 0.78 None -10.58 bsnip 3304.0 10302.0
# Host correction...
# 2005eu sn2005eu-20051006.584-deimos.flm 31.0761675643 0.89 None -10.06 bsnip 4808.0 9692.0
# Host correction...
# 2007ca sn2007ca-20070426.305-ui.flm 22.1854746588 0.89 None -11.14 bsnip 3460.0 10306.0
# Host correction...
# 1995bd sn1995bd-19951223.34-fast.flm 11.8767915847 0.94 None -12.16 cfa 3698.0 7426.0
# Host correction...
# 1997do sn1997do-19971102.46-fast.flm 32.1663898618 0.94 None -11.64 cfa 3734.0 7416.0
# Host correction...
# 1998es sn1998es-19981114.22-fast.flm 33.3838668445 0.85 None -11.48 cfa 3732.0 7394.0
# Host correction...
# 2001v sn2001V-20010220.29-fast.flm 34.4848141641 0.82 None -12.51 cfa 3434.0 7380.0
# Host correction...
# 2003fa sn2003fa-20030605.42-fast.flm 11.2428469023 0.8 None -10.78 cfa 3626.0 7198.0
# Host correction...
# 2006gr sn2006gr-20060923.22-fast.flm 7.41919281872 0.81 None -11.18 cfa 3412.0 7118.0
# Host correction...
# 9 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))
# Collecting data...
# 12 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 12 spectra left
# 0 Peculiar Ias removed 12 spectra left
# 12 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 12 spectra left
# 2002bo sn2002bo-20020311-ui-corrected.flm 23.7473268028 1.08 None -11.94 bsnip 3338.0 10308.0
# Host correction...
# 2006ax sn2006ax-20060322.396-ui.flm 33.3853454623 1.06 None -10.07 bsnip 3316.0 10278.0
# Host correction...
# 2006qo sn2006qo-20061201.436-ui.flm 17.9261440322 None 0.984546462647 -11.08 bsnip 3264.0 10140.0
# Host correction...
# 2007le sn2007le-20071015.325-br-corrected.flm 44.7142427209 1.01 None -10.31 bsnip 3230.0 9104.0
# Host correction...
# 1997dt sn1997dt-19971123.19-fast.flm 40.960735005 1.04 None -10.71 cfa 3744.0 7436.0
# Host correction...
# 1999cp sn1999cp-19990622.20-fast.flm 31.4080847656 0.98 None -12.0 cfa 3400.0 7104.0
# Host correction...
# 2000fa sn2000fa-20001203.48-fast.flm 14.453775136 1.0 None -10.62 cfa 3654.0 7334.0
# Host correction...
# 2001ah sn2001ah-20010328.22-fast.flm 8.09716395481 0.98 None -10.18 cfa 3568.0 7080.0
# Host correction...
# 2003du 2003du_20030425_3451_10400_00.dat 91.472446308 1.07 None -12.1 other 3480.0 10286.0
# Host correction...
# 2006cp sn2006cp-20060530.25-fast.flm 22.3000225532 0.98 None -11.45 cfa 3460.0 7196.0
# Host correction...
# 2007bm sn2007bm-20070423.23-fast.flm 28.0201836308 1.09 None -11.27 cfa 3504.0 7322.0
# Host correction...
# 2007af SN07af_070304_g01_NTT_EM.dat 69.9233318031 1.04 None -10.4300000002 csp 4030.0 10096.0
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= 1.1 or dm15_from_fits >= 1.1))
# Collecting data...
# 8 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 8 spectra left
# 0 Peculiar Ias removed 8 spectra left
# 8 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 8 spectra left
# 1994d sn1994D-19940310.36-mmt.flm 61.6257187727 1.37 None -11.14 cfa 3202.0 8986.0
# Host correction...
# 2005cf sn2005cf-20050601.385-ui.flm 1.54511 1.1 None -10.94 bsnip 3340.0 10434.0
# Host correction...
# 1997bq sn1997bq-19970408.14-mmt.flm 39.3152816598 1.14 None -11.76 cfa 2956.0 8792.0
# Host correction...
# 2002cr sn2002cr-20020503.29-fast.flm 35.7201218683 1.19 None -11.31 cfa 3736.0 7422.0
# Host correction...
# 2002dj 2002dj_20020614_3745_9776_00.dat 68.4967345755 1.19 None -11.6 other 3762.0 9638.0
# Host correction...
# 2003w sn2003W-20030129.35-mmt.flm 68.0841819734 1.14 None -11.35 cfa 3188.0 8578.0
# Host correction...
# 2002er 2002er_20020828_3642_7834_00.dat 33.8855304051 1.23 None -10.9 other 3662.0 7714.0
# Host correction...
# 2006x 2006X_20060209_3834_8139_00.dat 13.7230578158 1.18 None -11.1 other 3866.0 8048.0
# Host correction...
# 8 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_dm15_very_early, comps_dm15_very_early[0], True)
query_db.set_min_num_spec(comps_dm15_very_early, 5)
comparison_plot(comps_dm15_very_early)
# stacked_plot_max(comps_dm15_very_early,5,1)

# %% [markdown]
# # -1 Week

# %%
query_dm15_m1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_m1week, sn_arrays, boot_arrays = query_db.main(len(query_dm15_m1week), query_dm15_m1week, boot='b',medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# ERROR:  sn2006oa-20061122-not.dat None
# 22 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 21 spectra left
# 0 Peculiar Ias removed 21 spectra left
# 20 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 19 spectra left
# 1995ac sn1995ac-19950926-uoi.flm 11.0580910033 0.77 None -6.34 bsnip 3098.0 9904.0
# Host correction...
# 1997do sn1997do-19971108-uoi.flm 59.4674538197 0.94 None -5.67 bsnip 3288.0 10346.0
# Host correction...
# 1998dm sn1998dm-19980831-ui-corrected.flm 85.4663369966 0.9 None -5.61 bsnip 3330.0 10084.0
# Host correction...
# 1999dk sn1999dk-19990817-ui.flm 55.0112411584 None 0.8843593476 -6.6 bsnip 3342.0 10346.0
# Host correction...
# 2001eh sn2001eh-20010911-ui.flm 17.5454059317 0.92 None -5.63 bsnip 3234.0 9980.0
# Host correction...
# 2003fa sn2003fa-20030607.426-ui.flm 21.5636658802 0.8 None -8.15 bsnip 3226.0 10054.0
# Host correction...
# 2005eq sn2005eq-20051004.512-ui.flm 11.3607143678 0.88 None -6.01 bsnip 3280.0 10156.0
# Host correction...
# 2005eu sn2005eu-20051011.350-ui-corrected.flm 10.7062305856 0.89 None -5.46 bsnip 3260.0 10096.0
# Host correction...
# 2006gr sn2006gr-20060925.202-ui.flm 23.8917524438 0.81 None -8.7 bsnip 3250.0 10004.0
# Host correction...
# 2006le sn2006le-20061030.456-ui-corrected.flm 53.1660416644 0.88 None -8.69 bsnip 3322.0 10272.0
# Host correction...
# 1998es sn1998es-19981118.28-fast.flm 102.306827896 0.85 None -7.42 cfa 3416.0 7394.0
# Host correction...
# 1999aa sn1999aa-19990215.28-fast.flm 51.3020136738 0.78 None -8.12 cfa 3442.0 7068.0
# Host correction...
# 1999dq sn1999dq-19990906.43-fast.flm 71.5344714573 0.86 None -8.57 cfa 3720.0 7386.0
# Host correction...
# 2001cp sn2001cp-20010621.45-fast.flm 12.9686398185 0.88 None -6.95 cfa 3690.0 7326.0
# Host correction...
# 2001v sn2001V-20010225.30-fast.flm 29.4550597006 0.82 None -7.5 cfa 3716.0 7380.0
# Host correction...
# 2002cd sn2002cd-20020410.49-fast.flm 16.7235550996 0.84 None -8.71 cfa 3732.0 7414.0
# Host correction...
# 2004as sn2004as-20040313.30-fast.flm 11.9406698954 0.92 None -8.1 cfa 3660.0 7264.0
# Host correction...
# 2006oa sn2006oa-20061119.16-fast.flm 7.77499319647 0.89 None -8.03999999999 cfa 3332.0 6946.0
# Host correction...
# 2006s sn2006S-20060128.50-fast.flm 25.0787847296 0.93 None -5.7 cfa 3434.0 7132.0
# Host correction...
# 19 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 33 spectra found
# 152 questionable files currently ignored
# 3 questionable spectra removed 30 spectra left
# 0 Peculiar Ias removed 30 spectra left
# 25 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 25 spectra left
# 1998dk sn1998dk-19980824-90-br.flm 28.9891747848 1.05 None -7.24 bsnip 3308.0 9920.0
# Host correction...
# 2000fa sn2000fa-20001205-ui-corrected.flm 32.3178853169 1.0 None -8.25 bsnip 3282.0 10184.0
# Host correction...
# 2002hu sn2002hu-20021108-br.flm 49.1617490353 1.05 None -5.81 bsnip 3028.0 9038.0
# Host correction...
# 2003kf sn2003kf-20031129-br.flm 87.3985459745 1.1 None -7.5 bsnip 3028.0 9292.0
# Host correction...
# 2003w sn2003W-20030204-ui.flm 19.4479814533 1.14 None -5.06 bsnip 3092.0 10146.0
# Host correction...
# 2004dt sn2004dt-20040816.413-ui-corrected.flm 30.481639234 1.14 None -6.46 bsnip 3306.0 10150.0
# Host correction...
# 2006cp sn2006cp-20060605.281-ui.flm 28.8033667582 0.98 None -5.3 bsnip 3288.0 10320.0
# Host correction...
# 2007bm sn2007bm-20070426.278-ui.flm 48.5841517328 1.09 None -7.79 bsnip 3370.0 10386.0
# Host correction...
# 2007qe sn2007qe-20071118.104-ui.flm 0.480642 1.03 None -6.54 bsnip 3284.0 10332.0
# Host correction...
# 1997bq sn1997bq-19970412.13-fast.flm 7.75292390273 1.14 None -7.77 cfa 3716.0 7444.0
# Host correction...
# 1997br sn1997br-19970413.32-fast.flm 53.5121944874 1.09 None -7.98 cfa 3724.0 7460.0
# Host correction...
# 1997dt sn1997dt-19971125.11-fast.flm 60.983645772 1.04 None -8.79 cfa 3744.0 7436.0
# Host correction...
# 1998ab sn1998ab-19980403.38-fast.flm 25.3887519399 1.04 None -8.02 cfa 3674.0 7254.0
# Host correction...
# 1998aq sn1998aq-19980419.26-fast.flm 147.450890325 1.11 None -8.94 cfa 3536.0 7064.0
# Host correction...
# 2001g sn2001G-20010115.32-fast.flm 49.2095876898 None 1.01886545818 -5.28 cfa 3710.0 7366.0
# Host correction...
# 2002bo 2002bo_20020318_3184_7576_00.dat 124.783424436 1.08 None -5.7 other 3222.0 7496.0
# Host correction...
# 2002de sn2002de-20020602.24-fast.flm 9.60141882387 0.96 None -6.26 cfa 3670.0 7286.0
# Host correction...
# 2004fu sn2004fu-20041110.17-fast.flm 39.8557021596 1.08 None -6.43 cfa 3500.0 7294.0
# Host correction...
# 2005cf sn2005cf-20050605.7-uvot.flm 17.2131422394 1.1 None -7.7 uv 1686.0 9882.0
# Host correction...
# 2006ax SN06ax_060324_b01_DUP_WF.dat 42.7894975471 1.06 None -8.39000000013 csp 3788.0 9034.0
# Host correction...
# 2007af sn2007af-20070309.47-fast.flm 96.5233288315 1.04 None -5.63 cfa 3510.0 7324.0
# Host correction...
# 2007f sn2007F-20070115.53-fast.flm 27.6256292393 0.96 None -7.87 cfa 3442.0 7188.0
# Host correction...
# 2007le sn2007le-20071019.21-fast.flm 84.7688466286 1.01 None -6.49 cfa 3502.0 7318.0
# Host correction...
# 2005hc SN05hc_051018_g01_NTT_EM.dat 3.74414230839 1.03 None -5.37000000011 csp 3876.0 9704.0
# Host correction...
# 2008bf SN08bf_080320_b01_CLA_LD.dat 44.4551940628 1.05 None -8.75 csp 3596.0 9166.0
# Host correction...
# 25 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))
# Collecting data...
# 11 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 11 spectra left
# 0 Peculiar Ias removed 11 spectra left
# 10 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 10 spectra left
# 2002cr sn2002cr-20020507-ui-corrected.flm 49.5899013369 1.19 None -6.78 bsnip 3320.0 10254.0
# Host correction...
# 2002dj sn2002dj-20020617-ui-corrected.flm 39.6499941826 1.19 None -7.98 bsnip 3156.0 10254.0
# Host correction...
# 2005iq sn2005iq-20051107.215-deimos.flm 37.947799231 1.19 None -5.86 bsnip 4790.0 9680.0
# Host correction...
# 2007cq sn2007cq-20070623.431-ui.flm 27.1134529739 1.2 None -5.82 bsnip 3278.0 10186.0
# Host correction...
# 1998dh sn1998dh-19980727.40-fast.flm 54.7326302399 1.17 None -8.5 cfa 3738.0 7426.0
# Host correction...
# 1999cl sn1999cl-19990605.19-fast.flm 78.0118401218 1.17 None -8.31 cfa 3742.0 7434.0
# Host correction...
# 2003cq sn2003cq-20030403.28-fast.flm 6.45676876221 1.2 None -5.92 cfa 3652.0 7248.0
# Host correction...
# 2007co sn2007co-20070608.35-fast.flm 23.1710564633 1.16 None -5.25 cfa 3436.0 7168.0
# Host correction...
# 2002er 2002er_20020831_3375_9903_00.dat 33.6194969072 1.23 None -7.9 other 3396.0 9766.0
# Host correction...
# 2006x 2006X_20060212_4170_6794_00.dat 36.2247620276 1.18 None -8.1 other 4200.0 6710.0
# Host correction...
# 10 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))
# Collecting data...
# 18 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 18 spectra left
# 0 Peculiar Ias removed 18 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 13 spectra left
# 1994d 1994D_19940316_3331_10270_00.dat 80.1753653033 1.37 None -5.5 other 3372.0 10192.0
# Host correction...
# 1998ef sn1998ef-19981019-br.flm 29.8462370397 1.27 None -8.62 bsnip 3196.0 9874.0
# Host correction...
# 2002he sn2002he-20021101.642-joined.flm 25.5794251425 1.44 None -5.91 bsnip 3906.0 9906.0
# Host correction...
# 2002hw sn2002hw-20021111-br.flm 42.7660070151 1.44 None -6.27 bsnip 3092.0 9196.0
# Host correction...
# 2004ef sn2004ef-20040910.310-ui-corrected.flm 29.0163369435 1.39 None -5.52 bsnip 3262.0 10136.0
# Host correction...
# 2005el sn2005el-20050926.496-ui-corrected.flm 48.6306501119 1.27 None -6.7 bsnip 3308.0 10296.0
# Host correction...
# 2006lf sn2006lf-20061030.420-ui-corrected.flm 38.1207811201 1.3 None -6.3 bsnip 3336.0 10314.0
# Host correction...
# 2007bd sn2007bd-20070410.254-ui.flm 14.1729323948 1.3 None -5.79 bsnip 3268.0 10232.0
# Host correction...
# 2001ep sn2001ep-20011010.49-fast.flm 31.7417103691 1.3 None -7.11 cfa 3724.0 7394.0
# Host correction...
# 2003cg 2003cg_20030326_3650_9347_00.dat 81.6494670978 1.26 None -5.4 other 3686.0 9260.0
# Host correction...
# 2003u sn2003U-20030129.53-mmt.flm 49.0957378561 1.46 None -8.77 cfa 3164.0 8510.0
# Host correction...
# 2005ki SN05ki_051125_b01_DUP_MS.dat 41.054855473 1.41 None -5.76000000024 csp 3760.0 7104.0
# Host correction...
# 2006d sn2006d-20060114-snifs-r.dat 71.8412741951 1.35 None -8.0 other 5010.0 9860.0
# Host correction...
# 13 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))
# Collecting data...
# 12 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 12 spectra left
# 1 Peculiar Ias removed 11 spectra left
# 8 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 8 spectra left
# 2005bl sn2005bl-20050417.214-ui.flm 1.27490723244 1.93 None -5.56 bsnip 3468.0 9972.0
# Host correction...
# 2006kf sn2006kf-20061024.352-ui.flm 25.4263782219 1.55 None -8.96 bsnip 3294.0 10232.0
# Host correction...
# 2007ci sn2007ci-20070519.316-ui.flm 0.515576 1.6 None -6.57 bsnip 3418.0 9926.0
# Host correction...
# 1998de sn1998de-19980726.47-fast.flm 22.3068615579 1.88 None -6.23 cfa 3710.0 7368.0
# Host correction...
# 2000cn sn2000cn-20000604.38-fast.flm 14.7894992761 1.51 None -8.52 cfa 3686.0 7318.0
# Host correction...
# 2000dk sn2000dk-20000920.39-fast.flm 33.2349373368 1.62 None -5.21 cfa 3708.0 7362.0
# Host correction...
# 2005mz sn2005mz-20060103.13-fast.flm 16.8797278956 1.83 None -7.67000000001 cfa 3480.0 7232.0
# Host correction...
# 2007au sn2007au-20070319.26-fast.flm 30.320277997 1.69 None -5.74 cfa 3462.0 7222.0
# Host correction...
# 8 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_dm15_m1week, comps_dm15_m1week[0], True)
query_db.set_min_num_spec(comps_dm15_m1week, 5)
comparison_plot(comps_dm15_m1week)
stacked_plot_max(comps_dm15_m1week,5,1)

# %% [markdown]
# # +1 Week

# %%
query_dm15_p1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p1week, sn_arrays, boot_arrays = query_db.main(len(query_dm15_p1week), query_dm15_p1week, boot='b',medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# ERROR:  sn2001eh-20010925.757-hst.flm None
# 24 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 23 spectra left
# 0 Peculiar Ias removed 23 spectra left
# 21 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 21 spectra left
# 2001ay sn2001ay-20010430-ui.flm 26.4791797721 0.68 None 6.79 bsnip 3216.0 10240.0
# Host correction...
# 2005hj sn2005hj-20051108.457-deimos.flm 15.3038132464 None 0.797073500543 7.51 bsnip 4684.0 9464.0
# Host correction...
# 2005m sn2005m-20050211.413-br.flm 0.104109 0.87 None 8.23 bsnip 4988.0 9932.0
# Host correction...
# 2006ot sn2006ot-20061201.241-ui.flm 7.88603549063 0.84 None 6.541 bsnip 3190.0 9924.0
# Host correction...
# 2007s sn2007s-20070218.375-ui.flm 42.2940446126 0.94 None 5.18 bsnip 3340.0 10308.0
# Host correction...
# 1995al sn1995al-19951114.52-fast.flm 154.38733207 0.87 None 6.42 cfa 3732.0 7506.0
# Host correction...
# 1996c sn1996C-19960223.44-mmt.flm 11.0142162828 0.93 None 7.94 cfa 3324.0 9048.0
# Host correction...
# 1997do sn1997do-19971122.45-fast.flm 128.07210637 0.94 None 8.35 cfa 3734.0 7416.0
# Host correction...
# 1998dm sn1998dm-19980910.42-fast.flm 36.7010435088 0.9 None 6.52 cfa 3746.0 7442.0
# Host correction...
# 1999dq sn1999dq-19990920.46-fast.flm 82.8005560114 0.86 None 5.46 cfa 3720.0 7386.0
# Host correction...
# 1999gp sn1999gp-20000114.16-fast.flm 22.2938696862 0.87 None 7.06 cfa 3674.0 7296.0
# Host correction...
# 2001eh sn2001eh-20010926.37-fast.flm 17.4418991689 0.92 None 8.87 cfa 3638.0 8668.0
# Host correction...
# 2002jy sn2002jy-20030101.10-fast.flm 26.7117549749 0.88 None 6.1 cfa 3700.0 7346.0
# Host correction...
# 2003fa sn2003fa-20030623.33-fast.flm 14.0810468138 0.8 None 7.13 cfa 3626.0 7198.0
# Host correction...
# 2003hu sn2003hu-20030927.14-fast.flm 9.42291565476 None 0.880569111523 8.04 cfa 3512.0 6966.0
# Host correction...
# 2004as sn2004as-20040327.35-fast.flm 10.6805316666 0.92 None 5.95 cfa 3660.0 7264.0
# Host correction...
# 2005eu sn2005eu-20051025.29-fast.flm 21.1252918168 0.89 None 8.59 cfa 3418.0 7112.0
# Host correction...
# 2006le sn2006le-20061114.38-fast.flm 30.0191380021 0.88 None 5.98 cfa 3468.0 7236.0
# Host correction...
# 2007ca sn2007ca-20070512.27-fast.flm 40.9341239252 0.89 None 5.57 cfa 3476.0 7260.0
# Host correction...
# 2007if sn2007if-20070911.29-mmt.flm 22.5339878676 0.71 None 5.89 cfa 3048.0 7738.0
# Host correction...
# 2005eq SN05eq_051018_g01_NTT_EM.dat 17.876258762 0.88 None 7.37000000011 csp 3938.0 9864.0
# Host correction...
# 21 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= .95 and dm15_cfa < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))
# Collecting data...
# 50 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 49 spectra left
# 1 Peculiar Ias removed 48 spectra left
# 43 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 43 spectra left
# 1997bp sn1997bp-19970416-uoi.flm 45.3984985531 1.08 None 5.49 bsnip 3184.0 10334.0
# Host correction...
# 1998v sn1998v-19980326-br.flm 83.5622224849 0.99 None 7.2 bsnip 3834.0 8992.0
# Host correction...
# 1999ek sn1999ek-19991105-ui.flm 11.0251739387 1.14 None 5.66 bsnip 3554.0 10230.0
# Host correction...
# 2000fa sn2000fa-20001221-ui-corrected.flm 32.5284742858 1.0 None 6.86 bsnip 3244.0 10242.0
# Host correction...
# 2002bf sn2002bf-20020311-ui-corrected.flm 3.68436684745 1.12 None 6.9 bsnip 3274.0 10106.0
# Host correction...
# 2002de sn2002de-20020617-ui-corrected.flm 21.1389644279 0.96 None 8.37 bsnip 3282.0 9550.0
# Host correction...
# 2002fk sn2002fk-20021008-br-corrected.flm 73.477917143 1.13 None 7.74 bsnip 3042.0 9304.0
# Host correction...
# 2005a sn2005a-20050115.357-br.flm 0.158206 1.11 None 5.55 bsnip 3374.0 9028.0
# Host correction...
# 2006cf sn2006cf-20060523.291-ui.flm 6.46920039592 None 1.08670703312 6.28 bsnip 3238.0 10032.0
# Host correction...
# 2006cm sn2006cm-20060605.470-ui.flm 18.6360132836 1.04 None 6.77 bsnip 3308.0 10380.0
# Host correction...
# 2006en sn2006en-20060902.319-ui-corrected.flm 8.71390080979 None 1.09808848852 8.55 bsnip 3268.0 10030.0
# Host correction...
# 2006mp sn2006mp-20061120.101-ui.flm 35.6301134171 None 1.01984566687 5.66 bsnip 3278.0 10174.0
# Host correction...
# 2006os sn2006os-20061201.142-ui.flm 12.2586785696 None 1.07243123623 8.61 bsnip 3256.0 10118.0
# Host correction...
# 2007le sn2007le-20071102.182-ui-corrected.flm 50.2756524377 1.01 None 7.43 bsnip 3362.0 10500.0
# Host correction...
# 2007qe sn2007qe-20071201.176-ui.flm 0.546484 1.03 None 6.23 bsnip 3300.0 10332.0
# Host correction...
# 1994ae sn1994ae-19941207.55-mmt.flm 71.6443179355 0.96 None 8.05 cfa 2788.0 8630.0
# Host correction...
# 1995d sn1995D-19950228.26-fast.flm 94.9344148792 1.05 None 7.56 cfa 3428.0 6962.0
# Host correction...
# 1997br sn1997br-19970429.28-fast.flm 97.4212435443 1.09 None 7.98 cfa 3724.0 7460.0
# Host correction...
# 1998ab sn1998ab-19980419.29-fast.flm 31.4023117268 1.04 None 7.89 cfa 3458.0 6904.0
# Host correction...
# 1998aq sn1998aq-19980503.24-fast.flm 151.625756162 1.11 None 5.04 cfa 3756.0 7436.0
# Host correction...
# 1998bu sn1998bu-19980528.19-fast.flm 213.713414423 1.03 None 8.49000000001 cfa 3760.0 7470.0
# Host correction...
# 1998eg sn1998eg-19981030.16-fast.flm 5.24426778012 1.14 None 5.26 cfa 3680.0 7212.0
# Host correction...
# 1999ef sn1999ef-19991013.29-fast.flm 16.7772049203 1.06 None 6.99 cfa 3630.0 7206.0
# Host correction...
# 2000ce sn2000ce-20000510.15-fast.flm 13.8917617841 1.0 None 6.85 cfa 3712.0 7370.0
# Host correction...
# 2001bf sn2001bf-20010525.47-mmt.flm 66.4794987763 0.99 None 8.77 cfa 3222.0 9798.0
# Host correction...
# 2001da sn2001da-20010724.45-fast.flm 39.3542536789 1.12 None 7.95 cfa 3708.0 7364.0
# Host correction...
# 2001en sn2001en-20011015.31-fast.flm 42.2505404746 1.12 None 5.41 cfa 3710.0 7370.0
# Host correction...
# 2001fe sn2001fe-20011122.48-fast.flm 51.2934429126 1.0 None 6.28000000001 cfa 3722.0 7392.0
# Host correction...
# 2002dp sn2002dp-20020702.45-fast.flm 31.9916296817 1.12 None 7.14999999999 cfa 3728.0 7404.0
# Host correction...
# 2004bg sn2004bg-20040420.33-fast.flm 39.7756095424 1.05 None 5.83 cfa 3696.0 7318.0
# Host correction...
# 2004l sn2004L-20040130.33-fast.flm 24.3653737516 1.12 None 5.43 cfa 3654.0 7256.0
# Host correction...
# 2005hc sn2005hc-20051031.29-fast.flm 12.1335352244 1.03 None 6.59 cfa 3384.0 7032.0
# Host correction...
# 2006bt sn2006bt-20060508.31-fast.flm 23.6923667613 1.0 None 5.91 cfa 3426.0 7126.0
# Host correction...
# 2006cp sn2006cp-20060617.21-fast.flm 43.7196401434 0.98 None 6.51 cfa 3458.0 7194.0
# Host correction...
# 2006et sn2006et-20060922.37-fast.flm 21.7000869293 1.02 None 6.47 cfa 3452.0 7204.0
# Host correction...
# 2007af sn2007af-20070320.48-fast.flm 115.04384913 1.04 None 5.38 cfa 3512.0 7326.0
# Host correction...
# 2007bm SN07bm_070511_b01_DUP_BC.dat 43.0006188416 1.09 None 6.9299999997 csp 3374.0 9444.0
# Host correction...
# 2007cg sn2007cg-20070515.22-fast.flm 10.8283741219 1.05 None 6.72 cfa 3418.0 7128.0
# Host correction...
# 2008bf sn2008bf-20080406.29-fast.flm 42.1100732334 1.05 None 7.69 cfa 3442.0 7190.0
# Host correction...
# 2008c sn2008C-20080109.29-fast.flm 55.8973265535 1.11 None 8.49 cfa 3468.0 7244.0
# Host correction...
# 2000e 2000E_20000210_3217_7484_00.dat 93.2948045424 1.09 None 6.8 other 3254.0 7400.0
# Host correction...
# 2003du 2003du_20030516_3258_9799_00.dat 65.6183666308 1.07 None 8.9 other 3290.0 9688.0
# Host correction...
# 2005cf 2005cf_20050618_3258_9998_00.dat 57.3876960663 1.1 None 5.3 other 3288.0 9884.0
# Host correction...
# 43 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))
# Collecting data...
# 19 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 18 spectra left
# 0 Peculiar Ias removed 18 spectra left
# 18 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 18 spectra left
# 1999cl sn1999cl-19990621-ir-corrected.flm 4.1220867414 1.17 None 7.9 bsnip 5142.0 10402.0
# Host correction...
# 2002er sn2002er-20020913-ui-corrected.flm 42.3462102918 1.23 None 5.26 bsnip 3212.0 10262.0
# Host correction...
# 2002ha sn2002ha-20021111-br.flm 65.6647972567 1.22 None 7.89 bsnip 3030.0 9230.0
# Host correction...
# 2002hd sn2002hd-20021102-ui.flm 28.1205195037 1.16 None 6.48 bsnip 3046.0 10000.0
# Host correction...
# 2002kf sn2002kf-20030106-br.flm 60.8444795775 1.2 None 6.81 bsnip 2994.0 9202.0
# Host correction...
# 2006ac sn2006ac-20060222.439-ui-corrected.flm 24.7915430408 1.2 None 7.96 bsnip 3300.0 10018.0
# Host correction...
# 2006ak sn2006ak-20060222.389-ui.flm 36.0305121732 1.22 None 8.43 bsnip 3254.0 9872.0
# Host correction...
# 2007cq sn2007cq-20070707.439-ui.flm 22.8812955982 1.2 None 7.84 bsnip 3278.0 10186.0
# Host correction...
# 1993ac sn1993ac-19931016.49-mmt.flm 16.3844031955 1.19 None 7.29 cfa 3050.0 7732.0
# Host correction...
# 1995e sn1995E-19950308.16-mmt.flm 16.135142189 1.16 None 8.96000000001 cfa 3168.0 8344.0
# Host correction...
# 1996bo sn1996bo-19961105.24-fast.flm 25.967157406 1.16 None 5.24 cfa 3688.0 7378.0
# Host correction...
# 1996z sn1996Z-19960520.17-fast.flm 40.5415736514 1.22 None 6.17 cfa 3724.0 7454.0
# Host correction...
# 1997y sn1997Y-19970214.47-fast.flm 29.5724033304 1.15 None 6.97 cfa 3736.0 7388.0
# Host correction...
# 1999gd sn1999gd-19991215.46-fast.flm 25.314215033 1.18 None 8.06 cfa 3704.0 7356.0
# Host correction...
# 2003ch sn2003ch-20030402.03-ldss2.flm 110.522155326 1.22 None 5.73 cfa 3660.0 9220.0
# Host correction...
# 2005kc sn2005kc-20051130.11-fast.flm 37.0078955462 1.24 None 6.81 cfa 3498.0 7250.0
# Host correction...
# 2007co sn2007co-20070619.45-fast.flm 27.9554716662 1.16 None 5.85 cfa 3436.0 7170.0
# Host correction...
# 2002dj 2002dj_20020704_3340_10256_00.dat 37.9231674168 1.19 None 8.4 other 3360.0 10114.0
# Host correction...
# 18 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))
# Collecting data...
# 40 spectra found
# 152 questionable files currently ignored
# 4 questionable spectra removed 36 spectra left
# 0 Peculiar Ias removed 36 spectra left
# 30 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 30 spectra left
# 1998dx sn1998dx-19980921-ui.flm 21.8082679608 1.32 None 5.13 bsnip 3182.0 9626.0
# Host correction...
# 2001ep sn2001ep-20011025-ui-corrected.flm 37.8659769534 1.3 None 7.85 bsnip 3288.0 10218.0
# Host correction...
# 2004ef sn2004ef-20040924.302-ui-corrected.flm 10.2041329015 1.39 None 8.05 bsnip 3272.0 10136.0
# Host correction...
# 2005am SN05am_050315_b01_DUP_WF.dat 53.5285585206 1.3 None 7.98999999976 csp 3822.0 9114.0
# Host correction...
# 2005el sn2005el-20051011.512-ui-corrected.flm 50.7511888344 1.27 None 8.09 bsnip 3322.0 10296.0
# Host correction...
# 2005ki sn2005ki-20051209.514-ui.flm 14.1686590972 1.41 None 8.35 bsnip 3308.0 10348.0
# Host correction...
# 2006bq sn2006bq-20060427.636-br.flm 55.768600012 1.29 None 6.97 bsnip 3080.0 9002.0
# Host correction...
# 2006bw sn2006bw-20060505.353-ui.flm 21.4167228049 1.28 None 8.9 bsnip 3304.0 10048.0
# Host correction...
# 2006ej sn2006ej-20060902.398-ui.flm 27.3445751447 None 1.27714374679 5.09 bsnip 3306.0 10144.0
# Host correction...
# 1994m sn1994M-19940508.26-fast.flm 9.77948018345 1.26 None 5.76 cfa 3674.0 7410.0
# Host correction...
# 1996x 1996X_19960425_3059_10470_00.dat 72.4216415988 1.26 None 6.9 other 3090.0 10350.0
# Host correction...
# 1998co sn1998co-19980630.47-fast.flm 34.8284909712 None 1.43684328517 6.97 cfa 3704.0 7356.0
# Host correction...
# 1999ej sn1999ej-19991109.26-fast.flm 41.6087433762 1.48 None 8.16 cfa 3720.0 7390.0
# Host correction...
# 2000b sn2000B-20000128.13-fast.flm 29.6556796947 1.46 None 8.73 cfa 3702.0 7350.0
# Host correction...
# 2002es sn2002es-20020906.49-fast.flm 15.9769371566 None 1.36630609234 5.19 cfa 3706.0 7358.0
# Host correction...
# 2002he sn2002he-20021113.53-fast.flm 23.3675385517 1.44 None 5.73 cfa 3682.0 7310.0
# Host correction...
# 2003cg 2003cg_20030407_3700_7751_00.dat 60.3628865287 1.26 None 6.6 other 3736.0 7670.0
# Host correction...
# 2005be SN05be_050407_b01_DUP_WF.dat 8.04135169465 1.49 None 7.2200000002 csp 3722.0 8874.0
# Host correction...
# 2006al sn2006al-20060227.42-fast.flm 11.5315429764 1.35 None 5.72 cfa 3320.0 6894.0
# Host correction...
# 2006eu sn2006eu-20060916.17-fast.flm 7.03339603476 1.27 None 8.27 cfa 3448.0 7194.0
# Host correction...
# 2006ev sn2006ev-20060916.23-fast.flm 12.2943427124 1.32 None 5.63 cfa 3432.0 7160.0
# Host correction...
# 2006hb SN06hb_060928_b01_DUP_WF.dat 53.0613984704 1.44 None 8.01000000024 csp 3794.0 9046.0
# Host correction...
# 2007ap sn2007ap-20070315.45-fast.flm 45.1225356647 1.37 None 7.55 cfa 3478.0 7254.0
# Host correction...
# 2007bc SN07bc_070417_b01_DUP_WF.dat 34.8884329369 1.37 None 7.54000000004 csp 3774.0 8998.0
# Host correction...
# 2007bd sn2007bd-20070425.17-fast.flm 11.0891860806 1.3 None 8.67 cfa 3422.0 7144.0
# Host correction...
# 2007nq SN07nq_071030_g01_NTT_EM.dat 11.5998815021 1.47 None 5.56000000006 csp 3878.0 9712.0
# Host correction...
# 2008af sn2008af-20080211.48-fast.flm 16.6018869295 1.33 None 6.08 cfa 3416.0 7130.0
# Host correction...
# 2008l sn2008L-20080202.15-fast.flm 46.2804259323 1.38 None 5.75 cfa 3460.0 7226.0
# Host correction...
# 2006gj SN06gj_060927_b01_DUP_WF.dat 31.6405133097 1.48 None 6.18000000017 csp 3746.0 8932.0
# Host correction...
# 1994d 1994D_19940328_4403_7013_00.dat 70.2577335705 1.37 None 6.5 other 4442.0 6944.0
# Host correction...
# 30 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))
# Collecting data...
# 21 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 19 spectra left
# 1 Peculiar Ias removed 18 spectra left
# 15 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 15 spectra left
# 1999da sn1999da-19990718-ui.flm 33.2739938735 1.9 None 6.76 bsnip 3368.0 10368.0
# Host correction...
# 2001fh sn2001fh-20011116-ui-corrected.flm 21.1805827283 1.51 None 5.93 bsnip 3308.0 10218.0
# Host correction...
# 2003iv sn2003iv-20031028-ui.flm 9.70177218385 1.65 None 6.58 bsnip 3202.0 10006.0
# Host correction...
# 2005ke sn2005ke-20051202.334-deimos.flm 56.6967649174 1.82 None 7.8 bsnip 3882.0 8976.0
# Host correction...
# 2005mc sn2005mc-20060105.368-ui.flm 15.1755293623 1.63 None 6.64 bsnip 3280.0 10192.0
# Host correction...
# 2006h sn2006h-20060124.254-ui.flm 11.6951273488 1.83 None 7.01 bsnip 3326.0 10404.0
# Host correction...
# 2006ob sn2006ob-20061201.107-ui.flm 3.49554197765 None 1.55520409496 7.65 bsnip 3176.0 9864.0
# Host correction...
# 2007ba SN07ba_070412_b01_DUP_WF.dat 23.6476115801 1.89 None 6.26000000024 csp 3710.0 8844.0
# Host correction...
# 1999by sn1999by-19990517.16-fast.flm 106.220152736 1.97 None 5.96000000001 cfa 3762.0 7474.0
# Host correction...
# 1999gh sn1999gh-19991206.53-fast.flm 46.1346419956 1.69 None 5.53 cfa 3742.0 7434.0
# Host correction...
# 2000cn sn2000cn-20000621.37-fast.flm 12.6184635707 1.51 None 8.47 cfa 3686.0 7318.0
# Host correction...
# 2002eu sn2002eu-20020907.49-fast.flm 4.40382959605 1.52 None 5.19 cfa 3636.0 7218.0
# Host correction...
# 2006mo sn2006mo-20061113.21-fast.flm 18.8354740691 None 1.55989340254 5.41 cfa 3402.0 7098.0
# Host correction...
# 2006n sn2006N-20060131.22-fast.flm 60.7236192138 1.5 None 5.62 cfa 3490.0 7258.0
# Host correction...
# 2008r sn2008R-20080202.13-fast.flm 48.610839942 1.54 None 5.32999999999 cfa 3480.0 7270.0
# Host correction...
# 15 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
# print comps_dm15_p1week[0].flux
# plt.plot(comps_dm15_p1week[0].wavelength, comps_dm15_p1week[0].flux)
# plt.show()
# composite.optimize_scales(comps_dm15_p1week, comps_dm15_p1week[0], True)
query_db.set_min_num_spec(comps_dm15_p1week, 5)
comparison_plot(comps_dm15_p1week)
stacked_plot_max(comps_dm15_p1week,5,1)

# %% [markdown]
# # +2 Weeks

# %%
query_dm15_p2week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa < 1. or dm15_from_fits < 1.))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1. and dm15_cfa < 1.15) or (dm15_from_fits >= 1. and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.5) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.5)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p2week, sn_arrays, boot_arrays = query_db.main(len(query_dm15_p2week), query_dm15_p2week, boot='b',medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa < 1. or dm15_from_fits < 1.))
# Collecting data...
# 27 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 26 spectra left
# 1 Peculiar Ias removed 25 spectra left
# 23 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 23 spectra left
# 1990o sn1990o-19900717-opt2.flm 43.5261495889 None 0.971934867571 12.54 bsnip 3854.0 6820.0
# Host correction...
# 1998dm sn1998dm-19980920-ui-corrected.flm 49.1935872649 0.9 None 14.22 bsnip 3330.0 10184.0
# Host correction...
# 1999aa sn1999aa-19990309-uvoir.flm 85.557160516 0.78 None 14.04 bsnip 3698.0 10794.0
# Host correction...
# 1999cp sn1999cp-19990718-ui-corrected.flm 37.1229905302 0.98 None 13.85 bsnip 3380.0 10402.0
# Host correction...
# 1999cw sn1999cw-19990709-ui.flm 45.6968954374 0.94 None 14.79 bsnip 3300.0 10372.0
# Host correction...
# 2001v sn2001v-20010321-ui.flm 41.8793399816 0.82 None 15.86 bsnip 3302.0 10198.0
# Host correction...
# 2007a sn2007a-20070126.140-ui.flm 30.2065166965 0.95 None 15.07 bsnip 3320.0 10268.0
# Host correction...
# 1995al sn1995al-19951123.54-fast.flm 100.5626661 0.87 None 15.44 cfa 3732.0 7506.0
# Host correction...
# 1996ai sn1996ai-19960706.23-fast.flm 21.4268226705 0.88 None 15.13 cfa 3740.0 7490.0
# Host correction...
# 1997do sn1997do-19971126.37-fast.flm 58.4040527672 0.94 None 12.27 cfa 3734.0 7416.0
# Host correction...
# 1998es sn1998es-19981210.19-fast.flm 39.1614163024 0.85 None 14.49 cfa 3494.0 7174.0
# Host correction...
# 1998v sn1998V-19980331.48-fast.flm 20.5222753142 0.99 None 12.28 cfa 3708.0 7344.0
# Host correction...
# 2001bf sn2001bf-20010529.37-fast.flm 40.4307071786 0.99 None 12.67 cfa 3714.0 7376.0
# Host correction...
# 2002cd sn2002cd-20020504.47-fast.flm 13.2495830238 0.84 None 15.27 cfa 3732.0 7394.0
# Host correction...
# 2003fa sn2003fa-20030628.23-fast.flm 14.2712985639 0.8 None 12.03 cfa 3626.0 7198.0
# Host correction...
# 2005eq sn2005eq-20051025.38-fast.flm 9.3741571821 0.88 None 14.38 cfa 3438.0 7154.0
# Host correction...
# 2006gr sn2006gr-20061017.24-fast.flm 4.25739293021 0.81 None 12.84 cfa 3458.0 7164.0
# Host correction...
# 2006le sn2006le-20061121.37-fast.flm 28.257255891 0.88 None 12.97 cfa 3470.0 7238.0
# Host correction...
# 2007ca sn2007ca-20070520.22-fast.flm 35.2906701711 0.89 None 13.52 cfa 3490.0 7268.0
# Host correction...
# 2007if sn2007if-20070920.36-fast.flm 18.4207820456 0.71 None 14.96 cfa 3284.0 6854.0
# Host correction...
# 2007s sn2007S-20070225.30-fast.flm 21.8612487224 0.94 None 12.2 cfa 3480.0 7264.0
# Host correction...
# 2005lu SN05lu_051220_b01_DUP_WF.dat 23.1547288119 0.74 None 12.7200000002 csp 3734.0 8900.0
# Host correction...
# 2001ay sn2001ay-20010509.704-hst.flm 48.4613773487 0.68 None 16.0 uv 2896.0 5480.0
# Host correction...
# 23 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1. and dm15_cfa < 1.15) or (dm15_from_fits >= 1. and dm15_from_fits < 1.15))
# Collecting data...
# 36 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 36 spectra left
# 0 Peculiar Ias removed 36 spectra left
# 32 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 31 spectra left
# 1999x sn1999x-19990212-uoi.flm 3.02238384125 1.11 None 15.76 bsnip 3270.0 10194.0
# Host correction...
# 2001en sn2001en-20011025-ui-corrected.flm 36.9088872218 1.12 None 14.72 bsnip 3280.0 10188.0
# Host correction...
# 2001n sn2001n-20010201-ui.flm 14.2763044931 None 1.11269436615 13.05 bsnip 3244.0 10332.0
# Host correction...
# 2002bo sn2002bo-20020408-ui-corrected.flm 38.4491717298 1.08 None 15.99 bsnip 3338.0 10308.0
# Host correction...
# 2002dp sn2002dp-20020711-ui-corrected.flm 27.6128629197 1.12 None 15.55 bsnip 3116.0 10232.0
# Host correction...
# 2005hc sn2005hc-20051108.465-deimos.flm 4.67877176364 1.03 None 14.26 bsnip 4740.0 9578.0
# Host correction...
# 2005ms sn2005ms-20060123.318-ui.flm 16.7968332852 None 1.0139405966 14.62 bsnip 3286.0 10290.0
# Host correction...
# 2007bm sn2007bm-20070519.239-ui.flm 39.9198168218 1.09 None 15.03 bsnip 3416.0 10386.0
# Host correction...
# 2007qe sn2007qe-20071211.187-ui.flm 14.703724437 1.03 None 16.0 bsnip 3294.0 10204.0
# Host correction...
# 2008c sn2008c-20080115.444-ui.flm 12.1315074451 1.11 None 15.68 bsnip 3358.0 10378.0
# Host correction...
# 1994q sn1994Q-19940605.35-fast.flm 12.5595636809 1.03 None 12.15 cfa 3740.0 7452.0
# Host correction...
# 1995d sn1995D-19950307.32-fast.flm 53.8266740466 1.05 None 14.62 cfa 3428.0 6960.0
# Host correction...
# 1996bl sn1996bl-19961103.25-fast.flm 8.13056020455 1.07 None 13.75 cfa 3622.0 7244.0
# Host correction...
# 1997bq sn1997bq-19970502.19-mmt.flm 23.606873014 1.14 None 12.29 cfa 3212.0 8800.0
# Host correction...
# 1998bu sn1998bu-19980601.18-fast.flm 143.25493927 1.03 None 12.48 cfa 3760.0 7470.0
# Host correction...
# 1998dk sn1998dk-19980913.39-fast.flm 34.7584675153 1.05 None 13.29 cfa 3722.0 7392.0
# Host correction...
# 1999ek sn1999ek-19991112.46-fast.flm 10.1507038096 1.14 None 12.36 cfa 3708.0 7362.0
# Host correction...
# 2000fa sn2000fa-20001228.41-fast.flm 20.9273900319 1.0 None 14.31 cfa 3694.0 7334.0
# Host correction...
# 2002bf sn2002bf-20020317.33-fast.flm 23.8011679293 1.12 None 12.93 cfa 3682.0 7312.0
# Host correction...
# 2002ck sn2002ck-20020515.29-fast.flm 12.0023963642 1.08 None 12.29 cfa 3664.0 7274.0
# Host correction...
# 2003kf sn2003kf-20031222.39-fast.flm 65.1476922315 1.1 None 14.59 cfa 3744.0 7436.0
# Host correction...
# 2004bg sn2004bg-20040427.28-fast.flm 23.8916458255 1.05 None 12.78 cfa 3696.0 7318.0
# Host correction...
# 2004fu sn2004fu-20041202.07-fast.flm 40.8756846131 1.08 None 15.47 cfa 3524.0 7322.0
# Host correction...
# 2007af sn2007af-20070327.45-fast.flm 52.9049842506 1.04 None 12.35 cfa 3510.0 7330.0
# Host correction...
# 2007le sn2007le-20071108.16-fast.flm 40.0345616678 1.01 None 13.46 cfa 3504.0 7320.0
# Host correction...
# 2007sr sn2007sr-20071228.39-fixedbg-swift.flm 0.838118669997 1.05 None 14.0 swift_uv 1708.0 6700.0
# Host correction...
# 2008bf SN08bf_080412_b01_DUP_WF.dat 36.6803112393 1.05 None 14.1699999999 csp 3762.0 8970.0
# Host correction...
# 2005na SN05na_060116_g01_NTT_EM.dat 12.3829674202 1.09 None 12.0300000003 csp 3948.0 9890.0
# Host correction...
# 2006ax SN06ax_060416_b01_BAA_IM.dat 19.355695835 1.06 None 14.6299999999 csp 3830.0 9484.0
# Host correction...
# 2003du 2003du_20030523_3498_10103_00.dat 69.5609962023 1.07 None 15.9 other 3528.0 9990.0
# Host correction...
# 2005cf 2005cf_20050628_3476_9998_00.dat 62.1627464858 1.1 None 15.3 other 3504.0 9884.0
# Host correction...
# 31 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))
# Collecting data...
# 20 spectra found
# 152 questionable files currently ignored
# 2 questionable spectra removed 18 spectra left
# 0 Peculiar Ias removed 18 spectra left
# 18 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 2 spectra with nan ivars removed 16 spectra left
# 1993ac sn1993ac-19931022-uoi.flm 7.01651370269 1.19 None 12.68 bsnip 3026.0 9932.0
# Host correction...
# 2001n sn2001n-20010201-ui.flm 14.2763044931 None 1.11269436615 13.05 bsnip 3244.0 10332.0
# Host correction...
# 2006bq sn2006bq-20060505.375-ui.flm 18.4515856305 1.29 None 14.64 bsnip 3330.0 10128.0
# Host correction...
# 2007cq sn2007cq-20070715.374-ui-corrected.flm 23.6802066779 1.2 None 15.57 bsnip 3292.0 10186.0
# Host correction...
# 1994m sn1994M-19940515.27-mmt.flm 23.2443497076 1.26 None 12.77 cfa 3158.0 8628.0
# Host correction...
# 1995ak sn1995ak-19951114.25-fast.flm 23.3362201362 1.25 None 13.65 cfa 3668.0 7376.0
# Host correction...
# 1996z sn1996Z-19960528.16-fast.flm 7.64290825657 1.22 None 14.16 cfa 3724.0 7456.0
# Host correction...
# 1999ac sn1999ac-19990325.50-fast.flm 38.4913490342 1.23 None 12.0 cfa 3736.0 7420.0
# Host correction...
# 2000cf sn2000cf-20000523.31-fast.flm 9.8589641666 1.16 None 15.01 cfa 3640.0 7226.0
# Host correction...
# 2003ch sn2003ch-20030410.17-fast.flm 2.83766087936 1.22 None 13.87 cfa 3680.0 7308.0
# Host correction...
# 2006ac sn2006ac-20060228.36-fast.flm 26.9319104338 1.2 None 13.26 cfa 3458.0 7192.0
# Host correction...
# 2007jg sn2007jg-20071006.44-fast.flm 9.64011055426 1.17 None 13.64 cfa 3402.0 7104.0
# Host correction...
# 2005el SN05el_051018_g01_NTT_EM.dat 18.0405696441 1.27 None 14.75 csp 3992.0 10002.0
# Host correction...
# 2002dj 2002dj_20020711_3304_10259_00.dat 41.6538477574 1.19 None 15.4 other 3326.0 10116.0
# Host correction...
# 2002er 2002er_20020922_3281_9756_00.dat 33.1534960554 1.23 None 14.1 other 3302.0 9620.0
# Host correction...
# 2003cg 2003cg_20030416_3500_9249_00.dat 21.7005668648 1.26 None 15.6 other 3536.0 9162.0
# Host correction...
# 16 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.5) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.5)))
# Collecting data...
# ERROR:  sn2001ep-20011102.871-hst.flm None
# 14 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 14 spectra left
# 0 Peculiar Ias removed 14 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 13 spectra left
# 1994d sn1994d-19940404.flm 83.9465998146 1.37 None 14.04 bsnip 3166.0 9836.0
# Host correction...
# 2000bk sn2000bk-20000427-ui.flm 11.2325077967 1.46 None 14.84 bsnip 3270.0 10044.0
# Host correction...
# 2006lf sn2006lf-20061120.276-ui-corrected.flm 10.2587315033 1.3 None 14.29 bsnip 3322.0 10314.0
# Host correction...
# 1998dx sn1998dx-19980929.13-fast.flm 5.38452524564 1.32 None 13.23 cfa 3580.0 7048.0
# Host correction...
# 2000b sn2000B-20000202.24-fast.flm 22.0676475155 1.46 None 13.84 cfa 3702.0 7350.0
# Host correction...
# 2005am sn2005am-20050321.20-fast.flm 29.4494314473 1.3 None 14.9 cfa 3506.0 7300.0
# Host correction...
# 2005hf sn2005hf-20051103.26-fast.flm 23.7867670127 1.31 None 15.46 cfa 3388.0 7056.0
# Host correction...
# 2005be SN05be_050412_b01_DUP_WF.dat 15.2368986565 1.49 None 12.21 csp 3722.0 8874.0
# Host correction...
# 2006ev SN06ev_060925_b01_DUP_WF.dat 7.90476015516 1.32 None 14.4899999998 csp 3744.0 8928.0
# Host correction...
# 2006gj SN06gj_061005_g01_NTT_EM.dat 6.09316180099 1.48 None 14.1699999999 csp 3940.0 9870.0
# Host correction...
# 2006hb SN06hb_061005_g01_NTT_EM.dat 23.8521574567 1.44 None 15.1200000001 csp 3990.0 9996.0
# Host correction...
# 2007bd SN07bd_070430_b01_DUP_BC.dat 8.49023359413 1.3 None 13.46 csp 3420.0 9342.0
# Host correction...
# 2006d sn2006d-20060203-snifs-r.dat 80.5775792534 1.35 None 12.0 other 5010.0 9860.0
# Host correction...
# 13 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))
# Collecting data...
# 20 spectra found
# 152 questionable files currently ignored
# 4 questionable spectra removed 16 spectra left
# 3 Peculiar Ias removed 13 spectra left
# 9 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 8 spectra left
# 2000cn sn2000cn-20000627-ui-corrected.flm 22.6061894002 1.51 None 14.25 bsnip 3266.0 10112.0
# Host correction...
# 2005ke sn2005ke-20051209.363-ui.flm 15.2914415029 1.82 None 14.79 bsnip 3368.0 10500.0
# Host correction...
# 2006mo sn2006mo-20061120.174-ui.flm 18.2809501758 None 1.55989340254 12.46 bsnip 3246.0 10076.0
# Host correction...
# 2007ax sn2007ax-20070410.281-ui.flm 15.2484247501 1.87 None 14.93 bsnip 3342.0 10478.0
# Host correction...
# 1997cn sn1997cn-19970530.20-fast.flm 6.74019284005 1.9 None 12.1 cfa 3690.0 7394.0
# Host correction...
# 2006h sn2006H-20060130.16-fast.flm 26.0686492235 1.83 None 12.56 cfa 3496.0 7262.0
# Host correction...
# 2006gt SN06gt_061010_b01_DUP_WF.dat 4.0592901503 1.66 None 15.25 csp 3688.0 8790.0
# Host correction...
# 2006kf SN06kf_061116_b01_DUP_WF.dat 20.5984081438 1.55 None 14.48 csp 3772.0 8994.0
# Host correction...
# 8 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_dm15_p2week, comps_dm15_p2week[0], True)
query_db.set_min_num_spec(comps_dm15_p2week, 5)
comparison_plot(comps_dm15_p2week)
stacked_plot_max(comps_dm15_p2week,5,1)

# %% [markdown]
# # +1 Month

# %%
query_dm15_p1month = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.5) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.5)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p1month, sn_arrays, boot_arrays = query_db.main(len(query_dm15_p1month), query_dm15_p1month, boot='b',medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# 17 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 17 spectra left
# 0 Peculiar Ias removed 17 spectra left
# 17 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 17 spectra left
# 2001cp sn2001cp-20010727-ui.flm 24.3786594507 0.88 None 28.62 bsnip 3278.0 10124.0
# Host correction...
# 2001eh sn2001eh-20011020-ui.flm 12.0647109003 0.92 None 32.08 bsnip 3234.0 9980.0
# Host correction...
# 2005lu sn2005lu-20060105.180-ui.flm 4.88041502283 0.74 None 27.88 bsnip 3258.0 10124.0
# Host correction...
# 2005m sn2005m-20050307.179-ui.flm 24.0983970039 0.87 None 31.49 bsnip 3284.0 10224.0
# Host correction...
# 2007ca sn2007ca-20070609.277-ui-corrected.flm 19.9769837427 0.89 None 32.22 bsnip 3320.0 10306.0
# Host correction...
# 2007s sn2007s-20070318.357-br.flm 0.707841953198 0.94 None 32.78 bsnip 3454.0 9064.0
# Host correction...
# 1994s sn1994S-19940712.18-fast.flm 11.3126491764 0.94 None 26.88 cfa 3840.0 7608.0
# Host correction...
# 1998dm sn1998dm-19980930.36-fast.flm 38.4392695494 0.9 None 26.46 cfa 3746.0 7442.0
# Host correction...
# 1998es sn1998es-19981225.14-fast.flm 43.8483945722 0.85 None 29.44 cfa 3534.0 7214.0
# Host correction...
# 1999aa sn1999aa-19990322.27-fast.flm 32.9883470878 0.78 None 26.87 cfa 3718.0 7384.0
# Host correction...
# 1999dq sn1999dq-19991011.45-fast.flm 55.2674587947 0.86 None 26.45 cfa 3720.0 7386.0
# Host correction...
# 2001ay sn2001ay-20010525.34-mmt.flm 36.7509011181 0.68 None 32.34 cfa 3176.0 9032.0
# Host correction...
# 2001v sn2001V-20010401.22-fast.flm 24.8491710875 0.82 None 27.42 cfa 3716.0 7380.0
# Host correction...
# 2002jy sn2002jy-20030126.10-fast.flm 6.84214293848 0.88 None 31.1 cfa 3700.0 7346.0
# Host correction...
# 2004as sn2004as-20040419.26-fast.flm 6.67925581938 0.92 None 28.86 cfa 3660.0 7264.0
# Host correction...
# 2005eq sn2005eq-20051107.38-fast.flm 11.4048954623 0.88 None 27.38 cfa 3448.0 7164.0
# Host correction...
# 2006le sn2006le-20061212.30-fast.flm 19.7125131555 0.88 None 33.9 cfa 3466.0 7236.0
# Host correction...
# 17 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))
# Collecting data...
# ERROR:  2002bo_20020421_0_2_00.dat None
# 37 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 36 spectra left
# 1 Peculiar Ias removed 35 spectra left
# 31 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 31 spectra left
# 1990o sn1990o-19900731-opt2.flm 18.9422979174 None 0.971934867571 26.5 bsnip 3834.0 6762.0
# Host correction...
# 1995d sn1995d-19950325-uoi2.flm 29.4769344867 1.05 None 32.58 bsnip 3170.0 10978.0
# Host correction...
# 1998bu sn1998bu-19980618-ui.flm 64.1344102033 1.03 None 29.58 bsnip 3440.0 10320.0
# Host correction...
# 2000ce sn2000ce-20000531-ui.flm 12.1172611499 1.0 None 27.05 bsnip 3288.0 10234.0
# Host correction...
# 2002bo sn2002bo-20020420-ui.flm 36.0298336826 1.08 None 27.94 bsnip 3338.0 10308.0
# Host correction...
# 2003du 2003du_20030609_3200_10499_00.dat 32.8965246244 1.07 None 32.9 other 3232.0 10384.0
# Host correction...
# 2004bg sn2004bg-20040512.298-ui.flm 0.354612029091 1.05 None 28.01 bsnip 3522.0 10322.0
# Host correction...
# 2004gc sn2004gc-20041217.387-ui.flm 0.325409025791 1.08 None 31.33 bsnip 3312.0 9904.0
# Host correction...
# 2005ls sn2005ls-20060106.246-ui.flm 9.37784616768 0.98 None 26.29 bsnip 3292.0 10234.0
# Host correction...
# 2005na sn2005na-20060206.310-ui-corrected.flm 8.1536599479 1.09 None 31.19 bsnip 3566.0 10280.0
# Host correction...
# 2006ax sn2006ax-20060428.224-ui.flm 31.7530884677 1.06 None 26.16 bsnip 3316.0 10278.0
# Host correction...
# 2006bt sn2006bt-20060605.366-ui.flm 8.6606277003 1.0 None 32.23 bsnip 3258.0 10220.0
# Host correction...
# 2006en sn2006en-20060925.232-ui-corrected.flm 7.02579150564 None 1.09808848852 30.75 bsnip 3668.0 9876.0
# Host correction...
# 2006os sn2006os-20061220.233-ui.flm 9.7053374073 None 1.07243123623 27.09 bsnip 3256.0 10118.0
# Host correction...
# 2007af sn2007af-20070410.396-ui-corrected.flm 12.3711261742 1.04 None 26.45 bsnip 3346.0 10494.0
# Host correction...
# 2007sr sn2007sr-20080115.587-ui.flm 52.0393214303 1.05 None 32.61 bsnip 3352.0 10394.0
# Host correction...
# 2008bf sn2008bf-20080427-ui.flm 21.2545622777 1.05 None 27.93 bsnip 3274.0 10498.0
# Host correction...
# 1994ae sn1994ae-19941228.49-fast.flm 95.0294043909 0.96 None 28.99 cfa 3486.0 6904.0
# Host correction...
# 1997bp sn1997bp-19970512.22-fast.flm 37.2725892762 1.08 None 31.72 cfa 3720.0 7436.0
# Host correction...
# 1998dk sn1998dk-19980930.35-fast.flm 32.0773064992 1.05 None 30.25 cfa 3722.0 7392.0
# Host correction...
# 1998ec sn1998ec-19981029.50-fast.flm 11.3803608424 1.08 None 26.0 cfa 3698.0 7228.0
# Host correction...
# 1998v sn1998V-19980419.50-fast.flm 11.2581729832 0.99 None 31.3 cfa 3708.0 6634.0
# Host correction...
# 2000fa sn2000fa-20010115.41-fast.flm 5.26321887458 1.0 None 32.31 cfa 3694.0 7334.0
# Host correction...
# 2001fe sn2001fe-20011214.48-fast.flm 32.5148358902 1.0 None 28.28 cfa 3722.0 7392.0
# Host correction...
# 2001g sn2001G-20010216.31-fast.flm 31.6174406263 None 1.01886545818 26.71 cfa 3710.0 7366.0
# Host correction...
# 2002ck sn2002ck-20020602.23-fast.flm 4.32829968893 1.08 None 30.23 cfa 3664.0 7274.0
# Host correction...
# 2002de sn2002de-20020706.18-fast.flm 10.6637104773 0.96 None 27.68 cfa 3670.0 7286.0
# Host correction...
# 2004fu sn2004fu-20041214.09-fast.flm 18.9407456673 1.08 None 27.49 cfa 3500.0 7292.0
# Host correction...
# 2006cf sn2006cf-20060618.19-fast.flm 15.976014253 None 1.08670703312 31.79 cfa 3394.0 7060.0
# Host correction...
# 2007f sn2007F-20070219.43-fast.flm 8.27898660739 0.96 None 27.03 cfa 3448.0 7194.0
# Host correction...
# 2006et SN06et_061011_b01_DUP_WF.dat 29.7576689257 1.02 None 26.6400000001 csp 3768.0 8986.0
# Host correction...
# 31 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))
# Collecting data...
# 41 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 40 spectra left
# 0 Peculiar Ias removed 40 spectra left
# 37 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 36 spectra left
# 1993ac sn1993ac-19931108-ui.flm 4.28132103463 1.19 None 28.66 bsnip 3120.0 9484.0
# Host correction...
# 1995ak sn1995ak-19951126-opt.flm 39.6072773135 1.25 None 26.38 bsnip 5038.0 9906.0
# Host correction...
# 1998dh sn1998dh-19980831-ui-corrected.flm 20.2824540323 1.17 None 26.47 bsnip 3416.0 10060.0
# Host correction...
# 1998ef sn1998ef-19981125-ui.flm 35.0099105447 1.27 None 27.83 bsnip 3322.0 9974.0
# Host correction...
# 1998eg sn1998eg-19981125-ui.flm 6.41136160397 1.14 None 30.6 bsnip 3300.0 9904.0
# Host correction...
# 1999x sn1999x-19990223-ui.flm 8.50890670755 1.11 None 26.6 bsnip 3308.0 10242.0
# Host correction...
# 2002cr sn2002cr-20020617-ui.flm 31.6619535336 1.19 None 33.69 bsnip 3146.0 10254.0
# Host correction...
# 2004dt sn2004dt-20040924.400-ui-corrected.flm 28.755390854 1.14 None 31.77 bsnip 3306.0 10248.0
# Host correction...
# 2005bo sn2005bo-20050515.289-ui.flm 21.54991239 1.28 None 27.71 bsnip 3356.0 10210.0
# Host correction...
# 2005cf sn2005cf-20050710.221-ui.flm 35.4570718622 1.1 None 27.64 bsnip 3344.0 10308.0
# Host correction...
# 2006az sn2006az-20060428.289-ui.flm 14.5998937939 1.29 None 26.3 bsnip 3272.0 10136.0
# Host correction...
# 2006bw sn2006bw-20060528.383-ui.flm 5.96438733455 1.28 None 31.26 bsnip 3264.0 10048.0
# Host correction...
# 2006ef sn2006ef-20060919.421-ui-corrected.flm 13.3023481614 None 1.21197621888 28.71 bsnip 3312.0 10364.0
# Host correction...
# 2006ej sn2006ej-20060925.299-ui.flm 19.8433665729 None 1.27714374679 27.54 bsnip 3296.0 10144.0
# Host correction...
# 2006x sn2006x-20060322.422-ui.flm 41.444158435 1.18 None 31.01 bsnip 3354.0 10396.0
# Host correction...
# 2007co sn2007co-20070715.240-ui-corrected.flm 7.56135479274 1.16 None 30.81 bsnip 3556.0 9810.0
# Host correction...
# 1995e sn1995E-19950331.22-mmt.flm 19.0495406264 1.16 None 32.02 cfa 3254.0 8082.0
# Host correction...
# 1996x 1996X_19960519_3372_9254_00.dat 69.1062206408 1.26 None 30.9 other 3400.0 9144.0
# Host correction...
# 1998aq sn1998aq-19980528.22-fast.flm 69.7430549726 1.11 None 30.02 cfa 3756.0 7462.0
# Host correction...
# 1999ac sn1999ac-19990409.45-fast.flm 35.642848512 1.23 None 26.95 cfa 3736.0 7420.0
# Host correction...
# 1999gd sn1999gd-20000106.44-fast.flm 10.6510273769 1.18 None 30.04 cfa 3704.0 7356.0
# Host correction...
# 2000cf sn2000cf-20000603.33-fast.flm 9.59013104869 1.16 None 26.03 cfa 3640.0 7226.0
# Host correction...
# 2001n sn2001N-20010217.39-fast.flm 19.5085653776 None 1.11269436615 26.59 cfa 3694.0 7336.0
# Host correction...
# 2002bf sn2002bf-20020403.21-fast.flm 24.5458076606 1.12 None 29.81 cfa 3682.0 7312.0
# Host correction...
# 2002fk sn2002fk-20021103.37-mmt.flm 9.27621586648 1.13 None 33.47 cfa 3228.0 8736.0
# Host correction...
# 2002ha sn2002ha-20021205.09-fast.flm 6.3181001174 1.22 None 32.69 cfa 3718.0 7384.0
# Host correction...
# 2002kf sn2002kf-20030129.28-mmt.flm 38.3540680967 1.2 None 30.08 cfa 3190.0 8584.0
# Host correction...
# 2003cg sn2003cg-20030427.18-fast.flm 31.2349789299 1.26 None 26.78 cfa 3756.0 7460.0
# Host correction...
# 2003cq sn2003cq-20030509.15-fast.flm 2.68699087737 1.2 None 29.95 cfa 3652.0 7248.0
# Host correction...
# 2003w sn2003W-20030310.28-fast.flm 24.2397938579 1.14 None 28.58 cfa 3698.0 7342.0
# Host correction...
# 2004l sn2004L-20040220.29-fast.flm 18.2874539684 1.12 None 26.39 cfa 3654.0 7256.0
# Host correction...
# 2005el sn2005el-20051102.40-fast.flm 23.3746981937 1.27 None 30.0 cfa 3480.0 7250.0
# Host correction...
# 2005kc SN05kc_051222_b01_DUP_WF.dat 16.6253472311 1.24 None 28.8599999999 csp 3794.0 9048.0
# Host correction...
# 2008c sn2008C-20080130.28-fast.flm 33.9873610896 1.11 None 29.48 cfa 3468.0 7244.0
# Host correction...
# 1994m 1994M_19940605_3699_9505_00.dat 18.6476107382 1.26 None 33.5 other 3666.0 9240.0
# Host correction...
# 2002dj 2002dj_20020725_3741_10264_00.dat 39.2924194995 1.19 None 29.4 other 3758.0 10120.0
# Host correction...
# 36 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.5) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.5)))
# Collecting data...
# 19 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 19 spectra left
# 0 Peculiar Ias removed 19 spectra left
# 17 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 1 spectra with nan ivars removed 16 spectra left
# 1994d sn1994d-19940420.flm 44.924309615 1.37 None 29.63 bsnip 3256.0 10136.0
# Host correction...
# 1998dx sn1998dx-19981015-ui.flm 4.00295450705 1.32 None 27.84 bsnip 3182.0 9626.0
# Host correction...
# 2001ep sn2001ep-20011115-ui.flm 33.5135888596 1.3 None 28.46 bsnip 3288.0 10218.0
# Host correction...
# 2004ef sn2004ef-20041013.373-ui-corrected.flm 0.907627926592 1.39 None 26.55 bsnip 3644.0 9822.0
# Host correction...
# 2006d sn2006d-20060222.513-ui.flm 7.26563840671 1.35 None 32.54 bsnip 3348.0 10164.0
# Host correction...
# 2007ap sn2007ap-20070410.502-ui.flm 13.1052356838 1.37 None 32.85 bsnip 3314.0 10386.0
# Host correction...
# 2008l sn2008l-20080229-ir.flm 25.5241461457 1.38 None 32.37 bsnip 4358.0 9648.0
# Host correction...
# 1998co sn1998co-19980722.40-fast.flm 17.8575839038 None 1.43684328517 28.9 cfa 3704.0 7356.0
# Host correction...
# 2000bk sn2000bk-20000510.19-fast.flm 4.90495975165 1.46 None 27.19 cfa 3678.0 7304.0
# Host correction...
# 2002es sn2002es-20020928.43-fast.flm 5.75163336498 None 1.36630609234 27.13 cfa 3706.0 7358.0
# Host correction...
# 2004gs sn2004gs-20050118.36-fast.flm 3.3703094978 1.41 None 32.56 cfa 3446.0 7170.0
# Host correction...
# 2005am SN05am_050407_b01_DUP_WF.dat 38.8299204598 1.3 None 30.9399999999 csp 3822.0 9114.0
# Host correction...
# 2006hb sn2006hb-20061022.39-fast.flm 19.3920918692 1.44 None 30.79 cfa 3476.0 7254.0
# Host correction...
# 2007bc sn2007bc-20070511.18-fast.flm 15.7246114889 1.37 None 31.28 cfa 3458.0 7216.0
# Host correction...
# 2006ev SN06ev_061011_b01_DUP_WF.dat 18.3654859252 1.32 None 30.4099999997 csp 3744.0 8928.0
# Host correction...
# 2006gj SN06gj_061016_b01_HIL_BC.dat 9.41330792747 1.48 None 26.25 csp 3668.0 6926.0
# Host correction...
# 16 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))
# Collecting data...
# 22 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 22 spectra left
# 3 Peculiar Ias removed 19 spectra left
# 17 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 17 spectra left
# 1994t sn1994t-19940715-ui.flm 1.23305789416 1.51 None 33.09 bsnip 3066.0 10002.0
# Host correction...
# 1998de sn1998de-19980831-ui.flm 9.84707245429 1.88 None 29.49 bsnip 3298.0 9986.0
# Host correction...
# 2000dk sn2000dk-20001024-ui-corrected.flm 29.3331291105 1.62 None 28.41 bsnip 3294.0 10172.0
# Host correction...
# 2002eu sn2002eu-20021001.237-ui-corrected.flm 0.883139773437 1.52 None 26.73 bsnip 3232.0 9974.0
# Host correction...
# 2006em sn2006em-20060925.415-ui.flm 0.0392108 1.5 None 26.7 bsnip 3298.0 10154.0
# Host correction...
# 2006n sn2006n-20060222.131-ui.flm 31.775489849 1.5 None 27.54 bsnip 3330.0 10106.0
# Host correction...
# 2007au sn2007au-20070426.255-ui.flm 5.01785019389 1.69 None 31.85 bsnip 3682.0 9040.0
# Host correction...
# 2007ci sn2007ci-20070623.249-ui.flm 11.7353341045 1.6 None 27.75 bsnip 3300.0 10264.0
# Host correction...
# 1998bp sn1998bp-19980529.42-fast.flm 17.6233588619 1.79 None 26.02 cfa 3732.0 7414.0
# Host correction...
# 1999by sn1999by-19990609.17-fast.flm 45.9123682949 1.97 None 28.97 cfa 3762.0 7474.0
# Host correction...
# 1999gh sn1999gh-19991229.45-fast.flm 21.4034590884 1.69 None 28.45 cfa 3742.0 7434.0
# Host correction...
# 2000cn sn2000cn-20000709.24-fast.flm 7.43502463549 1.51 None 26.34 cfa 3686.0 7318.0
# Host correction...
# 2002do sn2002do-20020718.29-fast.flm 14.5487767107 1.56 None 30.89 cfa 3712.0 7374.0
# Host correction...
# 2002fb sn2002fb-20021009.34-fast.flm 5.78520068946 1.77 None 27.24 cfa 3714.0 7376.0
# Host correction...
# 2005ke SN05ke_051221_b01_DUP_WF.dat 36.5327974006 1.82 None 27.3700000001 csp 3832.0 9142.0
# Host correction...
# 2006eq SN06eq_060925_b01_DUP_WF.dat 5.81487051442 1.62 None 26.4199999999 csp 3672.0 8750.0
# Host correction...
# 2006kf SN06kf_061130_b01_HIL_BC.dat 3.57136125599 1.55 None 29.5 csp 3750.0 7032.0
# Host correction...
# 17 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_dm15_p1month, comps_dm15_p1month[0], True)
query_db.set_min_num_spec(comps_dm15_p1month, 5)
comparison_plot(comps_dm15_p1month)
stacked_plot_max(comps_dm15_p1month,5,1)

# %% [markdown]
# # +2 Months

# %%
query_dm15_p2month = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa < 1. or dm15_from_fits < 1.))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1. and dm15_cfa < 1.15) or (dm15_from_fits >= 1. and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.35) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.35))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.35 or dm15_from_fits >= 1.35))"]

# %%
comps_dm15_p2month, sn_arrays, boot_arrays = query_db.main(len(query_dm15_p2month), query_dm15_p2month, boot='b',medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa < 1. or dm15_from_fits < 1.))
# Collecting data...
# 15 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 15 spectra left
# 1 Peculiar Ias removed 14 spectra left
# 13 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 13 spectra left
# 1998es sn1998es-19990122.000-uvoir.flm 59.1670727714 0.85 None 57.42 bsnip 3514.0 10786.0
# Host correction...
# 1999aa sn1999aa-19990424-ui.flm 12.9867095051 0.78 None 59.34 bsnip 3304.0 10322.0
# Host correction...
# 2001eh sn2001eh-20011118.217-joined.flm 13.8359868588 0.92 None 59.9 bsnip 3840.0 9786.0
# Host correction...
# 2002cd sn2002cd-20020617-ui.flm 8.69200566116 0.84 None 58.4 bsnip 3250.0 10244.0
# Host correction...
# 2005ls sn2005ls-subtracted-20060206.260-ui.flm 3.54659431124 0.98 None 56.66 bsnip 3292.0 10234.0
# Host correction...
# 2007if sn2007if-20071112.204-br.flm 20.6776196828 0.71 None 63.12 bsnip 2972.0 8488.0
# Host correction...
# 2007s sn2007s-20070416.352-br.flm 15.5876402727 0.94 None 61.38 bsnip 3124.0 9154.0
# Host correction...
# 1994ae sn1994ae-19950131.40-fast.flm 29.520224654 0.96 None 62.9 cfa 3686.0 7436.0
# Host correction...
# 1999dq sn1999dq-19991112.31-fast.flm 40.320372008 0.86 None 58.31 cfa 3720.0 7386.0
# Host correction...
# 1999gp sn1999gp-20000303.12-fast.flm 12.5065900328 0.87 None 56.02 cfa 3674.0 7296.0
# Host correction...
# 2001ay sn2001ay-20010618.30-mmt.flm 15.4094635096 0.68 None 56.3 cfa 3158.0 8590.0
# Host correction...
# 2001bf sn2001bf-20010715.40-mmt.flm 28.5402188824 0.99 None 59.7 cfa 3202.0 9118.0
# Host correction...
# 2001v sn2001V-20010501.36-fast.flm 13.8109422322 0.82 None 57.56 cfa 3716.0 7380.0
# Host correction...
# 13 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1. and dm15_cfa < 1.15) or (dm15_from_fits >= 1. and dm15_from_fits < 1.15))
# Collecting data...
# 18 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 18 spectra left
# 0 Peculiar Ias removed 18 spectra left
# 16 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 16 spectra left
# 1995d sn1995d-19950422-uoi.flm 0.73281 1.05 None 60.3 bsnip 3326.0 10198.0
# Host correction...
# 1998bu sn1998bu-19980717-ui.flm 37.0618516077 1.03 None 58.49 bsnip 3392.0 10320.0
# Host correction...
# 2002bo sn2002bo-20020519-ui-corrected.flm 16.3937988065 1.08 None 56.7 bsnip 3338.0 10308.0
# Host correction...
# 2003du sn2003du-20030706.343-ui-corrected.flm 25.0077343602 1.07 None 60.26 bsnip 3330.0 10384.0
# Host correction...
# 2003w sn2003w-20030408-ui.flm 20.9854161518 1.14 None 56.56 bsnip 3164.0 10146.0
# Host correction...
# 1997bp sn1997bp-19970610.20-fast.flm 25.3427279749 1.08 None 60.7 cfa 3720.0 7448.0
# Host correction...
# 1998aq sn1998aq-19980624.19-fast.flm 42.8526016688 1.11 None 56.99 cfa 3756.0 7462.0
# Host correction...
# 2001da sn2001da-20010912.32-fast.flm 11.3960650135 1.12 None 57.82 cfa 3708.0 7364.0
# Host correction...
# 2001fe sn2001fe-20020118.37-fast.flm 12.7747903501 1.0 None 63.17 cfa 3722.0 7392.0
# Host correction...
# 2001g sn2001G-20010325.27-mmt.flm 25.2816100829 None 1.01886545818 63.67 cfa 3248.0 8654.0
# Host correction...
# 2004dt SN04dt_041024_b01_CLA_LD.dat 15.2648239541 1.14 None 63.71 csp 3582.0 8776.0
# Host correction...
# 2007af SN07af_070511_b01_DUP_BC.dat 25.4425644283 1.04 None 57.4300000002 csp 3376.0 9448.0
# Host correction...
# 2008bf sn2008bf-20080530.16-fast.flm 12.7651735491 1.05 None 61.56 cfa 3442.0 7190.0
# Host correction...
# 2005na SN05na_060308_b01_DUP_WF.dat 11.3128374112 1.09 None 62.98 csp 3754.0 8950.0
# Host correction...
# 2007sr SN07sr_080214_g01_NTT_EM.dat 37.2388713775 1.05 None 62.8199999998 csp 4030.0 10096.0
# Host correction...
# 2005cf 2005cf_20050812_3922_8763_00.dat 16.997776703 1.1 None 60.3 other 3948.0 8658.0
# Host correction...
# 16 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.15 and dm15_cfa < 1.35) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.35))
# Collecting data...
# 13 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 13 spectra left
# 0 Peculiar Ias removed 13 spectra left
# 12 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 12 spectra left
# 2002cr sn2002cr-20020711-ui-corrected.flm 17.7999855179 1.19 None 57.47 bsnip 3220.0 10254.0
# Host correction...
# 2002er sn2002er-20021108-br.flm 13.0199476165 1.23 None 60.64 bsnip 3162.0 9286.0
# Host correction...
# 2002ha sn2002ha-20030106-br.flm 8.84140590473 1.22 None 63.11 bsnip 3134.0 9250.0
# Host correction...
# 2007co sn2007co-20070814.276-ui.flm 9.48763063027 1.16 None 60.06 bsnip 3556.0 9570.0
# Host correction...
# 1996x 1996X_19960614_2806_9811_00.dat 7.08088187665 1.26 None 56.9 other 2838.0 9696.0
# Host correction...
# 1999ac sn1999ac-19990515.38-fast.flm 17.2816467932 1.23 None 62.88 cfa 3736.0 7420.0
# Host correction...
# 2001ep sn2001ep-20011214.32-fast.flm 7.62333755702 1.3 None 57.72 cfa 3724.0 7394.0
# Host correction...
# 2005am sn2005am-20050503.15-fast.flm 15.3135312559 1.3 None 57.85 cfa 3506.0 7300.0
# Host correction...
# 2005el sn2005el-20051202.43-fast.flm 10.3826754076 1.27 None 60.03 cfa 3570.0 7226.0
# Host correction...
# 2006x 2006X_20060423_4000_8999_00.dat 58.8669465623 1.18 None 61.9 other 4030.0 8904.0
# Host correction...
# 2006ef SN06ef_061016_b01_HIL_BC.dat 12.3098338294 None 1.21197621888 56.1199999996 csp 3704.0 6998.0
# Host correction...
# 2006ej SN06ej_061022_b01_HIL_BC.dat 10.6593746553 None 1.27714374679 56.1299999999 csp 3766.0 7048.0
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.35 or dm15_from_fits >= 1.35))
# Collecting data...
# 10 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 10 spectra left
# 1 Peculiar Ias removed 9 spectra left
# 9 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 9 spectra left
# 1999da sn1999da-19990910-ui.flm 2.27768892648 1.9 None 59.94 bsnip 3310.0 10320.0
# Host correction...
# 2002eu sn2002eu-20021108-br.flm 9.26430906978 1.52 None 63.12 bsnip 3122.0 8880.0
# Host correction...
# 2003d sn2003d-20030227-br.flm 15.9324868405 None 1.76694283898 59.88 bsnip 3112.0 9168.0
# Host correction...
# 2004ef sn2004ef-20041114-br.flm 4.35614152336 1.39 None 57.23 bsnip 3194.0 9068.0
# Host correction...
# 2005ke sn2005ke-20060123.221-ui.flm 2.36252438349 1.82 None 59.43 bsnip 3350.0 10500.0
# Host correction...
# 2006d sn2006d-20060322.449-ui.flm 6.74199246711 1.35 None 60.24 bsnip 3342.0 10362.0
# Host correction...
# 1994d sn1994D-19940517.17-fast.flm 17.0500585006 1.37 None 56.67 cfa 3780.0 7596.0
# Host correction...
# 2000dk sn2000dk-20001124.20-fast.flm 4.76543012478 1.62 None 59.6 cfa 3668.0 7362.0
# Host correction...
# 2007bc sn2007bc-20070610.18-fast.flm 6.83289661142 1.37 None 61.28 cfa 3460.0 7216.0
# Host correction...
# 9 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_dm15_p2month, comps_dm15_p2month[0], True)
query_db.set_min_num_spec(comps_dm15_p2month, 5)
comparison_plot(comps_dm15_p2month)
stacked_plot_max(comps_dm15_p2month,5,1)

# %% [markdown]
# # +1 Year

# %%
query_dm15_plong = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa < 1.2 or dm15_from_fits < 1.2))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.8) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.8))"]

# %%
comps_dm15_plong, sn_arrays, boot_arrays = query_db.main(len(query_dm15_plong), query_dm15_plong, boot='b',medmean=1)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa < 1.2 or dm15_from_fits < 1.2))
# Collecting data...
# ERROR:  1998bu_19990126_0_2_00.dat None
# 16 spectra found
# 152 questionable files currently ignored
# 1 questionable spectra removed 15 spectra left
# 1 Peculiar Ias removed 14 spectra left
# 14 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 14 spectra left
# 1994ae sn1994ae-19950706-ui.flm 0.0152347 0.96 None 218.55 bsnip 3628.0 10356.0
# Host correction...
# 1998bu sn1998bu-19990424-ui.flm 3.33254162775 1.03 None 338.73 bsnip 3342.0 10440.0
# Host correction...
# 1999aa sn1999aa-19991205-uvoir.flm 6.62159707461 0.78 None 281.51 bsnip 3994.0 9808.0
# Host correction...
# 1999cl sn1999cl-skyclose-19991215-hal.flm 12.2906764489 1.17 None 183.95 bsnip 5652.0 6834.0
# Host correction...
# 2002bo sn2002bo-20021106.657-joined.flm 2.94983388564 1.08 None 227.44 bsnip 3984.0 10106.0
# Host correction...
# 2005cf sn2005cf-20070216.617-deimos.flm 1.63809536523 1.1 None 610.27 bsnip 4622.0 7142.0
# Host correction...
# 2006x sn2006x-20061123.638-br.flm 9.22500754498 1.18 None 275.94 bsnip 3130.0 9152.0
# Host correction...
# 2007le sn2007le-20080827.490-br.flm 0.00916028 1.01 None 304.74 bsnip 3298.0 9130.0
# Host correction...
# 1995d sn1995D-19951202.44-mmt.flm 1.06825473451 1.05 None 284.74 cfa 3244.0 8728.0
# Host correction...
# 1998aq sn1998aq-19981124.54-fast.flm 5.16651534007 1.11 None 210.34 cfa 3756.0 7462.0
# Host correction...
# 2003kf sn2003kf-20050111.11-ldss2.flm 1.15512997028 1.1 None 400.31 cfa 4046.0 8302.0
# Host correction...
# 2007af sn2007af-20080111.53-mmt.flm 5.62580014235 1.04 None 302.43 cfa 3238.0 8306.0
# Host correction...
# 2007sr sn2007sr-20080623.00-ldss3.flm 23.3735687236 1.05 None 190.9 cfa 3780.0 10632.0
# Host correction...
# 2002dj 2002dj_20030326_3588_8628_00.dat 7.1011505182 1.19 None 273.4 other 3606.0 8500.0
# Host correction...
# 14 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.8) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.8))
# Collecting data...
# ERROR:  2003hv_20040901_51567_151964_00.dat None
# 9 spectra found
# 152 questionable files currently ignored
# 0 questionable spectra removed 9 spectra left
# 2 Peculiar Ias removed 7 spectra left
# 5 SNs with host corrections
# Arrays cleaned
# 152 questionable files currently ignored
# 0 spectra with nan ivars removed 5 spectra left
# 1994d sn1994D-19951124.46-mmt.flm 1.15786221455 1.37 None 612.96 cfa 3210.0 8098.0
# Host correction...
# 1996x 1996X_19961220_3489_9278_00.dat 0.638702399293 1.26 None 245.9 other 3516.0 9168.0
# Host correction...
# 2002er 2002er_20030410_3498_8062_00.dat 2.80724531674 1.23 None 214.1 other 3518.0 7942.0
# Host correction...
# 2003cg 2003cg_20040419_3905_8049_00.dat 5.36529589791 1.26 None 384.6 other 3940.0 7968.0
# Host correction...
# 2005am 2005am_20060324_5151_6910_00.dat 4.40934917332 1.3 None 382.7 other 5160.0 6804.0
# Host correction...
# 5 SNs with host corrections
# Creating composite...
# Done.
# Bootstrapping
# scaling boots...
# plotting...
# computing confidence intervals...

# %%
composite.optimize_scales(comps_dm15_plong, comps_dm15_plong[0], True)
query_db.set_min_num_spec(comps_dm15_plong, 4)
comparison_plot(comps_dm15_plong)
stacked_plot_max(comps_dm15_plong,20,1)

# %%
#normalize to first comp
comps_dm15_very_early = query_db.normalize_comps(comps_dm15_very_early)
comps_dm15_m1week = query_db.normalize_comps(comps_dm15_m1week)
comps_dm15_max_fewer_bins = query_db.normalize_comps(comps_dm15_max_fewer_bins)
comps_dm15_p1week = query_db.normalize_comps(comps_dm15_p1week)
comps_dm15_p2week = query_db.normalize_comps(comps_dm15_p2week)
comps_dm15_p1month = query_db.normalize_comps(comps_dm15_p1month)
comps_dm15_p2month = query_db.normalize_comps(comps_dm15_p2month)
comps_dm15_plong = query_db.normalize_comps(comps_dm15_plong)

# %%
# composite.optimize_scales(comps_dm15_very_early, comps_dm15_very_early[0], True)
# composite.optimize_scales(comps_dm15_m1week, comps_dm15_m1week[0], True)
# composite.optimize_scales(comps_dm15_max_fewer_bins, comps_dm15_max_fewer_bins[0], True)
# composite.optimize_scales(comps_dm15_p1week, comps_dm15_p1week[0], True)
# composite.optimize_scales(comps_dm15_p2week, comps_dm15_p2week[0], True)
# composite.optimize_scales(comps_dm15_p1month, comps_dm15_p1month[0], True)
# composite.optimize_scales(comps_dm15_p2month, comps_dm15_p2month[0], True)
# composite.optimize_scales(comps_dm15_plong, comps_dm15_plong[0], True)

# %%
f, axarr = plt.subplots(8, 5, figsize=[30,20], sharex = True, sharey = True)
plt.rc('font', family='serif')
f.text(0.5, 0.04, 'Rest Wavlength ($\AA$)', ha='center', fontsize=30)
axarr[0, 0].set_title('$\Delta m_{15} < 0.95$', fontsize=30)
axarr[0, 1].set_title('$0.95 < \Delta m_{15} < 1.15$', fontsize=30)
axarr[0, 2].set_title('$1.15 < \Delta m_{15} < 1.25$',fontsize=30)
axarr[0, 3].set_title('$1.25 < \Delta m_{15} < 1.50$', fontsize=30)
axarr[0, 4].set_title('$\Delta m_{15} > 1.50$', fontsize=30)

axarr[0, 0].set_ylabel('$\Delta t < -10$', fontsize=15)
axarr[1, 0].set_ylabel('$-9 < \Delta t < -5$', fontsize=15)
axarr[2, 0].set_ylabel('$-3 < \Delta t < +3$',fontsize=15)
axarr[3, 0].set_ylabel('$+5 < \Delta t < +9$', fontsize=15)
axarr[4, 0].set_ylabel('$+12 < \Delta t < +16$', fontsize=15)
axarr[5, 0].set_ylabel('$+26 < \Delta t < +34$', fontsize=15)
axarr[6, 0].set_ylabel('$+56 < \Delta t < +64$', fontsize=15)
axarr[7, 0].set_ylabel('$\Delta t > +180$', fontsize=15)
i = 0
for comp in comps_dm15_very_early:
    dm15 = np.round(np.average(comp.dm15_array[comp.x1:comp.x2]),2)
#     axarr[0, i].text(9700, .7, dm15)
    axarr[0, i].plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2])
    axarr[0, i].fill_between(comp.wavelength[comp.x1:comp.x2], 
                             comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], alpha = 0.5)
    i+=1
    
i = 0
for comp in comps_dm15_m1week:
    dm15 = np.round(np.average(comp.dm15_array[comp.x1:comp.x2]),2)
#     axarr[1, i].text(9700, .7, dm15)
    axarr[1, i].plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2])
    axarr[1, i].fill_between(comp.wavelength[comp.x1:comp.x2], 
                             comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], alpha = 0.5)
    i+=1
    
i = 0
for comp in comps_dm15_max_fewer_bins:
    dm15 = np.round(np.average(comp.dm15_array[comp.x1:comp.x2]),2)
#     axarr[2, i].text(9700, .7, dm15)
    axarr[2, i].plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2])
    axarr[2, i].fill_between(comp.wavelength[comp.x1:comp.x2], 
                             comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], alpha = 0.5)
    i+=1

i = 0
for comp in comps_dm15_p1week:
    dm15 = np.round(np.average(comp.dm15_array[comp.x1:comp.x2]),2)
#     axarr[3, i].text(9700, .7, dm15)
    axarr[3, i].plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2])
    axarr[3, i].fill_between(comp.wavelength[comp.x1:comp.x2], 
                             comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], alpha = 0.5)
    i+=1

i = 0
for comp in comps_dm15_p2week:
    dm15 = np.round(np.average(comp.dm15_array[comp.x1:comp.x2]),2)
#     axarr[4, i].text(9700, .7, dm15)
    axarr[4, i].plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2])
    axarr[4, i].fill_between(comp.wavelength[comp.x1:comp.x2], 
                             comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], alpha = 0.5)
    i+=1
    
i = 0
for comp in comps_dm15_p1month:
    dm15 = np.round(np.average(comp.dm15_array[comp.x1:comp.x2]),2)
#     axarr[5, i].text(9700, .7, dm15)
    axarr[5, i].plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2])
    axarr[5, i].fill_between(comp.wavelength[comp.x1:comp.x2], 
                             comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], alpha = 0.5)
    i+=1

i = 0
for comp in comps_dm15_p2month:
    dm15 = np.round(np.average(comp.dm15_array[comp.x1:comp.x2]),2)
#     axarr[6, i].text(9700, .7, dm15)
    axarr[6, i].plot(comp.wavelength[comp.x1:comp.x2], comp.flux[comp.x1:comp.x2])
    axarr[6, i].fill_between(comp.wavelength[comp.x1:comp.x2], 
                             comp.low_conf[comp.x1:comp.x2], 
                             comp.up_conf[comp.x1:comp.x2], alpha = 0.5)
    i+=1

dm15 = np.round(np.average(comps_dm15_plong[0].dm15_array[comps_dm15_plong[0].x1:comps_dm15_plong[0].x2]),2)
# axarr[7, 1].text(9700, .7, dm15)
axarr[7, 1].plot(comps_dm15_plong[0].wavelength[comps_dm15_plong[0].x1:comps_dm15_plong[0].x2], 
                 comps_dm15_plong[0].flux[comps_dm15_plong[0].x1:comps_dm15_plong[0].x2])
axarr[7, 1].fill_between(comps_dm15_plong[0].wavelength[comps_dm15_plong[0].x1:comps_dm15_plong[0].x2], 
                         comps_dm15_plong[0].low_conf[comps_dm15_plong[0].x1:comps_dm15_plong[0].x2], 
                         comps_dm15_plong[0].up_conf[comps_dm15_plong[0].x1:comps_dm15_plong[0].x2], alpha = 0.5)
dm15 = np.round(np.average(comps_dm15_plong[1].dm15_array[comps_dm15_plong[1].x1:comps_dm15_plong[1].x2]),2)
# axarr[7, 2].text(9700, .7, dm15)
axarr[7, 2].plot(comps_dm15_plong[1].wavelength[comps_dm15_plong[1].x1:comps_dm15_plong[1].x2], 
                 comps_dm15_plong[1].flux[comps_dm15_plong[1].x1:comps_dm15_plong[1].x2])
axarr[7, 2].fill_between(comps_dm15_plong[1].wavelength[comps_dm15_plong[1].x1:comps_dm15_plong[1].x2], 
                         comps_dm15_plong[1].low_conf[comps_dm15_plong[1].x1:comps_dm15_plong[1].x2], 
                         comps_dm15_plong[1].up_conf[comps_dm15_plong[1].x1:comps_dm15_plong[1].x2], alpha = 0.5)

f.subplots_adjust(hspace=0, wspace=0)
plt.setp([a.get_xticklabels() for a in f.axes[:-5]], visible=False)
need_label = [29,31,32,33]
for i in range(len(f.axes)):
    f.axes[i].set_ylim([-.1,1.1])
    f.axes[i].minorticks_on()
    # ax.xaxis.set_ticks(np.arange(np.round(old_wave[0],-3),np.round(old_wave[-1],-3),1000))
    f.axes[i].tick_params(
        which='major', 
        bottom='on', 
        top='on',
        left='on',
        right='on',
        length=10)
    f.axes[i].tick_params(
        which='minor', 
        bottom='on', 
        top='on',
        left='on',
        right='on',
        length=5)
#     if i%5 != 0 and i not in need_label:
#         plt.setp(f.axes[i].get_yticklabels(), visible=False)
    f.axes[i].xaxis.set_ticks(np.arange(4000,11000,1000))
# f.delaxes(axarr[0, 3])
# f.delaxes(axarr[0, 4])
# f.delaxes(axarr[6, 4])
# f.delaxes(axarr[7, 1])
# f.delaxes(axarr[7, 2])
# f.delaxes(axarr[7, 3])
plt.savefig('../../Paper_Drafts/dm15_grid.pdf', dpi = 100, bbox_inches = 'tight')
plt.show()

# %%
import spectral_analysis as sa
plt.cla()

# %%
all_comps = []
all_comps.append(comps_dm15_very_early)
all_comps.append(comps_dm15_max_fewer_bins)
all_comps.append(comps_dm15_p1week)
all_comps.append(comps_dm15_p2week)
all_comps.append(comps_dm15_p1month)

# %%
all_vels = []
all_phases = []
for epoch in all_comps:
    velocities = []
    phases = []
    for comp in epoch:
        p = np.average(comp.phase_array[comp.x1:comp.x2])
        v = -1.*sa.measure_si_velocity(comp)/1000.
        velocities.append(v)
        phases.append(p)
    all_vels.append(velocities)
    all_phases.append(phases)

# %%
for i in range (len(all_vels)):
    plt.plot(all_phases[i], all_vels[i], 'o')
plt.gca().invert_yaxis()
plt.show()
