# %%
import matplotlib
matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db

# %%
query_strings_low_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -7 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -7 and phase < -4 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4 and phase < -2 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2 and phase < -1 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 0 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0 and phase < 1 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 1 and phase < 2 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2 and phase < 3 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 3 and phase < 4 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4 and phase < 5 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 5 and phase < 6 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6 and phase < 7 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 7 and phase < 8 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8 and phase < 9 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 9 and phase < 10 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10 and phase < 11 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 11 and phase < 12 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12 and phase < 14 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14 and phase < 16 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16 and phase < 18 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18 and phase < 20 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20 and phase < 22 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22 and phase < 25 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 25 and phase < 28 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28 and phase < 31 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 31 and phase < 34 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 34 and phase < 39 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39 and phase < 49 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 49 and phase < 70 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 70 and phase < 110 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 110 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)"
                         ]

# %%
query_strings_high_dm15 = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -7 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -7 and phase < -4 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4 and phase < -2 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2 and phase < -1 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 0 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0 and phase < 1 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 1 and phase < 2 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2 and phase < 3 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 3 and phase < 4 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4 and phase < 5 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 5 and phase < 6 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6 and phase < 7 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 7 and phase < 8 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8 and phase < 9 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 9 and phase < 10 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10 and phase < 11 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 11 and phase < 12 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 12 and phase < 14 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 14 and phase < 16 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 16 and phase < 18 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 18 and phase < 20 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 20 and phase < 22 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 22 and phase < 25 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 25 and phase < 28 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28 and phase < 31 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 31 and phase < 34 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 34 and phase < 39 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39 and phase < 49 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 49 and phase < 70 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                          "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 70 and phase < 110 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)",
                         ]

# %%
comps_low_dm15 = query_db.main(len(query_strings_low_dm15), query_strings_low_dm15)
comps_high_dm15 = query_db.main(len(query_strings_high_dm15), query_strings_high_dm15)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase < -7 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 47 spectra found
# Arrays cleaned
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 45 spectra left
# 1998dk sn1998dk-19980824-90-br.flm -7.24 1.05 None
# Host correction...
# 1999aa sn1999aa-19990212-uoi.flm -10.58 0.78 None
# Host correction...
# 2000fa sn2000fa-20001205-ui-corrected.flm -8.25 1.0 None
# Host correction...
# 2002bo sn2002bo-20020311-ui-corrected.flm -11.94 1.08 None
# Host correction...
# 2002cs sn2002cs-20020507-ui.flm -7.76 0.99 None
# 2003fa sn2003fa-20030607.426-ui.flm -8.15 0.8 None
# Host correction...
# 2003kf sn2003kf-20031129-br.flm -7.5 1.1 None
# Host correction...
# 2005cf sn2005cf-20050605.7-uvot.flm -7.7 1.1 None
# Host correction...
# 2005eu sn2005eu-20051007.622-br.flm -9.06 0.89 None
# Host correction...
# 2006ax sn2006ax-20060322.396-ui.flm -10.07 1.06 None
# Host correction...
# 2006gr sn2006gr-20060925.202-ui.flm -8.7 0.81 None
# Host correction...
# 2006le sn2006le-20061030.456-ui-corrected.flm -8.69 0.88 None
# Host correction...
# 2006qo sn2006qo-20061201.436-ui.flm -11.08 None 1.00943200538
# Host correction...
# 2007bm sn2007bm-20070426.278-ui.flm -7.79 1.09 None
# Host correction...
# 2007ca sn2007ca-20070426.305-ui.flm -11.14 0.89 None
# Host correction...
# 2007f sn2007f-20070113.658-br.flm -9.35 0.96 None
# Host correction...
# 2007le SN07le_071016_b01_DUP_BC.dat -9.0700000003 1.01 None
# Host correction...
# 2008ar sn2008ar-20080229-ir-corrected.flm -8.87 1.1 None
# 1995bd sn1995bd-19951223.34-fast.flm -12.16 0.94 None
# Host correction...
# 1997bq sn1997bq-19970408.14-mmt.flm -11.76 1.14 None
# Host correction...
# 1997br sn1997br-19970413.32-fast.flm -7.98 1.09 None
# Host correction...
# 1997do sn1997do-19971102.46-fast.flm -11.64 0.94 None
# Host correction...
# 1997dt sn1997dt-19971123.19-fast.flm -10.71 1.04 None
# Host correction...
# 1998ab sn1998ab-19980403.38-fast.flm -8.02 1.04 None
# Host correction...
# 1998aq sn1998aq-19980418.29-fast.flm -9.91 1.11 None
# Host correction...
# 1998es sn1998es-19981118.28-fast.flm -7.42 0.85 None
# Host correction...
# 1999cp sn1999cp-19990622.20-fast.flm -12.0 0.98 None
# Host correction...
# 1999dq sn1999dq-19990905.45-fast.flm -9.55 0.86 None
# Host correction...
# 2000dn sn2000dn-20000929.29-fast.flm -7.91 1.04 None
# 2001ah sn2001ah-20010328.22-fast.flm -10.18 0.98 None
# Host correction...
# 2001v sn2001V-20010220.29-fast.flm -12.51 0.82 None
# Host correction...
# 2002cd sn2002cd-20020410.49-fast.flm -8.71 0.84 None
# Host correction...
# 2003du 2003du_20030425_3451_10400_00.dat -12.1 1.07 None
# Host correction...
# 2003w sn2003W-20030129.35-mmt.flm -11.35 1.14 None
# Host correction...
# 2004as sn2004as-20040313.30-fast.flm -8.1 0.92 None
# Host correction...
# 2004at sn2004at-20040319.24-fast.flm -8.76 1.05 None
# 2005eq sn2005eq-20051002.51-fast.flm -8.49 0.88 None
# Host correction...
# 2006cc sn2006cc-20060508.34-fast.flm -9.96000000001 0.97 None
# Host correction...
# 2006cp sn2006cp-20060530.25-fast.flm -11.45 0.98 None
# Host correction...
# 2006gz sn2006gz-20060928.13-fast.flm -13.57 0.69 None
# 2006oa sn2006oa-20061118.16-fast.flm -9.03999999999 0.89 None
# Host correction...
# 2007qe sn2007qe-20071115.28-fast.flm -9.62 1.03 None
# Host correction...
# 2008z sn2008Z-20080209.31-fast.flm -9.39 1.02 None
# 2007af SN07af_070304_g01_NTT_EM.dat -10.4300000002 1.04 None
# Host correction...
# 2008bf SN08bf_080320_b01_CLA_LD.dat -8.75 1.05 None
# Host correction...
# 39 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -7 and phase < -4 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 55 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 2 spectra with nan ivars removed
# Peculiar Ias removed 50 spectra left
# 1995ac sn1995ac-19950926-uoi.flm -6.34 0.77 None
# Host correction...
# 1997br sn1997br-19970416-uoi.flm -4.84 1.09 None
# Host correction...
# 1997do sn1997do-19971108-uoi.flm -5.67 0.94 None
# Host correction...
# 1998dm sn1998dm-19980831-ui-corrected.flm -5.61 0.9 None
# Host correction...
# 2001ba sn2001ba-20010430-ui.flm -4.64 None 0.990056432637
# Host correction...
# 2001eh sn2001eh-20010911-ui.flm -5.63 0.92 None
# Host correction...
# 2002hu sn2002hu-20021108-br.flm -5.81 1.05 None
# Host correction...
# 2003w sn2003W-20030204-ui.flm -5.06 1.14 None
# Host correction...
# 2004as sn2004as-20040316.608-br-corrected.flm -4.36 0.92 None
# Host correction...
# 2004dt sn2004dt-20040816.413-ui-corrected.flm -6.46 1.14 None
# Host correction...
# 2005eq sn2005eq-20051004.512-ui.flm -6.01 0.88 None
# Host correction...
# 2005eu sn2005eu-20051011.350-ui-corrected.flm -5.46 0.89 None
# Host correction...
# 2006bt sn2006bt-20060428.425-ui.flm -4.53 1.0 None
# Host correction...
# 2006cp sn2006cp-20060605.281-ui.flm -5.3 0.98 None
# Host correction...
# 2007co sn2007co-20070609.398-ui-corrected.flm -4.09 1.16 None
# Host correction...
# 2007qe sn2007qe-20071118.104-ui.flm -6.54 1.03 None
# Host correction...
# 1994s sn1994S-19940611.28-fast.flm -4.02 0.94 None
# Host correction...
# 1996bl sn1996bl-19961016.29-fast.flm -4.21 1.07 None
# Host correction...
# 1997bq sn1997bq-19970413.22-fast.flm -6.68 1.14 None
# Host correction...
# 1997dt sn1997dt-19971129.11-fast.flm -4.79 1.04 None
# Host correction...
# 1998es sn1998es-19981119.28-fast.flm -6.42 0.85 None
# Host correction...
# 1999aa sn1999aa-19990217.26-fast.flm -6.14 0.78 None
# Host correction...
# 1999dq sn1999dq-19990908.48-fast.flm -6.52 0.86 None
# Host correction...
# 1999gp sn1999gp-20000102.21-fast.flm -4.89 0.87 None
# Host correction...
# 2001cp sn2001cp-20010621.45-fast.flm -6.95 0.88 None
# Host correction...
# 2001g sn2001G-20010115.32-fast.flm -5.28 None 1.13936266574
# Host correction...
# 2001v sn2001V-20010226.30-fast.flm -6.5 0.82 None
# Host correction...
# 2002bo 2002bo_20020318_3184_7576_00.dat -5.7 1.08 None
# Host correction...
# 2002cd sn2002cd-20020412.49-fast.flm -6.71 0.84 None
# Host correction...
# 2002cs sn2002cs-20020511.44-fast.flm -4.56 0.99 None
# 2002de sn2002de-20020602.24-fast.flm -6.26 0.96 None
# Host correction...
# 2002dp sn2002dp-20020620.47-fast.flm -4.83 1.12 None
# Host correction...
# 2003fa sn2003fa-20030609.38-fast.flm -6.82 0.8 None
# Host correction...
# 2003kf sn2003kf-20031202.36-fast.flm -5.44 1.1 None
# Host correction...
# 2004at sn2004at-20040321.26-fast.flm -6.74 1.05 None
# 2004fu sn2004fu-20041110.17-fast.flm -6.43 1.08 None
# Host correction...
# 2005cf sn2005cf-20050606.7-uvot.flm -6.7 1.1 None
# Host correction...
# 2006ax sn2006ax-20060326.29-fast.flm -6.51 1.06 None
# Host correction...
# 2006gr sn2006gr-20060928.18-fast.flm -6.22 0.81 None
# Host correction...
# 2006le sn2006le-20061101.43-fast.flm -6.97 0.88 None
# Host correction...
# 2006oa sn2006oa-20061121.09-fast.flm -6.11 0.89 None
# Host correction...
# 2006s sn2006S-20060128.50-fast.flm -5.7 0.93 None
# Host correction...
# 2007af sn2007af-20070310.46-fast.flm -4.64 1.04 None
# Host correction...
# 2007le SN07le_071021_b01_DUP_BC.dat -4.14000000013 1.01 None
# Host correction...
# 2007s sn2007S-20070208.34-fast.flm -4.76 0.94 None
# Host correction...
# 2008ar sn2008ar-20080302.40-fast.flm -6.7 1.1 None
# 2008z sn2008Z-20080213.33-fast.flm -5.37 1.02 None
# 2005hc SN05hc_051018_g01_NTT_EM.dat -5.37000000011 1.03 None
# Host correction...
# 2008bf SN08bf_080324_b01_CLA_LD.dat -4.87000000011 1.05 None
# Host correction...
# 2006gz 2006gz_20061007_3751_7204_00.dat -4.7 0.69 None
# 45 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -4 and phase < -2 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 51 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 47 spectra left
# 1995e sn1995e-19950224-uoi2.flm -2.46 1.16 None
# Host correction...
# 1999dq sn1999dq-19990910-ui-corrected.flm -3.93 0.86 None
# Host correction...
# 2001az sn2001az-20010430-ui.flm -3.24 1.09 None
# Host correction...
# 2004fu sn2004fu-20041114-br.flm -2.65 1.08 None
# Host correction...
# 2005cf sn2005cf-20050610.7-uvot.flm -2.7 1.1 None
# Host correction...
# 2005eq sn2005eq-20051007.633-br-corrected.flm -2.98 0.88 None
# Host correction...
# 2006s sn2006s-20060130.375-ui.flm -3.93 0.93 None
# Host correction...
# 2008z sn2008z-20080216.463-ui.flm -2.29 1.02 None
# 1996bl sn1996bl-19961018.18-fast.flm -2.32 1.07 None
# Host correction...
# 1997bp sn1997bp-19970407.42-mmt.flm -3.08 1.08 None
# Host correction...
# 1998aq sn1998aq-19980424.37-fast.flm -3.82999999999 1.11 None
# Host correction...
# 1998bu sn1998bu-19980516.15-fast.flm -3.55 1.03 None
# Host correction...
# 1998ec sn1998ec-19980930.50-fast.flm -3.0 1.08 None
# Host correction...
# 1998es sn1998es-19981122.26-fast.flm -3.44 0.85 None
# Host correction...
# 1999aa sn1999aa-19990220.29-fast.flm -3.11 0.78 None
# Host correction...
# 2000cp sn2000cp-20000622.28-fast.flm -2.62 1.09 None
# 2000dn sn2000dn-20001003.30-fast.flm -3.89999999999 1.04 None
# 2001cp sn2001cp-20010624.40-fast.flm -4.0 0.88 None
# Host correction...
# 2001da sn2001da-20010714.46-fast.flm -2.04 1.12 None
# Host correction...
# 2001eh sn2001eh-20010915.42-fast.flm -2.08 0.92 None
# Host correction...
# 2001v sn2001V-20010301.47-fast.flm -3.33 0.82 None
# Host correction...
# 2002bo 2002bo_20020321_3306_9127_00.dat -2.7 1.08 None
# Host correction...
# 2002cd sn2002cd-20020415.49-fast.flm -3.71 0.84 None
# Host correction...
# 2002de sn2002de-20020605.41-fast.flm -3.09 0.96 None
# Host correction...
# 2002ef sn2002ef-20020801.44-fast.flm -2.96 1.06 None
# 2002fk sn2002fk-20020927.46-fast.flm -3.44 1.13 None
# Host correction...
# 2002hu sn2002hu-20021110.31-fast.flm -3.69 1.05 None
# Host correction...
# 2003kf sn2003kf-20031204.43-fast.flm -3.37 1.1 None
# Host correction...
# 2003w sn2003W-20030206.32-fast.flm -3.38 1.14 None
# Host correction...
# 2004as sn2004as-20040318.36-fast.flm -3.04 0.92 None
# Host correction...
# 2004at sn2004at-20040324.32-fast.flm -3.68 1.05 None
# 2004bg sn2004bg-20040411.39-fast.flm -3.11 1.05 None
# Host correction...
# 2005a sn2005A-20050107.25-fast.flm -2.25 1.11 None
# Host correction...
# 2005m sn2005M-20050201.30-fast.flm -2.8 0.87 None
# Host correction...
# 2006bt sn2006bt-20060429.41-fast.flm -2.99 1.0 None
# Host correction...
# 2006cj sn2006cj-20060521.29-fast.flm -2.21 0.81 None
# Host correction...
# 2006cq sn2006cq-20060531.27-fast.flm -3.53000000001 None 1.00205432495
# Host correction...
# 2006gr sn2006gr-20061002.26-fast.flm -2.14 0.81 None
# Host correction...
# 2006oa sn2006oa-20061125.08-fast.flm -2.12 0.89 None
# Host correction...
# 2007a sn2007A-20070109.12-fast.flm -3.48 0.95 None
# Host correction...
# 2007af sn2007af-20070311.45-fast.flm -3.65 1.04 None
# Host correction...
# 2007co sn2007co-20070610.39-fast.flm -3.21 1.16 None
# Host correction...
# 2007s sn2007S-20070209.30-fast.flm -3.8 0.94 None
# Host correction...
# 2008ar sn2008ar-20080306.40-fast.flm -2.7 1.1 None
# 2006ax SN06ax_060330_b01_DUP_WF.dat -2.36000000034 1.06 None
# Host correction...
# 2008bf SN08bf_080325_b01_CLA_LD.dat -3.75999999978 1.05 None
# Host correction...
# 2003du 2003du_20030504_3435_7775_00.dat -3.1 1.07 None
# Host correction...
# 41 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -2 and phase < -1 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 34 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# bad file removed
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 28 spectra left
# 2001da sn2001da-20010716-ui-corrected.flm -1.12 1.12 None
# Host correction...
# 2002bo sn2002bo-20020322-ui-corrected.flm -1.08 1.08 None
# Host correction...
# 2005cf sn2005cf-20050611.6-uvot.flm -1.7 1.1 None
# Host correction...
# 2005ms sn2005ms-20060106.400-ui.flm -1.88 None 0.997210431761
# Host correction...
# 2006ot sn2006ot-20061123.362-br.flm -1.338 0.84 None
# Host correction...
# 2007af sn2007af-20070313.545-ui-corrected.flm -1.25 1.04 None
# Host correction...
# 1997bp sn1997bp-19970409.29-fast.flm -1.21 1.08 None
# Host correction...
# 1998bu sn1998bu-19980518.16-fast.flm -1.53999999999 1.03 None
# Host correction...
# 1999gp sn1999gp-20000105.10-fast.flm -2.0 0.87 None
# Host correction...
# 2000cp sn2000cp-20000623.29-fast.flm -1.61 1.09 None
# 2001ay sn2001ay-20010421.48-fast.flm -1.52 0.68 None
# Host correction...
# 2001cp sn2001cp-20010627.26-fast.flm -1.14 0.88 None
# Host correction...
# 2001fe sn2001fe-20011114.49-fast.flm -1.71 1.0 None
# Host correction...
# 2002aw sn2002aw-20020217.51-fast.flm -1.89 1.05 None
# 2002fk sn2002fk-20020929.44-fast.flm -1.46 1.13 None
# Host correction...
# 2004as sn2004as-20040320.38-fast.flm -1.02 0.92 None
# Host correction...
# 2005a sn2005A-20050108.13-fast.flm -1.37 1.11 None
# Host correction...
# 2005eq sn2005eq-20051009.42-fast.flm -1.58 0.88 None
# Host correction...
# 2005na sn2005na-20060104.34-fast.flm -1.56 1.09 None
# Host correction...
# 2006bt sn2006bt-20060501.39-fast.flm -1.01 1.0 None
# Host correction...
# 2006cj sn2006cj-20060522.29-fast.flm -1.21 0.81 None
# Host correction...
# 2006gr sn2006gr-20061003.26-fast.flm -1.14 0.81 None
# Host correction...
# 2007co sn2007co-20070612.35-fast.flm -1.25 1.16 None
# Host correction...
# 2008ar sn2008ar-20080307.38-fast.flm -1.72 1.1 None
# 2005hc SN05hc_051022_b01_MGH_BC.dat -1.2200000002 1.03 None
# Host correction...
# 2006ax SN06ax_060331_b01_DUP_WF.dat -1.41000000015 1.06 None
# Host correction...
# 2006os SN06os_061122_b01_DUP_WF.dat -1.06999999983 None 1.13936266574
# Host correction...
# 2006gz 2006gz_20061010_3755_7204_00.dat -1.7 0.69 None
# 24 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= -1 and phase < 0 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 37 spectra found
# Arrays cleaned
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 34 spectra left
# 1996ai sn1996ai-19960620.15-mmt.flm -0.949999999997 0.88 None
# Host correction...
# 1998dk sn1998dk-19980831-ui.flm -0.54 1.05 None
# Host correction...
# 2000dn sn2000dn-20001006-uri-corrected.flm -0.94 1.04 None
# 2001fe sn2001fe-20011115-ui.flm -0.99 1.0 None
# Host correction...
# 2002de sn2002de-20020608.374-ui-corrected.flm -0.32 0.96 None
# Host correction...
# 2007o sn2007o-20070122.663-deimos.flm -0.33 None 1.10542148203
# Host correction...
# 1995e sn1995E-19950226.27-fast.flm -0.93 1.16 None
# Host correction...
# 1997bp sn1997bp-19970410.27-fast.flm -0.230000000003 1.08 None
# Host correction...
# 1998aq sn1998aq-19980427.29-fast.flm -0.909999999996 1.11 None
# Host correction...
# 1998eg sn1998eg-19981024.15-fast.flm -0.75 1.14 None
# Host correction...
# 1998es sn1998es-19981125.22-fast.flm -0.479999999996 0.85 None
# Host correction...
# 1999aa sn1999aa-19990223.25-fast.flm -0.150000000001 0.78 None
# Host correction...
# 2000cp sn2000cp-20000624.34-fast.flm -0.560000000005 1.09 None
# 2001br sn2001br-20010521.44-fast.flm -0.459999999999 1.16 None
# 2001da sn2001da-20010716.46-fast.flm -0.0400000000009 1.12 None
# Host correction...
# 2001eh sn2001eh-20010917.39-fast.flm -0.110000000001 0.92 None
# Host correction...
# 2002aw sn2002aw-20020218.52-fast.flm -0.880000000005 1.05 None
# 2002ck sn2002ck-20020502.46-fast.flm -0.540000000001 1.08 None
# Host correction...
# 2002hu sn2002hu-20021113.25-fast.flm -0.75 1.05 None
# Host correction...
# 2003w sn2003W-20030209.35-fast.flm -0.349999999999 1.14 None
# Host correction...
# 2004as sn2004as-20040321.27-fast.flm -0.130000000005 0.92 None
# Host correction...
# 2004at sn2004at-20040327.33-fast.flm -0.669999999998 1.05 None
# 2005cf 2005cf_20050612_3201_9285_00.dat -0.699999999997 1.1 None
# Host correction...
# 2006oa sn2006oa-20061127.10-fast.flm -0.0999999999985 0.89 None
# Host correction...
# 2006ot sn2006ot-20061124.23-fast.flm -0.469999999994 0.84 None
# Host correction...
# 2006s sn2006S-20060202.47-fast.flm -0.729999999996 0.93 None
# Host correction...
# 2007af SN07af_070314_b01_DUP_BC.dat -0.470000000205 1.04 None
# Host correction...
# 2007co sn2007co-20070613.39-fast.flm -0.209999999999 1.16 None
# Host correction...
# 2007f sn2007F-20070122.49-fast.flm -0.910000000003 0.96 None
# Host correction...
# 2007s sn2007S-20070212.33-fast.flm -0.769999999997 0.94 None
# Host correction...
# 2008ar sn2008ar-20080308.43-fast.flm -0.669999999998 1.1 None
# 2008bf SN08bf_080328_g01_NTT_EM.dat -0.709999999963 1.05 None
# Host correction...
# 2002bo 2002bo_20020323_3356_10385_00.dat -0.699999999997 1.08 None
# Host correction...
# 2003du 2003du_20030507_3404_10096_00.dat -0.0999999999985 1.07 None
# Host correction...
# 28 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 0 and phase < 1 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 36 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 32 spectra left
# 1998es sn1998es-19981125-ui-corrected.flm 0.28 0.85 None
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 0.24 0.78 None
# Host correction...
# 2005eq sn2005eq-20051011.376-ui-corrected.flm 0.66 0.88 None
# Host correction...
# 2005na sn2005na-20060105.335-ui.flm 0.03 1.09 None
# Host correction...
# 2007co sn2007co-20070614.468-ui-corrected.flm 0.85 1.16 None
# Host correction...
# 1994ae sn1994ae-19941130.49-fast.flm 0.989999999998 0.96 None
# Host correction...
# 1994s sn1994S-19940616.24-fast.flm 0.939999999995 0.94 None
# Host correction...
# 1996ai sn1996ai-19960621.23-fast.flm 0.130000000005 0.88 None
# Host correction...
# 1997dt sn1997dt-19971204.11-fast.flm 0.209999999999 1.04 None
# Host correction...
# 1998aq sn1998aq-19980428.26-fast.flm 0.0600000000049 1.11 None
# Host correction...
# 1998bu sn1998bu-19980520.15-fast.flm 0.450000000004 1.03 None
# Host correction...
# 1998v sn1998V-19980319.51-fast.flm 0.310000000005 0.99 None
# Host correction...
# 1999dq sn1999dq-19990915.45-fast.flm 0.449999999997 0.86 None
# Host correction...
# 1999gp sn1999gp-20000107.13-fast.flm 0.0299999999988 0.87 None
# Host correction...
# 2001bf sn2001bf-20010517.48-fast.flm 0.780000000006 0.99 None
# Host correction...
# 2001cp sn2001cp-20010629.28-fast.flm 0.879999999997 0.88 None
# Host correction...
# 2001fe sn2001fe-20011116.51-fast.flm 0.310000000005 1.0 None
# Host correction...
# 2002cd sn2002cd-20020419.48-fast.flm 0.280000000006 0.84 None
# Host correction...
# 2002ck sn2002ck-20020503.34-fast.flm 0.339999999997 1.08 None
# Host correction...
# 2002jy sn2002jy-20021226.12-fast.flm 0.120000000003 0.88 None
# Host correction...
# 2003w sn2003W-20030210.35-fast.flm 0.650000000001 1.14 None
# Host correction...
# 2004at sn2004at-20040328.20-fast.flm 0.199999999997 1.05 None
# 2005a sn2005A-20050110.11-ldss2.flm 0.610000000001 1.11 None
# Host correction...
# 2005cf sn2005cf-20050613.29-fast.flm 0.590000000004 1.1 None
# Host correction...
# 2005m sn2005M-20050204.26-fast.flm 0.160000000003 0.87 None
# Host correction...
# 2006ax SN06ax_060402_b01_DUP_WF.dat 0.5 1.06 None
# Host correction...
# 2006br SN06br_060426_b01_DUP_WF.dat 0.560000000056 1.12 None
# Host correction...
# 2006s sn2006S-20060203.47-fast.flm 0.270000000004 0.93 None
# Host correction...
# 2007af sn2007af-20070315.39-fast.flm 0.290000000001 1.04 None
# Host correction...
# 2008bf sn2008bf-20080330.31-fast.flm 0.709999999999 1.05 None
# Host correction...
# 2005hc SN05hc_051024_b01_MGH_BC.dat 0.699999999721 1.03 None
# Host correction...
# 2008ar SN08ar_080309_r01_BAA_IM.dat 0.60999999987 1.1 None
# 30 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 1 and phase < 2 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 38 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 37 spectra left
# 1994s sn1994s-19940616-uoi.flm 1.11 0.94 None
# Host correction...
# 1996ai sn1996ai-19960622-uoi.flm 1.231 0.88 None
# Host correction...
# 1997y sn1997y-19970209-uohp.flm 1.27 1.15 None
# Host correction...
# 2001bf sn2001bf-20010516-ui-corrected.flm 1.22 0.99 None
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 1.39 0.88 None
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 1.1 0.84 None
# Host correction...
# 2004dt sn2004dt-20040824-vis2-corrected.flm 1.38 1.14 None
# Host correction...
# 2005na sn2005na-20060106.361-ui-corrected.flm 1.03 1.09 None
# Host correction...
# 2007bz sn2007bz-20070426.419-ui.flm 1.65 1.05 None
# Host correction...
# 1995e sn1995E-19950228.23-fast.flm 1.03000000001 1.16 None
# Host correction...
# 1996ab sn1996ab-19960522.37-fast.flm 1.47 1.01 None
# Host correction...
# 1996c sn1996C-19960217.48-fast.flm 1.98 0.93 None
# Host correction...
# 1997bp sn1997bp-19970412.31-fast.flm 1.81 1.08 None
# Host correction...
# 1998aq sn1998aq-19980429.26-fast.flm 1.06 1.11 None
# Host correction...
# 1998es sn1998es-19981127.21-fast.flm 1.51 0.85 None
# Host correction...
# 1998v sn1998V-19980320.50-fast.flm 1.3 0.99 None
# Host correction...
# 1999dq sn1999dq-19990916.45-fast.flm 1.45 0.86 None
# Host correction...
# 2000fa sn2000fa-20001215.36-fast.flm 1.26 1.0 None
# Host correction...
# 2001ay sn2001ay-20010424.32-fast.flm 1.32 0.68 None
# Host correction...
# 2001da sn2001da-20010718.45-fast.flm 1.95 1.12 None
# Host correction...
# 2001en sn2001en-20011011.39-fast.flm 1.49 1.12 None
# Host correction...
# 2002aw sn2002aw-20020220.52-fast.flm 1.12 1.05 None
# 2002bf sn2002bf-20020306.22-fast.flm 1.82 1.12 None
# Host correction...
# 2002de sn2002de-20020610.28-fast.flm 1.78 0.96 None
# Host correction...
# 2002hd sn2002hd-20021029.52-fast.flm 1.42 1.16 None
# Host correction...
# 2002jy sn2002jy-20021227.11-fast.flm 1.11 0.88 None
# Host correction...
# 2003du 2003du_20030509_3402_10011_00.dat 1.9 1.07 None
# Host correction...
# 2004as sn2004as-20040323.26-fast.flm 1.86 0.92 None
# Host correction...
# 2004at sn2004at-20040329.21-fast.flm 1.21 1.05 None
# 2005cf sn2005cf-20050614.31-fast.flm 1.61 1.1 None
# Host correction...
# 2005eq sn2005eq-20051012.33-fast.flm 1.33 0.88 None
# Host correction...
# 2006bt sn2006bt-20060504.35-fast.flm 1.95 1.0 None
# Host correction...
# 2006cf sn2006cf-20060519.25-fast.flm 1.85 None 1.14732833364
# Host correction...
# 2006s sn2006S-20060204.47-fast.flm 1.27 0.93 None
# Host correction...
# 2007co sn2007co-20070615.36-fast.flm 1.76 1.16 None
# Host correction...
# 2008ar sn2008ar-20080310.36-fast.flm 1.26 1.1 None
# 2007ca SN07ca_070508_b01_BAA_IM.dat 1.41999999993 0.89 None
# Host correction...
# 34 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 2 and phase < 3 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 42 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 41 spectra left
# 1999dq sn1999dq-near-19990917-clear-ui-corrected.flm 2.97 0.86 None
# Host correction...
# 2000cp sn2000cp-20000627-ui-corrected.flm 2.92 1.09 None
# 2002aw sn2002aw-20020221-ui-corrected.flm 2.1 1.05 None
# 2002bf sn2002bf-20020307-os.flm 2.97 1.12 None
# Host correction...
# 2004fu sn2004fu-20041119-ui.flm 2.43 1.08 None
# Host correction...
# 2006bt sn2006bt-20060505.444-ui.flm 2.27 1.0 None
# Host correction...
# 2006cq sn2006cq-20060605.307-ui.flm 2.0 None 1.00205432495
# Host correction...
# 2006s sn2006s-20060206.517-ui.flm 2.99 0.93 None
# Host correction...
# 2007a sn2007a-20070113.208-br.flm 2.37 0.95 None
# Host correction...
# 2007af sn2007af-20070317.653-deimos-corrected.flm 2.84 1.04 None
# Host correction...
# 2008ar sn2008ar-20080312-ui-corrected.flm 2.83 1.1 None
# 1994ae sn1994ae-19941201.50-fast.flm 2.0 0.96 None
# Host correction...
# 1996ai sn1996ai-19960623.27-fast.flm 2.17 0.88 None
# Host correction...
# 1997bp sn1997bp-19970413.31-fast.flm 2.81 1.08 None
# Host correction...
# 1997dt sn1997dt-19971206.11-fast.flm 2.21 1.04 None
# Host correction...
# 1997y sn1997Y-19970210.40-fast.flm 2.9 1.15 None
# Host correction...
# 1998aq sn1998aq-19980430.24-fast.flm 2.04 1.11 None
# Host correction...
# 1998v sn1998V-19980321.51-fast.flm 2.31 0.99 None
# Host correction...
# 2000fa sn2000fa-20001216.36-fast.flm 2.26 1.0 None
# Host correction...
# 2001br sn2001br-20010524.46-mmt.flm 2.56 1.16 None
# 2001da sn2001da-20010719.47-fast.flm 2.97 1.12 None
# Host correction...
# 2001e sn2001E-20010119.49-fast.flm 2.89 0.92 None
# 2001eh sn2001eh-20010920.33-fast.flm 2.83 0.92 None
# Host correction...
# 2002cd sn2002cd-20020421.49-fast.flm 2.29 0.84 None
# Host correction...
# 2002ck sn2002ck-20020505.37-fast.flm 2.37 1.08 None
# Host correction...
# 2002de sn2002de-20020611.29-fast.flm 2.79 0.96 None
# Host correction...
# 2002fk sn2002fk-20021003.45-fast.flm 2.55 1.13 None
# Host correction...
# 2003du 2003du_20030510_3203_10000_00.dat 2.9 1.07 None
# Host correction...
# 2004as sn2004as-20040324.34-fast.flm 2.94 0.92 None
# Host correction...
# 2004at sn2004at-20040330.22-fast.flm 2.22 1.05 None
# 2004bg sn2004bg-20040417.19-fast.flm 2.69 1.05 None
# Host correction...
# 2004l sn2004L-20040127.40-fast.flm 2.5 1.12 None
# Host correction...
# 2005cf sn2005cf-20050615.24-fast.flm 2.54 1.1 None
# Host correction...
# 2006cf sn2006cf-20060520.16-fast.flm 2.76 None 1.14732833364
# Host correction...
# 2006et sn2006et-20060918.36-fast.flm 2.46 1.02 None
# Host correction...
# 2006ot sn2006ot-20061127.30-fast.flm 2.60000000001 0.84 None
# Host correction...
# 2007ae sn2007ae-20070225.54-fast.flm 2.54 0.98 None
# Host correction...
# 2007co sn2007co-20070616.35-fast.flm 2.75 1.16 None
# Host correction...
# 2008bf SN08bf_080331_b01_DUP_WF.dat 2.18999999994 1.05 None
# Host correction...
# 2007ai SN07ai_070314_b01_DUP_BC.dat 2.04000000004 None 0.891395606916
# Host correction...
# 2007le SN07le_071028_g01_CLA_LD.dat 2.84999999963 1.01 None
# Host correction...
# 35 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 3 and phase < 4 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 37 spectra found
# Arrays cleaned
# 2 spectra with nan ivars removed
# Peculiar Ias removed 35 spectra left
# 1995d sn1995d-19950224-uohp.flm 3.84 1.05 None
# Host correction...
# 2001br sn2001br-20010525-ui-corrected.flm 3.48 1.16 None
# 2001eh sn2001eh-20010920-ui.flm 3.26 0.92 None
# Host correction...
# 2002ck sn2002ck-20020507-ui.flm 3.64 1.08 None
# Host correction...
# 2006cj sn2006cj-20060528.349-ui.flm 3.43 0.81 None
# Host correction...
# 2006et sn2006et-20060919.345-ui.flm 3.29 1.02 None
# Host correction...
# 2007af sn2007af-20070318.633-br-corrected.flm 3.81 1.04 None
# Host correction...
# 2007f sn2007f-20070126.534-ui.flm 3.23 0.96 None
# Host correction...
# 1994ae sn1994ae-19941202.53-fast.flm 3.03 0.96 None
# Host correction...
# 1995e sn1995E-19950303.16-fast.flm 3.96000000001 1.16 None
# Host correction...
# 1996bo sn1996bo-19961103.27-fast.flm 3.27 1.16 None
# Host correction...
# 1997bp sn1997bp-19970414.30-fast.flm 3.8 1.08 None
# Host correction...
# 1998aq sn1998aq-19980501.25-fast.flm 3.05 1.11 None
# Host correction...
# 1999dq sn1999dq-19990918.45-fast.flm 3.45 0.86 None
# Host correction...
# 1999ek sn1999ek-19991103.40-fast.flm 3.3 1.14 None
# Host correction...
# 1999gp sn1999gp-20000110.11-fast.flm 3.01 0.87 None
# Host correction...
# 2000cf sn2000cf-20000511.34-fast.flm 3.03999999999 1.16 None
# Host correction...
# 2001ay sn2001ay-20010426.41-mmt.flm 3.41 0.68 None
# Host correction...
# 2001fe sn2001fe-20011119.47-fast.flm 3.27 1.0 None
# Host correction...
# 2002cd sn2002cd-20020422.49-fast.flm 3.29 0.84 None
# Host correction...
# 2002cs sn2002cs-20020519.39-fast.flm 3.39 0.99 None
# 2002de sn2002de-20020612.29-fast.flm 3.79 0.96 None
# Host correction...
# 2002jy sn2002jy-20021229.08-fast.flm 3.08 0.88 None
# Host correction...
# 2004fu sn2004fu-20041120.11-fast.flm 3.51 1.08 None
# Host correction...
# 2004l sn2004L-20040128.37-fast.flm 3.47 1.12 None
# Host correction...
# 2005cf 2005cf_20050616_3200_9721_00.dat 3.3 1.1 None
# Host correction...
# 2005na sn2005na-20060109.43-fast.flm 3.53 1.09 None
# Host correction...
# 2006bu sn2006bu-20060505.19-fast.flm 3.79 None 0.815876575935
# Host correction...
# 2006s sn2006S-20060206.48-fast.flm 3.28000000001 0.93 None
# Host correction...
# 2007ae sn2007ae-20070226.53-fast.flm 3.53 0.98 None
# Host correction...
# 2007ca sn2007ca-20070510.23-fast.flm 3.53000000001 0.89 None
# Host correction...
# 2007co sn2007co-20070617.34-fast.flm 3.74 1.16 None
# Host correction...
# 2008ar sn2008ar-20080312.36-fast.flm 3.26 1.1 None
# 2008bf sn2008bf-20080402.35-fast.flm 3.75 1.05 None
# Host correction...
# 2007le SN07le_071029_g01_NTT_EM.dat 3.9299999997 1.01 None
# Host correction...
# 32 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 4 and phase < 5 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 39 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 35 spectra left
# 1999cp sn1999cp-19990709-ui-corrected.flm 4.91 0.98 None
# Host correction...
# 2002ef sn2002ef-20020809-ui-corrected.flm 4.7 1.06 None
# 2006bu sn2006bu-20060505.325-ui.flm 4.22 None 0.815876575935
# Host correction...
# 1994ae sn1994ae-19941203.54-fast.flm 4.04 0.96 None
# Host correction...
# 1996ai sn1996ai-19960625.26-fast.flm 4.16 0.88 None
# Host correction...
# 1996c sn1996C-19960220.40-fast.flm 4.9 0.93 None
# Host correction...
# 1998aq sn1998aq-19980502.23-fast.flm 4.03000000001 1.11 None
# Host correction...
# 1998eg sn1998eg-19981029.19-fast.flm 4.29 1.14 None
# Host correction...
# 1999gp sn1999gp-20000112.09-fast.flm 4.99 0.87 None
# Host correction...
# 2000cf sn2000cf-20000512.36-fast.flm 4.06 1.16 None
# Host correction...
# 2000fa sn2000fa-20001218.38-fast.flm 4.28 1.0 None
# Host correction...
# 2001ay sn2001ay-20010427.36-fast.flm 4.36 0.68 None
# Host correction...
# 2001bf sn2001bf-20010521.43-fast.flm 4.73 0.99 None
# Host correction...
# 2001bg sn2001bg-20010515.23-fast.flm 4.23 1.06 None
# 2001ck sn2001ck-20010617.29-fast.flm 4.99 1.05 None
# 2001eh sn2001eh-20010922.35-fast.flm 4.85 0.92 None
# Host correction...
# 2001en sn2001en-20011014.34-fast.flm 4.44 1.12 None
# Host correction...
# 2001g sn2001G-20010125.34-fast.flm 4.74 None 1.13936266574
# Host correction...
# 2002bf sn2002bf-20020309.25-fast.flm 4.85 1.12 None
# Host correction...
# 2002ck sn2002ck-20020507.38-fast.flm 4.38 1.08 None
# Host correction...
# 2002fk sn2002fk-20021005.42-fast.flm 4.52 1.13 None
# Host correction...
# 2004fu sn2004fu-20041121.09-fast.flm 4.49 1.08 None
# Host correction...
# 2005cf sn2005cf-20050617.3-uvot.flm 4.3 1.1 None
# Host correction...
# 2006bt sn2006bt-20060507.30-fast.flm 4.9 1.0 None
# Host correction...
# 2006cj sn2006cj-20060528.19-fast.flm 4.69 0.81 None
# Host correction...
# 2006le sn2006le-20061112.40-fast.flm 4.0 0.88 None
# Host correction...
# 2006s sn2006S-20060207.43-mmt.flm 4.23 0.93 None
# Host correction...
# 2007a sn2007A-20070117.11-fast.flm 4.51 0.95 None
# Host correction...
# 2007af SN07af_070319_b01_DUP_BC.dat 4.47999999998 1.04 None
# Host correction...
# 2008ar sn2008ar-20080313.37-fast.flm 4.27 1.1 None
# 2008bf sn2008bf-20080403.30-fast.flm 4.7 1.05 None
# Host correction...
# 2008c sn2008C-20080105.27-fast.flm 4.46999999999 1.11 None
# Host correction...
# 2007bm SN07bm_070508_b01_BAA_IM.dat 4.12000000011 1.09 None
# Host correction...
# 2007ca SN07ca_070511_b01_DUP_BC.dat 4.25999999978 0.89 None
# Host correction...
# 2007le SN07le_071030_g01_NTT_EM.dat 4.9299999997 1.01 None
# Host correction...
# 31 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 5 and phase < 6 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 35 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 31 spectra left
# 1997bp sn1997bp-19970416-uoi.flm 5.49 1.08 None
# Host correction...
# 1999ek sn1999ek-19991105-ui.flm 5.66 1.14 None
# Host correction...
# 2005a sn2005a-20050115.357-br.flm 5.55 1.11 None
# Host correction...
# 2007s sn2007s-20070218.375-ui.flm 5.18 0.94 None
# Host correction...
# 1994ae sn1994ae-19941204.53-fast.flm 5.03 0.96 None
# Host correction...
# 1995d sn1995D-19950226.28-fast.flm 5.58 1.05 None
# Host correction...
# 1995e sn1995E-19950305.17-fast.flm 5.97 1.16 None
# Host correction...
# 1996bo sn1996bo-19961105.24-fast.flm 5.24 1.16 None
# Host correction...
# 1998aq sn1998aq-19980503.24-fast.flm 5.04 1.11 None
# Host correction...
# 1998eg sn1998eg-19981030.16-fast.flm 5.26 1.14 None
# Host correction...
# 1999dq sn1999dq-19990920.46-fast.flm 5.46 0.86 None
# Host correction...
# 2001bg sn2001bg-20010516.23-fast.flm 5.23 1.06 None
# 2001eh sn2001eh-20010923.37-fast.flm 5.87 0.92 None
# Host correction...
# 2001en sn2001en-20011015.31-fast.flm 5.41 1.12 None
# Host correction...
# 2002bf sn2002bf-20020310.24-fast.flm 5.84 1.12 None
# Host correction...
# 2004as sn2004as-20040327.35-fast.flm 5.95 0.92 None
# Host correction...
# 2004bg sn2004bg-20040420.33-fast.flm 5.83 1.05 None
# Host correction...
# 2004l sn2004L-20040130.33-fast.flm 5.43 1.12 None
# Host correction...
# 2005hc sn2005hc-20051030.32-fast.flm 5.62 1.03 None
# Host correction...
# 2006bt sn2006bt-20060508.31-fast.flm 5.91 1.0 None
# Host correction...
# 2006le sn2006le-20061114.38-fast.flm 5.98 0.88 None
# Host correction...
# 2007af sn2007af-20070320.48-fast.flm 5.38 1.04 None
# Host correction...
# 2007ca sn2007ca-20070512.27-fast.flm 5.57 0.89 None
# Host correction...
# 2007cg sn2007cg-20070514.24-fast.flm 5.74 1.05 None
# Host correction...
# 2007co sn2007co-20070619.45-fast.flm 5.85 1.16 None
# Host correction...
# 2007if sn2007if-20070911.29-mmt.flm 5.89 0.71 None
# Host correction...
# 2007le sn2007le-20071031.17-fast.flm 5.47 1.01 None
# Host correction...
# 2008ar sn2008ar-20080314.29-fast.flm 5.19 1.1 None
# 2003du 2003du_20030513_3300_7200_00.dat 5.9 1.07 None
# Host correction...
# 2005cf 2005cf_20050618_3258_9998_00.dat 5.3 1.1 None
# Host correction...
# 2006gz 2006gz_20061017_3248_6691_00.dat 5.3 0.69 None
# 28 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 6 and phase < 7 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 36 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 35 spectra left
# 2000fa sn2000fa-20001221-ui-corrected.flm 6.86 1.0 None
# Host correction...
# 2001ay sn2001ay-20010430-ui.flm 6.79 0.68 None
# Host correction...
# 2002bf sn2002bf-20020311-ui-corrected.flm 6.9 1.12 None
# Host correction...
# 2002hd sn2002hd-20021102-ui.flm 6.48 1.16 None
# Host correction...
# 2004bk sn2004bk-20040424.371-ui-corrected.flm 6.13 1.02 None
# 2006cf sn2006cf-20060523.291-ui.flm 6.28 None 1.14732833364
# Host correction...
# 2006cm sn2006cm-20060605.470-ui.flm 6.77 1.04 None
# Host correction...
# 2006ot sn2006ot-20061201.241-ui.flm 6.541 0.84 None
# Host correction...
# 2007qe sn2007qe-20071201.176-ui.flm 6.23 1.03 None
# Host correction...
# 1995al sn1995al-19951114.52-fast.flm 6.42 0.87 None
# Host correction...
# 1997y sn1997Y-19970214.47-fast.flm 6.97 1.15 None
# Host correction...
# 1998ab sn1998ab-19980418.28-fast.flm 6.88 1.04 None
# Host correction...
# 1998aq sn1998aq-19980504.26-fast.flm 6.06 1.11 None
# Host correction...
# 1998dm sn1998dm-19980910.42-fast.flm 6.52 0.9 None
# Host correction...
# 1999ef sn1999ef-19991013.29-fast.flm 6.99 1.06 None
# Host correction...
# 2000ce sn2000ce-20000510.15-fast.flm 6.85 1.0 None
# Host correction...
# 2001ck sn2001ck-20010618.33-mmt.flm 6.03 1.05 None
# 2001en sn2001en-20011016.33-fast.flm 6.43 1.12 None
# Host correction...
# 2001fe sn2001fe-20011122.48-fast.flm 6.28000000001 1.0 None
# Host correction...
# 2002fk sn2002fk-20021007.45-fast.flm 6.55 1.13 None
# Host correction...
# 2002jy sn2002jy-20030101.10-fast.flm 6.1 0.88 None
# Host correction...
# 2004as sn2004as-20040328.22-fast.flm 6.82 0.92 None
# Host correction...
# 2005hc sn2005hc-20051031.29-fast.flm 6.59 1.03 None
# Host correction...
# 2006cp sn2006cp-20060617.21-fast.flm 6.51 0.98 None
# Host correction...
# 2006et sn2006et-20060922.37-fast.flm 6.47 1.02 None
# Host correction...
# 2007bm SN07bm_070511_b01_DUP_BC.dat 6.9299999997 1.09 None
# Host correction...
# 2007ca sn2007ca-20070513.21-fast.flm 6.51 0.89 None
# Host correction...
# 2007cg sn2007cg-20070515.22-fast.flm 6.72 1.05 None
# Host correction...
# 2007co sn2007co-20070620.34-fast.flm 6.74 1.16 None
# Host correction...
# 2007if sn2007if-20070912.30-mmt.flm 6.9 0.71 None
# Host correction...
# 2007s sn2007S-20070219.32-fast.flm 6.22 0.94 None
# Host correction...
# 2000e 2000E_20000210_3217_7484_00.dat 6.8 1.09 None
# Host correction...
# 2003du 2003du_20030514_3303_7201_00.dat 6.9 1.07 None
# Host correction...
# 2005cf 2005cf_20050619_3335_9566_00.dat 6.3 1.1 None
# Host correction...
# 2006gz 2006gz_20061018_3722_7178_00.dat 6.3 0.69 None
# 32 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 7 and phase < 8 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 32 spectra found
# Arrays cleaned
# bad file removed
# 2 spectra with nan ivars removed
# Peculiar Ias removed 29 spectra left
# 1998v sn1998v-19980326-br.flm 7.2 0.99 None
# Host correction...
# 2002fk sn2002fk-20021008-br-corrected.flm 7.74 1.13 None
# Host correction...
# 2005hj sn2005hj-20051108.457-deimos.flm 7.51 None 0.85116780468
# Host correction...
# 2007le sn2007le-20071102.182-ui-corrected.flm 7.43 1.01 None
# Host correction...
# 1994ae sn1994ae-19941207.47-fast.flm 7.97 0.96 None
# Host correction...
# 1995d sn1995D-19950228.26-fast.flm 7.56 1.05 None
# Host correction...
# 1996c sn1996C-19960223.44-mmt.flm 7.94 0.93 None
# Host correction...
# 1997br sn1997br-19970429.28-fast.flm 7.98 1.09 None
# Host correction...
# 1998ab sn1998ab-19980419.29-fast.flm 7.89 1.04 None
# Host correction...
# 1998dm sn1998dm-19980911.33-fast.flm 7.43 0.9 None
# Host correction...
# 1999gp sn1999gp-20000114.16-fast.flm 7.06 0.87 None
# Host correction...
# 2001ay sn2001ay-20010430.36-fast.flm 7.36 0.68 None
# Host correction...
# 2001bf sn2001bf-20010524.44-fast.flm 7.74000000001 0.99 None
# Host correction...
# 2001da sn2001da-20010724.45-fast.flm 7.95 1.12 None
# Host correction...
# 2002dp sn2002dp-20020702.45-fast.flm 7.14999999999 1.12 None
# Host correction...
# 2002jy sn2002jy-20030102.12-fast.flm 7.12 0.88 None
# Host correction...
# 2003fa sn2003fa-20030623.33-fast.flm 7.13 0.8 None
# Host correction...
# 2004as sn2004as-20040329.23-fast.flm 7.83 0.92 None
# Host correction...
# 2006cp sn2006cp-20060618.21-fast.flm 7.51 0.98 None
# Host correction...
# 2006gz sn2006gz-20061019.13-fast.flm 7.43 0.69 None
# 2006le sn2006le-20061115.44-fast.flm 7.04 0.88 None
# Host correction...
# 2007cg sn2007cg-20070516.24-fast.flm 7.74 1.05 None
# Host correction...
# 2007co sn2007co-20070621.33-fast.flm 7.73 1.16 None
# Host correction...
# 2007if sn2007if-20070913.35-fast.flm 7.95 0.71 None
# Host correction...
# 2008ar sn2008ar-20080316.47-fast.flm 7.37 1.1 None
# 2008bf sn2008bf-20080406.29-fast.flm 7.69 1.05 None
# Host correction...
# 2008z sn2008Z-20080226.44-fast.flm 7.74000000001 1.02 None
# 2005eq SN05eq_051018_g01_NTT_EM.dat 7.37000000011 0.88 None
# Host correction...
# 2007ai SN07ai_070319_b01_DUP_BC.dat 7.0299999998 None 0.891395606916
# Host correction...
# 26 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 8 and phase < 9 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 31 spectra found
# Arrays cleaned
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 28 spectra left
# 2002de sn2002de-20020617-ui-corrected.flm 8.37 0.96 None
# Host correction...
# 2005m sn2005m-20050211.413-br.flm 8.23 0.87 None
# Host correction...
# 2006en sn2006en-20060902.319-ui-corrected.flm 8.55 None 1.10994353514
# Host correction...
# 2006os sn2006os-20061201.142-ui.flm 8.61 None 1.13936266574
# Host correction...
# 1994ae sn1994ae-19941207.55-mmt.flm 8.05 0.96 None
# Host correction...
# 1995al sn1995al-19951116.51-fast.flm 8.41 0.87 None
# Host correction...
# 1995e sn1995E-19950308.16-mmt.flm 8.96000000001 1.16 None
# Host correction...
# 1997do sn1997do-19971122.45-fast.flm 8.35 0.94 None
# Host correction...
# 1998bu sn1998bu-19980528.19-fast.flm 8.49000000001 1.03 None
# Host correction...
# 1999ef sn1999ef-19991014.31-fast.flm 8.00999999999 1.06 None
# Host correction...
# 2000ce sn2000ce-20000512.15-fast.flm 8.85 1.0 None
# Host correction...
# 2001bf sn2001bf-20010525.47-mmt.flm 8.77 0.99 None
# Host correction...
# 2001eh sn2001eh-20010926.37-fast.flm 8.87 0.92 None
# Host correction...
# 2001en sn2001en-20011018.35-fast.flm 8.45 1.12 None
# Host correction...
# 2002fk sn2002fk-20021009.36-fast.flm 8.46 1.13 None
# Host correction...
# 2002jy sn2002jy-20030103.12-fast.flm 8.12 0.88 None
# Host correction...
# 2003fa sn2003fa-20030624.29-fast.flm 8.09 0.8 None
# Host correction...
# 2004as sn2004as-20040330.24-fast.flm 8.84 0.92 None
# Host correction...
# 2005eu sn2005eu-20051025.29-fast.flm 8.59 0.89 None
# Host correction...
# 2006gz sn2006gz-20061020.12-fast.flm 8.42000000001 0.69 None
# 2006le sn2006le-20061116.42-fast.flm 8.02 0.88 None
# Host correction...
# 2007co sn2007co-20070622.38-fast.flm 8.78 1.16 None
# Host correction...
# 2007le sn2007le-20071103.17-fast.flm 8.47 1.01 None
# Host correction...
# 2007qe sn2007qe-20071203.12-fast.flm 8.22 1.03 None
# Host correction...
# 2007s sn2007S-20070221.32-fast.flm 8.22 0.94 None
# Host correction...
# 2008c sn2008C-20080109.29-fast.flm 8.49 1.11 None
# Host correction...
# 2003du 2003du_20030516_3258_9799_00.dat 8.9 1.07 None
# Host correction...
# 2005cf 2005cf_20050621_3240_9720_00.dat 8.3 1.1 None
# Host correction...
# 27 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 9 and phase < 10 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 29 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 29 spectra left
# 1994q sn1994q-19940603-uoh.flm 9.68 1.03 None
# Host correction...
# 2001da sn2001da-20010727-ui-corrected.flm 9.72 1.12 None
# Host correction...
# 2005m sn2005m-20050212.420-br.flm 9.23 0.87 None
# Host correction...
# 2006et sn2006et-20060925.321-ui.flm 9.14 1.02 None
# Host correction...
# 2007co sn2007co-20070623.408-ui-corrected.flm 9.55 1.16 None
# Host correction...
# 2008z sn2008z-20080229-ir.flm 9.99 1.02 None
# 1994ae sn1994ae-19941208.55-fast.flm 9.05 0.96 None
# Host correction...
# 1995d sn1995D-19950302.30-fast.flm 9.60000000001 1.05 None
# Host correction...
# 1996bo sn1996bo-19961109.28-fast.flm 9.28 1.16 None
# Host correction...
# 1997bq sn1997bq-19970429.17-fast.flm 9.27 1.14 None
# Host correction...
# 1997br sn1997br-19970501.27-fast.flm 9.96999999999 1.09 None
# Host correction...
# 1998bu sn1998bu-19980529.18-fast.flm 9.48 1.03 None
# Host correction...
# 1998dm sn1998dm-19980913.43-fast.flm 9.53 0.9 None
# Host correction...
# 1999ek sn1999ek-19991109.42-fast.flm 9.32 1.14 None
# Host correction...
# 2000fa sn2000fa-20001223.35-fast.flm 9.25 1.0 None
# Host correction...
# 2001ay sn2001ay-20010502.30-fast.flm 9.3 0.68 None
# Host correction...
# 2001v sn2001V-20010314.43-fast.flm 9.63 0.82 None
# Host correction...
# 2002fk sn2002fk-20021010.43-fast.flm 9.53 1.13 None
# Host correction...
# 2003fa sn2003fa-20030625.30-fast.flm 9.10000000001 0.8 None
# Host correction...
# 2006cj sn2006cj-20060602.21-fast.flm 9.71 0.81 None
# Host correction...
# 2006cp sn2006cp-20060620.19-fast.flm 9.49000000001 0.98 None
# Host correction...
# 2006gr sn2006gr-20061014.14-fast.flm 9.74 0.81 None
# Host correction...
# 2006gz sn2006gz-20061021.12-fast.flm 9.42000000001 0.69 None
# 2006le sn2006le-20061117.44-fast.flm 9.04 0.88 None
# Host correction...
# 2007bm sn2007bm-20070514.16-fast.flm 9.66 1.09 None
# Host correction...
# 2007ca sn2007ca-20070516.26-fast.flm 9.56 0.89 None
# Host correction...
# 2007le sn2007le-20071104.31-fast.flm 9.61 1.01 None
# Host correction...
# 2007qe sn2007qe-20071204.14-fast.flm 9.24 1.03 None
# Host correction...
# 2008bf SN08bf_080407_b01_DUP_WF.dat 9.20000000019 1.05 None
# Host correction...
# 27 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 10 and phase < 11 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 31 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 30 spectra left
# 2001en sn2001en-20011020-ui-corrected.flm 10.09 1.12 None
# Host correction...
# 2004bg sn2004bg-20040424.256-ui.flm 10.34 1.05 None
# Host correction...
# 2006br sn2006br-20060505.297-ui.flm 10.62 1.12 None
# Host correction...
# 1994ae sn1994ae-19941209.50-fast.flm 10.0 0.96 None
# Host correction...
# 1995al sn1995al-19951118.53-fast.flm 10.43 0.87 None
# Host correction...
# 1995bd sn1995bd-19960115.24-fast.flm 10.74 0.94 None
# Host correction...
# 1997do sn1997do-19971124.45-fast.flm 10.35 0.94 None
# Host correction...
# 1998bu sn1998bu-19980530.17-fast.flm 10.47 1.03 None
# Host correction...
# 1998dk sn1998dk-19980910.40-fast.flm 10.3 1.05 None
# Host correction...
# 1999ef sn1999ef-19991016.30-fast.flm 10.0 1.06 None
# Host correction...
# 2001bg sn2001bg-20010521.14-fast.flm 10.14 1.06 None
# 2001v sn2001V-20010315.44-fast.flm 10.64 0.82 None
# Host correction...
# 2002bf sn2002bf-20020315.22-fast.flm 10.82 1.12 None
# Host correction...
# 2002bo sn2002bo-20020403.19-fast.flm 10.49 1.08 None
# Host correction...
# 2002dp sn2002dp-20020705.43-fast.flm 10.13 1.12 None
# Host correction...
# 2002jy sn2002jy-20030105.11-fast.flm 10.11 0.88 None
# Host correction...
# 2003kf sn2003kf-20031218.35-fast.flm 10.55 1.1 None
# Host correction...
# 2005eu sn2005eu-20051027.36-fast.flm 10.66 0.89 None
# Host correction...
# 2005m sn2005M-20050214.29-fast.flm 10.19 0.87 None
# Host correction...
# 2006gz sn2006gz-20061022.09-fast.flm 10.39 0.69 None
# 2007af sn2007af-20070325.35-fast.flm 10.25 1.04 None
# Host correction...
# 2007co sn2007co-20070624.36-fast.flm 10.76 1.16 None
# Host correction...
# 2007if sn2007if-20070915.46-fast.flm 10.06 0.71 None
# Host correction...
# 2007le SN07le_071105_b01_DUP_WF.dat 10.8899999997 1.01 None
# Host correction...
# 2008bf sn2008bf-20080409.33-fast.flm 10.73 1.05 None
# Host correction...
# 2008c sn2008C-20080111.32-mmt.flm 10.52 1.11 None
# Host correction...
# 2008z sn2008Z-20080229.28-fast.flm 10.58 1.02 None
# 2005lu SN05lu_051218_g01_NTT_EM.dat 10.75 0.74 None
# Host correction...
# 2006et SN06et_060925_b01_DUP_WF.dat 10.7000000002 1.02 None
# Host correction...
# 2008ar SN08ar_080319_b01_CLA_MA.dat 10.4900000002 1.1 None
# 26 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 11 and phase < 12 and (dm15_cfa <= 1.16 or dm15_from_fits <= 1.16)
# Collecting data...
# 34 spectra found
# Arrays cleaned
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 32 spectra left
# 1998ec sn1998ec-19981015-ui.flm 11.86 1.08 None
# Host correction...
# 2000cp sn2000cp-20000706-ui-corrected.flm 11.7 1.09 None
# 2001g sn2001g-20010201-ui.flm 11.57 None 1.13936266574
# Host correction...
# 2002jy sn2002jy-20030107-br.flm 11.86 0.88 None
# Host correction...
# 2006cf sn2006cf-20060528.299-ui.flm 11.09 None 1.14732833364
# Host correction...
# 2006le sn2006le-20061120.427-ui-corrected.flm 11.92 0.88 None
# Host correction...
# 1994q 1994Q_19940605_3497_9708_00.dat 11.8 1.03 None
# Host correction...
# 1995d sn1995D-19950304.34-fast.flm 11.64 1.05 None
# Host correction...
# 1996bo sn1996bo-19961111.27-fast.flm 11.27 1.16 None
# Host correction...
# 1997bq sn1997bq-19970501.17-fast.flm 11.27 1.14 None
# Host correction...
# 1997br sn1997br-19970503.29-mmt.flm 11.99 1.09 None
# Host correction...
# 1997do sn1997do-19971125.38-fast.flm 11.28 0.94 None
# Host correction...
# 1998bu sn1998bu-19980531.18-fast.flm 11.48 1.03 None
# Host correction...
# 1998dk sn1998dk-19980911.34-fast.flm 11.24 1.05 None
# Host correction...
# 2001v sn2001V-20010316.29-fast.flm 11.49 0.82 None
# Host correction...
# 2002bo sn2002bo-20020404.37-fast.flm 11.67 1.08 None
# Host correction...
# 2003fa sn2003fa-20030627.30-fast.flm 11.1 0.8 None
# Host correction...
# 2005hc sn2005hc-20051105.31-fast.flm 11.61 1.03 None
# Host correction...
# 2005ls sn2005ls-20051221.22-fast.flm 11.02 0.98 None
# Host correction...
# 2006cj sn2006cj-20060604.27-fast.flm 11.77 0.81 None
# Host correction...
# 2006gz sn2006gz-20061023.09-fast.flm 11.39 0.69 None
# ...
# Host correction...
# 2007nq SN07nq_071117_r01_BAA_IM.dat 23.4899999998 1.47 None
# Host correction...
# 1994d 1994D_19940414_3045_10117_00.dat 23.5 1.37 None
# Host correction...
# 2003cg 2003cg_20030423_3800_7765_00.dat 22.6 1.26 None
# Host correction...
# 29 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 25 and phase < 28 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)
# Collecting data...
# 37 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 35 spectra left
# 1995ak sn1995ak-19951126-opt.flm 26.38 1.25 None
# Host correction...
# 1998dh sn1998dh-19980831-ui-corrected.flm 26.47 1.17 None
# Host correction...
# 1998dx sn1998dx-19981015-ui.flm 27.84 1.32 None
# Host correction...
# 1998ef sn1998ef-19981125-ui.flm 27.83 1.27 None
# Host correction...
# 1999cl sn1999cl-19990709-ui-corrected.flm 25.76 1.17 None
# Host correction...
# 2000dm sn2000dm-20001024-ui-corrected.flm 25.88 1.46 None
# 2002eu sn2002eu-20021001.237-ui-corrected.flm 26.73 1.52 None
# Host correction...
# 2003hv sn2003hv-20031002.472-ui-corrected.flm 25.73 1.31 None
# 2004ef sn2004ef-20041013.373-ui-corrected.flm 26.55 1.39 None
# Host correction...
# 2005bo sn2005bo-20050515.289-ui.flm 27.71 1.28 None
# Host correction...
# 2005mc sn2005mc-20060124.354-ui.flm 25.16 1.63 None
# Host correction...
# 2006az sn2006az-20060428.289-ui.flm 26.3 1.29 None
# Host correction...
# 2006ej sn2006ej-20060925.299-ui.flm 27.54 None 1.26491436748
# Host correction...
# 2006em sn2006em-20060925.415-ui.flm 26.7 1.5 None
# Host correction...
# 2006lf sn2006lf-20061201.194-ui-corrected.flm 25.06 1.3 None
# Host correction...
# 2006n sn2006n-20060222.131-ui.flm 27.54 1.5 None
# Host correction...
# 2007ci sn2007ci-20070623.249-ui.flm 27.75 1.6 None
# Host correction...
# 1998bp sn1998bp-19980528.47-fast.flm 25.07 1.79 None
# Host correction...
# 1999ac sn1999ac-19990409.45-fast.flm 26.95 1.23 None
# Host correction...
# 1999cc sn1999cc-19990612.32-fast.flm 25.72 1.35 None
# Host correction...
# 1999gd sn1999gd-20000102.39-fast.flm 25.99 1.18 None
# Host correction...
# 2000bk sn2000bk-20000510.19-fast.flm 27.19 1.46 None
# Host correction...
# 2000cn sn2000cn-20000709.24-fast.flm 26.34 1.51 None
# Host correction...
# 2002fb sn2002fb-20021009.34-fast.flm 27.24 1.77 None
# Host correction...
# 2002jg sn2002jg-20021227.08-fast.flm 25.48 1.42 None
# 2003cg 2003cg_20030426_3800_9347_00.dat 25.6 1.26 None
# Host correction...
# 2005am SN05am_050403_b01_DUP_WF.dat 25.8999999999 1.3 None
# Host correction...
# 2005ke SN05ke_051221_b01_DUP_WF.dat 27.3700000001 1.82 None
# Host correction...
# 2008af sn2008af-20080301.49-fast.flm 25.09 1.33 None
# Host correction...
# 2006eq SN06eq_060925_b01_DUP_WF.dat 26.4199999999 1.62 None
# Host correction...
# 2006gj SN06gj_061016_b01_HIL_BC.dat 26.25 1.48 None
# Host correction...
# 2007hj SN07hj_071003_r01_3P6_EF.dat 27.27 1.95 None
# 1994d 1994D_19940416_4657_11030_00.dat 25.5 1.37 None
# Host correction...
# 2006x 2006X_20060319_4213_6833_00.dat 26.9 1.18 None
# Host correction...
# 2001ex sn2001ex-20011119.272-hst.flm 27.9 1.56 None
# 30 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 28 and phase < 31 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)
# Collecting data...
# 29 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 28 spectra left
# 1993ac sn1993ac-19931108-ui.flm 28.66 1.19 None
# Host correction...
# 1994d sn1994d-19940420.flm 29.63 1.37 None
# Host correction...
# 1998de sn1998de-19980831-ui.flm 29.49 1.88 None
# Host correction...
# 2000dk sn2000dk-20001024-ui-corrected.flm 28.41 1.62 None
# Host correction...
# 2001ep sn2001ep-20011115-ui.flm 28.46 1.3 None
# Host correction...
# 2008a sn2008a-20080212-br.flm 29.9 1.28 None
# 1996x 1996X_19960519_3372_9254_00.dat 30.9 1.26 None
# Host correction...
# 1998bp sn1998bp-19980531.40-fast.flm 28.0 1.79 None
# Host correction...
# 1998co sn1998co-19980722.40-fast.flm 28.9 None 1.7342423379
# Host correction...
# 1999ac sn1999ac-19990411.48-fast.flm 28.98 1.23 None
# Host correction...
# 1999by sn1999by-19990609.17-fast.flm 28.97 1.97 None
# Host correction...
# 1999gd sn1999gd-20000106.44-fast.flm 30.04 1.18 None
# Host correction...
# 1999gh sn1999gh-19991229.45-fast.flm 28.45 1.69 None
# Host correction...
# 2002do sn2002do-20020718.29-fast.flm 30.89 1.56 None
# Host correction...
# 2002kf sn2002kf-20030129.28-mmt.flm 30.08 1.2 None
# Host correction...
# 2003cq sn2003cq-20030509.15-fast.flm 29.95 1.2 None
# Host correction...
# 2005el sn2005el-20051102.40-fast.flm 30.0 1.27 None
# Host correction...
# 2005kc SN05kc_051222_b01_DUP_WF.dat 28.8599999999 1.24 None
# Host correction...
# 2005ke SN05ke_051224_b01_DUP_WF.dat 30.4199999999 1.82 None
# Host correction...
# 2006hb sn2006hb-20061022.39-fast.flm 30.79 1.44 None
# Host correction...
# 2006n sn2006N-20060223.18-fast.flm 28.58 1.5 None
# Host correction...
# 2006x 2006X_20060321_3979_8921_00.dat 28.9 1.18 None
# Host correction...
# snf20080514-002 snf20080514-002-20080623.00-ldss3.flm 28.3 1.35 None
# 2005am SN05am_050407_b01_DUP_WF.dat 30.9399999999 1.3 None
# Host correction...
# 2006ej SN06ej_060926_b01_DUP_WF.dat 28.98 None 1.26491436748
# Host correction...
# 2006ev SN06ev_061011_b01_DUP_WF.dat 30.4099999997 1.32 None
# Host correction...
# 2006kf SN06kf_061130_b01_HIL_BC.dat 29.5 1.55 None
# Host correction...
# 2002dj 2002dj_20020725_3741_10264_00.dat 29.4 1.19 None
# Host correction...
# 26 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 31 and phase < 34 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)
# Collecting data...
# 29 spectra found
# Arrays cleaned
# bad file removed
# 2 spectra with nan ivars removed
# Peculiar Ias removed 26 spectra left
# 1994t sn1994t-19940715-ui.flm 33.09 1.51 None
# Host correction...
# 2000dm sn2000dm-20001101.166-ui-corrected.flm 33.76 1.46 None
# 2002cr sn2002cr-20020617-ui.flm 33.69 1.19 None
# Host correction...
# 2002eu sn2002eu-20021008-br.flm 33.25 1.52 None
# Host correction...
# 2004ef sn2004ef-20041018-br-corrected.flm 31.23 1.39 None
# Host correction...
# 2006bw sn2006bw-20060528.383-ui.flm 31.26 1.28 None
# Host correction...
# 2006d sn2006d-20060222.513-ui.flm 32.54 1.35 None
# Host correction...
# 2006x sn2006x-20060322.422-ui.flm 31.01 1.18 None
# Host correction...
# 2007ap sn2007ap-20070410.502-ui.flm 32.85 1.37 None
# Host correction...
# 2007au sn2007au-20070426.255-ui.flm 31.85 1.69 None
# Host correction...
# 2008l sn2008l-20080229-ir.flm 32.37 1.38 None
# Host correction...
# 1996x sn1996X-19960521.22-fast.flm 33.12 1.26 None
# Host correction...
# 1999ac sn1999ac-19990415.45-fast.flm 32.95 1.23 None
# Host correction...
# 1999by sn1999by-19990613.16-fast.flm 32.96 1.97 None
# Host correction...
# 2000dk sn2000dk-20001029.27-fast.flm 33.67 1.62 None
# Host correction...
# 2001ep sn2001ep-20011118.47-fast.flm 31.87 1.3 None
# Host correction...
# 2002ha sn2002ha-20021205.09-fast.flm 32.69 1.22 None
# Host correction...
# 2004gs sn2004gs-20050118.36-fast.flm 32.56 1.41 None
# Host correction...
# 2005am sn2005am-20050407.17-fast.flm 31.87 1.3 None
# Host correction...
# 2005kc sn2005kc-20051227.08-fast.flm 33.78 1.24 None
# Host correction...
# 2005ke sn2005ke-20051226.21-fast.flm 31.41 1.82 None
# Host correction...
# 2007bc sn2007bc-20070511.18-fast.flm 31.28 1.37 None
# Host correction...
# 2007hj sn2007hj-20071009.23-fast.flm 33.33 1.95 None
# 2008a sn2008A-20080214.16-fast.flm 32.06 1.28 None
# 2006hb SN06hb_061021_b01_HIL_BC.dat 32.2200000002 1.44 None
# Host correction...
# 1994m 1994M_19940605_3699_9505_00.dat 33.5 1.26 None
# Host correction...
# 23 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 34 and phase < 39 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)
# Collecting data...
# 29 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 27 spectra left
# 1999cl sn1999cl-19990718-ui-corrected.flm 34.68 1.17 None
# Host correction...
# 1999da sn1999da-19990817-ui.flm 36.3 1.9 None
# Host correction...
# 2000cu sn2000cu-20000827-ui-corrected.flm 38.96 1.48 None
# 2000dk sn2000dk-20001101-ui.flm 36.32 1.62 None
# Host correction...
# 2002ha sn2002ha-20021212-ui-corrected.flm 38.55 1.22 None
# Host correction...
# 2005am sn2005am-20050411.163-ui-corrected.flm 35.08 1.3 None
# Host correction...
# 2005ki sn2005ki-20060106.498-ui.flm 35.8 1.41 None
# Host correction...
# 2006ac sn2006ac-20060322.506-ui-corrected.flm 35.39 1.2 None
# Host correction...
# 2007ap sn2007ap-20070413.633-deimos.flm 35.93 1.37 None
# Host correction...
# 2007cq sn2007cq-20070807.330-ui-corrected.flm 37.95 1.2 None
# Host correction...
# 2007hj sn2007hj-20071015.315-br-corrected.flm 38.27 1.95 None
# 2008a sn2008a-20080216.228-ui.flm 34.128 1.28 None
# 1998co sn1998co-19980730.45-fast.flm 36.95 None 1.7342423379
# Host correction...
# 1998dh sn1998dh-19980910.37-fast.flm 36.47 1.17 None
# Host correction...
# 1999ac sn1999ac-19990417.50-fast.flm 35.0 1.23 None
# Host correction...
# 1999gd sn1999gd-20000111.40-fast.flm 35.0 1.18 None
# Host correction...
# 1999gh sn1999gh-20000104.45-fast.flm 34.45 1.69 None
# Host correction...
# 2000b sn2000B-20000226.28-fast.flm 37.88 1.46 None
# Host correction...
# 2001ep sn2001ep-20011122.28-fast.flm 35.68 1.3 None
# Host correction...
# 2002he sn2002he-20021213.47-fast.flm 35.67 1.44 None
# Host correction...
# 2004ef SN04ef_041024_b01_CLA_LD.dat 38.6600000001 1.39 None
# Host correction...
# 2006x sn2006X-20060326.26-fast.flm 34.16 1.18 None
# Host correction...
# 2007bc sn2007bc-20070516.19-fast.flm 36.29 1.37 None
# Host correction...
# 2005iq SN05iq_051222_b01_DUP_WF.dat 38.8599999999 1.19 None
# Host correction...
# 2006ej SN06ej_061005_g01_NTT_EM.dat 37.9299999997 None 1.26491436748
# Host correction...
# 2003cg 2003cg_20030508_4000_7767_00.dat 37.6 1.26 None
# Host correction...
# 2001ex sn2001ex-20011126.885-hst.flm 34.9 1.56 None
# 23 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 39 and phase < 49 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)
# Collecting data...
# 27 spectra found
# Arrays cleaned
# bad file removed
# 2 spectra with nan ivars removed
# Peculiar Ias removed 24 spectra left
# 1994d sn1994d-19940504.flm 43.61 1.37 None
# Host correction...
# 1998bp sn1998bp-19980618-ui.flm 45.61 1.79 None
# Host correction...
# 1998dh sn1998dh-19980921-ui-corrected.flm 47.26 1.17 None
# Host correction...
# 1999ac sn1999ac-19990424-ui-corrected.flm 41.73 1.23 None
# Host correction...
# 2005am sn2005am-20050417.167-ui-corrected.flm 41.04 1.3 None
# Host correction...
# 2005ke sn2005ke-20060105.242-ui.flm 41.54 1.82 None
# Host correction...
# 2006bq sn2006bq-20060605.439-ui.flm 44.94 1.29 None
# Host correction...
# 2006hb sn2006hb-20061030.489-ui.flm 39.38 1.44 None
# Host correction...
# 2006lf sn2006lf-20061220.150-ui-corrected.flm 43.77 1.3 None
# Host correction...
# 2007cq sn2007cq-20070814.346-ui-corrected.flm 44.79 1.2 None
# Host correction...
# 1997cn sn1997cn-19970701.25-mmt.flm 44.15 1.9 None
# Host correction...
# 1997e sn1997E-19970302.13-fast.flm 41.13 1.4 None
# Host correction...
# 1999by sn1999by-19990622.17-fast.flm 41.97 1.97 None
# Host correction...
# 1999gh sn1999gh-20000110.42-fast.flm 40.42 1.69 None
# Host correction...
# 2000b sn2000B-20000304.16-fast.flm 44.76 1.46 None
# Host correction...
# 2001ep sn2001ep-20011204.32-fast.flm 47.72 1.3 None
# Host correction...
# 2006x 2006X_20060407_4378_8913_00.dat 45.9 1.18 None
# Host correction...
# 2007bc sn2007bc-20070524.16-fast.flm 44.26 1.37 None
# Host correction...
# 2005ki SN05ki_060116_g01_NTT_EM.dat 46.23 1.41 None
# Host correction...
# 2006ej SN06ej_061011_b01_DUP_WF.dat 43.96 None 1.26491436748
# Host correction...
# 2007jg SN07jg_071104_r01_3P6_EF.dat 41.6000000001 1.17 None
# Host correction...
# 2007nq SN07nq_071203_b01_DUP_WF.dat 39.4699999997 1.47 None
# Host correction...
# 2003cg 2003cg_20030513_3810_9249_00.dat 42.6 1.26 None
# Host correction...
# 2001ex sn2001ex-20011203.964-hst.flm 41.9 1.56 None
# 23 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 49 and phase < 70 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)
# Collecting data...
# 32 spectra found
# Arrays cleaned
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 27 spectra left
# 1994d 1994D_19940510_3701_9842_00.dat 49.5 1.37 None
# Host correction...
# 1998de sn1998de-19980920-ui.flm 49.02 1.88 None
# Host correction...
# 1999da sn1999da-19990910-ui.flm 59.94 1.9 None
# Host correction...
# 2000cw sn2000cw-20000926-ui-corrected.flm 63.02 1.22 None
# 2002cr sn2002cr-20020711-ui-corrected.flm 57.47 1.19 None
# Host correction...
# 2002er sn2002er-20021108-br.flm 60.64 1.23 None
# Host correction...
# 2002eu sn2002eu-20021108-br.flm 63.12 1.52 None
# Host correction...
# 2002fb sn2002fb-20021108-br.flm 55.83 1.77 None
# Host correction...
# 2002ha sn2002ha-20030106-br.flm 63.11 1.22 None
# Host correction...
# 2004ef sn2004ef-20041114-br.flm 57.23 1.39 None
# Host correction...
# 2005ke sn2005ke-20060123.221-ui.flm 59.43 1.82 None
# Host correction...
# 2006d sn2006d-20060322.449-ui.flm 60.24 1.35 None
# Host correction...
# 2006x sn2006x-20060428.324-ui.flm 67.72 1.18 None
# Host correction...
# 1996x 1996X_19960613_2806_10203_00.dat 55.9 1.26 None
# Host correction...
# 1999ac sn1999ac-19990515.38-fast.flm 62.88 1.23 None
# Host correction...
# 1999gh sn1999gh-20000205.33-fast.flm 66.33 1.69 None
# Host correction...
# 2000b sn2000B-20000309.13-fast.flm 49.73 1.46 None
# Host correction...
# 2000cn sn2000cn-20000803.24-fast.flm 51.34 1.51 None
# Host correction...
# 2000dk sn2000dk-20001124.20-fast.flm 59.6 1.62 None
# Host correction...
# 2001ep sn2001ep-20011214.32-fast.flm 57.72 1.3 None
# Host correction...
# 2005am sn2005am-20050503.15-fast.flm 57.85 1.3 None
# Host correction...
# 2005el sn2005el-20051202.43-fast.flm 60.03 1.27 None
# Host correction...
# 2007bc sn2007bc-20070610.18-fast.flm 61.28 1.37 None
# Host correction...
# 2006ej SN06ej_061022_b01_HIL_BC.dat 56.1299999999 None 1.26491436748
# Host correction...
# 2007ux SN07ux_080225_b01_CLA_LD.dat 55.3599999999 1.74 None
# 2002dj 2002dj_20020902_3401_9093_00.dat 68.4 1.19 None
# Host correction...
# 2003cg 2003cg_20030522_3500_8048_00.dat 51.6 1.26 None
# Host correction...
# 25 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN and phase >= 70 and phase < 110 and (dm15_cfa > 1.16 or dm15_from_fits > 1.16)
# Collecting data...
# 21 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 19 spectra left
# 1994d sn1994d-19940616.flm 86.83 1.37 None
# Host correction...
# 1998de sn1998de-19981015-ui.flm 73.56 1.88 None
# Host correction...
# 1998dh sn1998dh-19981015-ui-corrected.flm 71.0 1.17 None
# Host correction...
# 1998ef sn1998ef-19990122-uvoir.flm 84.83 1.27 None
# Host correction...
# 2001ep sn2001ep-20020114-ui-corrected.flm 87.26 1.3 None
# Host correction...
# 2002cr sn2002cr-20020809-ui.flm 85.98 1.19 None
# Host correction...
# 2003hv sn2003hv-20031123-ui-corrected.flm 77.29 1.31 None
# 2004ef sn2004ef-20041212.217-br.flm 84.6 1.39 None
# Host correction...
# 2006x sn2006x-20060528.324-ui.flm 97.56 1.18 None
# Host correction...
# 2007hj sn2007hj-20071118.132-ui-corrected.flm 71.62 1.95 None
# 1995ak sn1995ak-19960115.17-fast.flm 75.57 1.25 None
# Host correction...
# 1998bp sn1998bp-19980719.25-fast.flm 76.85 1.79 None
# Host correction...
# 1999ac sn1999ac-19990608.38-fast.flm 86.88 1.23 None
# Host correction...
# 1999gh sn1999gh-20000210.33-fast.flm 71.33 1.69 None
# Host correction...
# 2000dk sn2000dk-20001224.16-fast.flm 89.56 1.62 None
# Host correction...
# 2003iv sn2003iv-20040118.21-mmt.flm 88.31 1.65 None
# Host correction...
# 2005ke SN05ke_060308_b01_DUP_WF.dat 104.21 1.82 None
# Host correction...
# 2006hb SN06hb_061203_b01_HIL_BC.dat 75.1099999999 1.44 None
# Host correction...
# 1996x 1996X_19960714_3015_10623_00.dat 86.9 1.26 None
# Host correction...
# 17 SNs with host corrections
# Creating composite...
# Done.

# %%
def stacked_plot(comps_low, comps_high):
    fig, ax = plt.subplots(1,1)
    ax.get_yaxis().set_ticks([])
    plt.ylabel('Relative Flux + const.')
    plt.xlabel('Wavelength (A)')
    fig.set_size_inches(8.5, 11.)
    comps_low, scales = composite.optimize_scales(comps_low, comps_low[0], True)
    comps_high, scales = composite.optimize_scales(comps_high, comps_high[0], True)
    upper_buff = 100

    for i in range(len(comps_low)):
        scaled_comps, scales = composite.optimize_scales([comps_low[i], comps_high[i]], comps_low[i], True)
        phase_1 = np.average(scaled_comps[0].phase_array[scaled_comps[0].x1:scaled_comps[0].x2])
        phase_2 = np.average(scaled_comps[1].phase_array[scaled_comps[1].x1:scaled_comps[1].x2])
        phase = (phase_1 + phase_2)/2.
        ax.plot(scaled_comps[0].wavelength[scaled_comps[0].x1:scaled_comps[0].x2], 2.e15*scaled_comps[0].flux[scaled_comps[0].x1:scaled_comps[0].x2] + upper_buff - 3.*phase, 'b-')
        ax.plot(scaled_comps[1].wavelength[scaled_comps[1].x1:scaled_comps[1].x2], 2.e15*scaled_comps[1].flux[scaled_comps[1].x1:scaled_comps[1].x2] + upper_buff - 3.*phase, 'r-')
#         plt.fill_between(scaled_comps[0].wavelength[scaled_comps[0].x1:scaled_comps[0].x2], 2.e15*scaled_comps[0].low_conf[scaled_comps[0].x1:scaled_comps[0].x2] + upper_buff - 3.*phase, 2.e15*scaled_comps[0].up_conf[scaled_comps[0].x1:scaled_comps[0].x2] + upper_buff - 3.*phase, alpha = 0.5)
#         plt.fill_between(scaled_comps[1].wavelength[scaled_comps[1].x1:scaled_comps[1].x2], 2.e15*scaled_comps[1].low_conf[scaled_comps[1].x1:scaled_comps[1].x2] + upper_buff - 3.*phase, 2.e15*scaled_comps[1].up_conf[scaled_comps[1].x1:scaled_comps[1].x2] + upper_buff - 3.*phase, color = 'r', alpha = 0.5)
        plt.text(scaled_comps[0].wavelength[scaled_comps[0].x2], scaled_comps[0].flux[scaled_comps[0].x2] + upper_buff - 3.*phase + 1, str(round(phase, 2)) + ' days')
    plt.show()

# %%
import composite

# %%
query_db.set_min_num_spec(comps_low_dm15, 5)
query_db.set_min_num_spec(comps_high_dm15, 5)

# %%
sub_list_1_low = comps_low_dm15[0:6]
sub_list_2_low = comps_low_dm15[6:12]
sub_list_3_low = comps_low_dm15[12:18]
sub_list_4_low = comps_low_dm15[18:24]
sub_list_5_low = comps_low_dm15[24:28]
sub_list_6_low = comps_low_dm15[28:30]
sub_list_7_low = comps_low_dm15[30:]

sub_list_1_high = comps_high_dm15[0:6]
sub_list_2_high = comps_high_dm15[6:12]
sub_list_3_high = comps_high_dm15[12:18]
sub_list_4_high = comps_high_dm15[18:24]
sub_list_5_high = comps_high_dm15[24:28]
sub_list_6_high = comps_high_dm15[28:30]
sub_list_7_high = comps_high_dm15[30:]

# %%
stacked_plot(sub_list_1_low, sub_list_1_high)

# %%
stacked_plot(sub_list_2_low, sub_list_2_high)

# %%
stacked_plot(sub_list_3_low, sub_list_3_high)

# %%
stacked_plot(sub_list_4_low, sub_list_4_high)

# %%
stacked_plot(sub_list_5_low, sub_list_5_high)

# %%
stacked_plot(sub_list_6_low, sub_list_6_high)

# %%
stacked_plot(sub_list_7_low, sub_list_7_high)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-7c15178f952a> in <module>()
# ----> 1 stacked_plot(sub_list_7_low, sub_list_7_high)
#
# <ipython-input-47-c949e0e75798> in stacked_plot(comps_low, comps_high)
#       6     fig.set_size_inches(8.5, 11.)
#       7     comps_low, scales = composite.optimize_scales(comps_low, comps_low[0], True)
# ----> 8     comps_high, scales = composite.optimize_scales(comps_high, comps_high[0], True)
#       9     upper_buff = 100
#      10
#
# IndexError: list index out of range

# %% [markdown]
# # Maximum Light - Max Bins

# %%
query_dm15_split_max = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa < .9 or dm15_from_fits < .9)",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .9 and dm15_cfa < 1.) or (dm15_from_fits >= .9 and dm15_from_fits < 1))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1 and dm15_cfa < 1.05) or (dm15_from_fits >= 1 and dm15_from_fits < 1.05))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.05 and dm15_cfa < 1.1) or (dm15_from_fits >= 1.05 and dm15_from_fits < 1.1))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.2) or (dm15_from_fits >= 1.1 and dm15_from_fits < 1.2))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.3) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.3))", 
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.4) or (dm15_from_fits >= 1.3 and dm15_from_fits < 1.4))", 
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.4 and dm15_cfa < 1.6) or (dm15_from_fits >= 1.4 and dm15_from_fits < 1.6))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa >= 1.6 or dm15_from_fits >= 1.6)"
                       ]

# %%
comps_dm15_split_max = query_db.main(len(query_dm15_split_max), query_dm15_split_max)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa < .9 or dm15_from_fits < .9)
# Collecting data...
# 19 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 17 spectra left
# 1996ai sn1996ai-19960622-uoi.flm 1.231 0.88 None
# Host correction...
# 1998es sn1998es-19981125-ui-corrected.flm 0.28 0.85 None
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 0.24 0.78 None
# Host correction...
# 1999dq sn1999dq-near-19990917-clear-ui-corrected.flm 2.97 0.86 None
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 1.39 0.88 None
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 1.1 0.84 None
# Host correction...
# 2005eq sn2005eq-20051011.376-ui-corrected.flm 0.66 0.88 None
# Host correction...
# 2006ot sn2006ot-20061123.362-br.flm -1.338 0.84 None
# Host correction...
# 1999gp sn1999gp-20000105.10-fast.flm -2.0 0.87 None
# Host correction...
# 2001ay sn2001ay-20010421.48-fast.flm -1.52 0.68 None
# Host correction...
# 2002jy sn2002jy-20021226.12-fast.flm 0.120000000003 0.88 None
# Host correction...
# 2006cj sn2006cj-20060522.29-fast.flm -1.21 0.81 None
# Host correction...
# 2006gr sn2006gr-20061002.26-fast.flm -2.14 0.81 None
# Host correction...
# 2006oa sn2006oa-20061125.08-fast.flm -2.12 0.89 None
# Host correction...
# 2007ai SN07ai_070314_b01_DUP_BC.dat 2.04000000004 None 0.891395606916
# Host correction...
# 2007ca SN07ca_070508_b01_BAA_IM.dat 1.41999999993 0.89 None
# Host correction...
# 2006gz 2006gz_20061010_3755_7204_00.dat -1.7 0.69 None
# 16 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= .9 and dm15_cfa < 1.) or (dm15_from_fits >= .9 and dm15_from_fits < 1))
# Collecting data...
# 16 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 1994s sn1994s-19940616-uoi.flm 1.11 0.94 None
# Host correction...
# 2001bf sn2001bf-20010516-ui-corrected.flm 1.22 0.99 None
# Host correction...
# 2002de sn2002de-20020608.374-ui-corrected.flm -0.32 0.96 None
# Host correction...
# 2005ms sn2005ms-20060106.400-ui.flm -1.88 None 0.997210431761
# Host correction...
# 2006s sn2006s-20060206.517-ui.flm 2.99 0.93 None
# Host correction...
# 2007a sn2007a-20070113.208-br.flm 2.37 0.95 None
# Host correction...
# 1994ae sn1994ae-19941201.50-fast.flm 2.0 0.96 None
# Host correction...
# 1996c sn1996C-19960217.48-fast.flm 1.98 0.93 None
# Host correction...
# 1998v sn1998V-19980319.51-fast.flm 0.310000000005 0.99 None
# Host correction...
# 2001e sn2001E-20010119.49-fast.flm 2.89 0.92 None
# 2001eh sn2001eh-20010915.42-fast.flm -2.08 0.92 None
# Host correction...
# 2004as sn2004as-20040319.28-fast.flm -2.12 0.92 None
# Host correction...
# 2007ae sn2007ae-20070225.54-fast.flm 2.54 0.98 None
# Host correction...
# 2007s sn2007S-20070210.32-fast.flm -2.78 0.94 None
# Host correction...
# 13 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1 and dm15_cfa < 1.05) or (dm15_from_fits >= 1 and dm15_from_fits < 1.05))
# Collecting data...
# 14 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 13 spectra left
# 2000dn sn2000dn-20001006-uri-corrected.flm -0.94 1.04 None
# 2001fe sn2001fe-20011115-ui.flm -0.99 1.0 None
# Host correction...
# 2006bt sn2006bt-20060505.444-ui.flm 2.27 1.0 None
# Host correction...
# 2006cq sn2006cq-20060605.307-ui.flm 2.0 None 1.00205432495
# Host correction...
# 2007af sn2007af-20070313.545-ui-corrected.flm -1.25 1.04 None
# Host correction...
# 2008z sn2008z-20080216.463-ui.flm -2.29 1.02 None
# 1996ab sn1996ab-19960522.37-fast.flm 1.47 1.01 None
# Host correction...
# 1997dt sn1997dt-19971204.11-fast.flm 0.209999999999 1.04 None
# Host correction...
# 1998bu sn1998bu-19980517.15-fast.flm -2.55 1.03 None
# Host correction...
# 2000fa sn2000fa-20001215.36-fast.flm 1.26 1.0 None
# Host correction...
# 2006et sn2006et-20060918.36-fast.flm 2.46 1.02 None
# Host correction...
# 2005hc SN05hc_051024_b01_MGH_BC.dat 0.699999999721 1.03 None
# Host correction...
# 2007le SN07le_071028_g01_CLA_LD.dat 2.84999999963 1.01 None
# Host correction...
# 11 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.05 and dm15_cfa < 1.1) or (dm15_from_fits >= 1.05 and dm15_from_fits < 1.1))
# Collecting data...
# 18 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 16 spectra left
# 1998dk sn1998dk-19980831-ui.flm -0.54 1.05 None
# Host correction...
# 2000cp sn2000cp-20000627-ui-corrected.flm 2.92 1.09 None
# 2002aw sn2002aw-20020221-ui-corrected.flm 2.1 1.05 None
# 2002bo sn2002bo-20020322-ui-corrected.flm -1.08 1.08 None
# Host correction...
# 2004fu sn2004fu-20041119-ui.flm 2.43 1.08 None
# Host correction...
# 2005na sn2005na-20060105.335-ui.flm 0.03 1.09 None
# Host correction...
# 2007bz sn2007bz-20070426.419-ui.flm 1.65 1.05 None
# Host correction...
# 1996bl sn1996bl-19961018.18-fast.flm -2.32 1.07 None
# Host correction...
# 1998ec sn1998ec-19980930.50-fast.flm -3.0 1.08 None
# Host correction...
# 2002ck sn2002ck-20020502.46-fast.flm -0.540000000001 1.08 None
# Host correction...
# 2002ef sn2002ef-20020801.44-fast.flm -2.96 1.06 None
# 2002hu sn2002hu-20021113.25-fast.flm -0.75 1.05 None
# Host correction...
# 2004at sn2004at-20040327.33-fast.flm -0.669999999998 1.05 None
# 2004bg sn2004bg-20040417.19-fast.flm 2.69 1.05 None
# Host correction...
# 2006ax SN06ax_060330_b01_DUP_WF.dat -2.36000000034 1.06 None
# Host correction...
# 2008bf SN08bf_080326_b01_CLA_LD.dat -2.77000000002 1.05 None
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.2) or (dm15_from_fits >= 1.1 and dm15_from_fits < 1.2))
# Collecting data...
# 27 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 25 spectra left
# 1995e sn1995e-19950224-uoi2.flm -2.46 1.16 None
# Host correction...
# 1997y sn1997y-19970209-uohp.flm 1.27 1.15 None
# Host correction...
# 1999gd sn1999gd-19991205-uvoir.flm -1.12 1.18 None
# Host correction...
# 2001da sn2001da-20010716-ui-corrected.flm -1.12 1.12 None
# Host correction...
# 2002bf sn2002bf-20020307-os.flm 2.97 1.12 None
# Host correction...
# 2004dt sn2004dt-20040824-vis2-corrected.flm 1.38 1.14 None
# Host correction...
# 2005cf sn2005cf-20050610.7-uvot.flm -2.7 1.1 None
# Host correction...
# 2007co sn2007co-20070614.468-ui-corrected.flm 0.85 1.16 None
# Host correction...
# 2007o sn2007o-20070122.663-deimos.flm -0.33 None 1.10542148203
# Host correction...
# 2008ar sn2008ar-20080312-ui-corrected.flm 2.83 1.1 None
# 1998aq sn1998aq-19980429.26-fast.flm 1.06 1.11 None
# Host correction...
# 1998dh sn1998dh-19980804.36-fast.flm -0.540000000001 1.17 None
# Host correction...
# 1998eg sn1998eg-19981024.15-fast.flm -0.75 1.14 None
# Host correction...
# 2001br sn2001br-20010524.46-mmt.flm 2.56 1.16 None
# 2001en sn2001en-20011011.39-fast.flm 1.49 1.12 None
# Host correction...
# 2002cr sn2002cr-20020515.28-fast.flm 0.68 1.19 None
# Host correction...
# 2002fk sn2002fk-20020929.44-fast.flm -1.46 1.13 None
# Host correction...
# 2002hd sn2002hd-20021029.52-fast.flm 1.42 1.16 None
# Host correction...
# 2003w sn2003W-20030207.40-fast.flm -2.3 1.14 None
# Host correction...
# 2004l sn2004L-20040127.40-fast.flm 2.5 1.12 None
# Host correction...
# 2005a sn2005A-20050110.11-ldss2.flm 0.610000000001 1.11 None
# Host correction...
# 2006br SN06br_060426_b01_DUP_WF.dat 0.560000000056 1.12 None
# Host correction...
# 2006cf sn2006cf-20060519.25-fast.flm 1.85 None 1.14732833364
# Host correction...
# 2007jg SN07jg_070922_b01_CLA_LD.dat -1.27000000002 1.17 None
# Host correction...
# 2006os SN06os_061122_b01_DUP_WF.dat -1.06999999983 None 1.13936266574
# Host correction...
# 23 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.3) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.3))
# Collecting data...
# 18 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 17 spectra left
# 1999ac sn1999ac-19990312-ui-corrected.flm -0.89 1.23 None
# Host correction...
# 2002ha sn2002ha-20021102-ui-corrected.flm -0.85 1.22 None
# Host correction...
# 2003cq sn2003cq-20030408-ui.flm -0.15 1.2 None
# Host correction...
# 2005el sn2005el-20051004.534-ui-corrected.flm 1.22 1.27 None
# Host correction...
# 2006sr sn2006sr-20061220.097-ui.flm -2.34 1.24 None
# Host correction...
# 2008a sn2008a-20080115.278-ui.flm 2.178 1.28 None
# 1994m sn1994M-19940504.15-fast.flm 1.65 1.26 None
# Host correction...
# 1996x 1996X_19960419_3077_10669_00.dat 0.900000000001 1.26 None
# Host correction...
# 1998ef sn1998ef-19981029.31-fast.flm 1.41 1.27 None
# Host correction...
# 2002g sn2002G-20020122.52-fast.flm -2.58 1.25 None
# Host correction...
# 2002kf sn2002kf-20021231.34-fast.flm 1.14 1.2 None
# Host correction...
# 2003ch sn2003ch-20030329.11-mmt.flm 1.81 1.22 None
# Host correction...
# 2005bo SN05bo_050418_b01_DUP_WF.dat -1.0299999998 1.28 None
# Host correction...
# 2006az sn2006az-20060331.37-fast.flm -1.03 1.29 None
# Host correction...
# 2008q sn2008Q-20080207.13-fast.flm -2.27 1.25 None
# 2005kc SN05kc_051125_b01_DUP_MS.dat 1.91999999993 1.24 None
# Host correction...
# 2002er 2002er_20020910_3209_9997_00.dat 2.1 1.23 None
# Host correction...
# 15 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.4) or (dm15_from_fits >= 1.3 and dm15_from_fits < 1.4))
# Collecting data...
# 14 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 2001ep sn2001ep-20011020-ui-corrected.flm 2.83 1.3 None
# Host correction...
# 2005bc sn2005bc-20050411.474-ui-corrected.flm 1.55 1.32 None
# 2005lz sn2005lz-20060101.381-deimos.flm 0.58 1.34 None
# Host correction...
# 2007bc sn2007bc-20070410.323-ui-corrected.flm 0.61 1.37 None
# Host correction...
# 1994d 1994D_19940323_3465_9203_00.dat 1.5 1.37 None
# Host correction...
# 1998dx sn1998dx-19980914.18-fast.flm -1.72 1.32 None
# Host correction...
# 1999cc sn1999cc-19990516.34-fast.flm -1.26 1.35 None
# Host correction...
# 2003it sn2003it-20031020.23-fast.flm -2.27 1.36 None
# Host correction...
# 2004ef SN04ef_040914_b01_DUP_WF.dat -1.35000000009 1.39 None
# Host correction...
# 2005am sn2005am-20050303.30-fast.flm -3.0 1.3 None
# Host correction...
# 2006al sn2006al-20060224.34-fast.flm 2.64 1.35 None
# Host correction...
# 2007bd SN07bd_070417_b01_DUP_WF.dat 0.540000000037 1.3 None
# Host correction...
# snf20080514-002 snf20080514-002-20080528.31-fast.flm 2.61 1.35 None
# 2006d sn2006d-20060120-snifs-r.dat -2.0 1.35 None
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and ((dm15_cfa >= 1.4 and dm15_cfa < 1.6) or (dm15_from_fits >= 1.4 and dm15_from_fits < 1.6))
# Collecting data...
# 17 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 2000dm sn2000dm-20000926-ui-corrected.flm -1.63 1.46 None
# 2001ex sn2001ex-20011020-ui-corrected.flm -1.82 1.56 None
# 2002eu sn2002eu-20020903-ui.flm -0.06 1.52 None
# Host correction...
# 2002he sn2002he-20021108-br.flm 0.29 1.44 None
# Host correction...
# 2003u sn2003U-20030204-ui.flm -2.55 1.46 None
# Host correction...
# 2004gs sn2004gs-20041217.447-ui-corrected.flm 0.44 1.41 None
# Host correction...
# 2005ki sn2005ki-20051202.649-deimos.flm 1.62 1.41 None
# Host correction...
# 2006n sn2006n-20060123.286-ui.flm -1.89 1.5 None
# Host correction...
# 1994t sn1994T-19940612.19-fast.flm 0.790000000001 1.51 None
# Host correction...
# 1999ej sn1999ej-19991030.28-fast.flm -1.82 1.48 None
# Host correction...
# 2002do sn2002do-20020619.43-fast.flm 2.03 1.56 None
# Host correction...
# 2003ic sn2003ic-20030921.36-fast.flm -2.44 None 1.42747919087
# Host correction...
# 2006gj sn2006gj-20060920.43-fast.flm -0.669999999998 1.48 None
# Host correction...
# 2006kf SN06kf_061103_g01_NTT_EM.dat 1.45000000019 1.55 None
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (dm15_cfa >= 1.6 or dm15_from_fits >= 1.6)
# Collecting data...
# 24 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# bad file removed
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 17 spectra left
# 1999da sn1999da-19990709-ui.flm -2.12 1.9 None
# Host correction...
# 2000dk sn2000dk-20000926-ui-corrected.flm 1.0 1.62 None
# Host correction...
# 2002cf sn2002cf-20020420-ui-corrected.flm -0.75 1.78 None
# 2002fb sn2002fb-20020913-ui-corrected.flm 0.98 1.77 None
# Host correction...
# 2003y sn2003Y-20030204-ui.flm -1.74 1.65 None
# 2006bz sn2006bz-20060505.218-ui.flm -2.44 2.09 None
# Host correction...
# 2007ba sn2007ba-20070410.475-ui.flm 2.14 1.89 None
# Host correction...
# 2007ci sn2007ci-20070524.264-ui-corrected.flm -1.71 1.6 None
# Host correction...
# 2007hj sn2007hj-20070905.250-ui-corrected.flm -1.23 1.95 None
# 1998bp sn1998bp-19980430.47-fast.flm -2.93 1.79 None
# Host correction...
# 1998co sn1998co-19980623.45-fast.flm -0.0500000000029 None 1.7342423379
# Host correction...
# 1998de sn1998de-19980730.46-fast.flm -2.24 1.88 None
# Host correction...
# 1999by sn1999by-19990514.15-fast.flm 2.95 1.97 None
# Host correction...
# 2006gt SN06gt_060925_b01_DUP_WF.dat 0.279999999795 1.66 None
# Host correction...
# 2007au sn2007au-20070326.15-fast.flm 1.15 1.69 None
# Host correction...
# 2007ax SN07ax_070326_b01_DUP_BC.dat -2.04000000004 1.87 None
# Host correction...
# 2007ux SN07ux_080103_r01_3P6_EF.dat 2.36999999965 1.74 None
# 13 SNs with host corrections
# Creating composite...
# Done.

# %%
def stacked_plot_max(composites,buff,label_buff):
    font1 = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 20,
        }
    
    font2 = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'bold',
        'size'   : 10,
        }
    
    fig, ax = plt.subplots(1,1)
    fig.set_size_inches(15, 30, forward = True)
    ax.get_yaxis().set_ticks([])
    ax.xaxis.set_tick_params(length=10, width = 2)
    plt.ylabel('Relative Flux + const.', fontdict = font1, fontsize = 40)
    plt.xlabel( 'Wavelength ' + "($\mathrm{\AA}$)", fontdict = font1, fontsize = 40)
    plt.xticks(fontsize = 20)
    composites, scales = composite.optimize_scales(composites, composites[0], True)

    i = 0
    for comp in composites:
        dm15 = np.average(comp.dm15[comp.x1:comp.x2])
#         ax.plot(comp.wavelength[comp.x1:comp.x2], 2.e15*comp.flux[comp.x1:comp.x2] - 1200*dm15, color = '#3F5D7D', linewidth = 4)
        ax.plot(comp.wavelength[comp.x1:comp.x2], 2.e15*comp.flux[comp.x1:comp.x2] - buff*i, color = '#3F5D7D', linewidth = 4)
#         plt.fill_between(comp.wavelength[comp.x1:comp.x2], 2.e15*comp.low_conf[comp.x1:comp.x2]- 1200*dm15, 2.e15*comp.up_conf[comp.x1:comp.x2] - 1200*dm15, alpha = 0.5)
#         plt.text(9700, comp.flux[comp.x2] - 1200*dm15 + 30, '$\mathbf{\Delta m_{15}}$ = ' + str(round(dm15, 2)), fontdict = font1)
        plt.text(8000, comp.flux[comp.x2] - buff*i +label_buff, '$\mathbf{\Delta m_{15}}$ = ' + str(round(dm15, 2)), fontdict = font2, fontsize = 30)
        i += 1
#     plt.title('Maximum Light Composite Spectra \n for Different Light Curve Shapes', fontdict = font1, fontsize = 40)
    plt.xlim([3000,10500])
#     plt.savefig('../../FOE_figures/dm15_split_max.png', dpi = 300, bbox_inches = 'tight')
    plt.show()

# %%
query_db.set_min_num_spec(comps_dm15_split_max, 5)
stacked_plot_max(comps_dm15_split_max, 110, 30)

# %% [markdown]
# # Very Early

# %%
query_dm15_very_early = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= 1.1 or dm15_from_fits >= 1.1))"]

# %%
comps_dm15_very_early = query_db.main(len(query_dm15_very_early), query_dm15_very_early)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# 12 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 10 spectra left
# 1999aa sn1999aa-19990212-uoi.flm -10.58 0.78 None
# Host correction...
# 2005eu sn2005eu-20051006.584-deimos.flm -10.06 0.89 None
# Host correction...
# 2007ca sn2007ca-20070426.305-ui.flm -11.14 0.89 None
# Host correction...
# 1995bd sn1995bd-19951223.34-fast.flm -12.16 0.94 None
# Host correction...
# 1997do sn1997do-19971102.46-fast.flm -11.64 0.94 None
# Host correction...
# 1998es sn1998es-19981114.22-fast.flm -11.48 0.85 None
# Host correction...
# 2001v sn2001V-20010220.29-fast.flm -12.51 0.82 None
# Host correction...
# 2003fa sn2003fa-20030605.42-fast.flm -10.78 0.8 None
# Host correction...
# 2006gr sn2006gr-20060923.22-fast.flm -11.18 0.81 None
# Host correction...
# 2006gz sn2006gz-20060928.13-fast.flm -13.57 0.69 None
# 9 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))
# Collecting data...
# 12 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 12 spectra left
# 2002bo sn2002bo-20020311-ui-corrected.flm -11.94 1.08 None
# Host correction...
# 2006ax sn2006ax-20060322.396-ui.flm -10.07 1.06 None
# Host correction...
# 2006qo sn2006qo-20061201.436-ui.flm -11.08 None 1.00943200538
# Host correction...
# 2007le sn2007le-20071015.325-br-corrected.flm -10.31 1.01 None
# Host correction...
# 1997dt sn1997dt-19971123.19-fast.flm -10.71 1.04 None
# Host correction...
# 1999cp sn1999cp-19990622.20-fast.flm -12.0 0.98 None
# Host correction...
# 2000fa sn2000fa-20001203.48-fast.flm -10.62 1.0 None
# Host correction...
# 2001ah sn2001ah-20010328.22-fast.flm -10.18 0.98 None
# Host correction...
# 2003du 2003du_20030425_3451_10400_00.dat -12.1 1.07 None
# Host correction...
# 2006cp sn2006cp-20060530.25-fast.flm -11.45 0.98 None
# Host correction...
# 2007bm sn2007bm-20070423.23-fast.flm -11.27 1.09 None
# Host correction...
# 2007af SN07af_070304_g01_NTT_EM.dat -10.4300000002 1.04 None
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase < -10 and ((dm15_cfa >= 1.1 or dm15_from_fits >= 1.1))
# Collecting data...
# 8 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 8 spectra left
# 1994d sn1994D-19940310.36-mmt.flm -11.14 1.37 None
# Host correction...
# 2005cf sn2005cf-20050601.385-ui.flm -10.94 1.1 None
# Host correction...
# 1997bq sn1997bq-19970408.14-mmt.flm -11.76 1.14 None
# Host correction...
# 2002cr sn2002cr-20020503.29-fast.flm -11.31 1.19 None
# Host correction...
# 2002dj 2002dj_20020614_3745_9776_00.dat -11.6 1.19 None
# Host correction...
# 2003w sn2003W-20030129.35-mmt.flm -11.35 1.14 None
# Host correction...
# 2002er 2002er_20020828_3642_7834_00.dat -10.9 1.23 None
# Host correction...
# 2006x 2006X_20060209_3834_8139_00.dat -11.1 1.18 None
# Host correction...
# 8 SNs with host corrections
# Creating composite...
# Done.

# %%
query_db.set_min_num_spec(comps_dm15_very_early, 5)
stacked_plot_max(comps_dm15_very_early,5,1)

# %% [markdown]
# # -1 Week

# %%
query_dm15_m1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.3 or dm15_from_fits >= 1.3))"]

# %%
comps_dm15_m1week = query_db.main(len(query_dm15_m1week), query_dm15_m1week)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# 21 spectra found
# Arrays cleaned
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 19 spectra left
# 1995ac sn1995ac-19950926-uoi.flm -6.34 0.77 None
# Host correction...
# 1997do sn1997do-19971108-uoi.flm -5.67 0.94 None
# Host correction...
# 1998dm sn1998dm-19980831-ui-corrected.flm -5.61 0.9 None
# Host correction...
# 2001eh sn2001eh-20010911-ui.flm -5.63 0.92 None
# Host correction...
# 2003fa sn2003fa-20030607.426-ui.flm -8.15 0.8 None
# Host correction...
# 2005eq sn2005eq-20051004.512-ui.flm -6.01 0.88 None
# Host correction...
# 2005eu sn2005eu-20051011.350-ui-corrected.flm -5.46 0.89 None
# Host correction...
# 2006gr sn2006gr-20060925.202-ui.flm -8.7 0.81 None
# Host correction...
# 2006le sn2006le-20061030.456-ui-corrected.flm -8.69 0.88 None
# Host correction...
# 1998es sn1998es-19981118.28-fast.flm -7.42 0.85 None
# Host correction...
# 1999aa sn1999aa-19990215.28-fast.flm -8.12 0.78 None
# Host correction...
# 1999dq sn1999dq-19990906.43-fast.flm -8.57 0.86 None
# Host correction...
# 2001cp sn2001cp-20010621.45-fast.flm -6.95 0.88 None
# Host correction...
# 2001v sn2001V-20010225.30-fast.flm -7.5 0.82 None
# Host correction...
# 2002cd sn2002cd-20020410.49-fast.flm -8.71 0.84 None
# Host correction...
# 2004as sn2004as-20040313.30-fast.flm -8.1 0.92 None
# Host correction...
# 2006gz sn2006gz-20061003.13-fast.flm -8.57 0.69 None
# 2006oa sn2006oa-20061119.16-fast.flm -8.03999999999 0.89 None
# Host correction...
# 2006s sn2006S-20060128.50-fast.flm -5.7 0.93 None
# Host correction...
# 18 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))
# Collecting data...
# 25 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 22 spectra left
# 1998dk sn1998dk-19980824-90-br.flm -7.24 1.05 None
# Host correction...
# 2000fa sn2000fa-20001205-ui-corrected.flm -8.25 1.0 None
# Host correction...
# 2002cs sn2002cs-20020507-ui.flm -7.76 0.99 None
# 2002hu sn2002hu-20021108-br.flm -5.81 1.05 None
# Host correction...
# 2006cp sn2006cp-20060605.281-ui.flm -5.3 0.98 None
# Host correction...
# 2007bm sn2007bm-20070426.278-ui.flm -7.79 1.09 None
# Host correction...
# 2007qe sn2007qe-20071118.104-ui.flm -6.54 1.03 None
# Host correction...
# 1997br sn1997br-19970413.32-fast.flm -7.98 1.09 None
# Host correction...
# 1997dt sn1997dt-19971125.11-fast.flm -8.79 1.04 None
# Host correction...
# 1998ab sn1998ab-19980403.38-fast.flm -8.02 1.04 None
# Host correction...
# 2000dn sn2000dn-20000929.29-fast.flm -7.91 1.04 None
# 2002bo 2002bo_20020318_3184_7576_00.dat -5.7 1.08 None
# Host correction...
# 2002de sn2002de-20020602.24-fast.flm -6.26 0.96 None
# Host correction...
# 2004at sn2004at-20040319.24-fast.flm -8.76 1.05 None
# 2004fu sn2004fu-20041110.17-fast.flm -6.43 1.08 None
# Host correction...
# 2006ax SN06ax_060324_b01_DUP_WF.dat -8.39000000013 1.06 None
# Host correction...
# 2007af sn2007af-20070309.47-fast.flm -5.63 1.04 None
# Host correction...
# 2007f sn2007F-20070115.53-fast.flm -7.87 0.96 None
# Host correction...
# 2007le sn2007le-20071019.21-fast.flm -6.49 1.01 None
# Host correction...
# 2008z sn2008Z-20080210.33-fast.flm -8.37 1.02 None
# 2005hc SN05hc_051018_g01_NTT_EM.dat -5.37000000011 1.03 None
# Host correction...
# 2008bf SN08bf_080320_b01_CLA_LD.dat -8.75 1.05 None
# Host correction...
# 18 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))
# Collecting data...
# 24 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 24 spectra left
# 1998ef sn1998ef-19981019-br.flm -8.62 1.27 None
# Host correction...
# 2002cr sn2002cr-20020507-ui-corrected.flm -6.78 1.19 None
# Host correction...
# 2002dj sn2002dj-20020617-ui-corrected.flm -7.98 1.19 None
# Host correction...
# 2003gn sn2003gn-20030727-ui.flm -5.38 1.22 None
# 2003kf sn2003kf-20031129-br.flm -7.5 1.1 None
# Host correction...
# 2003w sn2003W-20030204-ui.flm -5.06 1.14 None
# Host correction...
# 2004dt sn2004dt-20040816.413-ui-corrected.flm -6.46 1.14 None
# Host correction...
# 2005el sn2005el-20050926.496-ui-corrected.flm -6.7 1.27 None
# Host correction...
# 2005iq sn2005iq-20051107.215-deimos.flm -5.86 1.19 None
# Host correction...
# 2007cq sn2007cq-20070623.431-ui.flm -5.82 1.2 None
# Host correction...
# 2008ar sn2008ar-20080229-ir-corrected.flm -8.87 1.1 None
# 1997bq sn1997bq-19970412.13-fast.flm -7.77 1.14 None
# Host correction...
# 1998aq sn1998aq-19980419.26-fast.flm -8.94 1.11 None
# Host correction...
# 1998dh sn1998dh-19980727.40-fast.flm -8.5 1.17 None
# Host correction...
# 1999cl sn1999cl-19990605.19-fast.flm -8.31 1.17 None
# Host correction...
# 2001g sn2001G-20010115.32-fast.flm -5.28 None 1.13936266574
# Host correction...
# 2003cg 2003cg_20030326_3650_9347_00.dat -5.4 1.26 None
# Host correction...
# 2003cq sn2003cq-20030403.28-fast.flm -5.92 1.2 None
# Host correction...
# 2005cf sn2005cf-20050605.7-uvot.flm -7.7 1.1 None
# Host correction...
# 2007co sn2007co-20070608.35-fast.flm -5.25 1.16 None
# Host correction...
# 2008a sn2008A-20080105.08-fast.flm -8.02 1.28 None
# 2008q sn2008Q-20080202.11-fast.flm -7.29 1.25 None
# 2002er 2002er_20020831_3375_9903_00.dat -7.9 1.23 None
# Host correction...
# 2006x 2006X_20060212_4170_6794_00.dat -8.1 1.18 None
# Host correction...
# 20 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -9 and phase <= -5 and ((dm15_cfa >= 1.3 or dm15_from_fits >= 1.3))
# Collecting data...
# 25 spectra found
# Arrays cleaned
# 2 spectra with nan ivars removed
# Peculiar Ias removed 22 spectra left
# 1994d 1994D_19940316_3331_10270_00.dat -5.5 1.37 None
# Host correction...
# 2002cu sn2002cu-20020515.46-fast.flm -6.44 1.35 None
# 2002he sn2002he-20021101.642-joined.flm -5.91 1.44 None
# Host correction...
# 2002hw sn2002hw-20021111-br.flm -6.27 1.44 None
# Host correction...
# 2004ef sn2004ef-20040910.310-ui-corrected.flm -5.52 1.39 None
# Host correction...
# 2004fz sn2004fz-20041119-ui-corrected.flm -5.18 1.36 None
# 2005bl sn2005bl-20050417.214-ui.flm -5.56 1.93 None
# Host correction...
# 2006kf sn2006kf-20061024.352-ui.flm -8.96 1.55 None
# Host correction...
# 2006lf sn2006lf-20061030.420-ui-corrected.flm -6.3 1.3 None
# Host correction...
# 2007bd sn2007bd-20070410.254-ui.flm -5.79 1.3 None
# Host correction...
# 2007ci sn2007ci-20070519.316-ui.flm -6.57 1.6 None
# Host correction...
# 1998de sn1998de-19980726.47-fast.flm -6.23 1.88 None
# Host correction...
# 2000cn sn2000cn-20000604.38-fast.flm -8.52 1.51 None
# Host correction...
# 2000dk sn2000dk-20000920.39-fast.flm -5.21 1.62 None
# Host correction...
# 2001ep sn2001ep-20011010.49-fast.flm -7.11 1.3 None
# Host correction...
# 2002cf sn2002cf-20020415.30-fast.flm -5.5 1.78 None
# 2003u sn2003U-20030129.53-mmt.flm -8.77 1.46 None
# Host correction...
# 2005bc sn2005bc-20050403.33-fast.flm -6.17 1.32 None
# 2005mz sn2005mz-20060103.13-fast.flm -7.67000000001 1.83 None
# Host correction...
# 2007au sn2007au-20070319.26-fast.flm -5.74 1.69 None
# Host correction...
# 2005ki SN05ki_051125_b01_DUP_MS.dat -5.76000000024 1.41 None
# Host correction...
# 2006d sn2006d-20060114-snifs-r.dat -8.0 1.35 None
# Host correction...
# 18 SNs with host corrections
# Creating composite...
# Done.

# %%
query_db.set_min_num_spec(comps_dm15_m1week, 5)
stacked_plot_max(comps_dm15_m1week,5,1)

# %% [markdown]
# # +1 Week

# %%
query_dm15_p1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and (dm15_cfa < .9 or dm15_from_fits < .9)",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= .9 and dm15_cfa < 1.) or (dm15_from_fits >= .9 and dm15_from_fits < 1))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1 and dm15_cfa < 1.05) or (dm15_from_fits >= 1 and dm15_from_fits < 1.05))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.05 and dm15_cfa < 1.1) or (dm15_from_fits >= 1.05 and dm15_from_fits < 1.1))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.2) or (dm15_from_fits >= 1.1 and dm15_from_fits < 1.2))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.3) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.3))", 
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.4) or (dm15_from_fits >= 1.3 and dm15_from_fits < 1.4))", 
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.4 and dm15_cfa < 1.6) or (dm15_from_fits >= 1.4 and dm15_from_fits < 1.6))",
                        "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and (dm15_cfa >= 1.6 or dm15_from_fits >= 1.6)"
                       ]

# %%
comps_dm15_p1week = query_db.main(len(query_dm15_p1week), query_dm15_p1week)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and (dm15_cfa < .9 or dm15_from_fits < .9)
# Collecting data...
# 17 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 16 spectra left
# 2001ay sn2001ay-20010430-ui.flm 6.79 0.68 None
# Host correction...
# 2005hj sn2005hj-20051108.457-deimos.flm 7.51 None 0.85116780468
# Host correction...
# 2005m sn2005m-20050211.413-br.flm 8.23 0.87 None
# Host correction...
# 2006ot sn2006ot-20061201.241-ui.flm 6.541 0.84 None
# Host correction...
# 1995al sn1995al-19951114.52-fast.flm 6.42 0.87 None
# Host correction...
# 1999dq sn1999dq-19990920.46-fast.flm 5.46 0.86 None
# Host correction...
# 1999gp sn1999gp-20000114.16-fast.flm 7.06 0.87 None
# Host correction...
# 2002jy sn2002jy-20030101.10-fast.flm 6.1 0.88 None
# Host correction...
# 2003fa sn2003fa-20030623.33-fast.flm 7.13 0.8 None
# Host correction...
# 2005eu sn2005eu-20051025.29-fast.flm 8.59 0.89 None
# Host correction...
# 2006gz sn2006gz-20061019.13-fast.flm 7.43 0.69 None
# 2006le sn2006le-20061114.38-fast.flm 5.98 0.88 None
# Host correction...
# 2007ca sn2007ca-20070512.27-fast.flm 5.57 0.89 None
# Host correction...
# 2007if sn2007if-20070911.29-mmt.flm 5.89 0.71 None
# Host correction...
# 2005eq SN05eq_051018_g01_NTT_EM.dat 7.37000000011 0.88 None
# Host correction...
# 2007ai SN07ai_070319_b01_DUP_BC.dat 7.0299999998 None 0.891395606916
# Host correction...
# 15 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= .9 and dm15_cfa < 1.) or (dm15_from_fits >= .9 and dm15_from_fits < 1))
# Collecting data...
# 13 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 11 spectra left
# 1998v sn1998v-19980326-br.flm 7.2 0.99 None
# Host correction...
# 2002de sn2002de-20020617-ui-corrected.flm 8.37 0.96 None
# Host correction...
# 2007s sn2007s-20070218.375-ui.flm 5.18 0.94 None
# Host correction...
# 1994ae sn1994ae-19941207.55-mmt.flm 8.05 0.96 None
# Host correction...
# 1996c sn1996C-19960223.44-mmt.flm 7.94 0.93 None
# Host correction...
# 1997do sn1997do-19971122.45-fast.flm 8.35 0.94 None
# Host correction...
# 1998dm sn1998dm-19980910.42-fast.flm 6.52 0.9 None
# Host correction...
# 2001bf sn2001bf-20010525.47-mmt.flm 8.77 0.99 None
# Host correction...
# 2001eh sn2001eh-20010926.37-fast.flm 8.87 0.92 None
# Host correction...
# 2004as sn2004as-20040327.35-fast.flm 5.95 0.92 None
# Host correction...
# 2006cp sn2006cp-20060617.21-fast.flm 6.51 0.98 None
# Host correction...
# 11 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1 and dm15_cfa < 1.05) or (dm15_from_fits >= 1 and dm15_from_fits < 1.05))
# Collecting data...
# 14 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 2000fa sn2000fa-20001221-ui-corrected.flm 6.86 1.0 None
# Host correction...
# 2004bk sn2004bk-20040424.371-ui-corrected.flm 6.13 1.02 None
# 2006cm sn2006cm-20060605.470-ui.flm 6.77 1.04 None
# Host correction...
# 2007le sn2007le-20071102.182-ui-corrected.flm 7.43 1.01 None
# Host correction...
# 2007qe sn2007qe-20071201.176-ui.flm 6.23 1.03 None
# Host correction...
# 1998ab sn1998ab-19980419.29-fast.flm 7.89 1.04 None
# Host correction...
# 1998bu sn1998bu-19980528.19-fast.flm 8.49000000001 1.03 None
# Host correction...
# 2000ce sn2000ce-20000510.15-fast.flm 6.85 1.0 None
# Host correction...
# 2001fe sn2001fe-20011122.48-fast.flm 6.28000000001 1.0 None
# Host correction...
# 2005hc sn2005hc-20051031.29-fast.flm 6.59 1.03 None
# Host correction...
# 2006bt sn2006bt-20060508.31-fast.flm 5.91 1.0 None
# Host correction...
# 2006et sn2006et-20060922.37-fast.flm 6.47 1.02 None
# Host correction...
# 2007af sn2007af-20070320.48-fast.flm 5.38 1.04 None
# Host correction...
# 2008z sn2008Z-20080226.44-fast.flm 7.74000000001 1.02 None
# 12 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.05 and dm15_cfa < 1.1) or (dm15_from_fits >= 1.05 and dm15_from_fits < 1.1))
# Collecting data...
# 12 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 12 spectra left
# 1997bp sn1997bp-19970416-uoi.flm 5.49 1.08 None
# Host correction...
# 1995d sn1995D-19950228.26-fast.flm 7.56 1.05 None
# Host correction...
# 1997br sn1997br-19970429.28-fast.flm 7.98 1.09 None
# Host correction...
# 1999ef sn1999ef-19991013.29-fast.flm 6.99 1.06 None
# Host correction...
# 2001bg sn2001bg-20010516.23-fast.flm 5.23 1.06 None
# 2001ck sn2001ck-20010618.33-mmt.flm 6.03 1.05 None
# 2004bg sn2004bg-20040420.33-fast.flm 5.83 1.05 None
# Host correction...
# 2007bm SN07bm_070511_b01_DUP_BC.dat 6.9299999997 1.09 None
# Host correction...
# 2007cg sn2007cg-20070515.22-fast.flm 6.72 1.05 None
# Host correction...
# 2008bf sn2008bf-20080406.29-fast.flm 7.69 1.05 None
# Host correction...
# 2000e 2000E_20000210_3217_7484_00.dat 6.8 1.09 None
# Host correction...
# 2003du 2003du_20030516_3258_9799_00.dat 8.9 1.07 None
# Host correction...
# 10 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.2) or (dm15_from_fits >= 1.1 and dm15_from_fits < 1.2))
# Collecting data...
# 27 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 25 spectra left
# 1999cl sn1999cl-19990621-ir-corrected.flm 7.9 1.17 None
# Host correction...
# 1999ek sn1999ek-19991105-ui.flm 5.66 1.14 None
# Host correction...
# 2002bf sn2002bf-20020311-ui-corrected.flm 6.9 1.12 None
# Host correction...
# 2002fk sn2002fk-20021008-br-corrected.flm 7.74 1.13 None
# Host correction...
# 2002hd sn2002hd-20021102-ui.flm 6.48 1.16 None
# Host correction...
# 2005a sn2005a-20050115.357-br.flm 5.55 1.11 None
# Host correction...
# 2006cf sn2006cf-20060523.291-ui.flm 6.28 None 1.14732833364
# Host correction...
# 2006en sn2006en-20060902.319-ui-corrected.flm 8.55 None 1.10994353514
# Host correction...
# 2006os sn2006os-20061201.142-ui.flm 8.61 None 1.13936266574
# Host correction...
# 1993ac sn1993ac-19931016.49-mmt.flm 7.29 1.19 None
# Host correction...
# 1995e sn1995E-19950308.16-mmt.flm 8.96000000001 1.16 None
# Host correction...
# 1996bo sn1996bo-19961105.24-fast.flm 5.24 1.16 None
# Host correction...
# 1997y sn1997Y-19970214.47-fast.flm 6.97 1.15 None
# Host correction...
# 1998aq sn1998aq-19980503.24-fast.flm 5.04 1.11 None
# Host correction...
# 1998eg sn1998eg-19981030.16-fast.flm 5.26 1.14 None
# Host correction...
# 1999gd sn1999gd-19991215.46-fast.flm 8.06 1.18 None
# Host correction...
# 2001da sn2001da-20010724.45-fast.flm 7.95 1.12 None
# Host correction...
# 2001en sn2001en-20011015.31-fast.flm 5.41 1.12 None
# Host correction...
# 2002dp sn2002dp-20020702.45-fast.flm 7.14999999999 1.12 None
# Host correction...
# 2004l sn2004L-20040130.33-fast.flm 5.43 1.12 None
# Host correction...
# 2007co sn2007co-20070619.45-fast.flm 5.85 1.16 None
# Host correction...
# 2008ar sn2008ar-20080314.29-fast.flm 5.19 1.1 None
# 2008c sn2008C-20080109.29-fast.flm 8.49 1.11 None
# Host correction...
# 2002dj 2002dj_20020704_3340_10256_00.dat 8.4 1.19 None
# Host correction...
# 2005cf 2005cf_20050618_3258_9998_00.dat 5.3 1.1 None
# Host correction...
# 24 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.2 and dm15_cfa < 1.3) or (dm15_from_fits >= 1.2 and dm15_from_fits < 1.3))
# Collecting data...
# 18 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 18 spectra left
# 2002er sn2002er-20020913-ui-corrected.flm 5.26 1.23 None
# Host correction...
# 2002ha sn2002ha-20021111-br.flm 7.89 1.22 None
# Host correction...
# 2002kf sn2002kf-20030106-br.flm 6.81 1.2 None
# Host correction...
# 2005el sn2005el-20051011.512-ui-corrected.flm 8.09 1.27 None
# Host correction...
# 2006ac sn2006ac-20060222.439-ui-corrected.flm 7.96 1.2 None
# Host correction...
# 2006ak sn2006ak-20060222.389-ui.flm 8.43 1.22 None
# Host correction...
# 2006bq sn2006bq-20060427.636-br.flm 6.97 1.29 None
# Host correction...
# 2006bw sn2006bw-20060505.353-ui.flm 8.9 1.28 None
# Host correction...
# 2006ej sn2006ej-20060902.398-ui.flm 5.09 None 1.26491436748
# Host correction...
# 2007cq sn2007cq-20070707.439-ui.flm 7.84 1.2 None
# Host correction...
# 2008q sn2008q-20080216.113-ui.flm 6.46 1.25 None
# 1994m sn1994M-19940508.26-fast.flm 5.76 1.26 None
# Host correction...
# 1996x 1996X_19960425_3059_10470_00.dat 6.9 1.26 None
# Host correction...
# 1996z sn1996Z-19960520.17-fast.flm 6.17 1.22 None
# Host correction...
# 2003cg 2003cg_20030407_3700_7751_00.dat 6.6 1.26 None
# Host correction...
# 2003ch sn2003ch-20030402.03-ldss2.flm 5.73 1.22 None
# Host correction...
# 2005kc sn2005kc-20051130.11-fast.flm 6.81 1.24 None
# Host correction...
# 2006eu sn2006eu-20060916.17-fast.flm 8.27 1.27 None
# Host correction...
# 17 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.4) or (dm15_from_fits >= 1.3 and dm15_from_fits < 1.4))
# Collecting data...
# 18 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 15 spectra left
# 1998dx sn1998dx-19980921-ui.flm 5.13 1.32 None
# Host correction...
# 2001ep sn2001ep-20011025-ui-corrected.flm 7.85 1.3 None
# Host correction...
# 2004ef sn2004ef-20040924.302-ui-corrected.flm 8.05 1.39 None
# Host correction...
# 2005am SN05am_050315_b01_DUP_WF.dat 7.98999999976 1.3 None
# Host correction...
# 2005bc sn2005bc-20050417.373-ui-corrected.flm 7.37 1.32 None
# 1999bh sn1999bh-19990409.27-fast.flm 5.17 1.38 None
# 2006al sn2006al-20060227.42-fast.flm 5.72 1.35 None
# Host correction...
# 2006ev sn2006ev-20060916.23-fast.flm 5.63 1.32 None
# Host correction...
# 2007ap sn2007ap-20070315.45-fast.flm 7.55 1.37 None
# Host correction...
# 2007bc SN07bc_070417_b01_DUP_WF.dat 7.54000000004 1.37 None
# Host correction...
# 2007bd sn2007bd-20070425.17-fast.flm 8.67 1.3 None
# Host correction...
# 2008af sn2008af-20080211.48-fast.flm 6.08 1.33 None
# Host correction...
# 2008l sn2008L-20080202.15-fast.flm 5.75 1.38 None
# Host correction...
# snf20080514-002 snf20080514-002-20080531.18-fast.flm 5.48 1.35 None
# 1994d 1994D_19940328_4403_7013_00.dat 6.5 1.37 None
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and ((dm15_cfa >= 1.4 and dm15_cfa < 1.6) or (dm15_from_fits >= 1.4 and dm15_from_fits < 1.6))
# Collecting data...
# 19 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 18 spectra left
# 2000dm sn2000dm-20001006-ui-corrected.flm 8.18 1.46 None
# 2001fh sn2001fh-20011116-ui-corrected.flm 5.93 1.51 None
# Host correction...
# 2005ki sn2005ki-20051209.514-ui.flm 8.35 1.41 None
# Host correction...
# 2006ob sn2006ob-20061201.107-ui.flm 7.65 None 1.51447510013
# Host correction...
# 1999ej sn1999ej-19991109.26-fast.flm 8.16 1.48 None
# Host correction...
# 2000b sn2000B-20000128.13-fast.flm 8.73 1.46 None
# Host correction...
# 2000cn sn2000cn-20000621.37-fast.flm 8.47 1.51 None
# Host correction...
# 2000cu sn2000cu-20000726.26-fast.flm 7.46 1.48 None
# 2002eu sn2002eu-20020907.49-fast.flm 5.19 1.52 None
# Host correction...
# 2002he sn2002he-20021113.53-fast.flm 5.73 1.44 None
# Host correction...
# 2005be SN05be_050407_b01_DUP_WF.dat 7.2200000002 1.49 None
# Host correction...
# 2006hb SN06hb_060928_b01_DUP_WF.dat 8.01000000024 1.44 None
# Host correction...
# 2006mo sn2006mo-20061113.21-fast.flm 5.41 None 1.52140206972
# Host correction...
# 2006n sn2006N-20060131.22-fast.flm 5.62 1.5 None
# Host correction...
# 2007nq SN07nq_071030_g01_NTT_EM.dat 5.56000000006 1.47 None
# Host correction...
# 2008r sn2008R-20080202.13-fast.flm 5.32999999999 1.54 None
# Host correction...
# 2006gj SN06gj_060927_b01_DUP_WF.dat 6.18000000017 1.48 None
# Host correction...
# 2001ex sn2001ex-20011029.475-hst.flm 6.9 1.56 None
# 15 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and (dm15_cfa >= 1.6 or dm15_from_fits >= 1.6)
# Collecting data...
# 14 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 11 spectra left
# 1999da sn1999da-19990718-ui.flm 6.76 1.9 None
# Host correction...
# 2003iv sn2003iv-20031028-ui.flm 6.58 1.65 None
# Host correction...
# 2005ke sn2005ke-20051202.334-deimos.flm 7.8 1.82 None
# Host correction...
# 2005mc sn2005mc-20060105.368-ui.flm 6.64 1.63 None
# Host correction...
# 2006h sn2006h-20060124.254-ui.flm 7.01 1.83 None
# Host correction...
# 2007ba SN07ba_070412_b01_DUP_WF.dat 6.26000000024 1.89 None
# Host correction...
# 2007ux sn2007ux-20071231.459-ui.flm 5.59 1.74 None
# 1998co sn1998co-19980630.47-fast.flm 6.97 None 1.7342423379
# Host correction...
# 1999by sn1999by-19990517.16-fast.flm 5.96000000001 1.97 None
# Host correction...
# 1999gh sn1999gh-19991206.53-fast.flm 5.53 1.69 None
# Host correction...
# 2007hj SN07hj_070912_b01_DUP_BC.dat 6.39000000013 1.95 None
# 9 SNs with host corrections
# Creating composite...
# Done.

# %%
query_db.set_min_num_spec(comps_dm15_p1week, 5)
stacked_plot_max(comps_dm15_p1week,5,1)

# %% [markdown]
# # +2 Weeks

# %%
query_dm15_p2week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.5) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.5)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p2week = query_db.main(len(query_dm15_p2week), query_dm15_p2week)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# 21 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 21 spectra left
# 1990o sn1990o-19900717-opt2.flm 12.54 None 0.945794406924
# Host correction...
# 1998dm sn1998dm-19980920-ui-corrected.flm 14.22 0.9 None
# Host correction...
# 1999aa sn1999aa-19990309-uvoir.flm 14.04 0.78 None
# Host correction...
# 1999cw sn1999cw-19990709-ui.flm 14.79 0.94 None
# Host correction...
# 2001e sn2001e-20010201-ui.flm 15.01 0.92 None
# 2001v sn2001v-20010321-ui.flm 15.86 0.82 None
# Host correction...
# 1995al sn1995al-19951123.54-fast.flm 15.44 0.87 None
# Host correction...
# 1996ai sn1996ai-19960706.23-fast.flm 15.13 0.88 None
# Host correction...
# 1997do sn1997do-19971126.37-fast.flm 12.27 0.94 None
# Host correction...
# 1998es sn1998es-19981210.19-fast.flm 14.49 0.85 None
# Host correction...
# 2002cd sn2002cd-20020504.47-fast.flm 15.27 0.84 None
# Host correction...
# 2003fa sn2003fa-20030628.23-fast.flm 12.03 0.8 None
# Host correction...
# 2005eq sn2005eq-20051025.38-fast.flm 14.38 0.88 None
# Host correction...
# 2006gr sn2006gr-20061017.24-fast.flm 12.84 0.81 None
# Host correction...
# 2006le sn2006le-20061121.37-fast.flm 12.97 0.88 None
# Host correction...
# 2007ca sn2007ca-20070520.22-fast.flm 13.52 0.89 None
# Host correction...
# 2007if sn2007if-20070920.36-fast.flm 14.96 0.71 None
# Host correction...
# 2007s sn2007S-20070225.30-fast.flm 12.2 0.94 None
# Host correction...
# 2005lu SN05lu_051220_b01_DUP_WF.dat 12.7200000002 0.74 None
# Host correction...
# 2007ai SN07ai_070326_b01_DUP_BC.dat 13.98 None 0.891395606916
# Host correction...
# 2001ay sn2001ay-20010509.704-hst.flm 16.0 0.68 None
# Host correction...
# 20 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))
# Collecting data...
# 32 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 30 spectra left
# 1999cp sn1999cp-19990718-ui-corrected.flm 13.85 0.98 None
# Host correction...
# 2001bg sn2001bg-20010525-ui-corrected.flm 13.7 1.06 None
# 2002aw sn2002aw-20020307-os-corrected.flm 15.84 1.05 None
# 2002bo sn2002bo-20020408-ui-corrected.flm 15.99 1.08 None
# Host correction...
# 2005hc sn2005hc-20051108.465-deimos.flm 14.26 1.03 None
# Host correction...
# 2005ms sn2005ms-20060123.318-ui.flm 14.62 None 0.997210431761
# Host correction...
# 2007a sn2007a-20070126.140-ui.flm 15.07 0.95 None
# Host correction...
# 2007bm sn2007bm-20070519.239-ui.flm 15.03 1.09 None
# Host correction...
# 2007qe sn2007qe-20071211.187-ui.flm 16.0 1.03 None
# Host correction...
# 1994q sn1994Q-19940605.35-fast.flm 12.15 1.03 None
# Host correction...
# 1995d sn1995D-19950307.32-fast.flm 14.62 1.05 None
# Host correction...
# 1996bl sn1996bl-19961103.25-fast.flm 13.75 1.07 None
# Host correction...
# 1998bu sn1998bu-19980601.18-fast.flm 12.48 1.03 None
# Host correction...
# 1998dk sn1998dk-19980913.39-fast.flm 13.29 1.05 None
# Host correction...
# 1998v sn1998V-19980331.48-fast.flm 12.28 0.99 None
# Host correction...
# 2000fa sn2000fa-20001228.41-fast.flm 14.31 1.0 None
# Host correction...
# 2001bf sn2001bf-20010529.37-fast.flm 12.67 0.99 None
# Host correction...
# 2001cj sn2001cj-20010619.26-mmt.flm 13.96 0.96 None
# 2001ck sn2001ck-20010627.22-fast.flm 14.92 1.05 None
# 2002ck sn2002ck-20020515.29-fast.flm 12.29 1.08 None
# Host correction...
# 2004bg sn2004bg-20040427.28-fast.flm 12.78 1.05 None
# Host correction...
# 2004fu sn2004fu-20041202.07-fast.flm 15.47 1.08 None
# Host correction...
# 2007af sn2007af-20070327.45-fast.flm 12.35 1.04 None
# Host correction...
# 2007le sn2007le-20071108.16-fast.flm 13.46 1.01 None
# Host correction...
# 2007sr sn2007sr-20071230.54-fast.flm 15.44 1.05 None
# Host correction...
# 2008bf SN08bf_080412_b01_DUP_WF.dat 14.1699999999 1.05 None
# Host correction...
# 2008z sn2008Z-20080302.25-fast.flm 12.55 1.02 None
# 2005na SN05na_060116_g01_NTT_EM.dat 12.0300000003 1.09 None
# Host correction...
# 2006ax SN06ax_060416_b01_BAA_IM.dat 14.6299999999 1.06 None
# Host correction...
# 2003du 2003du_20030523_3498_10103_00.dat 15.9 1.07 None
# Host correction...
# 25 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))
# Collecting data...
# 28 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# 2 spectra with nan ivars removed
# Peculiar Ias removed 24 spectra left
# 1993ac sn1993ac-19931022-uoi.flm 12.68 1.19 None
# Host correction...
# 1999x sn1999x-19990212-uoi.flm 15.76 1.11 None
# Host correction...
# 2001en sn2001en-20011025-ui-corrected.flm 14.72 1.12 None
# Host correction...
# 2002dp sn2002dp-20020711-ui-corrected.flm 15.55 1.12 None
# Host correction...
# 2006bq sn2006bq-20060505.375-ui.flm 14.64 1.29 None
# Host correction...
# 2007cq sn2007cq-20070715.374-ui-corrected.flm 15.57 1.2 None
# Host correction...
# 2008c sn2008c-20080115.444-ui.flm 15.68 1.11 None
# Host correction...
# 1994m sn1994M-19940515.27-mmt.flm 12.77 1.26 None
# Host correction...
# 1995ak sn1995ak-19951114.25-fast.flm 13.65 1.25 None
# Host correction...
# 1996z sn1996Z-19960528.16-fast.flm 14.16 1.22 None
# Host correction...
# 1997bq sn1997bq-19970502.19-mmt.flm 12.29 1.14 None
# Host correction...
# 1999ac sn1999ac-19990325.50-fast.flm 12.0 1.23 None
# Host correction...
# 1999ek sn1999ek-19991112.46-fast.flm 12.36 1.14 None
# Host correction...
# 2000cf sn2000cf-20000523.31-fast.flm 15.01 1.16 None
# Host correction...
# 2002bf sn2002bf-20020317.33-fast.flm 12.93 1.12 None
# Host correction...
# 2003ch sn2003ch-20030410.17-fast.flm 13.87 1.22 None
# Host correction...
# 2003kf sn2003kf-20031222.39-fast.flm 14.59 1.1 None
# Host correction...
# 2006ac sn2006ac-20060228.36-fast.flm 13.26 1.2 None
# Host correction...
# 2007jg sn2007jg-20071006.44-fast.flm 13.64 1.17 None
# Host correction...
# 2005el SN05el_051018_g01_NTT_EM.dat 14.75 1.27 None
# Host correction...
# 2002dj 2002dj_20020711_3304_10259_00.dat 15.4 1.19 None
# Host correction...
# 2002er 2002er_20020922_3281_9756_00.dat 14.1 1.23 None
# Host correction...
# 2003cg 2003cg_20030416_3500_9249_00.dat 15.6 1.26 None
# Host correction...
# 2005cf 2005cf_20050628_3476_9998_00.dat 15.3 1.1 None
# Host correction...
# 24 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.5) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.5)))
# Collecting data...
# 14 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 1994d sn1994d-19940404.flm 14.04 1.37 None
# Host correction...
# 2000bk sn2000bk-20000427-ui.flm 14.84 1.46 None
# Host correction...
# 2006lf sn2006lf-20061120.276-ui-corrected.flm 14.29 1.3 None
# Host correction...
# 1998dx sn1998dx-19980929.13-fast.flm 13.23 1.32 None
# Host correction...
# 2000b sn2000B-20000202.24-fast.flm 13.84 1.46 None
# Host correction...
# 2005am sn2005am-20050321.20-fast.flm 14.9 1.3 None
# Host correction...
# 2005hf sn2005hf-20051103.26-fast.flm 15.46 1.31 None
# Host correction...
# snf20080514-002 snf20080514-002-20080607.22-fast.flm 12.52 1.35 None
# 2005be SN05be_050412_b01_DUP_WF.dat 12.21 1.49 None
# Host correction...
# 2006ev SN06ev_060925_b01_DUP_WF.dat 14.4899999998 1.32 None
# Host correction...
# 2006gj SN06gj_061005_g01_NTT_EM.dat 14.1699999999 1.48 None
# Host correction...
# 2006hb SN06hb_061005_g01_NTT_EM.dat 15.1200000001 1.44 None
# Host correction...
# 2007bd SN07bd_070430_b01_DUP_BC.dat 13.46 1.3 None
# Host correction...
# 2006d sn2006d-20060203-snifs-r.dat 12.0 1.35 None
# Host correction...
# 13 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 12 and phase <= 16 and ((dm15_cfa >= 1.5 or dm15_from_fits >= 1.5))
# Collecting data...
# 20 spectra found
# Arrays cleaned
# bad file removed
# bad file removed
# bad file removed
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 12 spectra left
# 2000cn sn2000cn-20000627-ui-corrected.flm 14.25 1.51 None
# Host correction...
# 2002cf sn2002cf-20020507-ui-corrected.flm 15.95 1.78 None
# 2005ke sn2005ke-20051209.363-ui.flm 14.79 1.82 None
# Host correction...
# 2006mo sn2006mo-20061120.174-ui.flm 12.46 None 1.52140206972
# Host correction...
# 2007ax sn2007ax-20070410.281-ui.flm 14.93 1.87 None
# Host correction...
# 2007hj sn2007hj-20070919.206-ui-corrected.flm 12.53 1.95 None
# 1997cn sn1997cn-19970530.20-fast.flm 12.1 1.9 None
# Host correction...
# 2006h sn2006H-20060130.16-fast.flm 12.56 1.83 None
# Host correction...
# 2007ux sn2007ux-20080111.39-mmt.flm 15.99 1.74 None
# 2006gt SN06gt_061010_b01_DUP_WF.dat 15.25 1.66 None
# Host correction...
# 2006kf SN06kf_061116_b01_DUP_WF.dat 14.48 1.55 None
# Host correction...
# 2001ex sn2001ex-20011106.424-hst.flm 14.9 1.56 None
# 8 SNs with host corrections
# Creating composite...
# Done.

# %%
query_db.set_min_num_spec(comps_dm15_p2week, 5)
stacked_plot_max(comps_dm15_p2week,5,1)

# %% [markdown]
# # +1 Month

# %%
query_dm15_p1month = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.6) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.6)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.6 or dm15_from_fits >= 1.6))"]

# %%
comps_dm15_p1month = query_db.main(len(query_dm15_p1month), query_dm15_p1month)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# 18 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 18 spectra left
# 1990o sn1990o-19900731-opt2.flm 26.5 None 0.945794406924
# Host correction...
# 2001cp sn2001cp-20010727-ui.flm 28.62 0.88 None
# Host correction...
# 2001eh sn2001eh-20011020-ui.flm 32.08 0.92 None
# Host correction...
# 2005lu sn2005lu-20060105.180-ui.flm 27.88 0.74 None
# Host correction...
# 2005m sn2005m-20050307.179-ui.flm 31.49 0.87 None
# Host correction...
# 2007ca sn2007ca-20070609.277-ui-corrected.flm 32.22 0.89 None
# Host correction...
# 2007s sn2007s-20070318.357-br.flm 32.78 0.94 None
# Host correction...
# 1994s sn1994S-19940712.18-fast.flm 26.88 0.94 None
# Host correction...
# 1998dm sn1998dm-19980930.36-fast.flm 26.46 0.9 None
# Host correction...
# 1998es sn1998es-19981225.14-fast.flm 29.44 0.85 None
# Host correction...
# 1999aa sn1999aa-19990322.27-fast.flm 26.87 0.78 None
# Host correction...
# 1999dq sn1999dq-19991011.45-fast.flm 26.45 0.86 None
# Host correction...
# 2001ay sn2001ay-20010525.34-mmt.flm 32.34 0.68 None
# Host correction...
# 2001v sn2001V-20010401.22-fast.flm 27.42 0.82 None
# Host correction...
# 2002jy sn2002jy-20030126.10-fast.flm 31.1 0.88 None
# Host correction...
# 2004as sn2004as-20040419.26-fast.flm 28.86 0.92 None
# Host correction...
# 2005eq sn2005eq-20051107.38-fast.flm 27.38 0.88 None
# Host correction...
# 2006le sn2006le-20061212.30-fast.flm 33.9 0.88 None
# Host correction...
# 18 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))
# Collecting data...
# 32 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 30 spectra left
# 1995d sn1995d-19950325-uoi2.flm 32.58 1.05 None
# Host correction...
# 1998bu sn1998bu-19980618-ui.flm 29.58 1.03 None
# Host correction...
# 2000ce sn2000ce-20000531-ui.flm 27.05 1.0 None
# Host correction...
# 2001ck sn2001ck-20010716-ui-corrected.flm 32.77 1.05 None
# 2002bo sn2002bo-20020420-ui.flm 27.94 1.08 None
# Host correction...
# 2002cs sn2002cs-20020617-ui-corrected.flm 32.61 0.99 None
# 2002ef sn2002ef-20020903-ui.flm 28.93 1.06 None
# 2003du 2003du_20030609_3200_10499_00.dat 32.9 1.07 None
# Host correction...
# 2004bg sn2004bg-20040512.298-ui.flm 28.01 1.05 None
# Host correction...
# 2004gc sn2004gc-20041217.387-ui.flm 31.33 1.08 None
# Host correction...
# 2005ls sn2005ls-20060106.246-ui.flm 26.29 0.98 None
# Host correction...
# 2005na sn2005na-20060206.310-ui-corrected.flm 31.19 1.09 None
# Host correction...
# 2006ax sn2006ax-20060428.224-ui.flm 26.16 1.06 None
# Host correction...
# 2006bt sn2006bt-20060605.366-ui.flm 32.23 1.0 None
# Host correction...
# 2007af sn2007af-20070410.396-ui-corrected.flm 26.45 1.04 None
# Host correction...
# 2007sr sn2007sr-20080115.587-ui.flm 32.61 1.05 None
# Host correction...
# 2008bf sn2008bf-20080427-ui.flm 27.93 1.05 None
# Host correction...
# 1994ae sn1994ae-19941228.49-fast.flm 28.99 0.96 None
# Host correction...
# 1997bp sn1997bp-19970512.22-fast.flm 31.72 1.08 None
# Host correction...
# 1998dk sn1998dk-19980930.35-fast.flm 30.25 1.05 None
# Host correction...
# 1998ec sn1998ec-19981029.50-fast.flm 26.0 1.08 None
# Host correction...
# 1998v sn1998V-19980419.50-fast.flm 31.3 0.99 None
# Host correction...
# 2000fa sn2000fa-20010115.41-fast.flm 32.31 1.0 None
# Host correction...
# 2001fe sn2001fe-20011214.48-fast.flm 28.28 1.0 None
# Host correction...
# 2002ck sn2002ck-20020602.23-fast.flm 30.23 1.08 None
# Host correction...
# 2002de sn2002de-20020706.18-fast.flm 27.68 0.96 None
# Host correction...
# 2004at sn2004at-20040427.26-fast.flm 30.26 1.05 None
# 2004fu sn2004fu-20041214.09-fast.flm 27.49 1.08 None
# Host correction...
# 2007f sn2007F-20070219.43-fast.flm 27.03 0.96 None
# Host correction...
# 2006et SN06et_061011_b01_DUP_WF.dat 26.6400000001 1.02 None
# Host correction...
# 26 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.3) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.3)))
# Collecting data...
# 43 spectra found
# Arrays cleaned
# bad file removed
# 1 spectra with nan ivars removed
# Peculiar Ias removed 41 spectra left
# 1993ac sn1993ac-19931108-ui.flm 28.66 1.19 None
# Host correction...
# 1995ak sn1995ak-19951126-opt.flm 26.38 1.25 None
# Host correction...
# 1998dh sn1998dh-19980831-ui-corrected.flm 26.47 1.17 None
# Host correction...
# 1998ef sn1998ef-19981125-ui.flm 27.83 1.27 None
# Host correction...
# 1998eg sn1998eg-19981125-ui.flm 30.6 1.14 None
# Host correction...
# 1999x sn1999x-19990223-ui.flm 26.6 1.11 None
# Host correction...
# 2002cr sn2002cr-20020617-ui.flm 33.69 1.19 None
# Host correction...
# 2004dt sn2004dt-20040924.400-ui-corrected.flm 31.77 1.14 None
# Host correction...
# 2005bo sn2005bo-20050515.289-ui.flm 27.71 1.28 None
# Host correction...
# 2005cf sn2005cf-20050710.221-ui.flm 27.64 1.1 None
# Host correction...
# 2006az sn2006az-20060428.289-ui.flm 26.3 1.29 None
# Host correction...
# 2006bw sn2006bw-20060528.383-ui.flm 31.26 1.28 None
# Host correction...
# 2006ej sn2006ej-20060925.299-ui.flm 27.54 None 1.26491436748
# Host correction...
# 2006en sn2006en-20060925.232-ui-corrected.flm 30.75 None 1.10994353514
# Host correction...
# 2006os sn2006os-20061220.233-ui.flm 27.09 None 1.13936266574
# Host correction...
# 2006x sn2006x-20060322.422-ui.flm 31.01 1.18 None
# Host correction...
# 2007co sn2007co-20070715.240-ui-corrected.flm 30.81 1.16 None
# Host correction...
# 2008a sn2008a-20080212-br.flm 29.9 1.28 None
# 1995e sn1995E-19950331.22-mmt.flm 32.02 1.16 None
# Host correction...
# 1996x 1996X_19960519_3372_9254_00.dat 30.9 1.26 None
# Host correction...
# 1998aq sn1998aq-19980528.22-fast.flm 30.02 1.11 None
# Host correction...
# 1999ac sn1999ac-19990409.45-fast.flm 26.95 1.23 None
# Host correction...
# 1999gd sn1999gd-20000106.44-fast.flm 30.04 1.18 None
# Host correction...
# 2000cf sn2000cf-20000603.33-fast.flm 26.03 1.16 None
# Host correction...
# 2001br sn2001br-20010618.44-mmt.flm 27.54 1.16 None
# 2001g sn2001G-20010216.31-fast.flm 26.71 None 1.13936266574
# Host correction...
# 2002bf sn2002bf-20020403.21-fast.flm 29.81 1.12 None
# Host correction...
# 2002fk sn2002fk-20021103.37-mmt.flm 33.47 1.13 None
# Host correction...
# 2002ha sn2002ha-20021205.09-fast.flm 32.69 1.22 None
# Host correction...
# 2002kf sn2002kf-20030129.28-mmt.flm 30.08 1.2 None
# Host correction...
# 2003cg sn2003cg-20030427.18-fast.flm 26.78 1.26 None
# Host correction...
# 2003cq sn2003cq-20030509.15-fast.flm 29.95 1.2 None
# Host correction...
# 2003w sn2003W-20030310.28-fast.flm 28.58 1.14 None
# Host correction...
# 2004l sn2004L-20040220.29-fast.flm 26.39 1.12 None
# Host correction...
# 2005el sn2005el-20051102.40-fast.flm 30.0 1.27 None
# Host correction...
# 2005kc SN05kc_051222_b01_DUP_WF.dat 28.8599999999 1.24 None
# Host correction...
# 2006cf sn2006cf-20060618.19-fast.flm 31.79 None 1.14732833364
# Host correction...
# 2008ar sn2008ar-20080407.29-fast.flm 29.19 1.1 None
# 2008c sn2008C-20080130.28-fast.flm 29.48 1.11 None
# Host correction...
# 1994m 1994M_19940605_3699_9505_00.dat 33.5 1.26 None
# Host correction...
# 2002dj 2002dj_20020725_3741_10264_00.dat 29.4 1.19 None
# Host correction...
# 38 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.3 and dm15_cfa < 1.6) or ((dm15_from_fits >= 1.3 and dm15_from_fits < 1.6)))
# Collecting data...
# 27 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 24 spectra left
# 1994d sn1994d-19940420.flm 29.63 1.37 None
# Host correction...
# 1994t sn1994t-19940715-ui.flm 33.09 1.51 None
# Host correction...
# 1998dx sn1998dx-19981015-ui.flm 27.84 1.32 None
# Host correction...
# 2000dm sn2000dm-20001101.166-ui-corrected.flm 33.76 1.46 None
# 2001ep sn2001ep-20011115-ui.flm 28.46 1.3 None
# Host correction...
# 2002eu sn2002eu-20021001.237-ui-corrected.flm 26.73 1.52 None
# Host correction...
# 2004ef sn2004ef-20041013.373-ui-corrected.flm 26.55 1.39 None
# Host correction...
# 2006d sn2006d-20060222.513-ui.flm 32.54 1.35 None
# Host correction...
# 2006em sn2006em-20060925.415-ui.flm 26.7 1.5 None
# Host correction...
# 2006n sn2006n-20060222.131-ui.flm 27.54 1.5 None
# Host correction...
# 2007ap sn2007ap-20070410.502-ui.flm 32.85 1.37 None
# Host correction...
# 2008l sn2008l-20080229-ir.flm 32.37 1.38 None
# Host correction...
# 2000bk sn2000bk-20000510.19-fast.flm 27.19 1.46 None
# Host correction...
# 2000cn sn2000cn-20000709.24-fast.flm 26.34 1.51 None
# Host correction...
# 2002do sn2002do-20020718.29-fast.flm 30.89 1.56 None
# Host correction...
# 2004gs sn2004gs-20050118.36-fast.flm 32.56 1.41 None
# Host correction...
# 2005am SN05am_050407_b01_DUP_WF.dat 30.9399999999 1.3 None
# Host correction...
# 2006hb sn2006hb-20061022.39-fast.flm 30.79 1.44 None
# Host correction...
# 2007bc sn2007bc-20070511.18-fast.flm 31.28 1.37 None
# Host correction...
# snf20080514-002 snf20080514-002-20080623.00-ldss3.flm 28.3 1.35 None
# 2006ev SN06ev_061011_b01_DUP_WF.dat 30.4099999997 1.32 None
# Host correction...
# 2006gj SN06gj_061016_b01_HIL_BC.dat 26.25 1.48 None
# Host correction...
# 2006kf SN06kf_061130_b01_HIL_BC.dat 29.5 1.55 None
# Host correction...
# 2001ex sn2001ex-20011119.272-hst.flm 27.9 1.56 None
# 21 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 26 and phase <= 34 and ((dm15_cfa >= 1.6 or dm15_from_fits >= 1.6))
# Collecting data...
# 13 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 12 spectra left
# 1998de sn1998de-19980831-ui.flm 29.49 1.88 None
# Host correction...
# 2000dk sn2000dk-20001024-ui-corrected.flm 28.41 1.62 None
# Host correction...
# 2007au sn2007au-20070426.255-ui.flm 31.85 1.69 None
# Host correction...
# 2007ci sn2007ci-20070623.249-ui.flm 27.75 1.6 None
# Host correction...
# 1998bp sn1998bp-19980529.42-fast.flm 26.02 1.79 None
# Host correction...
# 1998co sn1998co-19980722.40-fast.flm 28.9 None 1.7342423379
# Host correction...
# 1999by sn1999by-19990609.17-fast.flm 28.97 1.97 None
# Host correction...
# 1999gh sn1999gh-19991229.45-fast.flm 28.45 1.69 None
# Host correction...
# 2002fb sn2002fb-20021009.34-fast.flm 27.24 1.77 None
# Host correction...
# 2005ke SN05ke_051221_b01_DUP_WF.dat 27.3700000001 1.82 None
# Host correction...
# 2007hj SN07hj_071003_r01_3P6_EF.dat 27.27 1.95 None
# 2006eq SN06eq_060925_b01_DUP_WF.dat 26.4199999999 1.62 None
# Host correction...
# 11 SNs with host corrections
# Creating composite...
# Done.

# %%
query_db.set_min_num_spec(comps_dm15_p1month, 5)
stacked_plot_max(comps_dm15_p1month,5,1)

# %% [markdown]
# # +2 Months

# %%
query_dm15_p2month = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.25) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.25)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.35) or ((dm15_from_fits >= 1.25 and dm15_from_fits < 1.35)))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.35 or dm15_from_fits >= 1.35))"]

# %%
comps_dm15_p2month = query_db.main(len(query_dm15_p2month), query_dm15_p2month)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa < .95 or dm15_from_fits < .95))
# Collecting data...
# 10 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 10 spectra left
# 1998es sn1998es-19990122.000-uvoir.flm 57.42 0.85 None
# Host correction...
# 1999aa sn1999aa-19990424-ui.flm 59.34 0.78 None
# Host correction...
# 2001eh sn2001eh-20011118.217-joined.flm 59.9 0.92 None
# Host correction...
# 2002cd sn2002cd-20020617-ui.flm 58.4 0.84 None
# Host correction...
# 2007if sn2007if-20071112.204-br.flm 63.12 0.71 None
# Host correction...
# 2007s sn2007s-20070416.352-br.flm 61.38 0.94 None
# Host correction...
# 1999dq sn1999dq-19991112.31-fast.flm 58.31 0.86 None
# Host correction...
# 1999gp sn1999gp-20000303.12-fast.flm 56.02 0.87 None
# Host correction...
# 2001ay sn2001ay-20010618.30-mmt.flm 56.3 0.68 None
# Host correction...
# 2001v sn2001V-20010501.36-fast.flm 57.56 0.82 None
# Host correction...
# 10 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= .95 and dm15_cfa < 1.1) or (dm15_from_fits >= .95 and dm15_from_fits < 1.1))
# Collecting data...
# 16 spectra found
# Arrays cleaned
# 1 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 1995d sn1995d-19950422-uoi.flm 60.3 1.05 None
# Host correction...
# 1998bu sn1998bu-19980717-ui.flm 58.49 1.03 None
# Host correction...
# 2002bo sn2002bo-20020519-ui-corrected.flm 56.7 1.08 None
# Host correction...
# 2002cs sn2002cs-20020711.330-ui-corrected.flm 56.19 0.99 None
# 2003du sn2003du-20030706.343-ui-corrected.flm 60.26 1.07 None
# Host correction...
# 2005ls sn2005ls-subtracted-20060206.260-ui.flm 56.66 0.98 None
# Host correction...
# 1994ae sn1994ae-19950131.40-fast.flm 62.9 0.96 None
# Host correction...
# 1997bp sn1997bp-19970610.20-fast.flm 60.7 1.08 None
# Host correction...
# 2001bf sn2001bf-20010715.40-mmt.flm 59.7 0.99 None
# Host correction...
# 2001fe sn2001fe-20020118.37-fast.flm 63.17 1.0 None
# Host correction...
# 2007af SN07af_070511_b01_DUP_BC.dat 57.4300000002 1.04 None
# Host correction...
# 2008bf sn2008bf-20080530.16-fast.flm 61.56 1.05 None
# Host correction...
# 2005na SN05na_060308_b01_DUP_WF.dat 62.98 1.09 None
# Host correction...
# 2007sr SN07sr_080214_g01_NTT_EM.dat 62.8199999998 1.05 None
# Host correction...
# 13 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.1 and dm15_cfa < 1.25) or ((dm15_from_fits >= 1.1 and dm15_from_fits < 1.25)))
# Collecting data...
# 14 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 2000cw sn2000cw-20000926-ui-corrected.flm 63.02 1.22 None
# 2002cr sn2002cr-20020711-ui-corrected.flm 57.47 1.19 None
# Host correction...
# 2002er sn2002er-20021108-br.flm 60.64 1.23 None
# Host correction...
# 2002ha sn2002ha-20030106-br.flm 63.11 1.22 None
# Host correction...
# 2003w sn2003w-20030408-ui.flm 56.56 1.14 None
# Host correction...
# 2007co sn2007co-20070814.276-ui.flm 60.06 1.16 None
# Host correction...
# 1998aq sn1998aq-19980624.19-fast.flm 56.99 1.11 None
# Host correction...
# 1999ac sn1999ac-19990515.38-fast.flm 62.88 1.23 None
# Host correction...
# 2001da sn2001da-20010912.32-fast.flm 57.82 1.12 None
# Host correction...
# 2001g sn2001G-20010325.27-mmt.flm 63.67 None 1.13936266574
# Host correction...
# 2004dt SN04dt_041024_b01_CLA_LD.dat 63.71 1.14 None
# Host correction...
# 2006x 2006X_20060423_4000_8999_00.dat 61.9 1.18 None
# Host correction...
# 2008ar sn2008ar-20080505.21-fast.flm 57.11 1.1 None
# 2005cf 2005cf_20050812_3922_8763_00.dat 60.3 1.1 None
# Host correction...
# 12 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.25 and dm15_cfa < 1.35) or ((dm15_from_fits >= 1.25 and dm15_from_fits < 1.35)))
# Collecting data...
# 5 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 5 spectra left
# 1996x 1996X_19960614_2806_9811_00.dat 56.9 1.26 None
# Host correction...
# 2001ep sn2001ep-20011214.32-fast.flm 57.72 1.3 None
# Host correction...
# 2005am sn2005am-20050503.15-fast.flm 57.85 1.3 None
# Host correction...
# 2005el sn2005el-20051202.43-fast.flm 60.03 1.27 None
# Host correction...
# 2006ej SN06ej_061022_b01_HIL_BC.dat 56.1299999999 None 1.26491436748
# Host correction...
# 5 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 56 and phase <= 64 and ((dm15_cfa >= 1.35 or dm15_from_fits >= 1.35))
# Collecting data...
# 9 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 8 spectra left
# 1999da sn1999da-19990910-ui.flm 59.94 1.9 None
# Host correction...
# 2002eu sn2002eu-20021108-br.flm 63.12 1.52 None
# Host correction...
# 2004ef sn2004ef-20041114-br.flm 57.23 1.39 None
# Host correction...
# 2005ke sn2005ke-20060123.221-ui.flm 59.43 1.82 None
# Host correction...
# 2006d sn2006d-20060322.449-ui.flm 60.24 1.35 None
# Host correction...
# 1994d sn1994D-19940517.17-fast.flm 56.67 1.37 None
# Host correction...
# 2000dk sn2000dk-20001124.20-fast.flm 59.6 1.62 None
# Host correction...
# 2007bc sn2007bc-20070610.18-fast.flm 61.28 1.37 None
# Host correction...
# 8 SNs with host corrections
# Creating composite...
# Done.

# %%
query_db.set_min_num_spec(comps_dm15_p2month, 5)
stacked_plot_max(comps_dm15_p2month,5,1)

# %% [markdown]
# # +1 Year

# %%
query_dm15_plong = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa < 1.2 or dm15_from_fits < 1.2))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa >= 1.2 or dm15_from_fits >= 1.2))"]

# %%
comps_dm15_plong = query_db.main(len(query_dm15_plong), query_dm15_plong)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa < 1.2 or dm15_from_fits < 1.2))
# Collecting data...
# 16 spectra found
# Arrays cleaned
# bad file removed
# 0 spectra with nan ivars removed
# Peculiar Ias removed 14 spectra left
# 1994ae sn1994ae-19950706-ui.flm 218.55 0.96 None
# Host correction...
# 1998bu sn1998bu-19990424-ui.flm 338.73 1.03 None
# Host correction...
# 1999aa sn1999aa-19991205-uvoir.flm 281.51 0.78 None
# Host correction...
# 1999cl sn1999cl-skyclose-19991215-hal.flm 183.95 1.17 None
# Host correction...
# 2002bo sn2002bo-20021106.657-joined.flm 227.44 1.08 None
# Host correction...
# 2005cf sn2005cf-20070216.617-deimos.flm 610.27 1.1 None
# Host correction...
# 2006x sn2006x-20061123.638-br.flm 275.94 1.18 None
# Host correction...
# 2007le sn2007le-20080827.490-br.flm 304.74 1.01 None
# Host correction...
# 1995d sn1995D-19951202.44-mmt.flm 284.74 1.05 None
# Host correction...
# 1998aq sn1998aq-19981124.54-fast.flm 210.34 1.11 None
# Host correction...
# 2003kf sn2003kf-20050111.11-ldss2.flm 400.31 1.1 None
# Host correction...
# 2007af sn2007af-20080111.53-mmt.flm 302.43 1.04 None
# Host correction...
# 2007sr sn2007sr-20080623.00-ldss3.flm 190.9 1.05 None
# Host correction...
# 2002dj 2002dj_20030326_3588_8628_00.dat 273.4 1.19 None
# Host correction...
# 14 SNs with host corrections
# Creating composite...
# Done.
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 180 and ((dm15_cfa >= 1.2 or dm15_from_fits >= 1.2))
# Collecting data...
# 11 spectra found
# Arrays cleaned
# 0 spectra with nan ivars removed
# Peculiar Ias removed 9 spectra left
# 1999by sn1999by-19991109-uvoir.flm 183.5 1.97 None
# Host correction...
# 2005ke sn2005ke-20061123.377-br.flm 362.11 1.82 None
# Host correction...
# 2008a sn2008a-20081027.276-br.flm 288.176 1.28 None
# 2008q sn2008q-20080828.495-br.flm 199.31 1.25 None
# 1994d sn1994D-19951124.46-mmt.flm 612.96 1.37 None
# Host correction...
# 1996x 1996X_19961220_3489_9278_00.dat 245.9 1.26 None
# Host correction...
# 2002er 2002er_20030410_3498_8062_00.dat 214.1 1.23 None
# Host correction...
# 2003cg 2003cg_20040419_3905_8049_00.dat 384.6 1.26 None
# Host correction...
# 2005am 2005am_20060324_5151_6910_00.dat 382.7 1.3 None
# Host correction...
# 7 SNs with host corrections
# Creating composite...
# Done.

# %%
query_db.set_min_num_spec(comps_dm15_plong, 5)
stacked_plot_max(comps_dm15_plong,20,1)
