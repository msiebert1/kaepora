# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import composite
# %matplotlib inline
from numpy import trapz
import copy
import glob as glob
from numpy import trapz
from astropy.time import Time
from scipy import interpolate
import spectral_analysis as sa
import sqlite3 as sq3
import kaepora as kpora
import kaepora_plot as kplot
import add_new_columns as anc
c = 299792 #speed of light in km/s

# %% [markdown]
# # Adding Data into Database File

# %% [markdown]
# Observed silicon velocity

# %%
si_v_filenames = []
si_v = []

si_v_file = open("new_data/si_v.txt", "r")
for line in si_v_file:
    si_v_filenames.append(line.split()[0])
    si_v.append(line.split()[1])
si_v_file.close

si_v_dict = {}
for n in range(0, len(si_v)):
    si_v_dict[si_v_filenames[n]] = si_v[n]
    
anc.add_arbitrary_spectra_column('si_v', si_v_dict, 'float', "../data/kaepora_v1_DEV.db")

# %% [markdown]
# Silicon velocity at max light

# %%
si_v0_events = []
si_v0 = []

si_v0_file = open("new_data/si_v0.txt", "r")
for line in si_v0_file:
    si_v0_events.append(line.split()[0])
    si_v0.append(line.split()[1])
si_v0_file.close

si_v0_dict = {}
for n in range(0, len(si_v0)):
    si_v0_dict[si_v0_events[n]] = si_v0[n]
    
anc.add_arbitrary_event_column('si_v0', si_v0_dict, 'float', "../data/kaepora_v1.2.db")
# Out:
# 2006mp -10973.201930324245 si_v0
# 1994d -11119.009024216577 si_v0
# 1998dk -17250.959348331944 si_v0
# 2006hx -9517.365238077939 si_v0
# 1998dh -11965.694177089566 si_v0
# 1996bo -12710.163098350484 si_v0
# 1998de -10646.198197948766 si_v0
# 2006le -12672.571420033113 si_v0
# 1998dm -12343.611287708132 si_v0
# 2004as -11385.706127922447 si_v0
# 1996bv -17942.03887034177 si_v0
# 1994t -12711.073795350387 si_v0
# 2003cq -11123.201762619934 si_v0
# 1994s -10834.37250368459 si_v0
# 1994q -15765.163351735393 si_v0
# 2002eu -12162.27008733142 si_v0
# 2007on -10797.390580152347 si_v0
# 2006mo -12787.945918782434 si_v0
# 2002er -11262.057645947498 si_v0
# 2013dy -9979.944626423334 si_v0
# 2001ah -8654.16074634216 si_v0
# 2000b -18433.101024618936 si_v0
# 1989b -16058.213189830256 si_v0
# 2006eq -11832.959334311552 si_v0
# 2006et -14041.208526207898 si_v0
# 2006ev -28193.17629108986 si_v0
# 2001az -10599.527480192322 si_v0
# 2001ay -14427.212652540173 si_v0
# 2006em -11517.33835532464 si_v0
# 2006en -14163.421137652836 si_v0
# 2006ef -13811.182966904285 si_v0
# 1995e -10250.947026261883 si_v0
# 1995d -11126.216745617947 si_v0
# 1998ec -11027.461161229983 si_v0
# 2002dj -12015.928783153866 si_v0
# 2004gc -16239.672863066933 si_v0
# 1998ef -13226.55940430756 si_v0
# 1999gh -11786.434524206303 si_v0
# 2002de -11525.191545834487 si_v0
# 2008r -7359.661370116453 si_v0
# 2002jy -10578.47700301153 si_v0
# 2009f -11343.348222955125 si_v0
# 2007au -11589.038172268629 si_v0
# 2006al -12246.287398762073 si_v0
# 2006bq -15964.935129131456 si_v0
# 2001da -11747.525913058595 si_v0
# 2006bu -14091.048909590872 si_v0
# 1997cn -13630.23648562782 si_v0
# 2006bz -20026.562514921206 si_v0
# 2007as -12451.216762124359 si_v0
# 2007bz -21631.923019357986 si_v0
# 2007bd -12359.077933246737 si_v0
# 1998v -10938.814278063994 si_v0
# 2007bc -9903.89994687351 si_v0
# 1996ai -18780.045627166204 si_v0
# 2007bm -11693.914227909054 si_v0
# 1996ab -11673.249767573876 si_v0
# 2004bg -10211.737356029866 si_v0

# %% [markdown]
# Silicon equivalent width

# %%
si_eqw_filenames = []
si_eqw_values = []

si_eqw_file = open("new_data/si_eqw.txt", "r")
for line in si_eqw_file:
    si_eqw_filenames.append(line.split()[0])
    si_eqw_values.append(line.split()[1])
si_eqw_file.close

si_eqw_dict = {}
for n in range(0, len(si_eqw_values)):
    si_eqw_dict[si_eqw_filenames[n]] = si_eqw_values[n]
    
anc.add_arbitrary_spectra_column('si_eqw', si_eqw_dict, "float", "../data/kaepora_v1_DEV.db")

# %% [markdown]
# # Composite Test

# %%
v_obs_query = "SELECT * from Spectra inner join Events ON Spectra.SN = Events.SN where si_v < -15000 and phase between -2 and 2"
v_obs_spectra = composite.grab(v_obs_query, multi_epoch = True, make_corr = True)
# Out:
# Collecting data from ../data/kaepora_v1_DEV.db ...
# 7 Total Spectra found
# 0 flagged spectra removed 7 spectra left
# 0 spectra of peculiar Ias removed 7 spectra left
# 7 spectra of SNe that have host reddening corrections
# Arrays cleaned

# %%
composites, sn_arrays, boot_sn_arrays = kpora.make_composite([v_obs_query], boot=False, medmean=1, verbose=False, gini_balance=True, combine=True)
# Out:
# SQL Query: SELECT * from Spectra inner join Events ON Spectra.SN = Events.SN where si_v < -15000 and phase between -2 and 2
# Collecting data from ../data/kaepora_v1_DEV.db ...
# 7 Total Spectra found
# 0 flagged spectra removed 7 spectra left
# 0 spectra of peculiar Ias removed 7 spectra left
# 7 spectra of SNe that have host reddening corrections
# Arrays cleaned
# 7 spectra may have telluric contamination
# 3 total SNe
# removed spectra of SNe with A_V > 2.0
# Using 3 spectra of 2 SNe
# Gini balancing...
# Balanced after 1 iterations

# %%
kpora.set_min_num_spec(composites, 5)
kplot.comparison_plot(composites, min_num_show=5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-931ecd67a796> in <module>()
# ----> 1 kpora.set_min_num_spec(composites, 5)
#       2 kplot.comparison_plot(composites, min_num_show=5)
#
# /Users/msiebert/Documents/UCSC/Research/kaepora/src/kaepora.pyc in set_min_num_spec(composites, num)
#      30         comp.spec_bin = np.array(comp.spec_bin)
#      31         valid_range = np.where(comp.spec_bin >= num)[0]
# ---> 32         comp.x1, comp.x2 = valid_range[0], valid_range[-1]
#      33
#      34
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
