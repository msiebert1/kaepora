# %%
import matplotlib
matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db

# %%
# %load_ext autoreload
# %autoreload 2

# %%
query_dm15_m5days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -5.5 and phase <= -4.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -5.5 and phase <= -4.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -5.5 and phase <= -4.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -5.5 and phase <= -4.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -5.5 and phase <= -4.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_m5days, sn_arrays_dm15_m5days, boot_sn_arrays_dm15_m5days = query_db.main(len(query_dm15_m5days), query_dm15_m5days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -5.5 and phase <= -4.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# ERROR:  sn2006oa-20061122-not.dat None
# 164 questionable files currently ignored
# 0 questionable spectra removed 21 spectra left
# 0 Peculiar Ias removed 21 spectra left
# 20 spectra with host corrections
# 164 questionable files currently ignored
# 17 valid SNe found
# Arrays cleaned
# 17 spectra may have telluric contamination
# 1998dm sn1998dm-19980831-ui-corrected.flm 149.99265377 0.9 None -4.86520587957 0.006535 bsnip 3330.0 10084.0 14.0
# Host correction...
# 2001eh sn2001eh-20010912-ui.flm 26.326596113 0.92 None -5.1936480508 0.037036 bsnip 3234.0 9980.0 12.0
# Host correction...
# 2004as sn2004as-20040316.608-br-corrected.flm 44.6689640507 0.92 None -4.99116894806 0.031021 bsnip 3256.0 8904.0 None
# Host correction...
# ...

# %%
for i, comp in enumerate(comps_dm15_m5days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_m5days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_m5days, 2)
query_db.stacked_plot(comps_dm15_m5days)

# %%
query_db.save_comps_to_files(comps_dm15_m5days)
# Out:
# -4.9 nan 0.9
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-869b5aacc6e5> in <module>()
# ----> 1 query_db.save_comps_to_files(comps_dm15_m5days)
#
# C:\Users\siebe\Documents\UCSC\Research\SN_Database\astr596\src\query_db.py in save_comps_to_files(composites)
#     788                 dm15_str = str(dm15)
#     789
# --> 790                 file_path = '../../../Composites_m5_p5_dm15/' + sign + phase_str + '_days_' + dm15 + '_mag'+'.flm'
#     791                 print file_path
#     792                 with open(file_path, 'w') as file:
#
# TypeError: ufunc 'add' did not contain a loop with signature matching types dtype('S41') dtype('S41') dtype('S41')

# %%
query_dm15_m4days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -4.5 and phase <= -3.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -4.5 and phase <= -3.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -4.5 and phase <= -3.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -4.5 and phase <= -3.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -4.5 and phase <= -3.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_m4days, sn_arrays_dm15_m4days, boot_sn_arrays_dm15_m4days = query_db.main(len(query_dm15_m4days), query_dm15_m4days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -4.5 and phase <= -3.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 0 questionable spectra removed 14 spectra left
# 0 Peculiar Ias removed 14 spectra left
# 14 spectra with host corrections
# 164 questionable files currently ignored
# 12 valid SNe found
# Arrays cleaned
# 12 spectra may have telluric contamination
# 1999dq sn1999dq-19990910-ui-corrected.flm 51.9209028016 0.86 None -3.56098181356 0.014327 bsnip 3304.0 10302.0 14.0
# Host correction...
# 2005eq sn2005eq-20051007.633-br-corrected.flm 124.024352275 0.88 None -3.6064946058 0.028977 bsnip 3228.0 9018.0 15.0
# Host correction...
# 2006s sn2006s-20060130.375-ui.flm 15.5947530274 0.93 None -4.08777427037 0.032102 bsnip 3278.0 10222.0 19.0
# Host correction...
# 1994s sn1994S-19940611.28-fast.flm 39.53192578 0.94 None -3.98354178631 0.015177 cfa 3798.0 7564.0 11.0
# ...

# %%
for i, comp in enumerate(comps_dm15_m4days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_m4days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_m4days, 2)
query_db.stacked_plot(comps_dm15_m4days)

# %%
query_dm15_m3days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3.5 and phase <= -2.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3.5 and phase <= -2.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3.5 and phase <= -2.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3.5 and phase <= -2.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3.5 and phase <= -2.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_m3days, sn_arrays_dm15_m3days, boot_sn_arrays_dm15_m3days = query_db.main(len(query_dm15_m3days), query_dm15_m3days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -2.5 and phase <= -1.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 1 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 14 spectra with host corrections
# 164 questionable files currently ignored
# 14 valid SNe found
# Arrays cleaned
# 14 spectra may have telluric contamination
# 1998es sn1998es-19981122.26-fast.flm 100.882547541 0.85 None -2.46396329981 0.010567 cfa 3456.0 7134.0 8.0
# Host correction...
# 1999aa sn1999aa-19990220.29-fast.flm 65.2753326639 0.78 None -2.44469132321 0.014443 cfa 3402.0 7088.0 14.0
# Host correction...
# 1999dq sn1999dq-19990912.51-fast.flm 82.5516269677 0.86 None -1.60401921668 0.014327 cfa 3718.0 7384.0 14.0
# Host correction...
# 2001ay sn2001ay-20010421.48-fast.flm 18.6002366944 0.68 None -1.89275550258 0.030244 cfa 3662.0 7270.0 19.0
# Host correction...
# ...

# %%
for i, comp in enumerate(comps_dm15_m3days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_m3days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_m3days, 2)
query_db.stacked_plot(comps_dm15_m3days)

# %%
query_dm15_m2days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -2.5 and phase <= -1.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -2.5 and phase <= -1.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -2.5 and phase <= -1.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -2.5 and phase <= -1.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -2.5 and phase <= -1.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_m2days, sn_arrays_dm15_m2days, boot_sn_arrays_dm15_m2days = query_db.main(len(query_dm15_m2days), query_dm15_m2days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -2.5 and phase <= -1.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 1 questionable spectra removed 15 spectra left
# 0 Peculiar Ias removed 15 spectra left
# 14 spectra with host corrections
# 164 questionable files currently ignored
# 14 valid SNe found
# Arrays cleaned
# 14 spectra may have telluric contamination
# 1998es sn1998es-19981122.26-fast.flm 100.882547541 0.85 None -2.46396329981 0.010567 cfa 3456.0 7134.0 8.0
# Host correction...
# 1999aa sn1999aa-19990220.29-fast.flm 65.2753326639 0.78 None -2.44469132321 0.014443 cfa 3402.0 7088.0 14.0
# Host correction...
# 1999dq sn1999dq-19990912.51-fast.flm 82.5516269677 0.86 None -1.60401921668 0.014327 cfa 3718.0 7384.0 14.0
# Host correction...
# 2001ay sn2001ay-20010421.48-fast.flm 18.6002366944 0.68 None -1.89275550258 0.030244 cfa 3662.0 7270.0 19.0
# Host correction...
# ...

# %%
for i, comp in enumerate(comps_dm15_m2days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_m2days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_m2days, 2)
query_db.stacked_plot(comps_dm15_m2days)

# %%
query_dm15_m1days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1.5 and phase <= -0.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1.5 and phase <= -0.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1.5 and phase <= -0.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1.5 and phase <= -0.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1.5 and phase <= -0.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_m1days, sn_arrays_dm15_m1days, boot_sn_arrays_dm15_m1days = query_db.main(len(query_dm15_m1days), query_dm15_m1days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -1.5 and phase <= -0.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 2 questionable spectra removed 13 spectra left
# 0 Peculiar Ias removed 13 spectra left
# 12 spectra with host corrections
# 164 questionable files currently ignored
# 12 valid SNe found
# Arrays cleaned
# 12 spectra may have telluric contamination
# 1998es sn1998es-19981123.30-fast.flm 99.8207192156 0.85 None -1.43483806615 0.010567 cfa 3456.0 7134.0 8.0
# Host correction...
# 1999aa sn1999aa-19990221.29-fast.flm 65.3533968752 0.78 None -1.45892869288 0.014443 cfa 3718.0 7384.0 14.0
# Host correction...
# 1999gp sn1999gp-20000105.10-fast.flm 33.6898092142 0.87 None -1.23789256339 0.026745 cfa 3674.0 7296.0 12.0
# Host correction...
# 2001cp sn2001cp-20010627.26-fast.flm 28.5018058966 0.88 None -1.19718075668 0.022402 cfa 3690.0 7326.0 13.0
# Host correction...
# ...

# %%
for i, comp in enumerate(comps_dm15_m1days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_m1days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_m1days, 2)
query_db.stacked_plot(comps_dm15_m1days)

# %%
query_dm15_0days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -0.5 and phase <= 0.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -0.5 and phase <= 0.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -0.5 and phase <= 0.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -0.5 and phase <= 0.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -0.5 and phase <= 0.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_0days, sn_arrays_dm15_0days, boot_sn_arrays_dm15_0days = query_db.main(len(query_dm15_0days), query_dm15_0days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -0.5 and phase <= 0.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 0 questionable spectra removed 14 spectra left
# 0 Peculiar Ias removed 14 spectra left
# 14 spectra with host corrections
# 164 questionable files currently ignored
# 11 valid SNe found
# Arrays cleaned
# 11 spectra may have telluric contamination
# 1998es sn1998es-19981125-ui-corrected.flm 107.924025303 0.85 None 0.496750833938 0.010567 bsnip 3346.0 10044.0 8.0
# Host correction...
# 1999aa sn1999aa-19990223-ui.flm 51.2219895768 0.78 None 0.460351148368 0.014443 bsnip 3344.0 10350.0 14.0
# Host correction...
# 2005eq sn2005eq-20051011.376-ui-corrected.flm 39.5694055064 0.88 None 0.0310988486616 0.028977 bsnip 3278.0 10156.0 15.0
# Host correction...
# ...

# %%
for i, comp in enumerate(comps_dm15_0days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_0days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_0days, 2)
query_db.stacked_plot(comps_dm15_0days)

# %%
query_dm15_p1days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 0.5 and phase <= 1.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 0.5 and phase <= 1.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 0.5 and phase <= 1.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 0.5 and phase <= 1.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 0.5 and phase <= 1.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p1days, sn_arrays_dm15_p1days, boot_sn_arrays_dm15_p1days = query_db.main(len(query_dm15_p1days), query_dm15_p1days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 0.5 and phase <= 1.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 0 questionable spectra removed 21 spectra left
# 0 Peculiar Ias removed 21 spectra left
# 21 spectra with host corrections
# 164 questionable files currently ignored
# 19 valid SNe found
# Arrays cleaned
# 19 spectra may have telluric contamination
# 1994s sn1994s-19940616-uoi.flm 34.8321198485 0.94 None 0.998840596273 0.015177 bsnip 3124.0 11082.0 11.0
# Host correction...
# 2001cp sn2001cp-20010629-ui.flm 23.7501402626 0.88 None 0.917447344588 0.022402 bsnip 3278.0 10124.0 13.0
# Host correction...
# 2002cd sn2002cd-20020420-ui-corrected.flm 25.7022215808 0.84 None 1.36290214026 0.010344 bsnip 3318.0 10244.0 13.0
# Host correction...
# 2007n sn2007n-20070122.583-deimos.flm 54.7855706783 None 0.352566653026 0.636798726689 0.0128789097156 bsnip 4442.0 9398.0 None
# ...

# %%
for i, comp in enumerate(comps_dm15_p1days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_p1days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_p1days, 2)
query_db.stacked_plot(comps_dm15_p1days)

# %%
query_dm15_p2days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 1.5 and phase <= 2.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 1.5 and phase <= 2.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 1.5 and phase <= 2.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 1.5 and phase <= 2.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 1.5 and phase <= 2.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p2days, sn_arrays_dm15_p2days, boot_sn_arrays_dm15_p2days = query_db.main(len(query_dm15_p2days), query_dm15_p2days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 1.5 and phase <= 2.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 0 questionable spectra removed 8 spectra left
# 0 Peculiar Ias removed 8 spectra left
# 8 spectra with host corrections
# 164 questionable files currently ignored
# 8 valid SNe found
# Arrays cleaned
# 8 spectra may have telluric contamination
# 2006cs sn2006cs-20060605.335-ui.flm 10.5900759504 None 0.568168396501 1.81209679625 0.023676 bsnip 3284.0 10306.0 8.0
# Host correction...
# 1996c sn1996C-19960217.48-fast.flm 27.3447953372 0.93 None 1.86368062318 0.027 cfa 3654.0 7314.0 None
# Host correction...
# 1998es sn1998es-19981127.21-fast.flm 88.9113424977 0.85 None 2.43427699499 0.010567 cfa 3474.0 7214.0 8.0
# Host correction...
# 1999dq sn1999dq-19990916.45-fast.flm 86.0498427218 0.86 None 2.28032971615 0.014327 cfa 3718.0 7384.0 14.0
# Host correction...
# ...

# %%
for i, comp in enumerate(comps_dm15_p2days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_p2days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_p2days, 2)
query_db.stacked_plot(comps_dm15_p2days)

# %%
query_dm15_p3days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 2.5 and phase <= 3.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 2.5 and phase <= 3.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 2.5 and phase <= 3.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 2.5 and phase <= 3.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 2.5 and phase <= 3.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p3days, sn_arrays_dm15_p3days, boot_sn_arrays_dm15_p3days = query_db.main(len(query_dm15_p3days), query_dm15_p3days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 2.5 and phase <= 3.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 1 questionable spectra removed 14 spectra left
# 0 Peculiar Ias removed 14 spectra left
# 13 spectra with host corrections
# 164 questionable files currently ignored
# 9 valid SNe found
# Arrays cleaned
# 9 spectra may have telluric contamination
# 1999dq sn1999dq-near-19990917-clear-ui-corrected.flm 66.2640559968 0.86 None 3.33620223064 0.014327 bsnip 3304.0 10352.0 14.0
# Host correction...
# 2001eh sn2001eh-20010920-ui.flm 38.447282377 0.92 None 2.59682402539 0.037036 bsnip 3234.0 9980.0 12.0
# Host correction...
# 2006s sn2006s-20060206.517-ui.flm 14.1443147205 0.93 None 2.83208442577 0.032102 bsnip 3254.0 10124.0 19.0
# Host correction...
# 2001ay sn2001ay-20010426.41-mmt.flm 95.381385481 0.68 None 2.89251866548 0.030244 cfa 3206.0 8590.0 19.0
# ...

# %%
for i, comp in enumerate(comps_dm15_p3days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_p3days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_p3days, 2)
query_db.stacked_plot(comps_dm15_p3days)

# %%
query_dm15_p4days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 3.5 and phase <= 4.5 and ((dm15_source < .95 or dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 3.5 and phase <= 4.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 3.5 and phase <= 4.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 3.5 and phase <= 4.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 3.5 and phase <= 4.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p4days, sn_arrays_dm15_p4days, boot_sn_arrays_dm15_p4days = query_db.main(len(query_dm15_p4days), query_dm15_p4days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 3.5 and phase <= 4.5 and ((dm15_source < .95 or dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 1 questionable spectra removed 11 spectra left
# 0 Peculiar Ias removed 11 spectra left
# 11 spectra with host corrections
# 164 questionable files currently ignored
# 11 valid SNe found
# Arrays cleaned
# 11 spectra may have telluric contamination
# 2006cj sn2006cj-20060528.349-ui.flm 11.9492250879 0.81 None 3.64584357907 0.067517 bsnip 3152.0 9694.0 None
# Host correction...
# 1998co sn1998co-19980623.45-fast.flm 41.773891468 None -0.708275555661 3.59601285567 0.018072 cfa 3704.0 7358.0 8.0
# Host correction...
# 1999dq sn1999dq-19990918.45-fast.flm 89.1462026545 0.86 None 4.25208044348 0.014327 cfa 3718.0 7384.0 14.0
# Host correction...
# 1999gp sn1999gp-20000110.11-fast.flm 38.1689085446 0.87 None 3.64160526713 0.026745 cfa 3674.0 7296.0 12.0
# ...

# %%
for i, comp in enumerate(comps_dm15_p4days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_p4days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_p4days, 2)
query_db.stacked_plot(comps_dm15_p4days)

# %%
query_dm15_p5days = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 4.5 and phase <= 5.5 and ((dm15_source >= .7 and dm15_source < .95) or (dm15_from_fits >= .7 and dm15_from_fits < .95))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 4.5 and phase <= 5.5 and ((dm15_source >= .95 and dm15_source < 1.15) or (dm15_from_fits >= .95 and dm15_from_fits < 1.15))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 4.5 and phase <= 5.5 and ((dm15_source >= 1.15 and dm15_source < 1.25) or (dm15_from_fits >= 1.15 and dm15_from_fits < 1.25))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 4.5 and phase <= 5.5 and ((dm15_source >= 1.25 and dm15_source < 1.5) or (dm15_from_fits >= 1.25 and dm15_from_fits < 1.5))",
                         "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 4.5 and phase <= 5.5 and ((dm15_source >= 1.5 or dm15_from_fits >= 1.5))"]

# %%
comps_dm15_p5days, sn_arrays_dm15_p5days, boot_sn_arrays_dm15_p5days = query_db.main(len(query_dm15_p5days), query_dm15_p5days, boot='nb', medmean=1, gini_balance=False)
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 4.5 and phase <= 5.5 and ((dm15_source >= .7 and dm15_source < .95) or (dm15_from_fits >= .7 and dm15_from_fits < .95))
# ...
# 164 questionable files currently ignored
# 0 questionable spectra removed 7 spectra left
# 0 Peculiar Ias removed 7 spectra left
# 6 spectra with host corrections
# 164 questionable files currently ignored
# 6 valid SNe found
# Arrays cleaned
# 6 spectra may have telluric contamination
# 1996c sn1996C-19960220.40-fast.flm 26.2765085861 0.93 None 4.70691333983 0.027 cfa 3654.0 7314.0 None
# Host correction...
# 1998dm sn1998dm-19980910.42-fast.flm 36.7027781801 0.9 None 5.06688788765 0.006535 cfa 3746.0 7442.0 14.0
# Host correction...
# 2001eh sn2001eh-20010923.37-fast.flm 24.6175412864 0.92 None 5.38554109983 0.037036 cfa 3638.0 7222.0 12.0
# Host correction...
# ...

# %%
for i, comp in enumerate(comps_dm15_p5days):
    query_db.plot_comp_and_all_spectra(comp, sn_arrays_dm15_p5days[i], show_ivar=True)

# %%
query_db.set_min_num_spec(comps_dm15_p5days, 2)
query_db.stacked_plot(comps_dm15_p5days)
