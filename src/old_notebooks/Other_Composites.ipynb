# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
# matplotlib.use('qt5agg')
import matplotlib.pyplot as plt
import time
import numpy as np
import query_db
import composite
import matplotlib.gridspec as gridspec

# %% [markdown]
# # Hubble Residuals

# %%
query_hubble_res = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and Hubble_Res > 0 and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))",
                    "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3  and phase <= 3 and Hubble_Res <= 0 and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))"]

# %%
comps_hubres, sn_arrays_hubres, boot_sn_arrays_hubres = query_db.main(len(query_hubble_res), query_hubble_res, boot='b', medmean=1, selection = 'max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and Hubble_Res > 0 and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))
# ...
# 159 questionable files currently ignored
# 0 questionable spectra removed 54 spectra left
# 0 Peculiar Ias removed 54 spectra left
# 46 spectra with host corrections
# 159 questionable files currently ignored
# 20 valid SNe found
# Arrays cleaned
# 20 spectra may have telluric contamination
# 2002de sn2002de-20020608.374-ui-corrected.flm 7.9496540894 0.96 None -0.16048772706 0.028116 bsnip 3140.0 10066.0 19.0
# Host correction...
# 2005ms sn2005ms-20060106.400-ui.flm 16.6601127349 None 0.977959604108 -1.93815084608 0.025204 bsnip 3280.0 10192.0 19.0
# Host correction...
# 2006bt sn2006bt-20060428.425-ui.flm 26.0213799338 1.0 None -2.96757466894 0.032156 bsnip 3268.0 10124.0 9.0
# Host correction...
# ...

# %%
query_db.set_min_num_spec(comps_hubres, 1)

# %%
query_db.comparison_plot(comps_hubres, scale_type=False, min_num_show=1)
# Out:
# 1.08160816065
# 1.10095079477

# %%
query_hubble_res_p1week = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and Hubble_Res > 0 and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))",
                    "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >=5  and phase <= 9 and Hubble_Res <= 0 and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))"]

# %%
comps_hubres_p1week, sn_arrays_hubres_p1week, boot_sn_arrays_hubres_p1week = query_db.main(len(query_hubble_res_p1week), query_hubble_res_p1week, boot='b', medmean=1, selection = 'max_coverage_choose_uv')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= 5 and phase <= 9 and Hubble_Res > 0 and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))
# ...
# 159 questionable files currently ignored
# 1 questionable spectra removed 27 spectra left
# 0 Peculiar Ias removed 27 spectra left
# 24 spectra with host corrections
# 159 questionable files currently ignored
# 14 valid SNe found
# Arrays cleaned
# 14 spectra may have telluric contamination
# 1999ek sn1999ek-19991105-ui.flm 11.0251739387 1.14 None 5.2411643188 0.017522 bsnip 3554.0 10230.0 13.0
# Host correction...
# 2000fa sn2000fa-20001221-ui-corrected.flm 32.5284742858 1.0 None 6.92271915008 0.021275 bsnip 3244.0 10242.0 None
# Host correction...
# 2002de sn2002de-20020617-ui-corrected.flm 21.1389644279 0.96 None 8.52530259231 0.028116 bsnip 3282.0 9550.0 19.0
# Host correction...
# ...

# %%
query_db.set_min_num_spec(comps_hubres_p1week, 1)

# %%
query_db.comparison_plot(comps_hubres_p1week, scale_type=False, min_num_show=1)
# Out:
# 1.13826057477
# 1.12733630543

# %% [markdown]
# ## Velocity

# %%
query_velocity_max = ["SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (velocity between -21 and -11)  and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))",
                    "SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3  and phase <= 3 and (velocity between -10.99 and -8) and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))"]

# %%
comps_velocity_max, sn_arrays_velocity_max, boot_sn_array_velocity_max = query_db.main(len(query_velocity_max), query_velocity_max, boot='b', medmean=1, selection = 'max_coverage')
# Out:
# SQL Query: SELECT * from Supernovae inner join Photometry ON Supernovae.SN = Photometry.SN where phase >= -3 and phase <= 3 and (velocity between -21 and -11)  and ((dm15_source > .95 and dm15_source < 1.25) or (dm15_from_fits > .95 and dm15_from_fits < 1.25))
# ...
# 159 questionable files currently ignored
# 12 questionable spectra removed 110 spectra left
# 0 Peculiar Ias removed 110 spectra left
# 102 spectra with host corrections
# 159 questionable files currently ignored
# 41 valid SNe found
# Arrays cleaned
# 1 spectra may have telluric contamination
# 1995e sn1995e-19950224-uoi2.flm 44.325356664 1.16 None -2.1768034995 0.011575 bsnip 3136.0 11162.0 12.0
# Host correction...
# 1997y sn1997y-19970209-uohp.flm 44.230493937 1.15 None 2.77201914426 0.015866 bsnip 3202.0 9716.0 12.0
# Host correction...
# 2001da sn2001da-20010716-ui-corrected.flm 30.0099081637 1.12 None 2.21688073575 0.017195 bsnip 3296.0 10176.0 11.0
# Host correction...
# ...

# %%
query_db.set_min_num_spec(comps_velocity_max, 1)

# %%
query_db.comparison_plot(comps_velocity_max, scale_type=False, min_num_show=1)
# Out:
# 1.11856668536
# 1.10349066929
