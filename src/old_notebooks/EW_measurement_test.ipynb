# %%
import spectral_analysis as sa
import composite
import numpy as np
import matplotlib.pyplot as plt

# %%
spec = np.genfromtxt('2020ctr-combined-20200219.flm', unpack=True)
wave = spec[0]/(1.+0.030)

# %%
SN2020ctr = composite.spectrum(wavelength=wave, flux=spec[1])
SN2020ctr.phase = -1.

# %%
plt.plot(SN2020ctr.wavelength[1000:2000], SN2020ctr.flux[1000:2000])
plt.show()
output = sa.measure_EWs([SN2020ctr], w1=5760., w2=5900., w3=6000., error=False)
# Out:
# 0 4.6082891273497495 nan nan -1.0

# %%
print output
# Out:
# (nan, nan, [], [], [], [], [])
